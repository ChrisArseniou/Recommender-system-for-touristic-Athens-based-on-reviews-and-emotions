# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import re
import time
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
from pathlib import Path
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-e9cc0b531726> in <module>
# ----> 1 from selenium import webdriver
#       2 from bs4 import BeautifulSoup
#       3 import re
#       4 import time
#       5 from webdriver_manager.chrome import ChromeDriverManager
#
# ModuleNotFoundError: No module named 'selenium'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
data = []

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
url = "https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d6692592-Reviews-Atitamos-Athens_Attica.html#REVIEWS"
print("url is \n" + url)
driver.get(url)
time.sleep(10)
soup = BeautifulSoup(driver.page_source, 'html.parser')
driver.quit()
# Out:
# <ipython-input-3-101bbb92fbfc>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d6692592-Reviews-Atitamos-Athens_Attica.html#REVIEWS

# %%
containers = soup.find_all("div", {"class": "review-container"})

# %%
containers[0]
# Out:
# <div class="review-container" data-collapsed="true" data-deferred="false" data-reviewid="855734242"><!--trkN:1-->
# <!--trkR:855734242-->
# <div class="prw_rup prw_reviews_review_resp" data-prwidget-init="handlers" data-prwidget-name="reviews_review_resp"><div class="reviewSelector" data-reviewid="855734242" id="review_855734242"><div class="rev_wrap ui_columns is-multiline"><div class="ui_column is-2 memberInfoColumn"><div class="prw_rup prw_reviews_member_info_resp" data-prwidget-init="handlers" data-prwidget-name="reviews_member_info_resp"><div class="member_info"><div class="memberOverlayLink clickable" data-anchorwidth="90" id="UID_CFBE1CC2F9D7D457F0146E2C3D93F877-SRC_855734242" onclick="widgetEvCall('handlers.initMemberOverlay', event, this);"><div class="avatar profile_CFBE1CC2F9D7D457F0146E2C3D93F877"><div class="avatarWrapper"><a><div class="prw_rup prw_common_basic_image avatarImage" data-prwidget-init="" data-prwidget-name="common_basic_image"><div class="ui_avatar resp"> <img class="basicImg" data-mediaid="452389949" src="https://media-cdn.tripadvisor.com/media/photo-l/1a/f6/ec/3d/default-avatar-2020-1.jpg"/></div></div></a></div></div><div class="info_text pointer_cursor" onclick="widgetEvCall('handlers.usernameClick', event, this);"><div>D2501PV_</div></div></div><div class="memberOverlayLink clickable" data-anchorwidth="90" id="UID_CFBE1CC2F9D7D457F0146E2C3D93F877-SRC_855734242" onclick="widgetEvCall('handlers.initMemberOverlay', event, this);"><div class="memberBadging g10n is-shown-at-tablet"><div class="reviewerBadge badge"><span class="badgeText">2 κριτικές</span></div></div></div></div></div></div><div class="ui_column is-9"><span class="ui_bubble_rating bubble_50"></span><span class="ratingDate" title="22 Αυγούστου 2022">Η κριτική έγινε: 22 Αυγούστου 2022 </span><div class="quote"><a class="title" href="/ShowUserReviews-g189400-d6692592-r855734242-Atitamos-Athens_Attica.html" id="rn855734242" onclick="(ta.prwidgets.getjs(this,'handlers')).reviewClick(this.href, '0');"><span class="noQuotes">Το λατρέψαμε</span></a></div><div class="prw_rup prw_reviews_text_summary_hsx" data-prwidget-init="handlers" data-prwidget-name="reviews_text_summary_hsx"><div class="entry"><p class="partial_entry">Είναι τρομερό, το βρήκα μια μέρα τυχαία που το στέκι μας με την παρέα για φαγητό ήταν κλειστό και δεν τον αλλάξαμε ξανά.Είναι κατάλληλο για όλες τις περιστάσεις,έχει εκπληκτικό φαγητό, ποιοτικό και καθαρό πάνω από όλα, η εξυπηρέτηση του είναι επίσης τρομερή,τα  παιδιά στο προσωπικό...<span class="postSnippet">άψογα και με χιούμορ,πολύ φιλικά.Από τιμές γι αυτό που προσφέρουν είναι κυριολεκτικά αστείες, είναι πολύ οικονομικό και είναι για όλες τις ηλικίες.Το συστήνω ανεπιφύλακτα χίλιες φορές.</span><span class="taLnk ulBlueLinks" onclick="widgetEvCall('handlers.clickExpand',event,this);">Περισσότερα</span></p></div></div><div class="prw_rup prw_reviews_stay_date_hsx" data-prwidget-init="" data-prwidget-name="reviews_stay_date_hsx"><span class="stay_date_label">Ημερομηνία επίσκεψης:</span> Αύγουστος 2022</div><div class="prw_rup prw_reviews_vote_line_hsx" data-prwidget-deferred="deferred/clicks" data-prwidget-init="handlers" data-prwidget-name="reviews_vote_line_hsx"><div class="tooltips wrap"><span class="taLnk no_cpu ui_icon flag" data-content="Υπάρχει κάποιο πρόβλημα με αυτή την κριτική;" data-position="above" data-tooltip="" id="ReportIAP_855734242" onclick="ta.prwidgets.call('deferred/clicks.clickReport',event,this,855734242,'member');return false;" onmouseover="widgetEvCall('handlers.hoverReport',event,this);return false;"></span></div><div class="helpful redesigned hsx_helpful"><span class="isHelpful">Χρήσιμη;</span><span class="thankButton hsx_thank_button" onclick="ta.prwidgets.call('deferred/clicks.clickThank',event,this,'...');return false;"><span class="helpful_text"><span class="ui_icon thumbs-up"></span><span class="numHelp"></span></span><div class="buttonShade hidden"><img alt="" src="https://static.tacdn.com/img2/generic/site/loading_anim_gry_sml.gif"/></div></span></div></div><div class="prw_rup prw_common_html" data-prwidget-init="" data-prwidget ...
# <!--etk-->
# </div>

# %%
rating = containers[0].find("div", {"class": "ui_column is-9"})

# %%
rating
# Out:
# <div class="ui_column is-9"><span class="ui_bubble_rating bubble_50"></span><span class="ratingDate" title="22 Αυγούστου 2022">Η κριτική έγινε: 22 Αυγούστου 2022 </span><div class="quote"><a class="title" href="/ShowUserReviews-g189400-d6692592-r855734242-Atitamos-Athens_Attica.html" id="rn855734242" onclick="(ta.prwidgets.getjs(this,'handlers')).reviewClick(this.href, '0');"><span class="noQuotes">Το λατρέψαμε</span></a></div><div class="prw_rup prw_reviews_text_summary_hsx" data-prwidget-init="handlers" data-prwidget-name="reviews_text_summary_hsx"><div class="entry"><p class="partial_entry">Είναι τρομερό, το βρήκα μια μέρα τυχαία που το στέκι μας με την παρέα για φαγητό ήταν κλειστό και δεν τον αλλάξαμε ξανά.Είναι κατάλληλο για όλες τις περιστάσεις,έχει εκπληκτικό φαγητό, ποιοτικό και καθαρό πάνω από όλα, η εξυπηρέτηση του είναι επίσης τρομερή,τα  παιδιά στο προσωπικό...<span class="postSnippet">άψογα και με χιούμορ,πολύ φιλικά.Από τιμές γι αυτό που προσφέρουν είναι κυριολεκτικά αστείες, είναι πολύ οικονομικό και είναι για όλες τις ηλικίες.Το συστήνω ανεπιφύλακτα χίλιες φορές.</span><span class="taLnk ulBlueLinks" onclick="widgetEvCall('handlers.clickExpand',event,this);">Περισσότερα</span></p></div></div><div class="prw_rup prw_reviews_stay_date_hsx" data-prwidget-init="" data-prwidget-name="reviews_stay_date_hsx"><span class="stay_date_label">Ημερομηνία επίσκεψης:</span> Αύγουστος 2022</div><div class="prw_rup prw_reviews_vote_line_hsx" data-prwidget-deferred="deferred/clicks" data-prwidget-init="handlers" data-prwidget-name="reviews_vote_line_hsx"><div class="tooltips wrap"><span class="taLnk no_cpu ui_icon flag" data-content="Υπάρχει κάποιο πρόβλημα με αυτή την κριτική;" data-position="above" data-tooltip="" id="ReportIAP_855734242" onclick="ta.prwidgets.call('deferred/clicks.clickReport',event,this,855734242,'member');return false;" onmouseover="widgetEvCall('handlers.hoverReport',event,this);return false;"></span></div><div class="helpful redesigned hsx_helpful"><span class="isHelpful">Χρήσιμη;</span><span class="thankButton hsx_thank_button" onclick="ta.prwidgets.call('deferred/clicks.clickThank',event,this,'...');return false;"><span class="helpful_text"><span class="ui_icon thumbs-up"></span><span class="numHelp"></span></span><div class="buttonShade hidden"><img alt="" src="https://static.tacdn.com/img2/generic/site/loading_anim_gry_sml.gif"/></div></span></div></div><div class="prw_rup prw_common_html" data-prwidget-init="" data-prwidget-name="common_html"><div class="note">Αυτή η κριτική είναι η υποκειμενική γνώμη ενός μέλους του Tripadvisor και όχι η γνώμη της Tripadvisor LLC. Το Tripadvisor πραγματοποιεί ελέγχους στις κριτικές.</div></div><div class="loadingShade hidden"><div class="ui_spinner"></div></div></div>

# %%
user = containers[0].find_all("div", {"class": "info_text pointer_cursor"})

# %%
user
# Out:
# [<div class="info_text pointer_cursor" onclick="widgetEvCall('handlers.usernameClick', event, this);"><div>D2501PV_</div></div>]

# %%
review = containers[1].find("div", {"class": "prw_rup prw_reviews_text_summary_hsx"})

# %%
rating = containers[3].find("div", {"class": "ui_column is-9"})

# %%
rating.next
# Out:
# <span class="ui_bubble_rating bubble_50"></span>

# %%
for container in (containers):
    
    user = container.find("div", {"class": "info_text pointer_cursor"})
    review = container.find("div", {"class": "prw_rup prw_reviews_text_summary_hsx"})
    rating = container.find("div", {"class": "ui_column is-9"})
    rating_value = 0;
    if (str(rating.next) == "<span class=\"ui_bubble_rating bubble_0\"></span>"):
        rating_value = 0
    elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_10\"></span>"):
        rating_value = 1
    elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_20\"></span>"):
        rating_value = 2
    elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_30\"></span>"):
        rating_value = 3
    elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_40\"></span>"):
        rating_value = 4
    else :
        rating_value = 5
    
    if(review):
        print("User is :" + user.text.strip() + "\n")
        print("Review is :" + review.text.strip() + "\n")
        print("Rating is : ",rating_value)
        data_point = [user.text.strip(),review.text.strip(), rating_value]
        data.append(data_point)
        print("\n")
        print("\n")
# Out:
# User is :D2501PV_
#
# Review is :Είναι τρομερό, το βρήκα μια μέρα τυχαία που το στέκι μας με την παρέα για φαγητό ήταν κλειστό και δεν τον αλλάξαμε ξανά.Είναι κατάλληλο για όλες τις περιστάσεις,έχει εκπληκτικό φαγητό, ποιοτικό και καθαρό πάνω από όλα, η εξυπηρέτηση του είναι επίσης τρομερή,τα  παιδιά στο προσωπικό...άψογα και με χιούμορ,πολύ φιλικά.Από τιμές γι αυτό που προσφέρουν είναι κυριολεκτικά αστείες, είναι πολύ οικονομικό και είναι για όλες τις ηλικίες.Το συστήνω ανεπιφύλακτα χίλιες φορές.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :nickynin94
#
# Review is :Φανταστικό φαγητό καταπληκτικοί άνθρωποι !
# Συστήνω ανεπιφύλακτα ! Ο κύριος Χρήστος πολύ ευγενικός όπως και όλο το προσωπικό ☺️☺️☺️
#
# Rating is :  5
#
#
#
#
# User is :michalism386
#
# Review is :Τι να πω για το εστιατόριο αυτό; Πεντακάθαρο,  πολύ ωραιος χώρος, αψογη εξυπηρέτηση από το προσωπικό και σε πολύ καλούς χρόνους παρά το πλήθος πελατών (κάτσαμε 2 άτομα σαββατόβραδο), τα φαγητά - ορεκτικα και κυρίως- πεντανόστιμα! Εύγε στα παιδιά!
#
# Rating is :  5
#
#
#
#
# User is :Nomad812948
#
# Review is :Μεγάλη ποικιλία. Τα πιάτα της ημέρας αξίζει κανείς να τα δοκιμάσει. Μοιραστήκαμε αρνάκι στη λαδόκολα που έλιωνε στο στόμα με πατατούλες και κεφτεδάκια με δυόσμο. Στην αρχή πήραμε γαύρο μαρινάτο που σας τον συστήνω ανεπιφύλακτα και χόρτα. Στο τέλος μας προσέφεραν απο ενα σφηνάκι μαστίχα....Επίσης το δικό του λευκό κρασί πάρα πολύ καλό.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :Stathakios A
#
# Review is :Καλο μαγαζι για το κέντρο της Αθήνας. Καλά φαγητα, εξυπηρετηση άψογη, χαμόγελο. Τιμές λογικές , παρτε τα; ντολμαδιακια!
#
# Rating is :  5
#
#
#
#
# User is :PanagiotisTsigkos
#
# Review is :Πολύ ωραίος, ευχάριστος και καθαρός χώρος με λογικές τιμές και υπέροχα πιάτα. Το σέρβις γρήγορο και τα υλικά φρέσκα! Αρκετή ησυχία για τα δεδομένα τις περιοχής με κέρασμα στο τέλος!
# Φυσικά για κάποιον που δεν γνωρίζει την περιοχή και θέλει να προσεγγίσει με αυτοκίνητο είναι...λίγο "άθλος" η εύρεση χώρου στάθμευσης.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :fotini p
#
# Review is :Μια ευχάριστη έκπληξη στο κέντρο της Αθήνας,στα Εξάρχεια! Εκπληκτικό φαγητό, εξαιρετικά κεφτεδακια, τέλειες σαλάτες,νοστιμοτατα ζυμαρικά!
# Ότι κι αν παραγγείλαμε ήταν το ένα πιο ωραίο από το άλλο..
# Το ακόμη πιο ωραίο ήταν το προσωπικό.
# Νέα παιδιά, ευγενεστατα, εξυπηρετικοτατα, με αγάπη για αυτό που κάνουν.
# Το...ωραιότερο μεζεδοπωλείο της Αθήνας!
# Το αγαπήσαμε πολύ..Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :EvitaP3
#
# Review is :Πηγαμε πριν ενα μηνα λογω των παρα πολλών κριτικών στο tripadvisor και τις άξιζαν 100%!
# Φάγαμε καταπληκτικά πιάτα ημερας (γιουβαρλάκια, κότσι αρνίσιο , κλπ) και μια ρακή που δεν υπαρχει!
# Ενα θα σας πω. Πηγαμε βραδυ και το επόμενο πρωί αντι για βαρυστομαχιά ενοιωθα εσωτερική...ευτυχια και πληρότητα.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :Ioannisktst
#
# Review is :Εξαιρετικό μαγαζί στην καρδιά των Εξαρχείων. Ποιοτικά φαγητά για όλα τα γούστα, είτε ψάρι, είτε κρέας. Οι τιμές φυσιολογικές θα λέγαμε δεδομένων των ποσοτήτων και της ποιότητας. Το συστήνω ανεπιφύλακτα
#
# Rating is :  4
#
#
#
#
# User is :giannisBt
#
# Review is :Καλομαγειρεμενο φαγητο με φρεσκα υλικα, τρομερος χωρος και ωραια διακοσμημενος, φιλικες τιμες!!!Σιγουρα αξιζει μια επισκεψη αν ειστε κοντα και ψαχνετε για να φατε κατι αξιολογο.
#
# Rating is :  5

# %%
for i in range(10,1000,10):

    driver = webdriver.Chrome(ChromeDriverManager().install())
    url = "https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d6692592-Reviews-or" + str(i) + "-Atitamos-Athens_Attica.html#REVIEWS"
    print("url is \n" + url) 
    driver.get(url)
    time.sleep(10)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    driver.quit()

    containers = soup.find_all("div", {"class": "review-container"})
    
    for container in (containers):
    
        user = container.find("div", {"class": "info_text pointer_cursor"})
        review = container.find("div", {"class": "prw_rup prw_reviews_text_summary_hsx"})
        rating = container.find("div", {"class": "ui_column is-9"})
        rating_value = 0;
        if (str(rating.next) == "<span class=\"ui_bubble_rating bubble_0\"></span>"):
            rating_value = 0
        elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_10\"></span>"):
            rating_value = 1
        elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_20\"></span>"):
            rating_value = 2
        elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_30\"></span>"):
            rating_value = 3
        elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_40\"></span>"):
            rating_value = 4
        else :
            rating_value = 5

        if(review):
            print("User is :" + user.text.strip() + "\n")
            print("Review is :" + review.text.strip() + "\n")
            print("Rating is : ",rating_value)
            data_point = [user.text.strip(),review.text.strip(), rating_value]
            data.append(data_point)
            print("\n")
            print("\n")
# Out:
# <ipython-input-14-12671a8a029f>:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d6692592-Reviews-or10-Atitamos-Athens_Attica.html#REVIEWS
# User is :902stratosk
#
# Review is :Ποικιλία πιάτων πολύ νόστιμο φαγητό ο σεφ είναι από τους καλύτερους ωραία τοποθεσία όμορφο μαγαζί και πολύ καλή εξυπηρέτηση.
#
# Rating is :  5
#
#
#
#
# User is :936vasilb
#
# Review is :Υπέροχο φαγητό για όλα τα γούστα, ζεστό περιβάλλον με άριστη εξυπηρέτηση. Τιμές προσιτές σε όλους. Το συνιστώ ανεπιφύλακτα.
#
# Rating is :  5
#
#
#
#
# User is :Nikel_mjt
#
# Review is :Η μουσική και η διακόσμηση σε χαλαρώνουν από το άγχος της ημέρας. Έχει ωραια μαγειρευτά.
# Αν ειστε κοντά αξιζει
#
# Rating is :  5
#
#
#
#
# User is :556antreasl
#
# Review is :Ωραιος ο χωρος του μαγαζιου . Τα πιατα ηταν αρκετα καλα , αλλα οχι κατι το ιδιαιτερο . Οι τιμες ειναι μετριες για αυτο που προσφερει
#
# Rating is :  3
#
#
#
#
# User is :_L3414GJ
#
# Review is :Καλή κουζίνα,ότι πιάτα πήραμε ήτανε εξαιρετικά.πολυ καλές τιμές,άψογη εξυπηρέτηση ωραίο περιβάλλον.Το συνιστώ ανεπιφύλακτα.
#
# Rating is :  5
#
#
#
#
# User is :manolisb765
#
# Review is :Ενα αρκετά καλο και τίμιο μαγαζάκι στην περιοχή των Εξαρχείων.Τα πιάτα γευστικά και ποιότητα.Χώρος όμορφος και ζεστός.προσωπικό ευγενικό και φιλικό.μονο αν γεμίσει κόσμο είναι λίγο στριμωγμένα...αξίζει σίγουρα η επισκευή σ αυτο.
#
# Rating is :  4
#
#
#
#
# User is :alexandrosg96
#
# Review is :Βρεθήκαμε στο μαγαζί λόγο των καλών κριτικών. Μικρός ο κατάλογος για μεζεδοπωλείο Όχι κάτι φοβερό από γεύσεις. Ωραίος χώρος. Οικονομικό. Δεν γίνονται κρατήσεις και ώρες αιχμής έχει αναμονή.
#
# Rating is :  3
#
#
#
#
# User is :dimitris_zampoglou
#
# Review is :Οι μελιτζάνες με το αρνάκι γευστικότατο πιάτο. Οι μερίδες χορταστικές, το σέρβις άψογο και οι τιμές πολύ καλές. Αξίζει οπωσδήποτε να το έχεις πάντα υπόψη κάθε φορά που θα γευματίζεις στο κέντρο.
#
# Rating is :  5
#
#
#
#
# User is :localftad
#
# Review is :Πήγαμε συστημενοι,  μπορεί αλλιώς να περνάγαμε απέξω και να μην το βλέπαμε.  Μεσημέρι Κυριακής, κάτσαμε στην μικρή αυλή και ήταν γεμάτο.  Φάγαμε πάρα πολύ καλά και προσιτές τιμές. Το προσωπικό ευγενικό και γρήγορο.  Συνεχίστε την καλή δουλειά παιδιά, μπράβο σας.
#
# Rating is :  5
#
#
#
#
# User is :magdoula00
#
# Review is :Πολυ ωραιο μαγαζι.... Πολυ καθαρό... Αρκετα οικονομικο... Πολυ νοστιμο φαγητο οτο φαγαμε ηταν καλομαγειρεμενο και φρεσκο..
#
# Rating is :  4
#
#
#
#
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d6692592-Reviews-or20-Atitamos-Athens_Attica.html#REVIEWS
# User is :Κωνσταντίνος Γ
#
# Review is :Σίγουρα δεν θα σε απογοητεύσει, Αλλά θα σε κάνει να αναρωτηθείς γιατί έχει τόσους τουρίστες, εντάξει θα το καταλάβεις με την πρώτη.Γενικα θα έλεγα μια επιλογή για γρήγορο φαγητό αλλά μέχρι εκεί.
#
# Rating is :  3
#
#
#
#
# User is :germanicus20
#
# Review is :Το είχα δει πολλές φορές στο διάβα μου, αλλά δεν είχα ασχοληθεί. Είδα τις κριτικές στο tripadvisor και μου κινήθηκε το ενδιαφέρον. Εντυπωσιάστηκα θετικά με τα πάντα.
#
# Εξαιρετικό ψωμί. (μαύρο με προζύμι και ωραία σκληρή κόρα)
# Καπνιστή μελιτζανοσαλάτα που ήταν πραγματικά καπνιστή και πεντανόστιμη.
# Τη...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :stagon
#
# Review is :Βρεθήκαμε για φαγητό Κυριακή απόγευμα παραγγείλαμε 2 κυρίως πιάτα ένα κεμπάπ και πανσετακια με σως μπάρμπεκιου μια σαλάτα ατιταμος και ένα ορεκτικό φέτα σε φύλλο και μέλι . Τα πιάτα ήταν πεντανόστιμα καλομαγειρεμενα όπως και η σαλάτα και το ορεκτικό η ποσότητα σωστή όση πρέπει...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :teot388
#
# Review is :Πολύ νόστιμες γεύσεις και ιδανικό για χορτοφάγους ή δυσανεκτικους στη γλουτένη. Μπράβο στα παιδιά και τη διεύθυνση!!
#
# Rating is :  5
#
#
#
#
# User is :Akis_6
#
# Review is :Εξαιρετικό κατάστημα. Πεντανόστιμα πιάτα, χαμηλές τιμές, φιλικότατοι ιδιοκτήτες και πεντακάθαρη ατμόσφαιρα χωρίς τσιγάρο. Πολύ ζεστή ατμόσφαιρα με όμορφη διακόσμηση. Δεν μπορώ να βρω τίποτα αρνητικό. Παιδιά, τέτοια μαγαζιά οφείλουμε να τα στηρίζουμε. Το φαγητό είναι απίστευτο και φαίνεται ότι το φτιάχνουν άνθρωποι με μεράκι. Από...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :LilyDiafani
#
# Review is :Πήγαμε στον Ατίταμο τις προάλλες και περνώντας μπροστά από την κουζίνα για να πάω στην τουαλέτα που βρίσκεται ακριβώς δίπλα, είδα τον μάγειρα (έναν κύριο γύρω στα 35, με καράφλα και γένια και μαύρη στολή που το σέρβις τον φώναζε Γιώργο) να του πέφτει στο...Περισσότερα
#
# Rating is :  1
#
#
#
#
# User is :telumetar
#
# Review is :Το φαγητό εξαιρετικό. Από τα καλύτερα που μπορεί κάποιος να βρει στο κέντρο της Αθήνας. Αν και η γειτονιά είναι υπερβολικα άσχημη λόγω των graffiti και της μαζικότητας του τσιμέντου, το συγκεκριμένο εστιατόριο αποτελει όαση στην ασχήμια της Αθήνας και λόγω του υπέροχου εξωτερικού χώρου...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :mariaf152
#
# Review is :Επισκεφτήκαμε το "Ατίταμος" με τον σύζυγό μου Παρασκευή βράδυ χωρίς κράτηση. Θέλαμε να δοκιμάσουμε ποιοτικό φαγητό value for money. Και πραγματικά αποζημιωθήκαμε. Ενώ βρίσκεται σε μία κατά τα άλλα υποβαθμισμένη περιοχή, της δίνει αξία και είναι ένα μικρό στολίδι για τα στενά των Εξαρχείων. Ίσως...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :ΣΤΕΛΙΟΣ Τ
#
# Review is :Πολύ καλό μαγαζί. Τα πιατα εξαιρετικά.οτι δοκιμάσαμε ήταν τέλειο.Καθαρος χώρος κ το προσωπικό πολύ εξυπηρετικό
#
# Rating is :  4
#
#
#
#
# User is :isminiko
#
# Review is :Το βρήκαμε τυχαία και...μας βγήκε σε "καλο" !! Ενα μικρό μαγαζάκι με πολυ ζεστό περιβάλλον, γεύσης που θες να ξανα δοκιμάσεις και τιμές πολυ καλές ! Εμεις πήραμε θαλασσινά , ο ψήστης επαγγελματίας καθώς ηταν ολα τέλεια ψημένα ! Μπράβο σε όλη την ομάδα ,...Περισσότερα
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d6692592-Reviews-or30-Atitamos-Athens_Attica.html#REVIEWS
# User is :katerinatango
#
# Review is :Πήγαμε με φίλους Γάλλους για να γιορτάσουμε τα γενέθλια μιας φίλης. Το προσωπικό ήταν ευγενέστατο και το φαγητό υπέροχο. Ευχαριστούμε πολύ και σίγουρα θα σας ξανάρθουμε
#
# Rating is :  5
#
#
#
#
# User is :Ioalag
#
# Review is :Επισκεφθηκαμε το μαγαζί Σάββατο μεσημέρι. Είχε αρκετό κόσμο και ήμασταν μάλλον τυχεροί που βρήκαμε τραπέζι. Όσα πιάτα παραγγείλαμε ήταν νόστιμα. Πήραμε σαλάτα ατιταμος, φάβα, κολοκυθοκεφτέδες, μανιτάρια, κεφτεδάκια, πανσέτες, όλα νόστιμα και ποιοτικά. Το προσωπικό πολύ ευγενικό και εξυπηρετικό. Το μαγαζί πεντακάθαρο, οι τουαλέτες άστραφταν από...Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :Coastal822226
#
# Review is :Ωραίο φαγητό και καλή εξυπηρέτηση. Αρκετά όμορφη και ζεστή η ατμόσφαιρα στο εσωτερικό. Η τηγανιά κοτόπουλο όντως πολύ καλή, όπως και το χύμα κρασί. Οι μερίδες θα μπορούσαν να είναι λίγο μεγαλύτερες.
#
# Rating is :  5
#
#
#
#
# User is :nasosa2019
#
# Review is :Πολύ όμορφο μαγαζί ζέστη ατμόσφαιρα, το φαγητό ήταν πολύ καλο και σε λογικές τιμές και με γρήγορο σέρβις!! Συνιστώ ανεπιφύλακτα!!
#
# Rating is :  5
#
#
#
#
# User is :825arisp
#
# Review is :Πολυ γρηγορο και ευγενικο σερβις....
# Μετρια διακοσμηση...
# Μετριες γευσεις...
# Μετριες τιμες....
# Θα περιμενα καλυτερα με τοσες κριτικες
#
# Rating is :  3
#
#
#
#
# User is :17lizzy
#
# Review is :Ένα όμορφο μικρό μαγαζάκι καθαρό με όμορφη διακόσμηση.Το σέρβις πολύ καλό και τα παιδιά που μας εξυπηρετουσαν ευγενικά και χαμογελαστά! Τα φαγητά όλα  πολύ νόστιμα εκτός από την τηγάνια κοτόπουλο που μου φάνηκε αδιάφορη, η σαλάτα ροκα παρμεζανα πολύ ωραία, το χαλουμι νόστιμο αλλά μου...Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :sofia_dav
#
# Review is :Σε μια βόλτα στα Εξάρχεια καθώς ψάχναμε να πιούμε κρασάκι και να τσιμπήσουμε, εμφανίστηκε μπροστά μας ο Ατίταμος. Όμορφο ζεστό μαγαζί με ευγενικό και πολύ φιλικό σέρβις. Υπέροχο αρωματικό λευκό κρασάκι Λήμνου και ένας κατάλογος με ενδιαφέρον. Ότι δοκιμάσαμε προσεγμένο και νόστιμο. Ωραία πιάτα και...Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :Olgalgg
#
# Review is :Διαβάζοντας κριτικές, πήγαμε στο συγκεκριμένο εστιατόριο και δεν απογοητευτηκαμε καθόλου. Το φαγητό ήταν πολύ νόστιμο και καθόλου βαρύ! Άψογο σέρβις, ενώ το μαγαζί ήταν γεμάτο. Ο χώρος ευχάριστος και πολύ καθαρός. Όσο για τον λογαριασμό, μας εξέπληξε! Πήραμε 2 μερίδες, 1 σαλάτα και 2 coca...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :christsimpi
#
# Review is :Όμορφο περιβάλλον με νόστιμο μενού καθώς και η τιμή να κυμαίνεται σε φυσιολογικά επίπεδα.
# Το μόνο αρνητικό είναι η αργοπορία των φαγητών στο τραπέζι.
#
# Rating is :  4
#
#
#
#
# User is :angiekoy
#
# Review is :Είχαμε περάσει δεκάδες φορές μπροστά από τον πάντοτε γεμάτο Ατίταμο και τελικά αποφασίσαμε να τον επισκεφτούμε και αποδείχτηκε ότι κάναμε πολύ καλά!
# Ο χώρος είναι ζεστός, απλά διακοσμημένος αλλά κάπως μικρός γι' αυτό ίσως είναι καλύτερα να κλείσει κάποιος τραπέζι.
# Στα του φαγητού τώρα: Πολύ...Περισσότερα
#
# Rating is :  4
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d6692592-Reviews-or40-Atitamos-Athens_Attica.html#REVIEWS
# User is :DogoRobino
#
# Review is :Πολλή νόστιμη η στραπατσαδα, που σου φέρνει μνήμες από φαγητά της γιαγιάς. Το πιάτο ημέρας(λαχανοσαρμαδες) ήταν γευστικοτατο και πλήρως χορταστικό ενώ το σέρβις ήταν χαμογελαστό και πολύ φιλόξενο. Αξίζει μία βόλτα από εκεί!
#
# Rating is :  5
#
#
#
#
# User is :chrismala1
#
# Review is :Επισκεφθήκαμε το εν λόγω μεζεδοπωλείο μέσω φίλων που μας το πρότειναν. Γενικά θα έλεγα πως αξίζει κάποιος να το επισκεφτεί. Τα πιάτα είναι νόστιμα και η εξυπηρέτηση πολύ καλή. Επίσης είναι και πολύ ευγενικά τα παιδιά που εργάζονται εκεί.
# Ωραίο πιάτο ημέρας (χοιρινό στη γάστρα)....Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :marinaki3
#
# Review is :Ο,τι φαγαμε ηταν πολυ καλα μαγειρεμενο και ποιοτικο..αξιζει να το επισκεφτειτε αμα βρισκεστε στην περιοχη!!
#
# Rating is :  4
#
#
#
#
# User is :elenakX7781JE
#
# Review is :Επισκεφθήκαμε τον Ατίταμο για ακόμη μία φορά και μείναμε με την ίδια αρχική εντύπωση: εξαιρετικό. Πολύ καλά υλικά, καλομαγειρεμένα, καλό κρασί, καλές τιμές και οι σερβιτόροι εξυπηρετικότατοι και ευγενέστατοι. Οι πελάτες κάθε εθνικότητας. Πιστεύω ότι πλέον έχω δοκιμάσει όλα τα πιάτα του και δεν μπορώ...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :SENIOR1970
#
# Review is :Μια καθημερινή μεσημέρι βρέθηκα κοντα στην περιοχή κσι πήγα για να το δοκιμάσω μιας και είχε τόσο πολλες κριτικές .Τελικά δεν είναι κάτι το ιδιαίτερο ένα κλασικό μεζεδοπωλείο των εξαρχειων με συμπαθητικά απλά πιατα !!
#
# Rating is :  3
#
#
#
#
# User is :giannouzosd
#
# Review is :Όλα πολύ καλά, σίγουρα θα επαναλάβω την επίσκεψη στο συγκεκριμένο χώρο! Τα σκουφιχτα απλά τέλεια όπως και το συκώτι!! Περάσαμε ωραία αν και μεσημέρι!!
#
# Rating is :  5
#
#
#
#
# User is :berlin31318
#
# Review is :Φαγητό οχι πολυ καλο και κάπως τυποποιημένο. Ενοχλητικές οι συνεχείς ερωτήσεις των σερβιτόρων σχετικά με το να πάρουν τα πιάτα πριν ακόμα τελειώσουμε καλα καλα το φαγητό μας. Γενικά το κλίμα ήταν κάπως πιεστικό και η τουριστική κίνηση το καθιστά ίσως λίγο αφιλόξενο.
#
# Rating is :  3
#
#
#
#
# User is :390dimp
#
# Review is :Μια όαση στο κέντρο της Αθήνας και συγκεκριμένα στα Εξάρχεια..  Ότι πήραμε ήταν πραγματικά πεντανόστιμο με την διαφορά να την κάνει η τηγανιά κοτόπουλο.. Οι μερίδες του είναι πολύ καλές, ενώ οι τιμές είναι λογικές..  Στα θετικά είναι η ευγένεια του προσωπικού και η ποικιλία...Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :978hliass
#
# Review is :Ευγενικό προσωπικό γευστικά πιάτα ποιότητα που δεν την βρίσκεις στην Αθήνα λογικές τιμές χαίρομαι που το trip advisor για άλλη μια φορά δεν με απογοήτευσε.
#
# Rating is :  4
#
#
#
#
# User is :Aiva1234
#
# Review is :Μας αρέσει πολύ και το επισκεπτόμαστε συχνά. Γεύσεις θαυμάσιες, εξυπηρέτηση και στον εσωτερικό χώρο άκαπνο. Μόνο που ξεχνούν την πόρτα ανοιχτή και συχνά κρυώνουμε. Ωραίο το επιδόρπιο και οι σαλάτες. Το φαγητό καλομαγειρεμένο πάντα, χωρίς να ενοχλεί στο στομάχι. Παράπονο ότι συχνά δεν προλαβαίνουμε τα...Περισσότερα
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d6692592-Reviews-or50-Atitamos-Athens_Attica.html#REVIEWS
# User is :ankavafi
#
# Review is :Ζεστός χώρος με καταπληκτικά φαγητά και μεζεδάκια. Φιλική και ευγενική εξυπηρέτηση. Αξίζει να το επισκεφθείτε
#
# Rating is :  5
#
#
#
#
# User is :andreas1900
#
# Review is :Ειναι απο αυτα που πρεπει να επισκεφθεις. Ο χωρος πολυ ομορφος μεσα κ εξω. Το προσωπικο ακρως ευγενικο , πραγματικο κ ζεστο. Μου προταθηκε ψητη σαρδελα, η πιο φρεσκια θαλασσινη που θα φας. Σαλατα με μανουρι τοπ. Σουπιες με σπανακι. Ολα βασιλικες μεριδες. Προτεινεται ανεπιφυλακτα.
#
# Rating is :  5
#
#
#
#
# User is :Kostas T
#
# Review is :Σάββατο βράδυ 4 φίλοι, χωρίς κράτηση...ευτυχώς ήταν 8:30 έφευγαν ορισμένοι αλλοδαποί και βρήκαμε τραπέζι μέσα. Έξω όλα κρατημένα ή γεμάτα. Φιλική εξυπηρέτηση, καλές τιμές, κόσμος πολύς, όχι δυσάρεστα όμως... καλές και οι γεύσεις, καλή σχέση αξίας- τιμής,που λένε οι ειδικοί. Θα ξαναπήγαινα ευχαρίστως, αλλά νωρίς...Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :KONSTANTINOS D
#
# Review is :Επαρκέστατο. Η τηγανιά του κοτόπουλου, τα κεφτεδάκια του, τα γεμιστά και η σαλάτα με τον ντάκο ήταν αυτά που γευτήκαμε και ενθουσιαστήκαμε. Υποψιάζομαι ότι κάποια φαγητά του θα είναι ακόμη καλύτερα. Προσιτές τιμές και ευγενέστατες κοπέλες.
#
# Rating is :  4
#
#
#
#
# User is :Daniela P
#
# Review is :Ζεστό και φιλόξενο περιβάλλον. Γρήγορη και εξαιρετική ευπηρέτηση, νόστημα φαγητά και καλές τιμές!Αξίζει να το επισκεφτείτε!
#
# Rating is :  5
#
#
#
#
# User is :alexkouko
#
# Review is :Από τα καλύτερα στην Αθήνα. Εξαιρετικό φαγητό με καλές τιμές. Ωραίος χώρος, με σέρβις πολύ καλό.. Όταν επισκεπτομαστε την Αθήνα συνήθως περνάμε για φαγητό και ωραίο χύμα λευκό κρασί... Το μόνο που με χαλάει είναι ότι το μαγαζί κάνει κρατήσεις στα τραπέζια... Κατ εμε ένας...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :Alexandrossan
#
# Review is :Είναι ένα εστιατόριο το οποίο πρέπει να πάτε πολύ ωραίο φαγητό και το προσωπικό του είναι άψογο σίγουρα θα ξανά πήγαινα
#
# Rating is :  5
#
#
#
#
# User is :Trip144939
#
# Review is :Το μαγαζί είναι   πάρα πολύ καθαρο  και το φαγητό πάρα πολύ ποιοτικό και  νόστιμο .επισηςειχεπαραπολκες και φρεδκιεςεπιλογες
#
# Rating is :  5
#
#
#
#
# User is :Anastassios
#
# Review is :Τα τραπέζια στην στοά, περιτριγυρισμένα έξυπνα από την πρασινάδα, είναι μία όαση στην πολυσύχναστη διασταύρωση.
# Ο εσωτερικός χώρος, ζεστός και φιλικός, χωρίς υπερβολές.
# Η εξυπηρέτηση λίγο αργή, αλλά χαμογελαστή και ευγενική, με άψογα Αγγλικά.
# Το φαγητό, καταπληκτικό! Εξαιρετική ποιότητα υλικών, καλομαγειρεμένο, σε καλές ποσότητες. Το...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :737ledaa
#
# Review is :Ωραία μοντέρνα ατμόσφαιρα και φρέσκα πιάτα. Περιποιημένο , παραδοσιακά πιάτα αλλά με μοντέρνα πινελιά. Είναι μια καλή επιλογή για τα Εξάρχεια.
#
# Rating is :  4
#
#
#
#
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d6692592-Reviews-or60-Atitamos-Athens_Attica.html#REVIEWS
# User is :T8378FP_
#
# Review is :Αυτό το μεζεδοπωλείο αποτελεί εξαιρετική επιλογή στην περιοχή του κέντρου. Προσεγμένα πιάτα από άριστα υλικά σε αρκετά χαμηλές τιμές. Άψογη εξυπηρέτηση, φιλικό περιβάλλον, ποιότητα και χαμηλές τιμές. Το συστήνω ανεπιφύλακτα.
#
# Rating is :  5
#
#
#
#
# User is :Saito22AlldayMan
#
# Review is :Σχεδόν όλα τα πιάτα ήταν πολύ όμορφα !! Θα ξαναερχομουνα άνετα !! Όμορφη διακόσμηση και ευχάριστο σέρβις !!
#
# Rating is :  5
#
#
#
#
# User is :PrasinosPanagiotis
#
# Review is :Ένας φιλαράκος μου, μου είπε «Φιλε, σου έχω ένα μαγαζάκι, δεν σου λεω πραμα»!
#
# Κι ετσι κι έγινε!
#
# Ένα φανταστικό μαγαζάκι, περί των 20 τραπεζιών, τα οποία τραπέζια ειναι εξίσου απίστευτα σε ποιότητα!
#
# Οτι φάγαμε ήταν εξαιρετικό, αλλα και οτι πίναμε δεν ειχε τελειωμό!
#
# Τα...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :popigmar
#
# Review is :Καθισαμε μεσημερακι κυριακης, πρωτη φορα, αφου ειδαμε γεματο μαγαζι και αρκετους τουριστους, παροτι το σημειο δεν ειναι τουριστικο. Η διακοσμηση πολυ ομορφη, και οι υπαλληλοι πολυ εξυπηρετικες! Παραγγειλαμε σαλατα ατιταμος και μια ποικιλια δυο ατομων,και ηταν ολα πεντανοστιμα( η σαλατα απλα φοβερη). Γενικα μειναμε πολυ...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :_F4605CC
#
# Review is :Αντί για μαγειρείο-μεζεδοπωλείο θα επρεπε να λέγεται ΨΗΣΤΑΡΙΑ-Μεζεδοπωλείο. Είναι μόνο να τρως και να φεύγεις σύντομα, δεν είναι ελκυστικός χώρος για να κάτσεις χαλαρά και να πιεις το κρασάκι σου. Παρεμπιπτόντως το χύμα κρασί μέτριο, η τσικουδιά βαριά χωρίς λόγο και το φαγητό καλούτσικο. Η...Περισσότερα
#
# Rating is :  3
#
#
#
#
# User is :Q4044QQ_
#
# Review is :Ωραίος χορός. . Καλές τιμές και καλό φαγητό  !! Θα το ξανά προτιμούσα.
# Η μουσική  είναι ωραία και το σέρβις πολύ  καλό .
#
# Rating is :  4
#
#
#
#
# User is :ΣΤΑΥΡΟΣ Τ
#
# Review is :πολύ καλή κουζίνα και με ιδιαίτερες γεύσεις.
# Άριστη επιλογή για όλες τις ώρες στο κέντρο της Αθήνας
# Πολύ ζεστή ατμόσφαιρα , πολύ καλό service και πολύ καλές τιμές.
# Μειονέκτιμα ότι δεν δεχοταν ακομά πληρωμή με POS επλίζω να έχει αλλάξει.
#
# Rating is :  4
#
#
#
#
# User is :xristoforos2017
#
# Review is :Έχω γευματίσει εδώ αρκετές φορές, το προτιμώ όσο βρίσκομαι στη περιοχή. Τα φαγητά νόστιμα , ποιοτικά και σε καλές τιμές. Μια δοκιμή θα σας πείσει.
#
# Rating is :  5
#
#
#
#
# User is :Vlassis T
#
# Review is :Καθίσαμε για μεσημεριανό φαγητό και παρότι είχε κίνηση, όλα ήρθαν στη ώρα τους και ήταν νοστιμότατα!! Πολύ ευγενικό και γρήγορο σέρβις και καλό μαγειρευτό φαγητό!
#
# Rating is :  5
#
#
#
#
# User is :stavrosbatzakas
#
# Review is :Το service στην ώρα του, το φαγητό νοστιμότατο. Όμορφο περιβάλλον για να πάτε με την παρέα σας. Το συστήνω!
#
# Rating is :  5
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d6692592-Reviews-or70-Atitamos-Athens_Attica.html#REVIEWS
# User is :its123
#
# Review is :Επίσκεψη μετά τη δουλειά με ζευγάρι φίλων, δοκιμάσαμε το γωνιακό μαγαζί του κέντρου. Με κράτηση από πριν καθισαμε ανετα ανάμεσα σε παρέες τουριστών από Ασία,  Ισπανία κ.α. αποδεικνύοντας την απήχηση του μέσω tripadvisor. Πήραμε σαλάτα πρασινάδα με μανούρι, κολοκυθοκεφτέδες, χόρτα, πικάντικο (όχι και τόσο) λουκανικο,...Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :περη θ
#
# Review is :καλο φαγητο. πολυ ωραια σαλατα ,χορτα, κρασι χυμα , ψωμι. πολυ ωραιοι κολοκυθοκεφτεδες  ομως τα κρεατικα προκατ.τιμες αρκετα καλες
#
# Rating is :  3
#
#
#
#
# User is :elzi12
#
# Review is :Τι ωραιο μαγαζι..πολυ ομορφη διακοσμηση. Το φαγητο εξαιρετικο.. Οπως επισης και το προσωπικο του. Οι τιμες πολυ λογικες. Μπραβο τους..
#
# Rating is :  5
#
#
#
#
# User is :Konstantinospag
#
# Review is :Ένα μαγαζί που πραγματικά προσφέρει ωραίες γεύσεις, πιάτα με ιδιαίτερα γνωρίσματα. Έχει παραδοσιακή πολύ ωραία ατμόσφαιρα το εσωτερικό του μαγαζιού. Οι τιμές είναι σχετικά καλές.
#
# Rating is :  4
#
#
#
#
# User is :zafpetr
#
# Review is :Είχε πλάκα σε ένα μαγαζί σε...απόσταση αναπνοής από το Εθνικό Μετσόβειο Πολυτεχνείο που τα μήντια αναζητούνε "αιτίες" να πούνε τη βλακεία τους,έβλεπες διάφορους τουρίστες...από το πουθενά,είτε με χάρτη είτε με το σμαρτοφόουν να έρχονται σε μαγαζί λόγω των καλών του κριτικών. Δύο πιάτα έφαγα,αλλά ήταν...Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :panagiotis l
#
# Review is :Ζεστό μέρος με φανταστική ατμόσφαιρα, εξαιρετικό φαγητό και πολύ ευγενικό προσωπικό.
# Σίγουρα θα ξαναπάμε!
#
# Rating is :  5
#
#
#
#
# User is :Θενια Κ
#
# Review is :Όλα ήταν πολύ ωραία. Το φαγητό νοστιμότατο, το προσωπικό πολύ ευγενικό και εξυπηρετικό. Το μαγαζί πολύ καθαρό (υπάρχει ένα εσωτερικό παράθυρο στον τοίχο απ όπου φαίνεται κ η κουζίνα). Μέσα δεν επιτρέπεται το κάπνισμα (υπάρχουν όμως τραπέζια και έξω). Οι τιμές ήταν πολύ προσιτές. Εν...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :ArisD463
#
# Review is :Θα ήθελα να πω ότι όλα ήταν όμορφα
# Οι σερβιτόρες τέλειες
# Το μαγαζί ζεστό
# Τα πάντα ωραία
# Ολλα ζεστά
# Το πρόβλημα είναι ότι είναι ψησταριά
# Και τα μπιφτέκια είναι προκάτ και το κρέας προκάτ
# Οι μερίδες μικρές ...
# Γενικά ψητοπωλείο μόνο !!!
# Και για Εξαρχεια...Περισσότερα
#
# Rating is :  1
#
#
#
#
# User is :giorgos11pap
#
# Review is :Πήγαμε με την κοπέλα μου για μεσημεριανό και αντικρίσαμε ένα ζεστό μικρό εστιατόριο με όμορφη μουσική και αρκετά καλό σέρβις. Οι κοπέλες ήθελαν πραγματικά να εξυπηρετήσουν. Μου έκανε εντύπωση τα τραπέζια και οι καρέκλες που ήταν πολύ όμορφα,-ες. Καλές τιμές. Καλές ποσότητες και ποιότητα. Μπράβο.
#
# Rating is :  5
#
#
#
#
# User is :phidias10
#
# Review is :Γρήγορη εξυπηρέτηση, σχετικά καλό φαγητό(αλλά όχι κάτι ιδιαίτερο), μικρός χώρος. Οι τιμές προσεκτικές και ανάλογες της ποιότητας. Μία αποδεκτή λύση για ένα γεύμα.
#
# Rating is :  3
#
#
#
#
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d6692592-Reviews-or80-Atitamos-Athens_Attica.html#REVIEWS
# User is :Maria_Spath
#
# Review is :Πήγαμε στο συγκεκριμένο εστιατόριο, διαβάζοντας τις καλές κριτικές που εχει λάβει στο trip advisor. Δυστυχώς, η επίσκεψη δεν μου άφησε και τις καλύτερες εντυπώσεις. Τα πιάτα ιδιαίτερα μέτρια και στην ποικιλία που παραγγείλαμε το κρέας ηταν εξαιρετικά κακο. Όσα προϊόντα περιείχαν κιμά ηταν ιδιαίτερα άσχημα....Περισσότερα
#
# Rating is :  3
#
#
#
#
# User is :petrosgr69
#
# Review is :Κριτική μετά από πολλές επισκέψεις στον Ατιταμο. Έχοντας δοκιμάσει σχεδόν τα πάντα μπορώ με βεβαιότητα να πω πως ότι και αν παρει κανείς είναι απλά εξαιρετικό. Παραδοσιακά ελληνικά πιάτα, πιάτα της ώρας, σαλάτες, νοστιμιές που σίγουρα έχεις φάει και αλλου όμως εδώ τις ανακαλύπτεις ξανά....Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :theoni C
#
# Review is :Ευχάριστος χώρος πολύ κοντά στην πλατεία Κάνιγγος. Ο εξωτερικός χώρος περιβάλλεται από φυτά. Τον χειμώνα θερμένεται. Η εξυπηρέτηση είναι ευχάριστη. Ερχεται αμέσως νερό σε κανάτα. Το ψωμί δεν χρεώνεται. Οι τιμές είναι λογικές. Στα αρνητικά θα πω ότι το ψαρονέφρι ήταν τελείως άγευστο, ίσως ήταν...Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :petros_ter
#
# Review is :Αυθεντικό μεζεδοπωλείο με μεγαλη ποικιλία! Το περιβάλλον ειναι εξαιρετικό και προσεγμένο, αναδύει μια ανεπανάληπτη αίσθηση καθαρότητας. Σε αυτο συμβάλλει και το γεγονός οτι ΑΠΑΓΟΡΕΥΕΤΑΙ το κάπνισμα στο εσωτερικό του καταστήματος. Ειναι ιςως αυτονόητο αλλα ειναι και σπάνιο να γυρίζεις σπιτι χωρις να μυρίζουν τα ρούχα...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :stefaniakid
#
# Review is :Μείναμε πολύ ευχαριστημένοι από τις γεύσεις, τον χώρο, τη μουσική, τις τιμές, το προσωπικό και την καθαριότητα. Επίσης πολύ ικανοποιητικό το ότι δεν καπνίζουν μέσα!
#
# Rating is :  5
#
#
#
#
# User is :siamgl
#
# Review is :Το προσωπικό ήταν ευγενεστατο και πολύ εξυπηρετικό. Ο χώρος προσεγμένος και ζεστός! Τα φαγητά ήταν πολύ νόστιμα και ήρθαν γρήγορα. Το μόνο αρνητικό ήταν ότι μας φάνηκε μικρή η ποσότητα της ποικιλίας κρεάτων που παραγγείλαμε...
#
# Rating is :  5
#
#
#
#
# User is :alexopoulo
#
# Review is :Εξαιρετικό φαγητό με πλούσιες μερίδες, ευχάριστο περιβάλλον, ευγενικό και γρήγορο σέρβις, πολύ λογικές τιμές, πολύ καθαρό, σε κεντρικό σημείο
#
# Rating is :  5
#
#
#
#
# User is :kos_kal
#
# Review is :Ωραία κρέατα , πολλές επιλογές , πραγματικά πολύ οικονομικά !! Καλή εξυπηρέτηση επίσης ! Κάντε κράτηση καλύτερα πριν πάτε
#
# Rating is :  5
#
#
#
#
# User is :chrichat4
#
# Review is :Ωραίο φαγητό σε σχετικά καλές τιμές. Μας έκανε εντύπωση το γεγονος οτι ειναι πολυ International το περιβαλλον με τους περισσοτερους θαμωνες να ειναι ξενοι. Ικανοποιητικη ποικιλία μεζέδων,
#
# Rating is :  4
#
#
#
#
# User is :nmihailidis
#
# Review is :Πολυ ωραίο φαγητό. Οι τιμές είναι εξαιρετικές. 2 άτομα με φαγητό να περισσεύει 31,5 ευρώ.σερβις γρήγορο και ευγενικό.
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d6692592-Reviews-or90-Atitamos-Athens_Attica.html#REVIEWS
# User is :RenosL1
#
# Review is :Ολα τα πιατα ηταν υπεροχα,πολυ καλη και γρηγορη εξυπηρετηση. Καλαισθητο προσωπικο. Συγκριτικα με την ποιοτητα του φαγητου ,οι τιμες ηταν σχετικα χαμηλες!
#
# Rating is :  5
#
#
#
#
# User is :T8378FP_
#
# Review is :Αν θέλετε καλό φαγητό σε ένα καθαρό περιβάλλον σε καλές τιμές και με γρήγορη εξυπηρέτηση τότε η επιλογή σας ειναι ο Ατίταμος. Καλή σας όρεξη!!!
#
# Rating is :  4
#
#
#
#
# User is :thespartian
#
# Review is :Πολυ καλο φαγητο στο κεντρο της Αθηνας. Νοστιμα πιατα με καλες τιμες και επιπλεον ενας χωρος χωρις τσιγαρο! Αν δεν ξεχνουσαν; την αποδειξη και μαζι με αυτη και ενα πιατο θα ηταν αριστο! Παρολα αυτα, σιγουρα θα ξαναπαω!
#
# Rating is :  4
#
#
#
#
# User is :papadatou30
#
# Review is :Πολύ καλή επιλογή!! Καλό φαγητό και καλή εξυπηρέτηση. Ευχαριστούμε!! Θα σας επισκεφτούμε πάλι σύντομα
#
# Rating is :  5
#
#
#
#
# User is :Bambakas m
#
# Review is :Ένα καλό κουτούκι με καλό φαγητό καλές τιμές ωραίος χώρος μικρό ζεστό με πολύ ωραία ορεκτικά και σαλάτες
#
# Rating is :  4
#
#
#
#
# User is :Σπυρος Σ
#
# Review is :Πολύ καλό φαγητό σε πολύ προσιτές τιμές. Η πρόσβαση πολύ εύκολη και όσον αφορά το παρκάρισμα συνήθως βρίσκεις πολύ κοντά. Όλα τα πιάτα είναι πολύ νόστιμα αλλά η τηγανιά κοτόπουλο ξεχωρίζει!!!👌🏻👌🏻👌🏻
#
# Rating is :  5
#
#
#
#
# User is :fotmast
#
# Review is :Πηγαίναμε σχεδόν στον Ατίταμο κάθε ημέρα για φαγητό. Το σέρβις εξαιρετικό, το φαγητό  πολύ καλό με καλές τιμές και καλές μερίδες. Στα συν το ότι αγαπάνε τα ζώα και πάντα έδιναν νερό στο μαλτεζάκι μας.
#
# Rating is :  5
#
#
#
#
# User is :IoannaKar07
#
# Review is :Όμορφος ζεστός χώρος, φιλικό και ευγενικό προσωπικό, πολύ καλές τιμές, γενναίες μερίδες, υπέροχη η σαλάτα ατίταμος, ιδιαίτερη γεύση τα μανιτάρια κουμπιά, πολύ καλή η τηγανιά κοτόπουλο και τα πανσετάκια! Είναι η μόνιμη επιλογή στο κέντρο, value for money!
#
# Rating is :  5
#
#
#
#
# User is :Απόστολος Κ
#
# Review is :Προκειται για ενα εξαιρετικό μεζεδοπωλειο στο κεντρο της Αθηνας και συγκεκριμενα στα Εξαρχεια. Μερικα μετρα απο την πλατεια Κανιγγος. Πολυ ομορφος χωρος με πετρα και ξυλο. Δεν μπορω να βοηθησω για τους μεζεδες καθως οσες φορες εχω ερθει εχω επιλεξει πιατο απο τα εξαιρετικά μαγειρευτά....Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :chourza
#
# Review is :Ωραίος χώρος..Νόστιμο- καλομαγειρεμένο φαγητό.. Το σέρβις φιλικότατο..Μπράβο!!Οταν ξαναεπισκεφτώ την Αθήνα θα το προτιμήσω σίγουρα..
#
# Rating is :  4
#
#
#
#
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d6692592-Reviews-or100-Atitamos-Athens_Attica.html#REVIEWS
# User is :aser122016
#
# Review is :Ωραιο φαγητο,απλο,αλλα εντιμο.Καλες τιμες.Τα κοριτσια στο σερβις ευγενεστατα αλλα απειρα.Θα προτιμουσα να ειχαν δεμενα τα μαλλια τους.Ομως σε γενικες γραμμες ολα καλα.Θα ξαναπαω.
#
# Rating is :  4
#
#
#
#
# User is :157antonisa
#
# Review is :Το εστιατοριο βρίσκεται κοντά στο Εθνικό Αρχαιολογικό Μουσείο και αποτελεί μια ευχάριστη έκπληξη για την περιοχή. Πολύ όμορφος χώρος με το ξύλο και την πέτρα να κυριαρχούν. Εκτός απο τα πιάτα του καταλόγου υπάρχουν και πιάτα ημέρας (κυρίως μαγειρευτα). Οτι δοκιμάσαμε ηταν πολύ καλά μαγειρεμένο...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :alexevripides
#
# Review is :Κάνοντας μια βόλτα από την περιοχή αποφασίσαμε να σταματήσουμε για μεσημεριανό εδώ. Φαίνονταν ωραίος χώρος συν του οτι είχαμε ακούσει από φίλους καλά λόγια για το φαγητό. Το φαγητό εξαιρετικό όπως και η εξυπηρέτηση, και οι τιμές πολύ καλές!
# Μου άρεσε πολύ και για αυτό...Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :GioTsi
#
# Review is :Το επισκεφτήκαμε μεσημέρι, παρέα τριών ατόμων. Δοκιμάσαμε σαλάτα Ατίταμος, μανιτάρια πλευρώτους ψητά, κοτόπουλο φιλέτο, μπιφτέκια ψητά και λευκό κρασί. Όλα μας άρεσαν αρκετά. Η εξυπηρέτηση επίσης πολύ καλή και το προσωπικό ευγενικό. Τιμή 12 ευρώ το άτομο. Στο τέλος μας κέρασαν ρακί. Θα ξαναπάω!
#
# Rating is :  4
#
#
#
#
# User is :madaron
#
# Review is :Καλός χώρος.
# Σχετικά καλές τιμές...
# Μερίδες καλές.
# Λίγο αργό το σέρβις.
# Αρνητικό το θέμα με το πάρκινγκ.
# Κέρασμα γιαούρτι με μέλι!!!!!
#
# Rating is :  3
#
#
#
#
# User is :913spirosm
#
# Review is :Καλό εστιατόριο στο κέντρο της Αθήνας.  Οικονομικό φαγητό έως μέτριες τιμές. Κανονικές μερίδες φαγητού.
# Νόστιμα φαγητό, φρέσκο.
# Το προσωπικό, με χαμόγελο.
# Κυρίως για καλοκαίρι. Έχει μικρή αίθουσα. Έχει κ φαγητό για ( πακέτο ) έξω.
#      Ένα μείον, είναι ότι δεν έχει δικό του πάρκινγκ. Υπάρχει...Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :panoss600
#
# Review is :Συμπαθητικό μαγαζί με διακόσμηση και επιρροές από παλιές ελληνικές ταινίες. Γειτονιά πολύ μέτρια. Σαλάτα ωραία με μανούρι σπανάκι κτλ. Φάβα ωραία,  κολοκυθοκεφτεδες πολύ μέτριοι κατ εμε. Κυρίως πιάτο πανσετακια με πατάτες αρκετά καλό. Στο τέλος μας πρόσφεραν και γιαούρτι με μέλι. Αυτό που μου έκανε...Περισσότερα
#
# Rating is :  3
#
#
#
#
# User is :spyridoula_skk
#
# Review is :υπεροχο εστιατοριο ! στο κεντρο της αθηνας . το προσωπικο αριστο και γρηγορη εξυπηρετηση ! οι τιμες ειναι επισης πολυ καλες! αξιζει σιγουρα να το επισκεφθειτε
#
# Rating is :  5
#
#
#
#
# User is :241taniat
#
# Review is :Το φαγητο ηταν καλο οχι ομως κατι το ιδιαιτερο. Παρ οτι δν ειχε πολυ κοσμο ημασταν μολις 2 παρεες το σερβις ηταν αρκετα αργο...
#
# Rating is :  4
#
#
#
#
# User is :Konstantinos F
#
# Review is :Άψογο σέρβις, το προσπαθούν και το καταφέρνουν με το φαγητό. Πολύ νόστιμη σαλάτα, καθαρή και καλοψημένη ποικιλία κρεάτων και ονειρική σφακιανή πίτα.
# Θα έρθουμε ξανά 100%.
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d6692592-Reviews-or110-Atitamos-Athens_Attica.html#REVIEWS
# User is :Andreasxios
#
# Review is :Πολύ καλό φαγητό και πολύ εξυπηρετικό προσωπικό. Νομίζω πολύ καλό για την γύρω περιοχή, και για οτι υπάρχει εκεί κοντά. Και για παρέα, και για ζευγάρια. Έξυπνη διακόσμηση, τόσο στο χώρο όσο και στις πινελιές των πιάτων.
#
# Rating is :  4
#
#
#
#
# User is :anna p
#
# Review is :μια καταπληκτική ταβερνα στο κεντρο της Αθηνας ...νοστιμοτατο φαγητο καταπληκτικες   λιχουδιες ..... το περιβαλον του πολυ ζεστο με το προσωπικό του χαμογελαστο και προθυμο παντα για σε εξυπηρετήσει.... οι τιμες νομιζω με την ποιοητα που προσφερει  ειναι παρα πολυ οικονομικές .....σας ευχαριστουμε !!!!!!!!!!!!!!!!
#
# Rating is :  5
#
#
#
#
# User is :Polis P
#
# Review is :Το ανακαλύψαμε μέσω TripAdvisor! Είπαμε να δοκιμάσουμε και εμεις..Πολύ καλό και οικονομικό φαγητό! Γνωρίσαμε τον ιδιοκτήτη ο οποίος απλός και συμπαθέστατοςς μας εξυπηρέτησε! Δοκιμάσαμε και προτείνουμε κεμπαπακια  Φλωρίνης,  Ντακος κρητικός και λουκάνικο Καρπενησίου! Κρίμα που κάποιοι νηστευαν!
#
# Rating is :  5
#
#
#
#
# User is :demjervag
#
# Review is :Εξαιρετικη προσπαθεια..ομορφος χωρος με ξυλινα επιπλα και θερμη ατμοσφαιρα..πολυ νοστιμο φαγητο και αρκετα εξυπηρετικο σερβις..θα ξαναπαμε!
#
# Rating is :  5
#
#
#
#
# User is :episkeptiskalka
#
# Review is :τιποτα το ξεχωριστο, μια κοινη ταβερνιτσα οι ανθρωποι που το χουν φαινεται οτι προσπαθουν στα θετικα οι καλες τιμες
#
# Rating is :  2
#
#
#
#
# User is :Nikos T
#
# Review is :Einai konta sto kentro tis athinas 5 lefta  apo ton stathmo  tis  omonias ..
# Aksizei na to episkefteite. ..
#
# Rating is :  5
#
#
#
#
# User is :Stavroula K
#
# Review is :Επισκεφτηκαμε  σαββατο βραδυ το μαγαζι μετα απο τις καλές κριτικές που διαβάσαμε και μείναμε πολυ ευχαριστημένοι .δοκιμασαμε την ποικιλία κρεατικών για δυο άτομα και την σαλάτα ατιταμος και ηταν ολα πεντανοστιμα.ιδιαιτερη εντυπωση μας έκανε η μεγάλη ποικιλία απο ελληνικές μπυρες που είχαν.Η εξυπηρετηση ηταν φιλική...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :968elenip
#
# Review is :Μεσογειακή κουζίνα με επιλεγμένα προιοντα , υγιεινής διατροφής !!!
# Φιλικό περιβάλλον !! Καθαρό !!
# Το προτείνω ανεπιφύλακτα !! ❤️
#
# Rating is :  5
#
#
#
#
# User is :Ρενα Μ
#
# Review is :Απλός κόσμος, καλό σέρβις, οικείο προσωπικό και καλομαγειρεμένα φαγητά σε τιμές λογικές. Ηταν η πρώτη φορά αλλά σίγουρα θα ξαναπάμε.
#
# Rating is :  4
#
#
#
#
# User is :Michael-pits
#
# Review is :9 τραπέζια όλα κι όλα στο μικρό γωνιακό μαγαζί, αλλά εκεί κατοικούν οι 9 μούσες της μαγειρικης, κρητικής αλλά όχι επιδεικτικά ή ανόητα! Τα τηγανητά καθαρά, τα κρέατα θαυμάσια, η εξυπηρέτηση διακριτική και σίγουρη. Πήραμε μια φέτα σε φύλλο με σουσάμι και μέλι, μια πράσινη...Περισσότερα
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d6692592-Reviews-or120-Atitamos-Athens_Attica.html#REVIEWS
# User is :Σταματίνα Κ
#
# Review is :πολύ ζεστό και όμορφο περιβάλλον, το μαγαζί ειναι πολύ καθαρό τα πιάτα πολύ γευστικά σε καλές τιμές και ικανοποιητικες  μερίδες. Ένα καλό στέκι για τα Κυριακάτικα μεσημέρια και οχι μόνο!!!
#
# Rating is :  5
#
#
#
#
# User is :tsales366
#
# Review is :ενα απο τα καλυτερα μαγειρια στην Αθηνα με πεντανοστημα μεσογειακα πιατα..με μεγαλη ποικιλια στο μενου..τα φαγητα ειδικα αυτα που δοκιμασαμε σαλατα ατιταμος και αρνακι λεμονατο με πατατες φουρνου και κρασακι ηταν πεντανοστημα..μπραβο στο προσωπικο της κουζινας..η εξυπηρετηση πολυ γρηγορη..ο χωρος ανετος και ωραιος..πολυ καλο προσωπικο..τιμες...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :712natasak
#
# Review is :Εξαιρετικο φαγητο και πολυ φιλικη ατμοσφαιρα.Εχουμε επισκεφθει αρκετες φορες τον Ατιταμο και η ποιοτητα του φαγητου αλλα και της εξυπηρετησης ειναι εξισου πολυ καλες...το προτεινω ανεπιφυλακτα!!
#
# Rating is :  5
#
#
#
#
# User is :mariapapadopoulou79
#
# Review is :Αρκετά καλό μαγαζί αλλά όχι για γευματα ημέρας. Λίγο μικρό σε μέγεθος αλλά με καλές τιμές και εξυπηρέτηση,
#
# Rating is :  4
#
#
#
#
# User is :kasserkon
#
# Review is :Βρεθήκαμε  βράδυ  Σαββάτου  6/2/2016  μετά  από  μια  θεατρική  παράσταση χωρίς  να  έχουμε  κάνει κράτηση.Το  μαγαζί  είναι  μικρό  αλλά  ζεστό.Περιμέναμε  περίπου  δέκα  λεπτά  μέχρι  να  αδειάσει  ένα  τραπέζι και  να  καθίσουμε.Προτείνω  λοιπόν  ειδικά  Σαββατόβραδα  ή  σε  μέρες  αιχμής  να  κάνετε  κράτηση.Να  δοκιμάσετε  τη  σαλάτα  Ατίταμος  που...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :ioannisvgl
#
# Review is :Πολύ καλή εμπειρία. Κλείσαμε μέσω μιας εφαρμογής το τραπέζι μας. Καλή υποδοχή. Πολύ ζεστός χώρος. Άριστη αλλά στυφή εξυπηρέτηση. Η σαλάτα υπέροχη με φρέσκα προιόντα. Η ποικιλία επίσης μικρή μεν αλλά αρκετή για δύο άτομα. Στο τέλος μας πρόσφεραν γλυκό (γιαούρτι με μαρμελάδα) και ένα...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :ANDREAS T
#
# Review is :Ενα υπεροχο μαγαζι στα εξαρχεια! Με γνησια ελληνικη κουζινα! Γευσεις που σου μενουν αξεχαστες! Το περιβαλλον σε μεταφερει σε μια αλλη εποχη! Ευχαριστουμε πολυ
#
# Rating is :  5
#
#
#
#
# User is :George_Angelopoulos
#
# Review is :Στο μαγαζί βρεθήκαμε τυχαία αλλά μάλλον θα ξαναπάμε γιατί μας άφησε θετική εντύπωση. Ο κατάλογος είναι πολύ οικονομικός και φάγαμε καλά.
#
# Rating is :  4
#
#
#
#
# User is :Βασίλης Τ
#
# Review is :Από το μαγαζί αυτό θα σας μείνουν μόνο καλές αναμνήσεις. Υπέροχο φαγητό ζεστός χώρος άμεση εξυπηρέτηση πολύ φιλικό περιβάλλον και απίστευτο ρακί είναι αυτά που μου έρχονται πρώτο πράγμα στο μυαλό. Σας το προτείνω ανεπιφύλακτα.
#
# Rating is :  5
#
#
#
#
# User is :marilenap688
#
# Review is :Το φαγητο ηταν εξαιρετικο... Ο σερβιτορος πολυ εξυπηρετικος... Κ το μαγαζι πολυ ζεστο κ ομορφα διακοσμημενο.... Ενας πολυ ομορφος χωρος...για φαγητο η ακομα κ για ενα  κρασακι ... Το συνιστω ανεπιφύλακτα.... Ενα απροσδοκητα ομορφο μαγαζι στο κεντρο των εξαρχειων....
#
# Rating is :  5
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d6692592-Reviews-or130-Atitamos-Athens_Attica.html#REVIEWS
# User is :xristost2016
#
# Review is :Έτυχε να πάω για πρώτη φορά στο συγκεκριμένο μαγαζί πριν απο 2 χρόνια περίπου... Απο τότε πηγαίνω όποτε αποφασίσω ότι θέλω να βγω έξω για φαγητό! Είναι ένας πολύ ωραίος και ζεστός χώρος με άψογη και γρήγορη  εξυπηρέτηση. Τα πιάτα τους είναι όλα προσεγμένα και...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :Swtiris X
#
# Review is :Τρομερό φαγητό όλα υγειηνά ωραία και ζεστή ατμόσφαιρα και πολύ εξυπηρετικό και καλό προσωπικό ωραία μουσική θυμίζει Ελλάδα
#
# Rating is :  5
#
#
#
#
# User is :Peri1972
#
# Review is :Πολυ ζεστη ατμοσφαιρα και πολυ κ ομορφη διακοσμηση με το ξυλινο στοιχειο να κυριαρχει..,το προσωπικο πολυ εξυπηρετικο κ ευγενικο..ωραια μουσικη και εξαιρετικο φαγητο..προτεινω σε ολους τηγανια κοτοπουλο..!
#
# Rating is :  5
#
#
#
#
# User is :Bill C
#
# Review is :Πηγαμε στον ατιταμο παραμονη χριστουγεννων  (χωρις κράτηση).το μαγαζι ηταν γεματο. Εκεινη την στιγμη αδειασε ενα τραπέζι . Ο σερβιτόρος  ηταν πολυ φιλικός και  μας
#  εξυπηρέτησε αμέσως. Το φαγητό ηταν καλόμαγειρεμένο. Ολα ηταν πεντανοστιμα .περάσαμε ενα υπεροχο βραδυ. Ευχαριστουμε πολυ 1
#
# Rating is :  5
#
#
#
#
# User is :ΠΕΤΡΟΣ Μ
#
# Review is :Πολυ καλο, μικρο ζεστο μαγαζι... Ωραια μεζεδακια καλο περιβαλλον αψογο σερβις!! Ευκολη προσβαση με το μετρο της ομονοιας στη περιοχη των εξαρχιων. Σας το προτεινω με κλειστα ματια...
#
# Rating is :  5
#
#
#
#
# User is :416christosc
#
# Review is :Ζεστό παραδοσιακό μαγαζί με ποιότητα στο φαγητό παράδοση καλή εξυπηρετηση που σε κάνει να νιώθεις οικία με οικονομικές τιμές χωρίς να χάνεται η ποσότητα Κ η ποιοτητα
#
# Rating is :  5
#
#
#
#
# User is :Dimitris Z
#
# Review is :Πολύ ωραίο. δοκιμάστε τηγάνια κοτόπουλο, από τα καλύτερα πιάτα που έχω φάει ποτε.επισης  φέτα ατιταμος , και ποικίλια κρεάτων .άριστηξ υπηρέτηση!όλα τέλεια!!! θα πάμε ξανά και ξανά
#
# Rating is :  5
#
#
#
#
# User is :isaakstogios
#
# Review is :Τα χειροποίητα κεμπαπακια Φλώρινας....η ποικιλία κρεάτων....Πάρα πολύ καλό φαγητό, υπέροχη εξυπηρέτηση, μεγαλες ποσότητες, εκπληκτικές τιμές, ωραίο περιβάλλον! Πιείτε και δοκιμάστε όσο περισσότερα πιάτα μπορείτε...άφοβα... Ζωντανη μουσική και πιες μέρες!
#
# Rating is :  5
#
#
#
#
# User is :Loukos G
#
# Review is :Πολυ καλη ποιοτητα φαγητου με μοναδικες γευσεις.οσο για την εξυπηρετιση ηταν μοναδικη.το σημειο ειναι πολυ κεντρικο κι ευκολα προσβασιμο.
#
# Rating is :  5
#
#
#
#
# User is :Christina P
#
# Review is :Ομορφο και ζεστο περιβαλλον, με εξαιρετικο φαγητο και σερβις!!!! Πολυ φιλικη και οικογενειακη ατμοσφαιρα, ολες οι παρεες γινονται μια,διασκεδαζοντας με ζωντανη Ελληνικη μουσικη!!!!  Το μαγαζι που γρηγορα θα γινει το στεκι σας!!!!
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d6692592-Reviews-or140-Atitamos-Athens_Attica.html#REVIEWS
# User is :kostisssgr
#
# Review is :Ένα από τα καλύτερα εστιατόρια στην Αθήνα. Πολύ καθαρο, όμορφο, ζεστό και φιλικό περιβάλλον. Αυθεντικές γεύσεις και καλό κρασί. Το προτείνουμε ανεπιφύλακτα.
# Δοκιμάστε τα εξαιρετικά χειροποίητα κεμπαπάκια Φλωρίνης! Θα σας μείνουν αξέχαστα!
#
# Rating is :  5
#
#
#
#
# User is :panagiotisk145
#
# Review is :Πολύ καλό μικρό μαγαζί,μαζεμένο μενού με πιάτα ημέρας που αλλάζουν.Σταθερή ποιότητα και καθαριότητα.Γεύση σπιτικού φαγητού σε βαθμό να το προτείνω και ακόμα και για κάθε μέρα.
#
# Rating is :  5
#
#
#
#
# User is :manolog777
#
# Review is :Πολύ καλό φαγητό, παραδοσιακή κουζίνα με μεγάλη ποικιλία πιάτων. Ο ξύλινα διακοσμημένος χώρος δημιουργεί μια πολύ ωραία, ζεστή και φιλική ατμόσφαιρα! Προτείνω τηγανιά κοτόπουλο, φέτα μέλι,μαραθοπιτα και να δοκιμάσετε δίκταμο!
#
# Rating is :  5
#
#
#
#
# User is :Nikos P
#
# Review is :Δοαβαζοντας τις κριτικές τόσων ανθρώπων είπαμε με την παρεα να επισκεφτούμε τον μαγαζί! Αν και καθημερινή το μαγαζί γέμισε και έπαιζε καλη μουσική!
# Η παραγγελία ηρθε γρήγορα όπως επίσης σερβιρίστηκαν και πολυ γρήγορα τα γύρω τραπέζια!
# Τα πρωτα πιάτα ηταν πολυ καλα ειδικά η σαλάτα...Περισσότερα
#
# Rating is :  3
#
#
#
#
# User is :ellinarts
#
# Review is :Μοναδικές γεύσεις , πεντακάθαρα σε οικογενειακό περιβάλλον. (Μαραθοπιτα σφακιανη κρεατικα ψαροσουπα) όλα με εντυπωσίασαν μαζί με το άψογο σέρβις.
# ΑΞΊΖΕΙ ΚΑΙ ΓΙΑ ΖΕΥΓΆΡΙΑ ακόμα και για ρακί ή  τσίπουρο .
#
# Rating is :  5
#
#
#
#
# User is :8302014
#
# Review is :Εδώ και μερικούς μήνες τυχαία επισκέπτηκα τον ΑΤΤΙΤΑΜΟ.Από την πρώτη στιγμή αισθάνθηκα άνετα στον χώρο από το όμορφο περιβάλλον και το άψογο σέρβις φυσικά και από το καλό ποιοτικά  φαγητό και τις προσιτές τιμές .Επίσης η καθαριότητα και η διακόσμηση του μαγαζιού το κάνουν πιστεύω...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :Γιωργος Ν
#
# Review is :Πολύ ζεστός χώρος ....ωραία ορεκτικά και πολύ γρήγορο και εξυπηρετικό σέρβις... φιλικό περιβάλλον .!!!
#
# Rating is :  5
#
#
#
#
# User is :Αδαμόπουλος Γ
#
# Review is :Ενα ζεστο μαγαζι στα εξαρχεια με αριστο φαγητο και κλιμα! Σπανιο μερος στις μερες μας με φαγητο με ποσοτητα κ ποιοτητα σε χαμηλες τιμες.φοβερη διακοσμηση! Καταπληκτικη εξυπηρετηση!
#
# Rating is :  5
#
#
#
#
# User is :Evangelia S
#
# Review is :Έχουμε επισκεφθεί στο παρελθόν αρκετές φορές τον Ατίταμο, και πάντα ήταν όλα υπέροχα. Το κρασί είναι πολύ καλής ποιότητας και η τσικουδιά είναι αυθεντικότατη. Το φαγητό είναι καλομαγειρεμένο και πολύ γευστικό. Δοκιμάστε τις τηγανιές, είναι τρομερές! Η εξυπηρετηση ήταν πολύ καλή, ενώ εκτιμήσαμε ιδιαιτέρως το...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :SotirisZaks
#
# Review is :Το φαγητό υπερνοστιμο, η ατμόσφαιρα ζεστή και φιλική, η εξυπηρέτηση σε αφήνει άφωνο! Όσο για τις τιμές, κυμαίνονται σε εξαιρετικά χαμηλά επίπεδα.
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d6692592-Reviews-or150-Atitamos-Athens_Attica.html#REVIEWS
# User is :Sean S
#
# Review is :Αυτό είναι λίγο δύσκολο να το βρεις και η περιοχή φαίνεται δύσκολη αλλά σίγουρα αξίζει τον κόπο. Το φαγητό είναι παραδοσιακή σπιτική ελληνική κουζίνα. Στην κόρη μου αρέσουν οι πατάτες και πιστεύει ότι ήταν οι καλύτερες που έχει δοκιμάσει ποτέ. Πήρα το πιάτο της ημέρας...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :Nathael L
#
# Review is :Ωραίο μέρος. Το φαγητό ήταν πολύ καλό και σερβιρισμένο γενναιόδωρα. Η εξυπηρέτηση ήταν τέλεια. Εγώ θα πήγαινα και πάλι χωρίς δισταγμό.
# Και οι τιμές ήταν πολύ ελκυστικές! (38€ για 4 με ποτά)
#
# Rating is :  5
#
#
#
#
# User is :jasrwallace
#
# Review is :Εμφανιστήκαμε χωρίς κράτηση και αυτά τα παιδιά είχαν εξαιρετικό φαγητό και ποτά, καθώς και υπέροχη εξυπηρέτηση.
#
# Το φαγητό ήταν τόσο καλό που θέλαμε να συνεχίσουμε να τρώμε και να τρώμε. Καλές τιμές και καλή ποιότητα, πολλά εστιατόρια για να επιλέξετε. Χαίρομαι που διαλέξαμε αυτό.
#
# Rating is :  5
#
#
#
#
# User is :977danais
#
# Review is :Ωραίο φαγητό, προσιτές τιμές και ευγενικό προσωπικό. Πάμε συχνά με την παρέα, αν και είναι δύσκολοι οι καιροί.
# Η διακόσμηση είναι ωραία και σε μεταφέρει αλλού.
# Μια δοκιμή αξίζει.
#
# Rating is :  4
#
#
#
#
# User is :JohannesBA123Άαλμποργκ, Δανία
#
# Review is :Αυτό ήταν σίγουρα το καλύτερο μέρος που φάγαμε στην Αθήνα, παρόλο που είχαμε επιλέξει προσεκτικά ποια εστιατόρια θα φάνε με βάση κριτικές tripadvisor. Το μενού ήταν καλό και ελληνικό, νόστιμο και πολύ φθηνό - καταλήξαμε να πληρώνουμε μόνο 60 ευρώ για 5 άτομα και ήμασταν...όλοι γεμάτοι όταν φύγαμε.
#  Παραγγείλαμε μερικά αρνιά που μαγειρεύει για μεγάλο χρονικό διάστημα, χοιρινό σουβλάκι με τηγανητές πατάτες, σουβλάκι κοτόπουλου με πατάτες, βόειο κρέας και τοπικό λουκάνικο. Όλα τα πιάτα ήταν νόστιμα και σίγουρα μπορούν να τα συστήσουν.
#  Η εξυπηρέτηση ήταν πολύ καλή, ήταν πολύ φιλική και ενδιαφέρουσα. Το νερό ήταν ελεύθερο εκεί που ήταν ωραίο. Το σπίτι σερβίρεται επίσης τοπικό ελληνικό επιδόρπιο, το οποίο ήταν νόστιμο και μια καλή εμπειρία επίσης.
#  Η ατμόσφαιρα ήταν μεγάλη, ήταν ζεστή και απλά ένα ωραίο μέρος για να απολαύσετε δείπνο.
#  Το εστιατόριο βρίσκεται λίγο έξω από τις τουριστικές περιοχές γύρω από την Ακρόπολη και την Πλάκα. Ως εκ τούτου επιλέξαμε να φάμε εδώ αφού επισκεφθήκαμε το Εθνικό Αρχαιολογικό Μουσείο το οποίο βρίσκεται πολύ κοντά και κλείνει στις 8 μ.μ. Ήταν μια μεγάλη εμπειρία που μπορώ σίγουρα να συστήσω άλλους.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :295caraj
#
# Review is :Πεσαμε πάνω σε αυτό το εστιατόριο μία ημέρα για μεσημεριανό γεύμα και ήταν τόσο καλό πήγαμε πίσω δύο φορές περισσότερο για δείπνο κατά τη διαμονή μας στην Αθήνα. Το φαγητό ήταν εξαιρετικό, όλα όσα έχουμε δοκιμάσει (η οποία κατέληξε σε πολά) ήταν τέλεια. Η εξυπηρέτηση...ήταν εντάξει, καλό για τους Αγώνες της Αθήνας.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :maxcP6544CUΟυτρέχτη, Ολλανδία
#
# Review is :Αυτό είναι ένα καλό μέρος για να έχουν κάτι να φάτε. Αλλά θα πρέπει να πάτε αργά ή νωρίς επειδή είναι διαφορετικά πλήρες
#
# Rating is :  5
#
#
#
#
# User is :K2464KIalexgΛονδίνο, Ηνωμένο Βασίλειο
#
# Review is :Μόλις τελειώσει το φαγητό εδώ και πραγματικά ήθελα να γράψω μια θετική κριτική, επειδή το φαγητό ήταν απλώς καταπληκτικά. Όλοι είχαμε μια σαλάτα: Ελληνική σαλάτα, Πράσινη σαλάτα με manouri και κρητικά Ο ντάκος. σαλάτα. Κάθε σαλάτα ήταν περίπου 5 . 5 - 6 . 5...ευρώ, αλλά ήταν τεράστια και γευστικά τόόόόόόόόσο. Είχαμε επίσης ορισμένες τζατζίκι με πίτα που έχουμε απολύτως τους κατασπαράξει.
# Θα επιστρέψουμε στο Atitamos προτού αναχωρήσει την Αθήνα. Σίγουρα.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :CarminaGeorgescuΒουκουρέστι, Ρουμανία
#
# Review is :Εκπληκτικό σαλάτες και ορεκτικά. Πολύ φιλικοί σερβιτόροι και η εξυπηρέτηση ήταν άψογη. Άνετο και παραδοσιακό εστιατόριο με αυθεντική ελληνική ατμόσφαιρα.
#
# Rating is :  5
#
#
#
#
# User is :Shelle40Χέλσινγκορ, Δανία
#
# Review is :Υπέροχη ατμόσφαιρα. Εσωτερική ( (air condition) και υπαίθριο καθιστικό.
# Το φαγητό είναι πολύ καλό, ωραίο χταπόδι πιάτο και σαλάτες είναι μεγάλα eniugh για κοινή χρήση. Τα πάντα ήταν πολύ νόστιμο.
# Η εξυπηρέτηση φιλική.
#
# Rating is :  4
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d6692592-Reviews-or160-Atitamos-Athens_Attica.html#REVIEWS
# User is :SedaEgIstanbul
#
# Review is :Βρήκαμε το εστιατόριο στο tripadvisor και αποφάσισε να κινήσει. Ήμασταν εκεί περίπου 2 μ.μ., το μέρος ήταν μισογεμάτο. Παραγγείλαμε τηγανητό κοτόπουλο και ζυμαρικά Atitamos τόσο των οποίων ήταν πολύ καλό, ειδικά για τις τιμές με τις τιμές της Αθήνας. Το μέρος είναι μικρό και όμορφα...διακοσμημένο. Προσφέρουν ένα δωρεάν ποτό της Ελλάδος και γιαούρτι+μέλι επιδόρπιο μετά το γεύμα σας, η οποία είναι μια πολύ ωραία πινελιά. Η σερβιτόρα ήταν πολύ εξυπηρετικό και μιλούσε καλά αγγλικά. Τα πάντα ήταν καλό. Ο μόνος λόγος για τον οποίο αυτό δεν είναι πέντε έναρξη επανεξέτασης είναι η 1 ώρα και 15 λεπτά χρόνος αναμονής για τα τρόφιμα. Στις διακοπές σας ενδέχεται να μην ληφθεί υπόψη σε αναμονή, αλλά για εμάς, ήταν λίγο πολύ καιρό, ιδιαίτερα με μόνο 4 τραπέζια για δύο σερβιτόροι να παρευρεθεί. Να θυμάστε επίσης, το μέρος είναι γεμάτο τουρίστες και σχεδόν καθόλου οι ντόπιοι αν αυτό είναι κάτι που αναζητάτε σε ένα εστιατόριο. .Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :V2643ISjohnlSwadlincote, Ηνωμένο Βασίλειο
#
# Review is :Τόσο καλή επιστρέψαμε για δεύτερη φορά μέσα σε μια εβδομάδα. Καλό φαγητό, καλή εξυπηρέτηση και όλα αυτά σε μια πολύ προσιτή τιμή.
#
# Rating is :  5
#
#
#
#
# User is :Gosia RDerbyshire, Ηνωμένο Βασίλειο
#
# Review is :Ελιές και τοματών δεν ήταν επαρκώς ώριμα, υπερβολικά Ξύδι βαλσαμικό, τυρί ήταν υπέροχο αλλά γενικά δεν είναι ένα "Ελληνική εμπειρία, όπως ήταν αναμενόμενο, αλλά ήμασταν πεινασμένοι. Δεν πρόκειται να ξαναπάω. Προτάθηκε η πλάκα και monasteriakis να βρούμε καλό φαγητό!
#
# Rating is :  3
#
#
#
#
# User is :lauralM8581JQΕλσίνκι, Φινλανδία
#
# Review is :Εξαιρετική εξυπηρέτηση και πραγματικά νόστιμο φαγητό. Μέτριες τιμές. Dayily speacials. Πήρε το ψάρι και ήταν καταπληκτικό. < 3 έπρεπε να περιμένουν στην ουρά για λίγο αλλά άξιζε τον κόπο. : ) Πολλές ευχαριστίες για την εξαιρετική εξυπηρέτηση!
#
# Rating is :  5
#
#
#
#
# User is :Zyx007Σιγκαπούρη, Σιγκαπούρη
#
# Review is :Επισκέφθηκα αυτό το εστιατόριο δύο φορές κατά τη διάρκεια του ταξιδιού μου στην Ελλάδα. Όλα προσπαθήσαμε ήταν εκπληκτικό, φρέσκα και αληθινά πεντανόστιμος. Εξαιρετικά φθηνό ούζο, ως συμπλήρωμα της διατροφής, και το δωρεάν ερήμους και ρακί ήταν το κερασάκι στην τούρτα. Συνιστώ ανεπιφύλακτα και σίγουρα θα...επιστρέψουμε την επόμενη φορά που θα έρθουμε στην Αθήνα.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :GailT651
#
# Review is :Έφαγα εκεί 4 φορές κατά τη διάρκεια της θητείας μου 8 ημέρες στην Αθήνα. Ήταν σε κοντινή απόσταση με τα πόδια από το ξενοδοχείο μου. Αυτό δεν ήταν ο μόνος λόγος. Το φαγητό ήταν υπέροχο, είχε την Ελληνική σαλάτα (τομάτες στην Ελλάδα είναι το καλύτερο)...Ψάρια καπνιστά, κεμπάμπ και οι τιμές απίστευτα προσιτές για την ποιότητα. Το προσωπικό ήταν πάντα εξυπηρετικό και πάντα σέρβιρε ένα εγκάρδιο και κέικ μετά το γεύμα σας. Συνιστώ ανεπιφύλακτα αυτό το εστιατόριο.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :Cold_InfernoΠερθ, Αυστραλία
#
# Review is :Επισκεφθήκαμε για μεσημεριανό γεύμα και την τιμή και την ποιότητα του φαγητού ήταν εξαιρετική. Ήταν πολύ απασχολημένοι το Σάββατο το απόγευμα, αλλά θα το συνιστούσα ανεπιφύλακτα. Το αρνί ήταν ιδιαίτερα εντυπωσιακή!
#
# Rating is :  5
#
#
#
#
# User is :NalaLee
#
# Review is :Εστιατόριο ήταν πολύ ωραία και κοντά στο κέντρο της πόλης και η γειτονιά μας. Το προσωπικό ήταν φιλικό και οι μερίδες ήταν τεράστια. Παρήγγειλα χωριάτικη σαλάτα και οι φίλοι μου είχαν ζυμαρικά και πληρώσαμε 16 € για 3 γεύματα. Στο τέλος μας έδωσαν δωρεάν ελληνικό...γιαούρτι με μέλι και ούζο.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :romaincello75Παρίσι, Γαλλία
#
# Review is :Είχα το καλύτερο γεύμα σας στην πόλη. Θαυμάσιο φιλόξενο και πολύ καλό μέρος. Η ποιότητα είναι στο επάνω μέρος και η τιμή είναι πολύ φθηνή. Συνεχίστε με τον τρόπο αυτό, μπορείτε να κάνουν τους ανθρώπους ευτυχισμένους.
#
# Rating is :  5
#
#
#
#
# User is :Kyria AΛα Ροσέλ, Γαλλία
#
# Review is :Πραγματικά καλό φαγητό!
# Δεν μπορούμε να περιμένουμε λίγο πριν από το φαγητό αλλά ήμασταν απογοητευμένοι.
# Είχαμε μια σαλάτα και χοιρινό κρέας για διαμοιρασμό και πραγματικά το απολαύσαμε.
# Θα πρέπει να καταβληθεί σε μετρητά, αλλά το προσωπικό ήταν κατανόηση και ας πάμε λαμβάνουν χρήματα και θα...επιστρέψουμε.
# Προσφέρουν μας στην έρημο , γιαούρτι με μέλι και ρακί, αυτό ήταν υπέροχο!Περισσότερα
#
# Rating is :  4
#
#
#
#
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d6692592-Reviews-or170-Atitamos-Athens_Attica.html#REVIEWS
# User is :ginuwineΝτουμπάι, Ηνωμένα Αραβικά Εμιράτα
#
# ...
#
# Rating is :  5
#
#
#
#
# User is :Nomad812948
#
# Review is :Μεγάλη ποικιλία. Τα πιάτα της ημέρας αξίζει κανείς να τα δοκιμάσει. Μοιραστήκαμε αρνάκι στη λαδόκολα που έλιωνε στο στόμα με πατατούλες και κεφτεδάκια με δυόσμο. Στην αρχή πήραμε γαύρο μαρινάτο που σας τον συστήνω ανεπιφύλακτα και χόρτα. Στο τέλος μας προσέφεραν απο ενα σφηνάκι μαστίχα....Επίσης το δικό του λευκό κρασί πάρα πολύ καλό.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :Stathakios A
#
# Review is :Καλο μαγαζι για το κέντρο της Αθήνας. Καλά φαγητα, εξυπηρετηση άψογη, χαμόγελο. Τιμές λογικές , παρτε τα; ντολμαδιακια!
#
# Rating is :  5
#
#
#
#
# User is :PanagiotisTsigkos
#
# Review is :Πολύ ωραίος, ευχάριστος και καθαρός χώρος με λογικές τιμές και υπέροχα πιάτα. Το σέρβις γρήγορο και τα υλικά φρέσκα! Αρκετή ησυχία για τα δεδομένα τις περιοχής με κέρασμα στο τέλος!
# Φυσικά για κάποιον που δεν γνωρίζει την περιοχή και θέλει να προσεγγίσει με αυτοκίνητο είναι...λίγο "άθλος" η εύρεση χώρου στάθμευσης.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :fotini p
#
# Review is :Μια ευχάριστη έκπληξη στο κέντρο της Αθήνας,στα Εξάρχεια! Εκπληκτικό φαγητό, εξαιρετικά κεφτεδακια, τέλειες σαλάτες,νοστιμοτατα ζυμαρικά!
# Ότι κι αν παραγγείλαμε ήταν το ένα πιο ωραίο από το άλλο..
# Το ακόμη πιο ωραίο ήταν το προσωπικό.
# Νέα παιδιά, ευγενεστατα, εξυπηρετικοτατα, με αγάπη για αυτό που κάνουν.
# Το...ωραιότερο μεζεδοπωλείο της Αθήνας!
# Το αγαπήσαμε πολύ..Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :EvitaP3
#
# Review is :Πηγαμε πριν ενα μηνα λογω των παρα πολλών κριτικών στο tripadvisor και τις άξιζαν 100%!
# Φάγαμε καταπληκτικά πιάτα ημερας (γιουβαρλάκια, κότσι αρνίσιο , κλπ) και μια ρακή που δεν υπαρχει!
# Ενα θα σας πω. Πηγαμε βραδυ και το επόμενο πρωί αντι για βαρυστομαχιά ενοιωθα εσωτερική...ευτυχια και πληρότητα.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :Ioannisktst
#
# Review is :Εξαιρετικό μαγαζί στην καρδιά των Εξαρχείων. Ποιοτικά φαγητά για όλα τα γούστα, είτε ψάρι, είτε κρέας. Οι τιμές φυσιολογικές θα λέγαμε δεδομένων των ποσοτήτων και της ποιότητας. Το συστήνω ανεπιφύλακτα
#
# Rating is :  4
#
#
#
#
# User is :giannisBt
#
# Review is :Καλομαγειρεμενο φαγητο με φρεσκα υλικα, τρομερος χωρος και ωραια διακοσμημενος, φιλικες τιμες!!!Σιγουρα αξιζει μια επισκεψη αν ειστε κοντα και ψαχνετε για να φατε κατι αξιολογο.
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d6692592-Reviews-or960-Atitamos-Athens_Attica.html#REVIEWS
# User is :D2501PV_
#
# Review is :Είναι τρομερό, το βρήκα μια μέρα τυχαία που το στέκι μας με την παρέα για φαγητό ήταν κλειστό και δεν τον αλλάξαμε ξανά.Είναι κατάλληλο για όλες τις περιστάσεις,έχει εκπληκτικό φαγητό, ποιοτικό και καθαρό πάνω από όλα, η εξυπηρέτηση του είναι επίσης τρομερή,τα  παιδιά στο προσωπικό...άψογα και με χιούμορ,πολύ φιλικά.Από τιμές γι αυτό που προσφέρουν είναι κυριολεκτικά αστείες, είναι πολύ οικονομικό και είναι για όλες τις ηλικίες.Το συστήνω ανεπιφύλακτα χίλιες φορές.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :nickynin94
#
# Review is :Φανταστικό φαγητό καταπληκτικοί άνθρωποι !
# Συστήνω ανεπιφύλακτα ! Ο κύριος Χρήστος πολύ ευγενικός όπως και όλο το προσωπικό ☺️☺️☺️
#
# Rating is :  5
#
#
#
#
# User is :michalism386
#
# Review is :Τι να πω για το εστιατόριο αυτό; Πεντακάθαρο,  πολύ ωραιος χώρος, αψογη εξυπηρέτηση από το προσωπικό και σε πολύ καλούς χρόνους παρά το πλήθος πελατών (κάτσαμε 2 άτομα σαββατόβραδο), τα φαγητά - ορεκτικα και κυρίως- πεντανόστιμα! Εύγε στα παιδιά!
#
# Rating is :  5
#
#
#
#
# User is :Nomad812948
#
# Review is :Μεγάλη ποικιλία. Τα πιάτα της ημέρας αξίζει κανείς να τα δοκιμάσει. Μοιραστήκαμε αρνάκι στη λαδόκολα που έλιωνε στο στόμα με πατατούλες και κεφτεδάκια με δυόσμο. Στην αρχή πήραμε γαύρο μαρινάτο που σας τον συστήνω ανεπιφύλακτα και χόρτα. Στο τέλος μας προσέφεραν απο ενα σφηνάκι μαστίχα....Επίσης το δικό του λευκό κρασί πάρα πολύ καλό.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :Stathakios A
#
# Review is :Καλο μαγαζι για το κέντρο της Αθήνας. Καλά φαγητα, εξυπηρετηση άψογη, χαμόγελο. Τιμές λογικές , παρτε τα; ντολμαδιακια!
#
# Rating is :  5
#
#
#
#
# User is :PanagiotisTsigkos
#
# Review is :Πολύ ωραίος, ευχάριστος και καθαρός χώρος με λογικές τιμές και υπέροχα πιάτα. Το σέρβις γρήγορο και τα υλικά φρέσκα! Αρκετή ησυχία για τα δεδομένα τις περιοχής με κέρασμα στο τέλος!
# Φυσικά για κάποιον που δεν γνωρίζει την περιοχή και θέλει να προσεγγίσει με αυτοκίνητο είναι...λίγο "άθλος" η εύρεση χώρου στάθμευσης.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :fotini p
#
# Review is :Μια ευχάριστη έκπληξη στο κέντρο της Αθήνας,στα Εξάρχεια! Εκπληκτικό φαγητό, εξαιρετικά κεφτεδακια, τέλειες σαλάτες,νοστιμοτατα ζυμαρικά!
# Ότι κι αν παραγγείλαμε ήταν το ένα πιο ωραίο από το άλλο..
# Το ακόμη πιο ωραίο ήταν το προσωπικό.
# Νέα παιδιά, ευγενεστατα, εξυπηρετικοτατα, με αγάπη για αυτό που κάνουν.
# Το...ωραιότερο μεζεδοπωλείο της Αθήνας!
# Το αγαπήσαμε πολύ..Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :EvitaP3
#
# Review is :Πηγαμε πριν ενα μηνα λογω των παρα πολλών κριτικών στο tripadvisor και τις άξιζαν 100%!
# Φάγαμε καταπληκτικά πιάτα ημερας (γιουβαρλάκια, κότσι αρνίσιο , κλπ) και μια ρακή που δεν υπαρχει!
# Ενα θα σας πω. Πηγαμε βραδυ και το επόμενο πρωί αντι για βαρυστομαχιά ενοιωθα εσωτερική...ευτυχια και πληρότητα.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :Ioannisktst
#
# Review is :Εξαιρετικό μαγαζί στην καρδιά των Εξαρχείων. Ποιοτικά φαγητά για όλα τα γούστα, είτε ψάρι, είτε κρέας. Οι τιμές φυσιολογικές θα λέγαμε δεδομένων των ποσοτήτων και της ποιότητας. Το συστήνω ανεπιφύλακτα
#
# Rating is :  4
#
#
#
#
# User is :giannisBt
#
# Review is :Καλομαγειρεμενο φαγητο με φρεσκα υλικα, τρομερος χωρος και ωραια διακοσμημενος, φιλικες τιμες!!!Σιγουρα αξιζει μια επισκεψη αν ειστε κοντα και ψαχνετε για να φατε κατι αξιολογο.
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d6692592-Reviews-or970-Atitamos-Athens_Attica.html#REVIEWS
# User is :D2501PV_
#
# Review is :Είναι τρομερό, το βρήκα μια μέρα τυχαία που το στέκι μας με την παρέα για φαγητό ήταν κλειστό και δεν τον αλλάξαμε ξανά.Είναι κατάλληλο για όλες τις περιστάσεις,έχει εκπληκτικό φαγητό, ποιοτικό και καθαρό πάνω από όλα, η εξυπηρέτηση του είναι επίσης τρομερή,τα  παιδιά στο προσωπικό...άψογα και με χιούμορ,πολύ φιλικά.Από τιμές γι αυτό που προσφέρουν είναι κυριολεκτικά αστείες, είναι πολύ οικονομικό και είναι για όλες τις ηλικίες.Το συστήνω ανεπιφύλακτα χίλιες φορές.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :nickynin94
#
# Review is :Φανταστικό φαγητό καταπληκτικοί άνθρωποι !
# Συστήνω ανεπιφύλακτα ! Ο κύριος Χρήστος πολύ ευγενικός όπως και όλο το προσωπικό ☺️☺️☺️
#
# Rating is :  5
#
#
#
#
# User is :michalism386
#
# Review is :Τι να πω για το εστιατόριο αυτό; Πεντακάθαρο,  πολύ ωραιος χώρος, αψογη εξυπηρέτηση από το προσωπικό και σε πολύ καλούς χρόνους παρά το πλήθος πελατών (κάτσαμε 2 άτομα σαββατόβραδο), τα φαγητά - ορεκτικα και κυρίως- πεντανόστιμα! Εύγε στα παιδιά!
#
# Rating is :  5
#
#
#
#
# User is :Nomad812948
#
# Review is :Μεγάλη ποικιλία. Τα πιάτα της ημέρας αξίζει κανείς να τα δοκιμάσει. Μοιραστήκαμε αρνάκι στη λαδόκολα που έλιωνε στο στόμα με πατατούλες και κεφτεδάκια με δυόσμο. Στην αρχή πήραμε γαύρο μαρινάτο που σας τον συστήνω ανεπιφύλακτα και χόρτα. Στο τέλος μας προσέφεραν απο ενα σφηνάκι μαστίχα....Επίσης το δικό του λευκό κρασί πάρα πολύ καλό.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :Stathakios A
#
# Review is :Καλο μαγαζι για το κέντρο της Αθήνας. Καλά φαγητα, εξυπηρετηση άψογη, χαμόγελο. Τιμές λογικές , παρτε τα; ντολμαδιακια!
#
# Rating is :  5
#
#
#
#
# User is :PanagiotisTsigkos
#
# Review is :Πολύ ωραίος, ευχάριστος και καθαρός χώρος με λογικές τιμές και υπέροχα πιάτα. Το σέρβις γρήγορο και τα υλικά φρέσκα! Αρκετή ησυχία για τα δεδομένα τις περιοχής με κέρασμα στο τέλος!
# Φυσικά για κάποιον που δεν γνωρίζει την περιοχή και θέλει να προσεγγίσει με αυτοκίνητο είναι...λίγο "άθλος" η εύρεση χώρου στάθμευσης.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :fotini p
#
# Review is :Μια ευχάριστη έκπληξη στο κέντρο της Αθήνας,στα Εξάρχεια! Εκπληκτικό φαγητό, εξαιρετικά κεφτεδακια, τέλειες σαλάτες,νοστιμοτατα ζυμαρικά!
# Ότι κι αν παραγγείλαμε ήταν το ένα πιο ωραίο από το άλλο..
# Το ακόμη πιο ωραίο ήταν το προσωπικό.
# Νέα παιδιά, ευγενεστατα, εξυπηρετικοτατα, με αγάπη για αυτό που κάνουν.
# Το...ωραιότερο μεζεδοπωλείο της Αθήνας!
# Το αγαπήσαμε πολύ..Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :EvitaP3
#
# Review is :Πηγαμε πριν ενα μηνα λογω των παρα πολλών κριτικών στο tripadvisor και τις άξιζαν 100%!
# Φάγαμε καταπληκτικά πιάτα ημερας (γιουβαρλάκια, κότσι αρνίσιο , κλπ) και μια ρακή που δεν υπαρχει!
# Ενα θα σας πω. Πηγαμε βραδυ και το επόμενο πρωί αντι για βαρυστομαχιά ενοιωθα εσωτερική...ευτυχια και πληρότητα.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :Ioannisktst
#
# Review is :Εξαιρετικό μαγαζί στην καρδιά των Εξαρχείων. Ποιοτικά φαγητά για όλα τα γούστα, είτε ψάρι, είτε κρέας. Οι τιμές φυσιολογικές θα λέγαμε δεδομένων των ποσοτήτων και της ποιότητας. Το συστήνω ανεπιφύλακτα
#
# Rating is :  4
#
#
#
#
# User is :giannisBt
#
# Review is :Καλομαγειρεμενο φαγητο με φρεσκα υλικα, τρομερος χωρος και ωραια διακοσμημενος, φιλικες τιμες!!!Σιγουρα αξιζει μια επισκεψη αν ειστε κοντα και ψαχνετε για να φατε κατι αξιολογο.
#
# Rating is :  5
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d6692592-Reviews-or980-Atitamos-Athens_Attica.html#REVIEWS
# User is :D2501PV_
#
# Review is :Είναι τρομερό, το βρήκα μια μέρα τυχαία που το στέκι μας με την παρέα για φαγητό ήταν κλειστό και δεν τον αλλάξαμε ξανά.Είναι κατάλληλο για όλες τις περιστάσεις,έχει εκπληκτικό φαγητό, ποιοτικό και καθαρό πάνω από όλα, η εξυπηρέτηση του είναι επίσης τρομερή,τα  παιδιά στο προσωπικό...άψογα και με χιούμορ,πολύ φιλικά.Από τιμές γι αυτό που προσφέρουν είναι κυριολεκτικά αστείες, είναι πολύ οικονομικό και είναι για όλες τις ηλικίες.Το συστήνω ανεπιφύλακτα χίλιες φορές.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :nickynin94
#
# Review is :Φανταστικό φαγητό καταπληκτικοί άνθρωποι !
# Συστήνω ανεπιφύλακτα ! Ο κύριος Χρήστος πολύ ευγενικός όπως και όλο το προσωπικό ☺️☺️☺️
#
# Rating is :  5
#
#
#
#
# User is :michalism386
#
# Review is :Τι να πω για το εστιατόριο αυτό; Πεντακάθαρο,  πολύ ωραιος χώρος, αψογη εξυπηρέτηση από το προσωπικό και σε πολύ καλούς χρόνους παρά το πλήθος πελατών (κάτσαμε 2 άτομα σαββατόβραδο), τα φαγητά - ορεκτικα και κυρίως- πεντανόστιμα! Εύγε στα παιδιά!
#
# Rating is :  5
#
#
#
#
# User is :Nomad812948
#
# Review is :Μεγάλη ποικιλία. Τα πιάτα της ημέρας αξίζει κανείς να τα δοκιμάσει. Μοιραστήκαμε αρνάκι στη λαδόκολα που έλιωνε στο στόμα με πατατούλες και κεφτεδάκια με δυόσμο. Στην αρχή πήραμε γαύρο μαρινάτο που σας τον συστήνω ανεπιφύλακτα και χόρτα. Στο τέλος μας προσέφεραν απο ενα σφηνάκι μαστίχα....Επίσης το δικό του λευκό κρασί πάρα πολύ καλό.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :Stathakios A
#
# Review is :Καλο μαγαζι για το κέντρο της Αθήνας. Καλά φαγητα, εξυπηρετηση άψογη, χαμόγελο. Τιμές λογικές , παρτε τα; ντολμαδιακια!
#
# Rating is :  5
#
#
#
#
# User is :PanagiotisTsigkos
#
# Review is :Πολύ ωραίος, ευχάριστος και καθαρός χώρος με λογικές τιμές και υπέροχα πιάτα. Το σέρβις γρήγορο και τα υλικά φρέσκα! Αρκετή ησυχία για τα δεδομένα τις περιοχής με κέρασμα στο τέλος!
# Φυσικά για κάποιον που δεν γνωρίζει την περιοχή και θέλει να προσεγγίσει με αυτοκίνητο είναι...λίγο "άθλος" η εύρεση χώρου στάθμευσης.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :fotini p
#
# Review is :Μια ευχάριστη έκπληξη στο κέντρο της Αθήνας,στα Εξάρχεια! Εκπληκτικό φαγητό, εξαιρετικά κεφτεδακια, τέλειες σαλάτες,νοστιμοτατα ζυμαρικά!
# Ότι κι αν παραγγείλαμε ήταν το ένα πιο ωραίο από το άλλο..
# Το ακόμη πιο ωραίο ήταν το προσωπικό.
# Νέα παιδιά, ευγενεστατα, εξυπηρετικοτατα, με αγάπη για αυτό που κάνουν.
# Το...ωραιότερο μεζεδοπωλείο της Αθήνας!
# Το αγαπήσαμε πολύ..Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :EvitaP3
#
# Review is :Πηγαμε πριν ενα μηνα λογω των παρα πολλών κριτικών στο tripadvisor και τις άξιζαν 100%!
# Φάγαμε καταπληκτικά πιάτα ημερας (γιουβαρλάκια, κότσι αρνίσιο , κλπ) και μια ρακή που δεν υπαρχει!
# Ενα θα σας πω. Πηγαμε βραδυ και το επόμενο πρωί αντι για βαρυστομαχιά ενοιωθα εσωτερική...ευτυχια και πληρότητα.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :Ioannisktst
#
# Review is :Εξαιρετικό μαγαζί στην καρδιά των Εξαρχείων. Ποιοτικά φαγητά για όλα τα γούστα, είτε ψάρι, είτε κρέας. Οι τιμές φυσιολογικές θα λέγαμε δεδομένων των ποσοτήτων και της ποιότητας. Το συστήνω ανεπιφύλακτα
#
# Rating is :  4
#
#
#
#
# User is :giannisBt
#
# Review is :Καλομαγειρεμενο φαγητο με φρεσκα υλικα, τρομερος χωρος και ωραια διακοσμημενος, φιλικες τιμες!!!Σιγουρα αξιζει μια επισκεψη αν ειστε κοντα και ψαχνετε για να φατε κατι αξιολογο.
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d6692592-Reviews-or990-Atitamos-Athens_Attica.html#REVIEWS
# User is :D2501PV_
#
# Review is :Είναι τρομερό, το βρήκα μια μέρα τυχαία που το στέκι μας με την παρέα για φαγητό ήταν κλειστό και δεν τον αλλάξαμε ξανά.Είναι κατάλληλο για όλες τις περιστάσεις,έχει εκπληκτικό φαγητό, ποιοτικό και καθαρό πάνω από όλα, η εξυπηρέτηση του είναι επίσης τρομερή,τα  παιδιά στο προσωπικό...άψογα και με χιούμορ,πολύ φιλικά.Από τιμές γι αυτό που προσφέρουν είναι κυριολεκτικά αστείες, είναι πολύ οικονομικό και είναι για όλες τις ηλικίες.Το συστήνω ανεπιφύλακτα χίλιες φορές.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :nickynin94
#
# Review is :Φανταστικό φαγητό καταπληκτικοί άνθρωποι !
# Συστήνω ανεπιφύλακτα ! Ο κύριος Χρήστος πολύ ευγενικός όπως και όλο το προσωπικό ☺️☺️☺️
#
# Rating is :  5
#
#
#
#
# User is :michalism386
#
# Review is :Τι να πω για το εστιατόριο αυτό; Πεντακάθαρο,  πολύ ωραιος χώρος, αψογη εξυπηρέτηση από το προσωπικό και σε πολύ καλούς χρόνους παρά το πλήθος πελατών (κάτσαμε 2 άτομα σαββατόβραδο), τα φαγητά - ορεκτικα και κυρίως- πεντανόστιμα! Εύγε στα παιδιά!
#
# Rating is :  5
#
#
#
#
# User is :Nomad812948
#
# Review is :Μεγάλη ποικιλία. Τα πιάτα της ημέρας αξίζει κανείς να τα δοκιμάσει. Μοιραστήκαμε αρνάκι στη λαδόκολα που έλιωνε στο στόμα με πατατούλες και κεφτεδάκια με δυόσμο. Στην αρχή πήραμε γαύρο μαρινάτο που σας τον συστήνω ανεπιφύλακτα και χόρτα. Στο τέλος μας προσέφεραν απο ενα σφηνάκι μαστίχα....Επίσης το δικό του λευκό κρασί πάρα πολύ καλό.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :Stathakios A
#
# Review is :Καλο μαγαζι για το κέντρο της Αθήνας. Καλά φαγητα, εξυπηρετηση άψογη, χαμόγελο. Τιμές λογικές , παρτε τα; ντολμαδιακια!
#
# Rating is :  5
#
#
#
#
# User is :PanagiotisTsigkos
#
# Review is :Πολύ ωραίος, ευχάριστος και καθαρός χώρος με λογικές τιμές και υπέροχα πιάτα. Το σέρβις γρήγορο και τα υλικά φρέσκα! Αρκετή ησυχία για τα δεδομένα τις περιοχής με κέρασμα στο τέλος!
# Φυσικά για κάποιον που δεν γνωρίζει την περιοχή και θέλει να προσεγγίσει με αυτοκίνητο είναι...λίγο "άθλος" η εύρεση χώρου στάθμευσης.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :fotini p
#
# Review is :Μια ευχάριστη έκπληξη στο κέντρο της Αθήνας,στα Εξάρχεια! Εκπληκτικό φαγητό, εξαιρετικά κεφτεδακια, τέλειες σαλάτες,νοστιμοτατα ζυμαρικά!
# Ότι κι αν παραγγείλαμε ήταν το ένα πιο ωραίο από το άλλο..
# Το ακόμη πιο ωραίο ήταν το προσωπικό.
# Νέα παιδιά, ευγενεστατα, εξυπηρετικοτατα, με αγάπη για αυτό που κάνουν.
# Το...ωραιότερο μεζεδοπωλείο της Αθήνας!
# Το αγαπήσαμε πολύ..Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :EvitaP3
#
# Review is :Πηγαμε πριν ενα μηνα λογω των παρα πολλών κριτικών στο tripadvisor και τις άξιζαν 100%!
# Φάγαμε καταπληκτικά πιάτα ημερας (γιουβαρλάκια, κότσι αρνίσιο , κλπ) και μια ρακή που δεν υπαρχει!
# Ενα θα σας πω. Πηγαμε βραδυ και το επόμενο πρωί αντι για βαρυστομαχιά ενοιωθα εσωτερική...ευτυχια και πληρότητα.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :Ioannisktst
#
# Review is :Εξαιρετικό μαγαζί στην καρδιά των Εξαρχείων. Ποιοτικά φαγητά για όλα τα γούστα, είτε ψάρι, είτε κρέας. Οι τιμές φυσιολογικές θα λέγαμε δεδομένων των ποσοτήτων και της ποιότητας. Το συστήνω ανεπιφύλακτα
#
# Rating is :  4
#
#
#
#
# User is :giannisBt
#
# Review is :Καλομαγειρεμενο φαγητο με φρεσκα υλικα, τρομερος χωρος και ωραια διακοσμημενος, φιλικες τιμες!!!Σιγουρα αξιζει μια επισκεψη αν ειστε κοντα και ψαχνετε για να φατε κατι αξιολογο.
#
# Rating is :  5

# %%
df = pd.DataFrame(data, columns=['User', 'Review','Rating'])

# %%
df.shape
# Out:
# (991, 3)

# %%
df.head()
# Out:
#            User                                             Review  Rating
# 0      D2501PV_  Είναι τρομερό, το βρήκα μια μέρα τυχαία που το...       5
# 1    nickynin94  Φανταστικό φαγητό καταπληκτικοί άνθρωποι ! \nΣ...       5
# 2  michalism386  Τι να πω για το εστιατόριο αυτό; Πεντακάθαρο, ...       5
# 3   Nomad812948  Μεγάλη ποικιλία. Τα πιάτα της ημέρας αξίζει κα...       5
# 4  Stathakios A  Καλο μαγαζι για το κέντρο της Αθήνας. Καλά φαγ...       5

# %%
filepath = Path('atitamos_test.csv') 
df.to_csv(filepath, index=False)
