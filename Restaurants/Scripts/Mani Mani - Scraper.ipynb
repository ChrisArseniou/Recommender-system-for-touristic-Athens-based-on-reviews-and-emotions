# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import re
import time
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
from pathlib import Path

# %%
data = []

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
url = "https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d695929-Reviews-Mani_Mani-Athens_Attica.html#REVIEWS"
print("url is \n" + url)
driver.get(url)
time.sleep(10)
soup = BeautifulSoup(driver.page_source, 'html.parser')
driver.quit()
# Out:
# <ipython-input-3-d17c0ff8f9f3>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d695929-Reviews-Mani_Mani-Athens_Attica.html#REVIEWS

# %%
containers = soup.find_all("div", {"class": "review-container"})

# %%
containers[0]
# Out:
# <div class="review-container" data-collapsed="false" data-deferred="false" data-reviewid="865394276"><!--trkN:1-->
# <!--trkR:865394276-->
# <div class="prw_rup prw_reviews_review_resp" data-prwidget-init="handlers" data-prwidget-name="reviews_review_resp"><div class="reviewSelector" data-reviewid="865394276" id="review_865394276"><div class="rev_wrap ui_columns is-multiline"><div class="ui_column is-2 memberInfoColumn"><div class="prw_rup prw_reviews_member_info_resp" data-prwidget-init="handlers" data-prwidget-name="reviews_member_info_resp"><div class="member_info"><div class="memberOverlayLink clickable" data-anchorwidth="90" id="UID_CC0EB907B97187686516F5FB2D2560F5-SRC_865394276" onclick="widgetEvCall('handlers.initMemberOverlay', event, this);"><div class="avatar profile_CC0EB907B97187686516F5FB2D2560F5"><div class="avatarWrapper"><a><div class="prw_rup prw_common_basic_image avatarImage" data-prwidget-init="" data-prwidget-name="common_basic_image"><div class="ui_avatar resp"> <img class="basicImg" data-mediaid="452387457" src="https://media-cdn.tripadvisor.com/media/photo-l/1a/f6/e2/81/default-avatar-2020-43.jpg"/></div></div></a></div></div><div class="info_text pointer_cursor" onclick="widgetEvCall('handlers.usernameClick', event, this);"><div>_amaliakorakakh</div></div></div><div class="memberOverlayLink clickable" data-anchorwidth="90" id="UID_CC0EB907B97187686516F5FB2D2560F5-SRC_865394276" onclick="widgetEvCall('handlers.initMemberOverlay', event, this);"><div class="memberBadging g10n is-shown-at-tablet"><div class="reviewerBadge badge"><span class="badgeText">11 κριτικές</span></div></div></div></div></div></div><div class="ui_column is-9"><span class="ui_bubble_rating bubble_50"></span><span class="ratingDate" title="21 Οκτωβρίου 2022">Η κριτική γράφτηκε πριν από 3 ημέρες </span><span class="viaMobile" onclick="widgetEvCall('handlers.viaMobileClick', event, this)"><span class="ui_icon mobile-phone"></span>μέσω κινητής συσκευής </span><div class="quote isNew"><a class="title" href="/ShowUserReviews-g189400-d695929-r865394276-Mani_Mani-Athens_Attica.html" id="rn865394276" onclick="(ta.prwidgets.getjs(this,'handlers')).reviewClick(this.href, '0');"><span class="noQuotes">Πολύ καλή κουζίνα</span></a></div><div class="prw_rup prw_reviews_text_summary_hsx" data-prwidget-init="handlers" data-prwidget-name="reviews_text_summary_hsx"><div class="entry"><p class="partial_entry">Ένα εξαιρετικό μαγαζί με πλούσιες γευσεις βασισμένες στην ελληνική κουζίνα σε προσιτές τιμές και πολύ ευγενικό προσωπικό</p></div></div><div class="prw_rup prw_reviews_stay_date_hsx" data-prwidget-init="" data-prwidget-name="reviews_stay_date_hsx"><span class="stay_date_label">Ημερομηνία επίσκεψης:</span> Οκτώβριος 2022</div><div class="prw_rup prw_reviews_vote_line_hsx" data-prwidget-deferred="deferred/clicks" data-prwidget-init="handlers" data-prwidget-name="reviews_vote_line_hsx"><div class="tooltips wrap"><span class="taLnk no_cpu ui_icon flag" data-content="Υπάρχει κάποιο πρόβλημα με αυτή την κριτική;" data-position="above" data-tooltip="" id="ReportIAP_865394276" onclick="ta.prwidgets.call('deferred/clicks.clickReport',event,this,865394276,'member');return false;" onmouseover="widgetEvCall('handlers.hoverReport',event,this);return false;"></span></div><div class="helpful redesigned hsx_helpful"><span class="isHelpful">Χρήσιμη;</span><span class="thankButton hsx_thank_button" onclick="ta.prwidgets.call('deferred/clicks.clickThank',event,this,'...');return false;"><span class="helpful_text"><span class="ui_icon thumbs-up"></span><span class="numHelp">1  </span></span><div class="buttonShade hidden"><img alt="" src="https://static.tacdn.com/img2/generic/site/loading_anim_gry_sml.gif"/></div></span></div></div><div class="prw_rup prw_common_html" data-prwidget-init="" data-prwidget-name="common_html"><div class="note">Αυτή η κριτική είναι η υποκειμενική γνώμη ενός μέλους του Tripadvisor και όχι η γνώμη της Tripadvisor LLC. Το Tripadvisor πραγματοποιεί ελέγχους στις κριτικές.</div></div><div class="loadingShade hidden"><div class="ui_spinner"></div></div></div></div></div></div><!--et ...
# <!--etk-->
# </div>

# %%
rating = containers[0].find("div", {"class": "ui_column is-9"})

# %%
rating
# Out:
# <div class="ui_column is-9"><span class="ui_bubble_rating bubble_50"></span><span class="ratingDate" title="21 Οκτωβρίου 2022">Η κριτική γράφτηκε πριν από 3 ημέρες </span><span class="viaMobile" onclick="widgetEvCall('handlers.viaMobileClick', event, this)"><span class="ui_icon mobile-phone"></span>μέσω κινητής συσκευής </span><div class="quote isNew"><a class="title" href="/ShowUserReviews-g189400-d695929-r865394276-Mani_Mani-Athens_Attica.html" id="rn865394276" onclick="(ta.prwidgets.getjs(this,'handlers')).reviewClick(this.href, '0');"><span class="noQuotes">Πολύ καλή κουζίνα</span></a></div><div class="prw_rup prw_reviews_text_summary_hsx" data-prwidget-init="handlers" data-prwidget-name="reviews_text_summary_hsx"><div class="entry"><p class="partial_entry">Ένα εξαιρετικό μαγαζί με πλούσιες γευσεις βασισμένες στην ελληνική κουζίνα σε προσιτές τιμές και πολύ ευγενικό προσωπικό</p></div></div><div class="prw_rup prw_reviews_stay_date_hsx" data-prwidget-init="" data-prwidget-name="reviews_stay_date_hsx"><span class="stay_date_label">Ημερομηνία επίσκεψης:</span> Οκτώβριος 2022</div><div class="prw_rup prw_reviews_vote_line_hsx" data-prwidget-deferred="deferred/clicks" data-prwidget-init="handlers" data-prwidget-name="reviews_vote_line_hsx"><div class="tooltips wrap"><span class="taLnk no_cpu ui_icon flag" data-content="Υπάρχει κάποιο πρόβλημα με αυτή την κριτική;" data-position="above" data-tooltip="" id="ReportIAP_865394276" onclick="ta.prwidgets.call('deferred/clicks.clickReport',event,this,865394276,'member');return false;" onmouseover="widgetEvCall('handlers.hoverReport',event,this);return false;"></span></div><div class="helpful redesigned hsx_helpful"><span class="isHelpful">Χρήσιμη;</span><span class="thankButton hsx_thank_button" onclick="ta.prwidgets.call('deferred/clicks.clickThank',event,this,'...');return false;"><span class="helpful_text"><span class="ui_icon thumbs-up"></span><span class="numHelp">1  </span></span><div class="buttonShade hidden"><img alt="" src="https://static.tacdn.com/img2/generic/site/loading_anim_gry_sml.gif"/></div></span></div></div><div class="prw_rup prw_common_html" data-prwidget-init="" data-prwidget-name="common_html"><div class="note">Αυτή η κριτική είναι η υποκειμενική γνώμη ενός μέλους του Tripadvisor και όχι η γνώμη της Tripadvisor LLC. Το Tripadvisor πραγματοποιεί ελέγχους στις κριτικές.</div></div><div class="loadingShade hidden"><div class="ui_spinner"></div></div></div>

# %%
user = containers[0].find_all("div", {"class": "info_text pointer_cursor"})

# %%
user
# Out:
# [<div class="info_text pointer_cursor" onclick="widgetEvCall('handlers.usernameClick', event, this);"><div>_amaliakorakakh</div></div>]

# %%
review = containers[1].find("div", {"class": "prw_rup prw_reviews_text_summary_hsx"})

# %%
rating = containers[3].find("div", {"class": "ui_column is-9"})

# %%
rating.next
# Out:
# <span class="ui_bubble_rating bubble_30"></span>

# %%
if (str(rating.next) == "<span class=\"ui_bubble_rating bubble_40\"></span>"):
    print("rating is 3")

# %%
for container in (containers):
    
    user = container.find("div", {"class": "info_text pointer_cursor"})
    review = container.find("div", {"class": "prw_rup prw_reviews_text_summary_hsx"})
    rating = container.find("div", {"class": "ui_column is-9"})
    rating_value = 0;
    if (str(rating.next) == "<span class=\"ui_bubble_rating bubble_0\"></span>"):
        rating_value = 0
    elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_10\"></span>"):
        rating_value = 1
    elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_20\"></span>"):
        rating_value = 2
    elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_30\"></span>"):
        rating_value = 3
    elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_40\"></span>"):
        rating_value = 4
    else :
        rating_value = 5
    
    if(review):
        print("User is :" + user.text.strip() + "\n")
        print("Review is :" + review.text.strip() + "\n")
        print("Rating is : ",rating_value)
        data_point = [user.text.strip(),review.text.strip(), rating_value]
        data.append(data_point)
        print("\n")
        print("\n")
# Out:
# User is :_amaliakorakakh
#
# Review is :Ένα εξαιρετικό μαγαζί με πλούσιες γευσεις βασισμένες στην ελληνική κουζίνα σε προσιτές τιμές και πολύ ευγενικό προσωπικό
#
# Rating is :  5
#
#
#
#
# User is :yiannissar2017
#
# Review is :Λεπτες γευσεις με εκλεκτα υλικά Ελληνικής παραγωγής, κυριως απο τη Μάνη. Το αποτέλεσμα γευστικό, ικανοποιεί τους γευστικους καλυκες. Το περιβάλλον σε χαλαρώνει και η μουσική συντροφεύει ευχάριστα. Το προσωπικό είναι ευδιάθετο, οικείο και εξυπηρετικό. Ότι τρώει κανείς είναι φρεσκομαγειρεμένο  και όχι ετοιμο και ζεσταμένο στα...μικροκύματα. Στο τέλος το κερασμα λικέρ ροδάκινο είναι πολύ ευχάριστο.Η καθαριότητα είναι ένα ακόμα συν στην όλη εικόνα. Θα ξαναπάμε.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :Στράτος Μ
#
# Review is :Ήταν μια γευστική εμπειρία !! Πολύ ωραίες γεύσεις και πλούσιες !! Καλοστημένα πιάτα με απίστευτους συνδυασμούς και παρασκευές ! Θα πάμε σίγουρα ξανά ! Αξίζει να το δοκιμάσει κανείς!
#
# Rating is :  5
#
#
#
#
# User is :V M
#
# Review is :Όμορφος χώρος σε ένα ψηλοτάβανο παλιό σπίτι, ευγενικό προσωπικό, καλή μουσική. Το φαγητό 'πολύ' πειραγμένο, πιο πολύ σημασία στον στολισμό του πιάτου παρά στη γεύση.
#
# Rating is :  3
#
#
#
#
# User is :xripanag
#
# Review is :Δοκιμάσαμε πιάτα από όλα τις κατηγορίες του μενού, όλα ήταν γευστικά και όμορφα παρουσιασμένα. Η τιμή λογική και αντίστοιχη της ποιότητας και της ποσότητας του φαγητού, του χώρου και της εξυπηρέτησης, η οποία επίσης ήταν άψογη.
#
# Rating is :  5
#
#
#
#
# User is :Γιολεττα Π
#
# Review is :Επισκέφτηκαμε το εστιατοριο Σάββατο βράδυ με υψηλές προσδοκίες. Δυστυχώς, παρά τα γευστικά του ορεκτικά τα κυρίως πιάτα ήταν επιεικώς απαράδεκτα. Οι τιμές του ήταν Ιδιαίτερα υψηλές όπως και οι ποσότητες μικρές.
#
# Rating is :  3
#
#
#
#
# User is :mariosrenieris
#
# Review is :Αρχικά ο κύριος λόγος που βάζω 2/5 είναι ότι το μενου που έχουν στο σάιτ τους δεν έχει καμία σχέση με αυτό που είναι στο εστιατόριο. Πήγα με εντελώς διαφορετικες προσδοκίες και βρήκα ένα φτωχότερο μενου που δεν μου εδινε και πολλες επιλογές ειδικά στα...ορεκτικά. Τα πιατα ήταν αρκετά νόστιμα αλλά για το κόστος τους δεν ήταν κάτι ιδιαίτερο. Το προσωπικό επίσης αδιάφορο.Περισσότερα
#
# Rating is :  2
#
#
#
#
# User is :panoskaratzas
#
# Review is :Εστιατόριο που τιμά απόλυτα την ελληνική τοπική κουζίνα. Γεύσεις πολύ καλές, εξυπηρέτηση επιπέδου, ένα εστιατόριο όπως πρέπει να είναι.
#
# Rating is :  4
#
#
#
#
# User is :ioannisgsep64
#
# Review is :Κυριακή μεσημέρι μετά από βόλτα στο Μουσείο της Ακρόπολης και έχοντας παρκάρει μπροστά στο μαγαζί είπαμε να κάτσουμε και η επιλογή μας , μας ικανοποίησε απόλυτα .
# Υπέροχες γεύσεις, φιλική και άμεση εξυπηρέτηση , καλές τιμές . Έτσι πρέπει να τελειώνουν οι βόλτες.
# Άριστα λοιπόν....Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :PanosK216
#
# Review is :Όταν αποφασίζεις να επισκεφθείς ένα εστιατόριο, θα πρέπει το επίπεδο 3 παραγόντων να είναι πάνω του μετρίου. Γεύση, Εξυπηρέτηση , Αξία. Και αν η αξία είναι κάτι που διαπραγματεύεται στο μυαλό του καθενός, η γεύση και η εξυπηρέτηση είναι όροι αδιαπραγμάτευτοι.
# Το συγκεκριμένο εστιατόριο σε...καλύπτει πολύ όσον αφορά τη γεύση αλλά και την εξυπηρέτηση. Τα περισσότερο πιάτα έχουν βάθος στη νοστιμιά ενώ και η εξυπηρέτηση είναι άμεση και φιλική. Ως οφείλουν να είναι όλοι.
# Όσον αφορά την αξία, το κόστος δηλαδή, θεωρώ ότι είναι σε πολύ τίμια επίπεδα.
# Μπράβο στην ομάδα.Περισσότερα
#
# Rating is :  4

# %%
for i in range(10,500,10):

    driver = webdriver.Chrome(ChromeDriverManager().install())
    url = "https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d695929-Reviews-or" + str(i) + "-Mani_Mani-Athens_Attica.html#REVIEWS"
    print("url is \n" + url) 
    driver.get(url)
    time.sleep(10)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    driver.quit()

    containers = soup.find_all("div", {"class": "review-container"})
    
    for container in (containers):
    
        user = container.find("div", {"class": "info_text pointer_cursor"})
        review = container.find("div", {"class": "prw_rup prw_reviews_text_summary_hsx"})
        rating = container.find("div", {"class": "ui_column is-9"})
        rating_value = 0;
        if (str(rating.next) == "<span class=\"ui_bubble_rating bubble_0\"></span>"):
            rating_value = 0
        elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_10\"></span>"):
            rating_value = 1
        elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_20\"></span>"):
            rating_value = 2
        elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_30\"></span>"):
            rating_value = 3
        elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_40\"></span>"):
            rating_value = 4
        else :
            rating_value = 5

        if(review):
            print("User is :" + user.text.strip() + "\n")
            print("Review is :" + review.text.strip() + "\n")
            print("Rating is : ",rating_value)
            data_point = [user.text.strip(),review.text.strip(), rating_value]
            data.append(data_point)
            print("\n")
            print("\n")
# Out:
# <ipython-input-15-ba1c16b0c08c>:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d695929-Reviews-or10-Mani_Mani-Athens_Attica.html#REVIEWS
# User is :travelrecipes
#
# Review is :Ένα εστιατόριο που πραγματικά αξίζει να δοκιμάσετε... Εκπληκτικές γέυσεις σε έναν υπέροχο χώρο. Οι τιμές είναι φυσιολογικές για αυτό που προσφέρει γευστικά.
#
# Rating is :  5
#
#
#
#
# User is :IOSIF-ANASTASIO... S
#
# Review is :Πολύ ωραίο περιβάλλον. Τα πιάτα πολύ νόστιμα. Ειδικά η μανιταροσουπα,  καταπληκτική. Δυστυχώς δίνουν μεγαλύτερη προσοχή στο food styling με αποτέλεσμα να είναι πολύ μικρή η ποσότητα του φαγητού στο πιάτο. Όμως όλες οι γεύσεις πολύ ωραίες.
#
# Rating is :  3
#
#
#
#
# User is :anothergreekvisitor
#
# Review is :Έχουμε επισκεφτεί το εστιατόριο Μάνη Μάνη τρείς φορές και τις δύο πρώτες είχαμε μείνει παραπάνω από ευχαριστινενοι.
# Δυστυχώς, στην τελευταία μας επίσκεψη, διαπιστώσαμε πως κάτι έχει αλλάξει, η εξυπηρέτηση δεν ήταν στο επίπεδο που μας είχε συνηθίσει, ο χώρος μας φάνηκε λίγο"κουρασμένος" και το μενού...Περισσότερα
#
# Rating is :  3
#
#
#
#
# User is :manolisp698
#
# Review is :Κλασσικό μαγαζί με βαθιά νόστιμη κουζίνα, πολύ καλή επιλογή και συνδιασμό υλικών. Κρίμα που δεν έχει αυλή για καλοκαιρινή απόλαυση.
#
# Rating is :  4
#
#
#
#
# User is :LeonHarryP
#
# Review is :Προσεγμένο, καθαρό, άνετο και πολύ φιλόξενο εστιατόριο. Ωραίος χώρος. Φωτεινός. Γρήγορο σέρβις. Καλομαγειρεμένο φαγητό. Ωραία μανιταρόσουπα και με βαθιά γεύση. Η πίτα ημέρας νόστιμη, αλλά για την ποσότητα και το μέγεθος της ήταν λίγο ακριβή. Τα κυρίως πιάτα, νόστιμα και με έναν συνδιασμό μοντέρνου και...Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :Anastasios B
#
# Review is :Ένα ακριβό  εστιατόριο.  Προσεγμένο  αρκετά.  Οι γεύσεις  σε όλα  τα πιάτα  δένουν  απίστευτα,  όσο  κ αν στην αρχή  λες "αποκλείεται  να δένει  το χοιρινό  με το μήλο ". Οι μερίδες  είναι  ακριβώς ζυγισμένες. Όταν  θα σηκωθείς  από το τραπέζι  είσαι χορτάτο τόσο όσο.   Ωστόσο εμείς...Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :george_tsitsos
#
# Review is :Πήγαμε στο συγκεκριμένο εστιατόριο έχοντας ακούσει μόνο καλά λόγια. Δυστυχώς όμως το φαγητό που δοκιμάσαμε ήταν μέτριο. Παραγγείλαμε με αρκετή καθυστέρηση, την πίτα ημέρας (κρεμμυδόπιτα) η οποία είχε παρά πολύ ποσότητα τυριού και δεν καταλάβαινες καθόλου το κρεμμύδι. Έδειχνε να είναι έτοιμη από ώρα και...Περισσότερα
#
# Rating is :  3
#
#
#
#
# User is :26121965
#
# Review is :Κλείσαμε τραπέζι Σάββατο μεσημέρι,αν και τελικά είχε τραπέζια.Ότι παραγγείλαμε ήτανε πολύ νόστιμο.Κατ'αρχήν το σέρβις πολύ καλό και τα πιάτα ευφάνταστα και νόστιμα.Το χταπόδι με τη φάβα πολύ νόστιμο(είχε μια καταπληκτική σάλτσα.)και η πειραγμένη χωριάτικη σαλάτα πολύ ωραία επίσης,καταπληκτικό το τυλιχτό κανταίφι με τυρί που είχε...Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :Anna_S810817
#
# Review is :Ότι πήραμε εξαιρετικό όπως και η εξυπηρέτηση του προσωπικού! Ένα μαγαζί που διαφημίζει όχι μόνο την κουζίνα της Μάνης αλλά και την Αθήνα γενικότερα! Αλλά και ο χώρος καταπληκτικός! Σου ξυπνάει αναμνήσεις από την παλιά όμορφη Αθήνα!
#
# Rating is :  5
#
#
#
#
# User is :Ourania_Mavroutsou
#
# Review is :Άψογη εξυπηρέτηση. Όμορφο μέρος και το φαγητό πολύ νόστιμο. Υπέροχος συνδυασμός  γεύσεων με ιδιαίτερη έμφαση στη μανιάτικη και λακωνική κουζίνα!
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d695929-Reviews-or20-Mani_Mani-Athens_Attica.html#REVIEWS
# User is :V1809CT_
#
# Review is :Εξαίρετικες γεύσεις πολύ έξυπνα συνδυασμενες τις οποίες αξίζει σίγουρα να δοκιμάσεις.Επίσης ιδιαίτερος και ζεστός χώρος σε συνδυασμό με ένα φιλικό και πολύ εξυπηρετικό σερβις.Το συστήνω σίγουρα.
#
# Rating is :  5
#
#
#
#
# User is :Joker1908
#
# Review is :Το περιβάλλον είναι πολύ καλό, οι σερβιτόροι πολύ εξυπηρετικοί,οι πρώτες ύλες πολύ καλές,τώρα η ποσότητα των φαγητών δεν είναι και ότι καλύτερο στην φάβα ψάχναμε κυριολεκτικά το σύγκλινο...οι τιμές των πιάτων για αυτή την ποσότητα θα μπορούσαν να είναι χαμηλότερες...
#
# Rating is :  4
#
#
#
#
# User is :Giannis E
#
# Review is :Ελληνικές γεύσεις , ποιοτικά πιάτα , εντυπωσιακό service.Eνας γευστικός παράδεισος λίγα βήματα από την Ακρόπολη. Καλή λίστα κρασιών
#
# Rating is :  5
#
#
#
#
# User is :ge0rg222
#
# Review is :Πήγαμε μεσημέρι προς απόγευμα επειδή διαφημίζεται πολύ και γιατί η περιοχή έχει κυρίως τα κλασσικά τουριστικά. Με το που μπαίνουμε ζηταμε τραπέζι, σε ένα σχεδόν άδειο μαγαζί και με δυσκολία και ύφος 100 καρδιναλιων μας έδωσαν ένα. Παράγγειλαμε παραδοσιακά πιάτα που είδαμε πως ήταν μεν...Περισσότερα
#
# Rating is :  2
#
#
#
#
# User is :ANNA S
#
# Review is :Επισκεφτήκαμε το εστιατοριο βράδυ Σαββάτου.Στεγάζεται σε ένα ωραίο νεοκλασσικό κτίριο,χωρίς, όμως.εξωτερικό χώρο, οπότε αν είστε καπνιστές ή απλά σας αρέσει να κάθεστε έξω τα καλοκαιρινά βράδια,θα δυσαρεστηθείτε. Μέσα ο χώρος είναι ευχάριστος αλλά .λόγω στενότητος,  δεν προσφέρεται για ηχηρές συζητήσεις. Τρία άτομα,παραγγείλαμε ραβιόλες για ορεκτικό...Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :emilia1443
#
# Review is :Έχουμε επισκεφθεί το συγκεκριμένο εστιατόριο πολλές φορές και πάντα μείναμε ικανοποιημένοι από την ποιότητα και το σέρβις. Αυτοί τη φορά  δοκιμάσαμε  την σαλάτα απλά ελληνική εξαιρετική και πολύ πρωτότυπη και τη φάβα με συγκλινο Μάνης και καραμελωμένα κρεμμύδια τέλεια  και για κυρίως τις γκόγκες με...Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :ioannaa655
#
# Review is :Όμορφος και ζεστός χωρίς με λιτή και ήσυχη διακόσμηση. Εξυπηρετικό και ευγενικό σέρβις.. Ευπαρουσιαστα πιάτα και παράλληλα πανδαισία γεύσεων.!! Το επισκεφθηκαμε για μεσημεριανό γεύμα και μας ενθουσίασε τόσο η ατμόσφαιρα όσο και το φαγητό. Πήραμε πρασινη σαλάτα, γκογκες και ψαρονεφρι με πουρέ ρεβυθιων. Το επιδόρπιο...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :royla k
#
# Review is :Πολύ καλη περιποίηση, και πολύ ωραίες γεύσεις!τα πιάτα είχαν πολύ ωραία παρουσίαση!το προσωπικό εξαιρετικό και ευγενέστατο!
#
# Rating is :  5
#
#
#
#
# User is :F4754XQchristinan
#
# Review is :Το πάντρεμα της σύγχρονης άποψης με την παράδοση χαρακτηρίζει αυτό το εστιατόριο διαμαντάκι σε μια από τις πιο όμορφες γειτονιές της Αθήνας. Στην δεύτερη επίσκεψης μας επιβεβαίωσα την εικόνα που είχα πριν από 2 χρόνια που πρωτοπήγα. Όχι μόνο διατηρούν την ποιότητα αλλά βελτιώνονται και...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :Sotiris_Filippako
#
# Review is :Πρόκειται για ένα πολύ όμορφο χώρο, σε παλιό νεοκλασικό κτήριο που προσφέρει απλόχερα πολύ ποιοτικά πιάτα εκμεταλλεύμενο πλήρως υλικά και συνταγές που προσφέρει η ελληνική γη και η ελληνική παράδοση αντίστοιχα.
# Πολύ ευγενικό και άρτιο επαγγελματικά προσωπικό.
# Άξια αναφορας είναι η καθαριότητα του χώρου.
# Αξίζει...Περισσότερα
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d695929-Reviews-or30-Mani_Mani-Athens_Attica.html#REVIEWS
# User is :DimitrisT82
#
# Review is :Μόνος κουρασμένος από έντονη μέρα βρηκα καταφύγιο στο εξαιρετικό εστιατόριο. Κρύα σούπα, χειροποίητη πίτα με κρεμμύδι, μπιφτέκια και angus, μαγική πορτοκαλόπίτα με ροζέ κρασί. Ψωμί φρέσκο με ελιές Μάνης. Φανταστική εμπειρία, χωρίς περισσότερα λόγια ...
#
# Rating is :  5
#
#
#
#
# User is :780yannisb
#
# Review is :Θεωρώ από τα καλύτερα εστιατόρια της πόλης μας. Καταπληκτική κουζίνα που παντρεύει την παράδοση με τη μοντέρνα κουζίνα, γεύσεις που σε απογειώνουν και σε πολύ προσιτές τιμές. Αξίζει τον κόπο να το τιμήσετε.
#
# Rating is :  5
#
#
#
#
# User is :leeahs2015
#
# Review is :Ευγενέστατο προσωπικό, πολυ ιδιαίτερες γευσεις από τη Μάνη. Ικανοποιητικες σε μεγεθος μεριδες. Ενα θετικο ειναι η ευκολια στο παρκινγκ μιας και εχει απεναντι απο το μαγαζι στάθμευση με πληρωμη.
#
# Rating is :  5
#
#
#
#
# User is :maria0377
#
# Review is :Ο χώρος είναι ωραίος η ατμόσφαιρα είναι ευχάριστη... το κρασί πολύ ωραίο και το φαγητό νόστιμο.. οι μερίδες ικανοποιητικές
#
# Rating is :  4
#
#
#
#
# User is :thomasmarkosc
#
# Review is :Αρκετά καλό εστιατόριο. Το μέγεθος των μερίδων ικανοποιητικό. Παρήγγειλα τον κόκορα ο οποίος ήταν πολύ μαλακός και γευστικός αλλά θα ήθελα κάτι έξτρα για συνοδευτικό. Τα ορεκτικά (φάβα και κρεμμυδοπιττα) και η σαλάτα πολύ γευστικά και καλόμαγειρεμενα. Το σέρβις πολύ γρήγορο εξυπηρετικό και ευγενικό. Οι...Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :MariaKapageridou
#
# Review is :Το επισκέφτηκα με έναν φίλο μου και δοκιμάσαμε μια πράσινη σαλάτα ,ένα γιουβέτσι θαλασσινών ,μπιφτεκακια από βουβαλίσιο κρέας και μια πίτα με κρεμμύδια και τυρί .Μαζι με 4 ποτήρια κρασί και μια πορτοκαλοπιτα το κόστος στα 74 ευρώ .Η ποιότητα ήταν άριστη ,η εξυπηρέτηση άψογη...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :gspanou71
#
# Review is :Εξαιρετική κουζίνα με προσεγμένες πρώτες ύλες και φαντασία στην παρουσίαση, υπέροχη σαλάτα εποχής και εξαιρετικό κέρασμα. Η λίστα κρασιών καλή και το προσωπικό ευγενικό και ταχύτατο στην εξυπηρετηση
#
# Rating is :  4
#
#
#
#
# User is :976mariliap
#
# Review is :Ο τέλειος συνδιασμός ...φανταστικος χώρος αψογη εξυπηρέτηση αξιοπρεπέστατο φαγητό ..πολύ καλές τιμές .Θα ξαναερθουμε σύντομα
#
# Rating is :  5
#
#
#
#
# User is :Kadmos_Thebes
#
# Review is :Η κουζίνα ελληνική, αναδεικνύει τα εξαιρετικά υλικά. Από τα ορεκτικά, η τριλογία μελιτζανοσαλάτα, ταραμοσαλάτα και φάβα ήταν πάρα πολύ καλή. Οι δε ραβιόλες γεμιστές με τυρί και κόκκινη σάλτσα ήταν το κάτι άλλο. Την επόμενη φορά θα κοιτάξω καλύτερα το μενού να δω τι άλλα...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :580aggelikis
#
# Review is :Επιλεξαμε το συγκεκριμενο μαγαζι για να γιορτασουμε τα γενεθλια ενος αγαπημενου προσωπου. Ολα ηταν πολυ ωραια! ο χωρος θυμιζει παλιο αρχοντικο σπιτι, η διακοσμηση ηταν λιτη και το προσωπικο πολυ ευγενικο. Το μενου ηταν μεγαλο και οι μεριδες ικανοποιητικες. Οι τιμες ηταν λιγο ακριβες αλλα...Περισσότερα
#
# Rating is :  4
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d695929-Reviews-or40-Mani_Mani-Athens_Attica.html#REVIEWS
# User is :jmakrigiannis
#
# Review is :Ευχάριστη ατμόσφαιρα, καλή εξυπηρέτηση, λογικές τιμές και ενδιαφέρον φαγητό. Με ιδιαίτερες γεύσεις λόγω Μάνης και μπερδεμένων γεύσεων, αλλά καλό.
#
# Rating is :  4
#
#
#
#
# User is :986xarisb
#
# Review is :Πολύ καλό φαγητό, ποιοτικό και σε πολύ καλές τιμές. Δίπλα στην Ακρόπολη. Το προσωπικό είναι πολύ εξυπηρετικο.
#
# Rating is :  5
#
#
#
#
# User is :am37
#
# Review is :Πολύ νόστιμα φαγητά με καλή εξυπηρέτηση ! υπέροχο το χοιρινό με σέλινο! 50 -60 € το ζευγάρι μαζί με μπουκάλι κρασί
#
# Rating is :  5
#
#
#
#
# User is :mapapa2000
#
# Review is :Αρκετά καλο το φαγητο νόστιμο, τιμια πιατα, η σαλάτα μέτρια, το κρασί τους καλο για την τιμη μου, το προσωπικό ευγενεστατο. Ο χωρος ομως βρε παιδι μου εντελως αδιαφορος καμια αισθητικη δυστυχως! Οι τουαλετες κατω του μετριου. Οι τιμες απο την αλλη τσιμπιμενες. Με τετοιες...Περισσότερα
#
# Rating is :  3
#
#
#
#
# User is :sotiriss668
#
# Review is :Δυσκολια στο παρκάρισμα στη γύρω περιοχή.
# Σκάλες να ανέβεις.
# Πρέπει να κάνεις κράτηση.παρολα αυτά χωρίς κράτηση έκαναν ότι μπορούσαν και μας βρήκαν τραπέζι.. .όμορφος χωρίς σε παλιο νεοκλασικό που θυμιζει Ελλάδα.τουαλετες πεντακαθαρες...φωτισμος σωστός αίθουσες καθαρές.. .
# Οποίο φαγητό κ να φάγαμε ήταν υπέροχο με ελληνικές...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :ΣΤΕΛΙΟΣ Τ
#
# Review is :Πολύ καλή επιλογη για φαγητό. Τα πιατα εξαιρετικά μαγειρεμένα κ το προσωπικό πολύ. Το περιβάλλον πολύ φιλικό
#
# Rating is :  4
#
#
#
#
# User is :Nikolaos K
#
# Review is :Στην πρόσφατη επίσκεψη μου στο συγκεκριμένο κατάστημα έμεινα πάρα πολύ ευχαριστημένος. Ένας χώρος με λίγα τραπέζια, χωρίς ενοχλητικό θόρυβο την ώρα που θέλεις να απολαύσεις το γεύμα σου. Το προσωπικό πολύ ευγενικο, άριστη εξυπηρέτηση και το ίδιο ισχύει και για τους πελάτες που δεν μιλούν...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :nikitasp2015
#
# Review is :Εξαιρετικό εστιατόριο με ελληνική μανιατικη κουζίνα.
# Πολύ όμορφος χώρος σε ένα παλαιό 2οροφο σπίτι.
# Άψογο σέρβις, εξαιρετικά πιάτα.
# Είμασταν 3, πήραμε μοναδική στραπατσαδα με συγκλινο και λουκάνικο σερβιρισμένη σε μανιάτικη πιτα, Ριζότο δημητριακών ποίημα, γευστικοτατα μπιφτεκακια με πιτουλες, δροσερη πράσινη σαλατα, πορτοκαλοπιτα με παγωτό για...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :angelosliontos
#
# Review is :Παρα πολυ καλες γευσεις, με ισορροπια κ φαντασια! Θυμισε Μανη στα πιατα του! Εξαιρετικο το ποτο μαστιχα που προσφερεται στο τελος! Ομορφος κ προσεγμενος χωρος!
#
# Rating is :  4
#
#
#
#
# User is :NinaT1523
#
# Review is :Επισκεφτήκαμε το μαγαζι με το dine in Athens και φάγαμε συγκεκριμένο μενού.
# Ήταν πολύ χορταστικό,νόστιμο και το προσωπικό ευγενεστατο.Συνδυάζει το παραδοσιακό με το gourmet..Εφαγα πρώτη φορά σαλάτα με φακές και ήταν πολύ ωραίος συνδυασμος υλικών.
#
# Rating is :  4
#
#
#
#
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d695929-Reviews-or50-Mani_Mani-Athens_Attica.html#REVIEWS
# User is :christinak779
#
# Review is :Φανταστικό εστιατόριο στο hip Κουκάκι. Ο χώρος είναι ζεστός και ιδανικός για τα κρύα μεσημέρια του χειμώνα. Το φαγητό ήταν υπέροχο και το σέρβις ευγενέστατο. Κορυφαίο πιάτο του μαγαζιού ο κόκκορας με χυλοπίτες και οι τσουχτές, μανιάτικα ζυμαρικά.
#
# Rating is :  5
#
#
#
#
# User is :thomimpat
#
# Review is :Δεν μπορείς να πεις κάτι λιγότερο από υπέροχο για αυτό το μαγαζί. Το φαγητό πεντανόστιμο και θα έλεγα και οικονομικό για αυτό που προσφέρει. Το προσωπικό ευγενέστατο και ο χώρος πολύ ζεστός.
#
# Rating is :  5
#
#
#
#
# User is :kostasgrn
#
# Review is :Στο Κουκάκι, πολύ κοντά στην Ακρόπολη. Στεγάζεται σε ενα όμορφο νεοκλασικό κτίριο. Περιβάλλον τέλειο. Ο'τι δοκιμάσαμε ήταν πολύ νόστιμο. Προσεγμένα πιάτα. Προσωπικό πολύ ευγενικό. Σίγουρα θα ξαναπάω.
#
# Rating is :  5
#
#
#
#
# User is :gastronomad16
#
# Review is :Το επισκεφθήκαμε στο πλαίσιο του Dine Athens χωρίς να έχουμε πάει άλλη φορά.
# Ο χώρος κάπως άνευρος χωρίς ζωντάνια, κάτι που γενικά δεν μου αρέσει στα εστιατόρια.
# Το σέρβις επαγγελματικό αν και όταν φύγαμε κανείς δεν μας χαιρέτισε ή ευχαρίστησε!
# Το φαγητό ήταν ικανοποιητικό από...Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :schrodingerscatt
#
# Review is :Πήγαμε μέσω dine Athens. Ο χώρος λιτός, ανοιχτόχρωμος σε προδιαθέτει θετικά. Είναι μάλλον μικρός αλλά δεν νιώθεις και αποπνικτικά. Το σέρβις πολύ καλό. Το φαγητό ποιοτικό και νόστιμο, ειδικά ο κόκορας ήταν άριστος. Και το γλυκό τους πολύ καλό. Ήταν μια ωραία εμπειρία και σίγουρα...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :Eleni S
#
# Review is :Προσεγμένος χώρος, εξαιρετική ατμόσφαιρα, ευγενικό προσωπικό πρόθυμο να σε εξυπηρετήσει, εξαιρετική παρουσίαση των πιάτων. Εξευγενισμένες γεύσεις με άρωμα Μάνης, θα πρότεινα περισσότερα παραδοσιακά Μανιάτικα πιάτα.
#
# Rating is :  4
#
#
#
#
# User is :Ariadni2019
#
# Review is :Όλα τα πιάτα που δοκιμάσαμε (ψαρόσουπα, καγιανάς, ραβιόλες,  μπιφτεκάκια black angus & παρφέ σοκολάτας) ήταν εξαιρετικά τόσο στη γεύση όσο και στην παρουσίαση. Οι μερίδες είναι χορταστικές! Το  σέρβις άψογο!
#
# Rating is :  5
#
#
#
#
# User is :tasosv698
#
# Review is :Ο χώρος πανέμορφος, οι γεύσεις μοναδικές, η ποιότητα μοναδική, ποσότητα τόση όσο χρειάζεται, τιμές κανονικές, και το σέρβις Μοναδικό. Θα ξαναπαμε σίγουρα .!!!
#
# Rating is :  5
#
#
#
#
# User is :maniato
#
# Review is :Υπέροχο φαγητό , όμορφος κ προσεγμένος χώρος με ευγενεστατο προσωπικό .Όλα τα πιάτα που δοκιμάσαμε μας τα πρόσφεραν σε μια διαφορετική πεντανόστιμη εκδοχή .
#
# Rating is :  4
#
#
#
#
# User is :chriskarn
#
# Review is :Η πίτα της ημέρας (σπανακόπιτα), Καγιανάς και τα κυρίως (χυλόπιτες με κόκορα και χοιρινό με σέλινο) ήταν εξαιρετικά. Η αποθέωση όμως ήταν ο χαλβάς. Δοκιμάστε τον οπωσδήποτε.
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d695929-Reviews-or60-Mani_Mani-Athens_Attica.html#REVIEWS
# User is :M9950PM_
#
# Review is :Παραδοσιακές γεύσεις της Μάνης, όπως δεν τις έχετε φανταστεί.
# Πολύ γευστικά πιάτα, με ποιοτικά υλικά.
# Ήσυχο και ζεστό περιβάλλον. Πολύ καλή εξυπηρέτηση, με τους σερβιτόρους πολύ ευγενικούς και φιλικούς. Συστήνεται ανεπιφύλακτα. Μην ξεχάσετε να κάνετε κράτηση.
#
# Rating is :  5
#
#
#
#
# User is :V1809CT_
#
# Review is :Γρηγορο σερβις,τα πιατα προσεγμενα με ιδιαιτερη γευση.Αξιζει σιγουρα να πας,το συστινω ανεπιφυλακτα!
#
# Rating is :  5
#
#
#
#
# User is :adamantios78
#
# Review is :Καθαρές, αυθεντικές και υπέροχες γεύσεις πολύ καλό και ζεστό το σέρβις... Συγχαρητήρια γιατί αποδεικνύετε ότι η Γαστρονομία είναι μνήμες και δημιουργια
#
# Rating is :  5
#
#
#
#
# User is :oneiro1979
#
# Review is :Το καλύτερο εστιατόριο στο νομό Αττικής!Υπέροχες γεύσεις Πελοποννήσου και όχι μόνο!Υπέροχος διαμορφωμένος χώρος άψογη εξυπηρέτηση!Θα επιστρέψουμε σύντομα και θα το συστήσουμε και σε φίλους!Πολλά συγχαρητήρια στους ιδιοκτήτες και το σεφ!
#
# Rating is :  5
#
#
#
#
# User is :Thalia K
#
# Review is :Σ' έναν όμορφα διακοσμημένο χώρο, στον πρώτο όροφο ενός διατηρητέου σπιτιού, η φιλοξενία με τη νοστιμιά συμβαδίζουν. Εκπληκτικά πιάτα βασισμένα στις μανιάτικες σπεσιαλιτέ, όπως οι τραβηχτές και οι τσουχτές, αλλά και άλλα από την Πελοποννησιακή και όχι μόνο κουζίνα εντυπωσιάζουν με τη γεύση και την...Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :JIMISLAND
#
# Review is :Παρά το γεγονός ότι ήμουν διστακτικός λόγω λίγων κακών κριτικών, θα πω ότι ήταν απλά καταπληκτικά όλα τα πιάτα, από starterάκια μέχρι κυρίως πιάτα.
# Αξίζει έστω μια επίσκεψη και για την όμορφη γραφική περιοχή όπου το μαγαζί εδράζεται.
# Καλή όρεξη σε όλους σας.
#
# Rating is :  5
#
#
#
#
# User is :EvAKR
#
# Review is :Φαγητο κατω του μετρίου έβαλα μέτριο γιατι το προσωπικο ειναι εξαιρετικό. Γρήγορο φιλικό.
# Ριζότο μανιταριών μέτριο στη γευση οπως κ στη θερμοκρασία. Η θερμοκρασία σε ενα πιάτο να το φας ζεστο παιζει σημαντικο ρολο σε ενα μαγαζί κ ειδικά οταν εχει μονο δυο τραπέζια, αν...Περισσότερα
#
# Rating is :  3
#
#
#
#
# User is :169fanip
#
# Review is :Το καλύτερο στο είδος του.
# Καταπληκτικο ελληνικό φαγητό με εξαιρετικη παρουσίαση και καλό σέρβις. Το συνιστώ ανεπιφύλακτα
#
# Rating is :  5
#
#
#
#
# User is :anastasiost444
#
# Review is :Οικείο περιβάλλον, ποικιλία από εδέσματα και κρασιά.
# Λογικές τιμές,άριστο σέρβις.
# Η παρέα μας ηταν 5 άτομα και όλοι
# πολύ θα θέλαμε να ξαναπάμε.
#
# Rating is :  5
#
#
#
#
# User is :Lavria P
#
# Review is :πιάτα με παραδοσιακά υλικά και εκπληκτικούς συνδυασμούς γεύσεων και αρωμάτων.
# Κρασιά άριστης ποιότητας και σε πολύ καλές τιμές.
#
# Rating is :  5
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d695929-Reviews-or70-Mani_Mani-Athens_Attica.html#REVIEWS
# User is :Despina A
#
# Review is :Μεσογειακά πιάτα, εξαιρετική ποιότητα πρώτης ύλης, πολύ καλό σέρβις και πολύ καλές τιμές.  Μπράβο σε όλους.
#
# Rating is :  5
#
#
#
#
# User is :GeorgeDasoulas81
#
# Review is :Μετά από παρότρυνση συνεργάτη μου που έχει επισκεφτεί αρκετές φορές το μαγαζί το επισκέφτηκα για επαγγελματικούς σκοπούς πρόσφατα! Ένα πράγμα θα πω....θα πάω σύντομα με την οικογένεια μου για να απολαύσω υπέροχο φαγητό!
# Το μαγαζί είναι μικρό αλλά όμορφο μέσα και το προσωπικό πολύ καλό...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :leonidasp491
#
# Review is :Πολύ νόστιμα και ευρηματικά πιάτα σε ένα ωραίο περιβάλλον και ευχάριστο προσωπικό.  Οι σαλάτες πολύ αξιόλογες και τα ορεκτικά ένα κι ένα.
#
# Rating is :  4
#
#
#
#
# User is :christinama_1_1
#
# Review is :Αυτό που σε κερδίζει περισσότερο είναι το περιβάλλον! Μας άφησαν να περιμένουμε αρκετή ώρα πριν να πάμε στο τραπέζι μας ενώ είχαν βρει την κράτηση μας. Καλές γεύσεις με λίγο τσιμπημένη τιμή. Κεραστήκαμε ποτό μαστίχα στο τέλος! Παρ'όλο που ήταν καλή επιλογή δε θα το...Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :chris m
#
# Review is :Κυριακή μεσημέρι χωρίς κράτηση με τέλεια και γρήγορη εξυπηρέτηση...σαλάτα με φακές και σύγκλινο, μακαρόνια με χοιρινό και μανιτάρια, κόκορα γεμιστό και γλυκό που όποιο και να πάρεις αξίζει να αφήσεις χώρο! Δοκιμάστε και τη μπύρα sparta της περιοχής...Μπράβο! Θα τα ξαναπούμε σύντομα😉
#
# Rating is :  5
#
#
#
#
# User is :Georgia P
#
# Review is :Οπότε πάω δεν ξέρω τι να πρωτοδιαλεξω! Εξαιρετικές σαλάτες, ορεκτικά και κυρίως πιάτα!! Όσο για τα γλυκα... κρατήστε χώρο  στο στομάχι σας για να δοκιμάστε σίγουρα!
#
# Rating is :  5
#
#
#
#
# User is :GioTsi
#
# Review is :Πολύ καλή επιλογή για φαγητό στο κέντρο! Πεντανόστιμα πιάτα, ωραίο περιβάλλον, πλην όμως ελαφρά ακριβό. Συνιστώ ανεπιφύλακτα τη σαλάτα με τις φακές και το σύγκλινο.
#
# Rating is :  4
#
#
#
#
# User is :dikastis
#
# Review is :Εξαιρετικός χώρος απλός για ένα επαγγελματικό γεύμα και μη ! Πλ καλες γεύσεις κ γενναιόδωρες μερίδες πολύ καλό στις τιμές του σίγουρα θα ξαναπάμε !
#
# Rating is :  5
#
#
#
#
# User is :ilogios
#
# Review is :Όταν χτίζει κανείς την φήμη του στο χώρο της δουλειάς χρειάζεται χρόνο για ένα καλό αποτέλεσμα. Όταν έρθει αυτό το πολυπόθητο σημείο της αναγνώρισης, τότε όπως στην περίπτωση του Μάνη Μάνη χρειάζεται να κάνεις κράτηση οπωσδήποτε. Το λιτό και προσεγμένο περιβάλλον συνδυάζεται απόλυτα με τις...Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :dimtziona
#
# Review is :Υπέροχο φαγητό... αριστο service...ζεστή ατμόσφαιρα με χαλαρή μουσική!!
# Παραμένει αγαπημένος προορισμός!
# Μη χάσετε το φιλέτο ψαριού με δροσερή καλοκαιρινή σαλάτα, το μοσχαρίσιο συκωτάκι με παντζάρι, και οπωσδήποτε αφήστε ...χώρο για γλυκό!!!
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d695929-Reviews-or80-Mani_Mani-Athens_Attica.html#REVIEWS
# User is :Natalia K
#
# Review is :Ενθουσιαστήκαμε όλοι! Καταπληκτικό φαγητό. Υπέροχα γλυκά και μοναδικός χώρος. Θα το επισκεφτούμε σίγουρα ξανά.
#
# Rating is :  5
#
#
#
#
# User is :panagis83
#
# Review is :Ο χώρος του αναπαλαιωμένου αρχοντικού και η  απαλή μουσική με το που μπαινεις σε προδιαθέτουν για μια υπέροχη εμπειρία. Το μενου υπέροχο οτι και να διαλέξεις, μανιταροσουπα, σαλατα αλα ελληνικά με τα λαχταριστά τυροπιτακια καταϊφιού, στις φωτογραφιες θα δειτε πανσετακια με πουρε και σαλτσα τζιντζερ...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :stavross987
#
# Review is :Πράγματι δεν υπερβάλω .
#  Ένας όμορφος αναπαλαιομένος  χώρος σε κεντρίζει με το που μπαίνεις στη είσοδο κάτω. Εξαιρετικό φαγητό , πολύ καλό σέρβις .
# Το συστήνω και θα ξαναπάω
#
# Rating is :  5
#
#
#
#
# User is :Panagiota T
#
# Review is :Είχα καιρό να φαω τόσο νόστιμα πιάτα! Αγνά παραδοσιακά υλικά από τη Μάνη μαγειρεμένα με σύγχρονες τεχνικές που δίνουν ένα άριστο αποτέλεσμα και ικανοποιούν ακόμα και τον πιο απαιτητικό ουρανίσκο! Πολύ ευχάριστο περιβάλλον και ακαπνο. Ευγενεστατο προσωπικό,  γρήγορο σέρβις και τιμές λογικές. Τι άλλο να...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :giorgos_tsaf
#
# Review is :Ψάχνοντας εστιατόριο κοντά στο κέντρο μας πρότειναν αυτό!  Σταθήκαμε τυχερή καθώς βρήκαμε τραπέζι χωρίς κράτηση. Είναι αναγκαίο να κάνετε κρατηση. Το εστιατόριο υπέροχο.  Τα πιάτα γευστικά και ο συνδυασμός γεύσεων φοβερός! Ωραίες επιλογές κρασιού και σε ποτήρι. Λίγο ακριβά αλλά αξίζει να το δοκιμάσετε !!
#
# Rating is :  5
#
#
#
#
# User is :Vasilis A
#
# Review is :Τετάρτη βράδυ παρέα 12 ατόμων .Ελληνες και ξένοι .Το μαγαζί το διάλεξα εγώ λόγω καλών κριτικών και συστάσεων .Το μετάνιωσα πολύ .Πρώτον η εξυπηρέτηση πολύ κακή .Μετά από 15 λεπτά ήρθαν να μας ρωτήσουν για ποτά .Γενικά το προσωπικό χωρίς συνεννόηση και πολύ αργό .Η...Περισσότερα
#
# Rating is :  2
#
#
#
#
# User is :helenBN
#
# Review is :Όμορφα πιάτα, ωραίες γεύσεις, υλικά και αρώματα Μάνης στο κέντρο της Αθήνας!
# Δοκιμάσαμε τον γεμιστό κόκοραα, το συκώτι και τα φιλετίνια! Μας άρεσαν όλα!
# Επίσης, γρήγορο service!
#
# Rating is :  4
#
#
#
#
# User is :pennyss2004
#
# Review is :Πολύ ωραίος χώρος και πολύ καλό σέρβις! Πολύ ωραία τα πουγκιά (ορεκτικά) και εξαιρετικά τα κυρίως (ψαρονέφρι, κόκκορας, μακαρούνες)! Μπράβο τους!!!
#
# Rating is :  5
#
#
#
#
# User is :mayranan
#
# Review is :Πολύ ωραίες γεύσεις όμορφα πιάτα και πολύ καλή εξυπηρέτηση. Ένας χώρος ελκυστικός με προσεγμένη διακόσμηση.  Δεν βάζω 5 αστέρια για τον λόγο του ότι το προσωπικό δεν γνωρίζει τις χρονολογίες των κρασιών που διαθέτει το κατάστημα και γενικά γύρω από αυτό επιδέχεται βελτίωση. Φυσικά και...Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :MariaKhg
#
# Review is :Όμορφος κ ζεστός χώρος,αν κ γεμάτα τα τραπέζια δεν είχε φασαρια(ίσως κ να οφείλεται στους ξένους τουρίστες)!Το φαγητό εξαιρετικό!Δοκιμαστε οπωσδήποτε τον κόκορα γεμιστό με μανιτάρια κ πεκορινο Αμφιλοχίας σε σπασμένη πατάτα με καπνιστό χοιρινό κ πράσο!Επισης πολυ καλο το οσομπουκο κ η σαλάτα Μανη Μανη!Για...Περισσότερα
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d695929-Reviews-or90-Mani_Mani-Athens_Attica.html#REVIEWS
# User is :mariaE1402LV
#
# Review is :Μικρό μενού με εξαιρετικά πιάτα κ υπέροχα επιδόρπια!  Επιλέξαμε το δικό τους κόκκινο κρασί κ ήταν υπέροχο. Σχετικά με τις τιμές , best value for money!
#
# Rating is :  5
#
#
#
#
# User is :ELENI1956
#
# Review is :Μια γυναικοπαρέα που αρέσκεται στο καλό φαγητ'ο βρεθήκαμε στο εστιατόριο αυτό.Το φαγητό  ήταν  εξαιρετικό όλα τα πιάτα πο δοκιμάσαμε με έξοχο κοκορα , μπιφτεκάκια, ρυζότο κλπ.Το σερβισ αψογο και φιλικό .Ητιμή ανάλογη των φαγητών και της παρουσιασης τους΄.Θα ξαναπάω σίγουρα.Εύκολη πρόσβαση.
#
# Rating is :  5
#
#
#
#
# User is :georgebkl
#
# Review is :Το περιβάλλον είναι συμπαθητικό και το φαγητο  λίγο άνω του μετρίου. Με 2-3 ορεκτικά ένα οχι πολυ ακριβό κρασί και χωρις γλυκό πληρωσαμε 40€ / άτομο. Νομίζω ότι το μενού χρειάζεται εμπλουτισμό κι ανανέωση.
#
# Rating is :  3
#
#
#
#
# User is :mikesA31SZ
#
# Review is :Εξαιρετική κουζίνα με όσες επιλογές πρέπει να έχει ένα μαγαζί χωρίς να κουράζει !εχω πάει τρεις φορές κ ότι έχω δοκιμάσει είναι πολύ νόστιμο και ξεχωριστό,δε μοιάζει με κανένα άλλο μαγαζί στη κατηγορία των τιμών που παίζει έχεις την αίσθηση ότι τρως σε ένα πολύ...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :586constantinosp
#
# Review is :Ένα εξαιρετικό εστιατόριο στο Κουκάκι. Ο χώρος λιτός και προσεγμένος, με άψογο σέρβις και υπέροχο φαγητό ! Σας το συστήνω ανεπιφύλακτα !!
#
# Rating is :  5
#
#
#
#
# User is :PatrickSimo
#
# Review is :Η ελληνική δημιουργική κουζίνα στα καλύτερα της. Τιμά τα παραδοσιακά προϊόντα και τα αναδυκνύει με μεράκι και σεβασμό. Είναι από τα εστιατόρια που μπορείς να έχεις πολύ καλό φαγητό, να επιλέξεις από αξιόλογη λίστα κρασιών σε λογικές τιμές.
#
# Rating is :  5
#
#
#
#
# User is :937anastasiad
#
# Review is :Τέλεια επιλογή!! Το λατρεύω αυτό το εστιατόριο! Πάω το λιγότερο 2 φορές το χρόνο από τότε που το ανακάλυψα και παρατηρώ με χαρά πως τόσα χρόνια..δεν έχει χάσει ούτε το ελάχιστο από την εξαιρετική του ποιότητα..και σε γευστικό επίπεδο..και στο service..και στις τιμές..και στον χώρο!...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :sotmar
#
# Review is :Μόνο θετικά μπορώ να πω για το μαγαζί.  Οι γεύσεις σε συναρπάζουν υα ιατα είναι το ένα καλύτερο από το αλλο και το προσωπικό έχει επαγγελματισμό όσο σε λίγα εστιατόρια. Ωραίος χώρος και σίγουρα θα το επισκεφτώ ξανά.
#
# Rating is :  4
#
#
#
#
# User is :ExtremeGreece
#
# Review is :Φιλικότατο προσωπικό. Ωραίες Ελληνικές γευσεις. Καλοστημενα πιάτα. Καλό σημείο για να πας με τα πόδια το βραδάκι, συνδυάζοντας βόλτα με καλό φαγητό και ωραίο κόκκινο κρασί!
#
# Rating is :  5
#
#
#
#
# User is :nikolaos90
#
# Review is :Ωραίος χώρος ωραίο κτήριο λιτό νεοκλασικό.Εξαιρετικο φαγητό παραδοσιακό και δημιουργικό συνάμα πολύ ωραίος ο κόκορας και το αρνί απο τα κυρίως.Οικονομικες και σχετικά πολλές επιλογές σε κρασιά,τέλος το σέρβις ήταν εξυπηρετικό φιλικό και γρήγορο.Σιγουρα θα ξαναπάω στο μέλλον
#
# Rating is :  5
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d695929-Reviews-or100-Mani_Mani-Athens_Attica.html#REVIEWS
# User is :iosifv2014
#
# Review is :Ο χώρος, ένα παλαιό αρχοντικό, με τραπέζια άνετα και καλή ηχομόνωση. Τα πιάτα εύγευστα και με καλή παρουσίαση. Το service πολύ καλό και γρήγορο. Οι τιμές λογικές γι'αυτό  που προσφέρει.
#
# Rating is :  5
#
#
#
#
# User is :koukr
#
# Review is :Όλες οι γεύσεις ήταν καλές, και πολύ καλά τα κρασιά τους. Τα παιδιά στο service σα να βαριόντουσαν λίγο, πολύς θόρυβος να βγαίνει από την κουζίνα, και ένα εκκοφαντικό φτέρνισμα που βγήκε από την κουζίνα μας ξύπνησε κανονικά. Μακάρι να γίνει πιο επαγγελματικό το σερβις...Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :Katerina N
#
# Review is :Ο χώρος όμορφος και ζεστός , τα πιάτα ευφάνταστα, οι μερίδες ικανοποιητικές και οι τιμές λογικές γι αυτό που προσφέρει το εστιατόριο. Δίκαια θεωρείται ένα από τα καλύτερα εστιατόρια στο είδος του.
# Το μοναδικό πρόβλημα είναι το parking που είναι ιδιαίτερα δύσκολο στην περιοχή.
#
# Rating is :  5
#
#
#
#
# User is :ANEMWNH
#
# Review is :Ζεστό κ φιλικό περιβάλλον άψογο σέρβις γευστικά πιάτα κ άψογη εμφάνιση.
# Σαλάτες εξαιρετικές γκουρμέ γεύσεις και τιμές.
#
# Rating is :  5
#
#
#
#
# User is :Elpidayoga
#
# Review is :Σχέση ποιότητας τιμής στο 100%
# Άψογο σέρβις και πολύ νόστιμα πιάτα
# Ωραίο και ζεστό περιβάλλον
# Το συνιστώ ανεπιφύλακτα!
#
# Rating is :  5
#
#
#
#
# User is :169fanip
#
# Review is :Πειραγμενες συνταγές Μάνης με πολύ ωραία παρουσίαση και καταπληκτική γεύση. Πολύ καλό σέρβις καλές τιμές σε  σχέση με την ποιότητα και τη παρουσίαση. Το μόνο που το αδικεί η τοποθεσία και ο χώρος που δεν είναι για καλοκαίρι.
#
# Rating is :  5
#
#
#
#
# User is :Dejkl70
#
# Review is :Έχουμε επισκεφτεί αρκετές φορές το Μανη Μανη!!!το πάντρεμα που έχουν κάνει με τα παραδοσιακα προϊόντα της Μάνης με την μοντέρνα κουζίνα μοναδικό συνεχίστε έτσι να μας εκπλήσετε κάθε φορά!!!
#
# Rating is :  5
#
#
#
#
# User is :n1kkos
#
# Review is :ότι και να πει κανείς για το ΜΑΝΗΜΑΝΗ ειναι λίγο. Ο σεφ δημιουργεί με υλικά της μαμάς πιάτα που πρώτη φορά τρως με αυτό τον τρόπο (πχ κόκκορας γεμιστός με μανητάρια, φρικασέ). Το μενού με νέες προσθήκες, ο χώρος καλαίσθητος και προσεγμένος, το προσωπικό άψογο....Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :AthanasiaGreece
#
# Review is :Σε παλιό νεοκλασικό σπίτι ένα εστιατόριο ελληνικής κουζίνας (επιρροές από Μάνη) που μπορείς άνετα να φέρεις ξένους φίλους να φιλέψεις... Αρκεί να υπολογίσεις γενναίο ποσό, αφού είναι ακριβό τελικά!
# Δοκιμάσαμε λευκή ταραμοσαλάτα (σε τιμή άουτς 8€), χταπόδι με φάβα (14€), σαλάτα Μάνη-Μάνη (πράσινη με μανούρι...Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :notaf313
#
# Review is :Ενα νεοκλασσικό κτίριο με άρωμα παρελθόντος είναι ο χώρος που στεγάζει τις νοστιμιές της Μάνης. Ευγενικό γρήγορο εξυπηρετικό προσωπικό, σωστό service, ψαγμένες γεύσεις, πιάτα με φαντασία! Μια σωστή επιλογή !!!!!!
#
# Rating is :  4
#
#
#
#
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d695929-Reviews-or110-Mani_Mani-Athens_Attica.html#REVIEWS
# User is :sotirisme888
#
# Review is :Καταπληκτικό Φαγητό Σε Πολύ Καλή Τιμή!!!! Ο Χώρος Χρειάζεται Μια Πινελιά.... Και Θα Προτιμούσα Να Είχε Και Μουσική!!!! Όλα Τα Πιάτα Ήταν Υπέροχα!!!! 😉
#
# Rating is :  3
#
#
#
#
# User is :evcr65
#
# Review is :Όλα πολύ μέτρια, τίποτα το ιδιαίτερο, εκτός από την καλή παρουσίαση των πιάτων. Ο χώρος είναι κάπως «άχαρος» και στενός. Έχει όμως πολύ καλό σέρβις, το προσωπικό είναι άψογο.
#
# Rating is :  3
#
#
#
#
# User is :Tonia M
#
# Review is :Υπεροχο φαγητο, υπεροχες πρωτες ύλες, χώρος καλοφτιαγμενος σερβις πολυ καλο...γεύσεις φοβέρες ,μπερδεμένες ...απλα τέλεια.....
#
# Rating is :  5
#
#
#
#
# User is :devagelou
#
# Review is :Έχουμε επισκεφτεί αρκετές φορές το εστιατόριο. Την τελευταία φορά δεν μείναμε τόσο ικανοποιημένοι όσο στο παρελθόν. Ο χώρος πολύ καλός σε ένα νεοκλασσικό στο Κουκάκι. Το εστιατόριο πολύ καθαρό. Οι γεύσεις του όμως δεν συμβαδίζουν τον τελικό λογαριασμό και την φήμη του.
#
# Rating is :  3
#
#
#
#
# User is :814harrisp
#
# Review is :Το επισκεφθήκαμε Κυριακή μεσημέρι, μετά από μία ξενάγηση στο Μουσείο της Ακρόπολης, μια και απέχει μόλις πέντε λεπτά με τα πόδια. Η εξυπηρέτηση ήταν άψογη, η δε κουζίνα πολύ καλή. Μας ικανοποίησαν ιδιαίτερα 1) τα πουγκιά με μανούρι, παστουρμά, κατσικίσιο τυρί, πιπεριά Φλωρίνης, δεντρολίβανο και...Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :helenloverdou
#
# Review is :Το φαγητο ειναι πραγματικα καλο! Δοκιμασαμε τη σαλατα με φακες, τα πουγκακια (αποκαλυψη), ψαρονεφρι με συκα (ελιωνε στο στομα) και την πιο ωραια πορτοκαλοπιτα που εφαγα ποτε. Μην πατε χωρις κρατηση & υπολογιστε 25 ευρω ανα ατομο.
#
# Rating is :  4
#
#
#
#
# User is :mariageorgakakou
#
# Review is :Ήθελα χρόνια να πάω στο Μάνη-Μάνη λόγω καταγωγής και για το ότι είχα διαβάσει καλές κριτικές.
# Ο χώρος δεν θύμιζε ούτε στο ελάχιστο Μάνη, το σέρβις, χωρίς να έχει καθόλου κόσμο, πολύ αργό και το φαγητό πολύ μέτριο για την τιμή του. Επίσης απαράδεκτο ένα...Περισσότερα
#
# Rating is :  2
#
#
#
#
# User is :Elena C
#
# Review is :Εξαιρετικό εστιατόριο, με υπέροχο περιβάλλον, άψογο service και καταπληκτικό μενού με προσιτές τιμές ! Το συστήνω ανεπιφύλακτα !
#
# Rating is :  5
#
#
#
#
# User is :Mariangela R
#
# Review is :Εξαιρετικές ελληνικές γεύσεις! Καλύτερα πιάτα η σαλάτα με τις φακές, οι τσουχτές, και τα μπιφτεκάκια με τις πιτούλες και τη sauce μελιτζάνας. Τα γλυκά πολύ ωραία. Tο σέρβις εξαιρετικό και η ατμόσφαιρα επίσης.
#
# Rating is :  5
#
#
#
#
# User is :Stel A
#
# Review is :Επισκέφτηκα το μαγαζί μετά απο καλές κριτικές. Το φαγητό ήταν γευστικοτατο και η εξυπηρέτηση άψογη. Τα αρνητικά: ακριβές τιμές, αδυναμία πρόσβασης αμεα
#
# Rating is :  4
#
#
#
#
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d695929-Reviews-or120-Mani_Mani-Athens_Attica.html#REVIEWS
# User is :Ka7781
#
# Review is :Από τα εστιατόρια που καταλαβαίνεις ότι σέβονται την πρώτη ύλη και λατρεύουν να δημιουργούν. Μοναδικής γεύσης και ποιότητας. Δίνει μια νεα ματια στην παράδοση. Ότι και να φάγαμε ήταν απίστευτα νόστιμο. Από την σαλατα φακές με σύγκλινο και πορτοκαλι έως την ελληνική ματια στην καρμπονάρα...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :Scamfoghter S
#
# Review is :Το σέρβις ειναι φιλικό και προσεγμένο και το φαγητό δημιουργείται με πολυ καλα υλικά και ειναι εξαιρετικά  φρέσκο. Ο Καγιανάς ειναι ένα  πολυ νόστιμο πιάτο και τα ζυμαρικά με τα θαλασσινά ήταν εξαιρετικά ! Οι τιμές ειναι πολυ φυσιολογικές σε σχεση με την ποιότητα .
#
# Rating is :  5
#
#
#
#
# User is :Nikos K
#
# Review is :Πολύ ωραία και ψαγμένα πιάτα, καλή ποιότητα και μερίδες, λογικές τιμές και ευγενέστατο σέρβις. Πρέπει να κλείσετε τραπέζι γιατί έχει αρκετούς ξένους και γεμίζει.
#
# Rating is :  5
#
#
#
#
# User is :maria g
#
# Review is :Μας άρεσε ιδιαίτερα το φαγητό, ο χώρος και η διακόσμησή του, αλλά και η πολύ φιλική εξυπηρέτηση από το προσωπικό. Από τα πιάτα που δοκιμάσαμε θα ήθελα μόνο λίγη παραπάνω τρούφα στο κριθαρώτο. Τα υπόλοιπα πολύ καλά, με το λαδάκι που προσφέρετε στην αρχή εξαιρετικό!!!!
#
# Rating is :  4
#
#
#
#
# User is :kal_mou
#
# Review is :Ωραίος φιλικός χώρος..! Το προσωπικό ευγενικό κ εξυπηρετικό..! Όσα πιάτα δοκιμάσαμε ήταν νόστιμα..! Και για την περιοχή μια χαρά οι τιμές..!
#
# Rating is :  5
#
#
#
#
# User is :stratosk1
#
# Review is :εχοντας παει αρκετες φορες γιατι το θεωρω ενα πολυ καλο εστιατορειο με ενδιαφερουσες γευσεις νομιζω οτι εφτασε η στιγμη για μερικες αλλαγες στο menu.επισης αυτη την φορα το service  ηταν λιγο ανοργανωτο χωρις προφανη λογο.γενικα  φαγητο καλο ανετο περιβαλλον .και μια ακομη καλοπροαιρετη παρατηρηση το...Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :ParEvi
#
# Review is :Πολυ ωραιος χωρος σε παλιο νεοκλασικο σπιτι, αρκετα φιλικο κ εξυπηρετικο προσωπικο! Πολυ ωραιο το κριθαροτο!! Στις τιμες λιγο ακριβο!
#
# Rating is :  5
#
#
#
#
# User is :937anastasiad
#
# Review is :Έχω επισκεφτεί παααάρα πολλές φορές το Μάνη Μάνη και ο λόγος είναι το ανεπανάληπτο φαγητό τους! Όλες τις φορές έφυγα ενθουσιασμένη! Γκουρμέ παραδοσιακή κουζίνα, έξοχη λίστα ποτών, άνετο, ήσυχο και φιλικό περιβάλλον με άριστο προσωπικό! Τέλος...για την άριστη ποιότητά του, είναι πολύ οικονομικό!!!
#
# Rating is :  5
#
#
#
#
# User is :C3732NOmichaelg
#
# Review is :Το λατρεύω αυτό το εστιατόριο!
# Σε όλα του είναι τέλειο.
# Φαγητό, σέρβις, τιμές.
# Δεν βρίσκω ούτε ένα μειονέκτημα.
# Ο χώρος είναι πολύ καλός. Το μόνο μικρό πρόβλημα είναι οι σκάλες. Χαίρομαι πολύ όταν πάω και θα ξαναπάω πάλι και πάλι!!
#
# Rating is :  5
#
#
#
#
# User is :GEORGIOS M
#
# Review is :Αξίζει πραγματικά να επισκεφθεί κανείς αυτό το εστιατόριο.Στο ανερχόμενο Κουκάκι το εν λόγω εστιατόριο διαφημίζει το καλό ελληνικό φαγητό και την Μάνη και είμαι ιδιαίτερα περήφανος γιατί είναι και η καταγωγή μου.Το επισκεφθήκαμε Δευτέρα βράδυ με την σύζυγο στην γιορτή της . Όμορφα λιτό περιβάλλον...Περισσότερα
#
# Rating is :  5
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d695929-Reviews-or130-Mani_Mani-Athens_Attica.html#REVIEWS
# User is :petrosk2863
#
# Review is :Το εστιατόριο είναι ιδιαίτερο.Παλιο κτήριο νεοκλασικό με μειονέκτημα η δημιουργία θορύβου από τους θαμώνες. Ωραίες μεσογειακές γεύσεις με αρκετή φαντασία του μάγειρα. Στα συν του εστιατορίου το ότι δεν επιτρέπεται το κάπνισμα.
#
# Rating is :  4
#
#
#
#
# User is :koukost
#
# Review is :Κοντά στο μουσείο της Ακρόπολης και εύκολα προσβάσιμο.Υπέροχα πιάτα εμπνευσμένα από την μανιάτικη κουζίνα. Πήραμε μακαρούνες με φιλέτο χοιρινό, φακές με σύγκλινο, ψαρονέφρι με κατσικίσιο τυρί και ήταν όλα εξαιρετικά. Το περιβάλλον είναι πολύ προσεγμένο  και ζεστό. Το προσωπικό ευγενικό και φιλικό.
#
# Rating is :  5
#
#
#
#
# User is :sakispv
#
# Review is :Με  διακόσμηση και κάποιες μοντέρνες πινελιές δημιουργεί την ιδανική ατμόσφαιρα για να απολαύσετε το γεύμα σας. ΜΕ τραπέζι δίπλα σε παράθυρα που είναι κ πιο φωτεινά.
#
# Rating is :  4
#
#
#
#
# User is :FALLITSA
#
# Review is :Ιδανικη επιλογη για φαγητο στο κεντρο, ειδικα αν συνδυασθει με βολτα στην Ακροπολη και την Πλακα.Ο χωρος καλαισθητος και ευχαριστος.Τα τραπεζια ανετα και σε καλη αποσταση μεταξυ τους. Το προσωπικο ευγενικο και εξυπηρετικο. Μας εκανε πολυ θετικη εντυπωση ο καλος ρυθμος με τον οποιο ερχονταν...Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :Catherine A
#
# Review is :Αν και πήγαμε για πρώτη φορά στο Μανημανη για εμάς δεν αποτέλεσε έκπληξη καθώς δεν είναι τυχαία η υψηλή του βαθμολογία.
# Δημιουργική κουζίνα: Αφεθήκαμε στα χέρια του προσωπικού οι οποίοι μας βοήθησαν πολύ με τα πιάτα. Φασολάκια μαυρομάτικα με γαύρο,  φακές με πορτοκάλι, ριζότο με...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :st_bi_2014
#
# Review is :Πολύ νόστιμες σαλάτες, με πολύ ωραία παρουσίαση των πιάτων και αρκετά χορταστικά! Πολύ φιλικό κι εξυπηρετικό το προσωπικό!
#
# Rating is :  5
#
#
#
#
# User is :Maria S
#
# Review is :Ότι και να πω, δεν μπορεί να περιγράψει το εστιατόριο. Μακράν από τα καλύτερα γεύματα που είχα ποτέ ! Είναι από τα μέρη που όλοι πρέπει να επισκεφτούν. Ο χώρος απλός , όμορφος και σου δημιουργεί μια ηρεμία που σε βοηθάει να απολαύσεις το φαγητό...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :elkalot
#
# Review is :Αν και γνώριζα την ύπαρξή του δεν το είχα επισκεφθεί ! Βλέποντας ότι αντέχει στο χρόνο και στις κρίσεις δύσκολων φίλων το γνώρισα και με εντυπωσίασε! Μενού λογικό σε αριθμό πιάτων , δοκιμάσαμε πολλά και όλα ήταν υπέροχα! Γρήγορο και έξυπνο σέρβις ,λογικότατες τιμές !!!...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :KOSTAS09
#
# Review is :Εξαιρετική Ατμόσφαιρα και φαγητό..Ιδανικό για δείπνο για δύο και όχι μόνο...Το φαγητό προσεγμένο, Ιδιαίτερες  γεύσεις από  Ελλάδα,τοπικά προιόντα που μου άρεσαν πολύ!! Κρασί εμφιαλωσης δικής του καταπληκτικό!!! Θα το επισκεφτώ ξανά σίγουρα!!!
#
# Rating is :  5
#
#
#
#
# User is :XATZ
#
# Review is :Το φαγητό ειναι καταπληκτικό  με ιδιαίτερες γεύσεις .Καλυτερα να δοκιμάσει κάποιος μικρές μπουκιές απο τα διαφορα πιάτα .Υπαρχει parking ακριβώς απεναντι
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d695929-Reviews-or140-Mani_Mani-Athens_Attica.html#REVIEWS
# User is :Aris K
#
# Review is :Μη φιλικό σε άτομα με ειδικές ανάγκες.Πολλά σκαλιά  για ανέβασμα κατέβασμα.Ζητούν υψηλό μπουρμπουαρ και φαγητά όχι τόσο γευστικά!!!!
#
# Rating is :  1
#
#
#
#
# User is :olgaki81
#
# Review is :Θαυμάσιο μαγαζί, εξαιρετικός χώρος ατμοσφαιρικός και ιδιαίτερος! Οι γεύσεις πολυ ξεχωριστές αξίζει πραγματικά να το επισκεφτεί κανεις!!!
#
# Rating is :  5
#
#
#
#
# User is :n1kkos
#
# Review is :ό,τι και να πει κανείς, πρέπει να το ζήσεις από κοντά. Το μενού ανανεώθηκε με φρέσκες ιδέες και προσθήκες. Το προσωπικό πάντα εξαιρετικό. Να δοκιμάσετε τον κόκκορα και από τα γλυκά την γαλατόπιτα. Με βάση την παραδοσιακή συνταγή και υλοποίηση με μοντέρνες πινελιές.
#
# Rating is :  5
#
#
#
#
# User is :Petros K
#
# Review is :Θαυμάσιο φαγητό, με ιδιαίτερες Ελληνικές πειραγμενες γεύσεις, όμορφα παρουσιασμενες. "Καθαρος" απέριττος χώρος και ευγενικο προσωπικό.
#
# Λίγο τσιμπιμενες τιμές αλλά  το αξίζει.
#
# Rating is :  4
#
#
#
#
# User is :Nella2106
#
# Review is :Εξαιρετική κουζινα! Αψογη εξυπηρετηση, αρκετά καλή κάβα!
# Εξαίρετη αναλογία ποιότητας/τιμής!
# Δεν το λες "γκουρμέ" .... αλλά είναι ο,τι πρέπει για ενα γευστικό και ποιοτικό γεύμα. Ωραιος χωρος, αφαιρετικος, λιτός και ιδιαίτερος...
# Θα ξαναπάω οπωσδήποτε!
#
# Rating is :  5
#
#
#
#
# User is :NicLive
#
# Review is :Αυτό που ξεχωρίζει είναι οι εξαιρετικοί συνδιασμοί γεύσεων σε κάθε πιάτο και η απόλυτα έντιμη gourmet δημιουργία. Προσφέρουμε σαν ανακάλυψη την πρόσκλησε σε φίλους για γεύμα στο Μάνη Μάνη.
#
# Rating is :  4
#
#
#
#
# User is :tereza t
#
# Review is :Κυριακη μεσημερι,μετα μια υπεροχη βολτα κατω απο την Ακροπολη,φτασαμε στο Μανη Μανη οπου μας δεχτηκαν ευγενεστατα,αν και χωρις κρατηση.Ο χωρος ζεστος και φιλικος ,η εξυπηρετηση αμεση απο νεους και κοπελιες ευγενεστατους.Φυσικο νερο της βρυσης και οχι ψωμακια οπως ζητησαμε.Το φαγητο μας...Σαλατα Μανη Μανη,πουγκακια με παστουρμα...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :Georgios G
#
# Review is :Μόνο το όνομα του παραπέμπει στην πανέμορφη Μάνη, το κτίριο βέβαια ωραίο νεοκλασσικό. Ατονες γεύσεις, η φάβα αδιάφορη, το πουγκί μέτριο, όπως και η πανσέτα. Το σέρβις μεταδίδει νευρικότητα. Τη ημέρα που πήγαμε το 70% ήταν τουρίστες. Δεν θα το πρότεινα.
#
# Rating is :  3
#
#
#
#
# User is :PANAGIOTIS K
#
# Review is :Πολύ ενδιαφέρουσα επιλογή. Σε ιδιαίτερα βολική περιοχή με εύκολη πρόσβαση.
# Εξυπηρετικό προσωπικό, πρόθυμο να εξηγήσει τα πιάτα και να προτείνει όπου χρειάζεται.
# Δεν το λες φθηνό αλλά αξίζει τα λεφτά του.
# Θα ξαναπάμε με την  πρώτη ευκαιρία.
#
# Rating is :  4
#
#
#
#
# User is :alexandrosb969
#
# Review is :Πρόκειται για μια πολυ καλη επιλογή καθως συνδιάζει την μεσογειακή κουζίνα με τις γκουρμέ γεύσεις.
# Μετά απο μια επίσκεψη στο μουσείο της Ακρόπολης επισκέφθηκαμε το συγκεκριμένο εστιατόριο κ πραγματικά μείναμε αρκετά ευχαριστημένοι.
# Καλό και γρήγορο service.Λιγα αλλά πρωτότυπα πιάτα.
# Προτιμήστε το ψαρονέφρι με μανούρι κ...Περισσότερα
#
# Rating is :  4
#
#
#
#
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d695929-Reviews-or150-Mani_Mani-Athens_Attica.html#REVIEWS
# User is :pbdvm
#
# Review is :Η ονομασία του και οι πολύ καλές κριτικές σε προδιαθέτουν για ένα εστιατόρειο εμπνευσμένο από την παράδοση της Μάνης με εκσυγχρονισμένη κουζίνα και πολύ καλή ποιότητα στα υλικά αλλά και στην παρασκευή των φαγητών. Η πραγματικότητα είναι διαφορετική.
#
# Ο χώρος ωραίος αλλά καμία σχέση με...Περισσότερα
#
# Rating is :  3
#
#
#
#
# User is :ge0rge1977
#
# Review is :+ Από τα πρώτα μαγαζιά στην Ελλάδα που καθιέρωσε το συγκεκριμένο concept:
# + Κουζίνα βασισμένη στην παράδοση με ποιοτικές πρώτες ύλες και προϊόντα ΠΟΠ, δοσμένη με  μοντέρνες γκουρμέ πινελιές, χωρίς να πρέπει να πληρώσεις 150 ευρώ το άτομο.
# + Μενού φτιαγμένο με μεράκι και φαντασία...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :lmemis
#
# Review is :Επισκεφτήκαμε το μαγαζί για μεσημεριανό τις μέρες των Χριστουγέννων. Όμορφος προσεγμένος χώρος φτιαγμένος στον όροφο ενός παλιού αρχοντικού. Λιτά τα τραπέζια χωρίς καν σουπλά. Μια υφασμάτινη πετσέτα, θα έδινε άλλο τόνο στο styling(Οι τιμές του εστιατορίου, θα την δικαιολογούσαν).
# Νέα παιδιά στο service, που βέβαια...Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :I4849CDmarya
#
# Review is :Πηγαμε με μεγαλη διαθεση λογω των κριτικων που ειχαμε ακουσει.το αποτελεσμα μετριο για καποιον που οταν πληρωνει 25 ευρω το ατομο περιμενει να εντυπωσιαστει.κριθαροτο με μανιταρια χωρις ενταση μπιφτεκακια με πουρε μελιτζανας οχι αρκετα πυκνο.ψαρονεφρι με φρουτα μικρη ποσοτητα και οσομπουκο με πουρε αρκετα καλο.ατμοσφαιρα...Περισσότερα
#
# Rating is :  3
#
#
#
#
# User is :931dimitriss
#
# Review is :Ωραίο ελληνικό φαγητό , προσεγμένες γεύσεις και παρουσίαση! Οι τιμές μέτριες προς ακριβές για τα ελληνικά δεδομένα άρα άκρως λογικές έως φθηνές με τα επίπεδα του εξωτερικού για το επίπεδο που προσφέρουν !!!! Οι τσούχτρα ήταν ένα από τα δυνατά πιάτα ( αν και προσωπικά...Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :EleniV120
#
# Review is :Μετα απο μια πολυ ωραια ξεναγηση στο μουσειο της Ακροπολης το Μανη Μανη ηταν οτι επρεπε! Ολοι μειναμε πολυ ευχαριστημενοι! Ειδικη μεταχειρηση για τα παιδια που πεινουσαν, πολυ ωραιεςκ αι πρωτοπυπες γευσεις. Μπιφτακακια, κοκορας με καστανα (εορταστικος), καγιανα μεταξυ αλλων. Πανω απο ολα η ευγενεια...Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :Αλεξάνδρα Π
#
# Review is :Η ατμόσφαιρα και το περιβάλλον ήταν εξαιρετικά, όλα καθαρά και περιποιημένα. Το προσωπικό ήταν γρήγορο και εξυπηρετικό. Η γλυκιά πράσινη σαλάτα ήταν γευστικά αρκετά καλή, η ποσότητά της υπέρ του δέοντος για 2 άτομα, καλοπλυμένη και φρέσκια. Οι μακαρούνες με τα χοιρινά φιλετάκια επίσης πολύ...Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :E_kai_G
#
# Review is :Επισκεφθήκαμε με τον σύζυγό μου,το εστιατόριο Μάνη Μάνη και το ταξίδι στις ελληνικές γεύσεις μας γοήτευσε!!! Ένας συνδυασμός ελληνικής κουζίνας με μοντέρνες πινελιές και σίγουρα μοντέρνο στήσιμο των πιάτων!!! Αξίζει ανεπιφύλακτα!!! Αν πας πριν τις 6, έχει την δυνατότητα στα περισσότερα πιάτα για 1/2 μερίδα,...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :Γιάννος Χ
#
# Review is :Σε ένα πολύ ωραίο χώρο, με ευγενκούς και επαγγελματίες σερβιτόρους, απολαμβάνεις ελληνική κουζίνα με βάση τις γεύσεις της Μάνης. Σχεδόν όλα όσα πήραμε ήταν καταπληκτικά. Ταραμοσαλάτα μοναδική, καγιανάς εκπληκτικός, κριθαρότο με καπνιστά μανιτάρια, Τα μπιφτέκια και τα ψαρονέφρι πολύ νόστιμα και ιδιαίτερα, Το οσομπούκο  εντυποσιακό...Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :annygeo
#
# Review is :Διαλέξαμε το Μανη Μανη αφού είχαμε διαβάσει ωραίες κριτικές για την κουζίνα του.  Δυστυχώς την παραμονή των Χριστουγέννων είχε συγκεκριμένο menu με νόστιμα φαγητά μεν, αλλά χωρίς την δυνατότητα να δοκιμάσουμε και αλλα πιάτα. Το menu ήταν λίγο υπερτιμημένο. Θα ήθελα να ξαναπάω μια συνηθισμένη...Περισσότερα
#
# Rating is :  3
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d695929-Reviews-or160-Mani_Mani-Athens_Attica.html#REVIEWS
# User is :216konstantinost
#
# Review is :Και νόστιμο φαγητό που έχει μαγειρευτεί και σερβιριστεί με επαγγελματισμό και σεβασμό προς τον πελάτη.Επιλεξαμε από κυρίως πιάτα τα μπιφτέκακια, την πανσέτα και τα μακαρόυνια με τα τελευταία να αποτελούν το κορυφαίο πιάτο του τραπεζιού. Καλή εντύπωση επίσης μας άφησε η χορταστικοτατη σαλάτα και οι...Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :maryrvn
#
# Review is :Ένα όμορφο (μάλλον παλιό διαμέρισμα )μέρος , με ωραία διακόσμηση και ευχάριστο περιβάλλον . Το φαγητό πολυ ωραίο , προσωπικά θα πρότεινα το πιάτο "τσουχτες" και κυρίως την πανσέτα . Οι τιμές μέτριες προς τα πάνω .θα πήγαινα πάλι ευχαρίστως !
#
# Rating is :  5
#
#
#
#
# User is :savvasgr
#
# Review is :Ένα εκπληκτικό εστιατοριο που σέβεται τον πελάτη του...
# Το συνιστώ ανεπιφύλακτα για τον οποιονδήποτε θέλει να βγάλει έναν άνθρωπο έξω και να αφήσει καλές εντυπώσεις..
#
# Rating is :  5
#
#
#
#
# User is :vanessa k
#
# Review is :Το φαγητό ειναι φανταστικό αξίζει να το επισκεφθεί κάνεις και να δοκιμάσει τα πάντα!!!!Εχω πάει αρκετές φορές πάντα μένουμε ικανοποιημένοι!Το προσωπικό ευγενικό, ωραίο περιβάλλον ,καλό κόσμο!Και τα πιάτα είναι ένα κ ενα!
#
# Rating is :  5
#
#
#
#
# User is :225antoniost
#
# Review is :Η πρόσβαση στο εστιατόριο είναι εύκολη και επιπλέον βρίσκεται σε πολύ καλή θέση. Ο χώρος είναι πολύ καλός και φωτεινός. Η εξυπηρέτηση εξαιρετική και γρήγορη και το φαγητό εύγευστο. Αντίρρηση υπήρξε ως προς τις τιμές, 30 ευρώ το άτομο για μέτρια κατανάλωση, δεδομένου ότι δεν...Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :konstantpo
#
# Review is :Πολυ καλο εστιατοριο!!! Απλο και γευστικό Ελληνικό φαγητό όμορφα παραλαγμενο!!!Ζεστή και φιλική  εξυπηρέτηση!!!Καλες τιμες για αυτό που  προσφέρει!!
#
# Rating is :  5
#
#
#
#
# User is :_D2665AK
#
# Review is :Φοβερό εστιατόριο που στεγάζεται σε ένα πανεμορφο νεοκλασικό κτίριο . Το φαγητό ήταν υπέροχο και το  service εξαιρετικό !
#
# Rating is :  5
#
#
#
#
# User is :563aggelikit
#
# Review is :Κουζίνα εμπνευσμένη από τη Μανη σε γκουρμέ απόδοση. Όλα τα πιάτα συμπαθητικά, κανένα δε με απογείωσε. Φιλικό προσωπικό, ευχάριστο περιβάλλον, δεν με εντυπωσίασαν τα επιδόρπια. Αποτελεί μια μέτρια επιλογή αν βρεθεί κανείς στην περιοχή!
#
# Rating is :  3
#
#
#
#
# User is :jackstil
#
# Review is :Σάββατο μεσημέρι φαγητό για δυο, εύκολη κράτηση.Προσεγμενα φαγητά, καλή πρώτη υλη( ο chef τον είδαμε λίγο, ωραίος τύπος ).Εξυπηρετηση ευγενική χαμογελαστή.Λογικες τιμές ,wine list σωστή τιμολόγηση όχι υπερβολές .Μας άρεσε η αλλαγή μαχαιροπήρουνα, τέλος κέρασμα μαστίχα.ΣΕΒΟΝΤΑΙ τον μη καπνιστή, μουσική χαλαρωτική ,τέλος στα + έχεις...Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :Domna81
#
# Review is :Μανη μανη.η ονομασια τα λεει ολα.εμπνευσμενες συνταγες απο την περιοχη της μανης λιγο τραβηγμενες ομως..καλο περιβαλλον.ομορφα πιατα με καλο σερβις.
#
# Rating is :  4
#
#
#
#
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d695929-Reviews-or170-Mani_Mani-Athens_Attica.html#REVIEWS
# User is :filotast
#
# ...
#
# Rating is :  5
#
#
#
#
# User is :Brian SΌστιν, Τέξας
#
# Review is :Το φαγητό είναι υπέροχο. Η εξυπηρέτηση είναι εξαιρετική, αλλά το φαγητό έρχεται αργά. Μερίδες είναι μικρές και οι τιμές είναι λίγο ακριβό, αλλά δεν θεωρώ σκανδαλώδες. Το πορτοκαλί ενδεικτικό, κέικ, γιαούρτι με το παγωτό άμεσης κατανάλωσης είναι μία από τις νοστιμότερες μεζέδες πηδαλίου μου έχει...πειραχτεί.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :617arisl
#
# Review is :Θαυμάσιο!! Εξαιρετικό φαγητό παρουσίαση σε συνδυασμό με μοναδικές γεύσεις!! Το προσωπικό ήταν πολύ ευγενικό και καλές τιμές!!
#
# Rating is :  5
#
#
#
#
# User is :LisawalkerlacΛαγκούνα Μπιτς, Καλιφόρνια
#
# Review is :Είχαμε ένα φανταστικό γεύμα εδώ στο κέντρο του Acropolisdistrict. Η διεστραμμένη χωριάτικη σαλάτα ήταν εκπληκτικό, καθώς και η προσφορά περισσότερων χοιρινού κρέατος που είχα ποτέ. Ψάχναμε κάτι κοντά στο ξενοδοχείο μας κοντά στην Ακρόπολη που ήταν διαφορετικό από το πραματευτές προσπαθώντας να τραβήξτε μας και...σίγουρα το βρήκαμε. Οι ιδιοκτήτες ήταν εξαιρετικό και θα μπορούσαμε να έχουμε πάντα ordereds στο μενού. Ήταν τόσο καλό! Κάναμε κράτηση και ήταν πραγματικά χαρούμενοι που το κάναμε επειδή ήταν συσκευασμένα! ΑπολαύστεΠερισσότερα
#
# Rating is :  5
#
#
#
#
# User is :lucianRomanΒουκουρέστι, Ρουμανία
#
# Review is :Είχαμε μόνο μια μπύρα και η φίλη μου είχε ένα επιδόρπιο και κρασί. Η ατμόσφαιρα ήταν πολύ ευχάριστη. Περιμέναμε ένα αίθριο, αλλά το εσωτερικό ήταν με πολλά γεύση
#
# Rating is :  4
#
#
#
#
# User is :lh007Σιέμ Ριπ, Καμπότζη
#
# Review is :Δεν θα σας ζητώ συγνώμη για τον χρόνο για να βρείτε αυτό το εστιατόριο. Βρίσκεται δίπλα στο κεντρικό σύρετε σε πιο ήσυχο δρόμο. Ξεκινήσαμε με twisted χωριάτικη σαλάτα που ήταν φανταστικό! Είχα το ριζότο με θαλασσινά και ο σύζυγός μου είχε ένα παραδοσιακό ελληνικό πιάτο...ζυμαρικών (ένα με το αυγό πάνω)· τόσο εξαιρετική entrees. Ολοκληρώσαμε το γεύμα μας με σοκολάτα αφρό. Το γεύμα σας με ένα μπουκάλι κρασί ήταν μόνο 65 ευρώ. Σίγουρα θα ξαναπήγαινα αν ποτέ στην Αθήνα και πάλι.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :lematoviΑλμπουκέρκη, Νέο Μεξικό
#
# Review is :Πήγαμε για δείπνο νωρίς. Δεν είχαμε επιφυλάξεις, αλλά δεν έχουν να περιμένουν. Το φαγητό είναι πεντανόστιμο! Είχαμε τις ελιές και brusketas ως ορεκτικά. Ρεύμα ήταν το χοιρινό και της κοιλιάς πετεινό. Τόσο νόστιμο!!! Το προσωπικό ήταν πολύ ευγενικό και η εξυπηρέτηση πολύ γρήγορα. Θα επανέλθω!
#
# Rating is :  5
#
#
#
#
# User is :Br0kkSouth Africa
#
# Review is :Ακούσαμε για αυτό το μέρος από ένα φίλο. Προσπάθησα να κάνουν κράτηση μέσω email. Κανείς δεν απάντησε, έτσι προσπαθήσαμε μας τύχη περίπου 2 ώρες νωρίτερα από ό,τι μας αρχικής κράτησης.
# Το μόνο που μπορώ να πω είναι, σίγουρα θα ξαναπάμε!
# Το εστιατόριο του ξενοδοχείου είναι...λίγο περίεργο να βρω, ώστε να στρέψουμε την προσοχή μας.
# Η διακόσμηση είναι πολύ ωραίο και εντελώς διαφορετική από τη γύρω περιοχή.
# Το φαγητό είναι απλά φανταστική. Είχαμε 2 αρνί και 2 χοιρινό ζυμαρικά. Έκαναν κάτι ιδιαίτερο για μου 2 ετών. Το φαγητό είναι παρουσίασε πραγματικά καλά. Τα γούστα είναι απλά καταπληκτικό και το έργο τόσο καλά μαζί. Όλοι λάτρεψαν απολύτως την τροφή τους.
# Δεν επιτρέπονται ούτε και ωραίο και φιλικό προσωπικό.
# Θα συνιστούσα αυτό το μέρος.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :YGEORGPleven, Βουλγαρία
#
# Review is :Καλό μικρό μέρος για να χαλαρώσετε, στην καρδιά της πόλης. Η επιλογή μας πρέπει να μας περιοχή-Kukaki, αλλά όχι πολύ μακριά από την πλάκα. Σύντομο κατάλογο - ζυμαρικά και κρέας, πολύ νόστιμο. Εξαιρετική εξυπηρέτηση.
#
# Rating is :  5
#
#
#
#
# User is :Yves CΜόντρεαλ, Καναδάς
#
# Review is :Το φαγητό ήταν πολύ καλό και η διακόσμηση ήταν ωραία. Η εξυπηρέτηση ήταν εξαιρετική. Εστιατόριο βρίσκεται στο δεύτερο όροφο, έτσι ώστε να είναι εξυπηρετικό όταν αναζητάτε. Απόθεμα εκ των προτέρων και να τους ζητήσουμε εάν δέχονται πιστωτικές κάρτες, εάν σκοπεύετε να καταβάλει κατ' αυτόν τον...τρόπο όπως μας είπαν το σύστημά τους ήταν κάτω όταν πήγαμε (ή είχαν προσπαθήσει να αποφύγει τους φόρους;)Περισσότερα
#
# Rating is :  4
#
#
#
#
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d695929-Reviews-or480-Mani_Mani-Athens_Attica.html#REVIEWS
# User is :796JenniferBThe Colony, Τέξας
#
# Review is :Μάνη Ξενοδοχεία Μάνη, έχει μια ήρεμη και γαλήνια, αριστοκρατική ατμόσφαιρα και νόστιμο φαγητό. Μετά από μια κουραστική μέρα που ασχολούνται με τα πλήθη.
# Αυτό το μέρος είναι τόσο καλό που ο σύντροφός μου και εγώ φάγαμε εκεί 2 φορές. Κατά τη διάρκεια του ταξιδιού μας...στην Ελλάδα, βασιστήκαμε στο Trip Advisor για επιλογές εστιατορίων και ήταν πάντα ικανοποιημένοι. Μάνη Ξενοδοχεία Μάνη, υπήρξε μια σαφής εγκοπή πάνω από το υπόλοιπο των τόπων προσπαθήσαμε στην Αθήνα.
# Εάν ψάχνετε για κάτι λίγο διαφορετικό να φάτε στη συνέχεια τα τυπικά ελληνικά πιάτα που διαπιστώθηκαν στις τουριστικές περιοχές, τότε αυτό το μέρος είναι για σας. Τα πιάτα ζυμαρικών είναι απολύτως εκπληκτικό. Θεώρησα παραγγελία ζυμαρικά και πάλι τη δεύτερη φορά, αλλά εγώ διακλαδίζεται προς τα έξω και πήραμε το χοιρινό κοιλιά και χάρηκα που έκανε. Το ειδικό επιδόρπιο το βράδυ πήγαμε ήταν moose σοκολάτας. Ήταν απολύτως παρακμιακή.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :Travelers0205Greer, South Carolina
#
# Review is :Τα πάντα ήταν νοστιμότατο. Ξεκινήσαμε με twisted χωριάτικη σαλάτα..ουάου! Ήταν τόσο νόστιμο και φως! Στη συνέχεια, μας είχε μια πλατεία filo με σάλτσα ντομάτας ... υπέροχο. Τελευταίο, αλλά όχι λιγότερο σημαντικό ήταν η παραδοσιακή καλλιέργεια μανιταριών χοιρινό πιάτο ζυμαρικών. Θαυμάσιο! Τι έκπληξη- είχαμε ένα καλό...γεύμα την ημέρα πριν, αλλά αυτό το εστιατόριο χτύπησε ένα σπίτι! Ήταν λίγο δύσκολο να το βρεις αλλά άξιζε τον κόπο.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :mamagdaΠόλη του Λουξεμβούργου, Λουξεμβούργο
#
# Review is :Το μέρος είναι άνετο και το φαγητό είναι απλά καταπληκτική. Ιδιαίτερα μας άρεσε σπιτικά ραβιόλια με τη φέτα και ζυμαρικά με τηγανητό αυγό πάνω. Αλλά τα πάντα ήταν πολύ καλό. Πληρώσαμε 67e για δείπνο για δύο - 3 ορεκτικά, 2 κύρια πιάτα και 1 επιδόρπιο...δύο μερίδιο συν ένα μπουκάλι κρασί. Πραγματικά ωραίο δείπνο!Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :BlackAcreSouthDakotaΣιού Φολς, Νότια Ντακότα
#
# Review is :Αυτό θα μπορούσε να έχει το γαστρονομικό αποκορύφωμα του ταξιδιού μας στην Ελλάδα. Βρήκαμε Manh Manh τόσο πλούσια Steves και στο Trip Advisor. Αν ήταν μια μικρή αύξηση από τα ξενοδοχεία μας, αλλά, όπως έχουν αναφέρει και άλλοι, δεν ήταν ακόμα δύσκολο να το βρεις....Ένα από τα ξενοδοχεία στην περιοχή είχε την ευγενή καλοσύνη να μας προσανατολίσει προς τη σωστή κατεύθυνση, αλλά να το κάνουμε ξανά, θα ήθελα να λάβετε λεπτομερέστερες οδηγίες από το Google Maps ή κάπου πριν ξεκινήσετε.
# Φτάσαμε στο Manh Manh χωρίς επιφυλάξεις στις 8:00 το απόγευμα της Κυριακής. Μας έδωσαν ό,τι μας είπαν ότι ήταν το τελευταίο φλίπερ. Το εστιατόριο δεν φαίνονται ωραίες. Υπάρχουν δύο δωμάτια με απλή ξύλινα τραπέζια διαφόρων μεγεθών και περιγραφές που χωρίζονται με ανοιχτή κουζίνα. Το μέρος είναι ελκυστική σε μινιμαλιστικό στιλ. Αλλά, είστε πραγματικά εκεί για τη δημιουργική κουζίνα!
# Η εξυπηρέτηση ήταν αποτελεσματική και ενδεδειγμένη. Κλείσαμε μια χωριάτικη σαλάτα με μερίδιο αγοράς. Ήταν τεράστια και κάναμε μια αρκετά επιβαρύνει, αλλά δεν μπορούσε να ολοκληρωθεί η μεγάλη σειρά. Δεν ήταν η παραδοσιακή ελληνική σαλάτα ως τομάτες ήταν ντοματάκια νάνους και ήταν όλοι αρκετά ψιλοκομμένο. Η φέτα που ήταν πολύ ωραίο και μας άρεσε η βουτυράτα ελιές. Ήταν όμορφα herbed με φρέσκο, βασιλικού νομισματοκοπείου και sumac. Σκοπεύουμε να απασχολούν ότι βότανα συνδυασμός στην επόμενη χωριάτικη σαλάτα στο σπίτι.
# Σύντροφος μου παραγγείλει orzo μανιταριών, να μοιραστείτε το οποίο ήταν απλά υπέροχο. Η γεύση των μανιταριών ήταν καλά συμπυκνωμένου μέσα στην κάψα. Παρήγγειλα ένα πιάτο meatball. Ο σερβιτόρος πρότεινε medium σπάνια! Είχαν μια γενναιόδωρη συμβολή του νομισματοκοπείου. Έχουμε δύο πίστευαν ότι ήταν εξαιρετικό.
# Κανένας από εμάς δεν θα μπορούσε να φάτε επιδόρπιο, οπότε περάσαμε στην έρημο, αλλά ήταν μία μετά το δείπνο ούζο. Ακόμη και με πολλά ποτήρια κρασί μεταξύ μας, ένα μεγάλο μπουκάλι νερό, σκληρό ψωμί και το ελαιόλαδο, ή νομοσχέδιο ήταν μόνο 55,5 ευρώ! Με μια συμβουλή, ήμασταν έξω από την πόρτα για 65 ευρώ. Περάσαμε περισσότερο από ότι στις 12.00 για ένα πολύ μέτριο γεύμα. Πιστεύαμε ότι ήταν θαυμάσιοι καινοτόμων τροφίμων, αλλά ήταν όλα τα ευνοϊκά σε χαμηλές τιμές.
# Η συμβουλή μου είναι να πάτε σε αυτό το μέρος. Αποκτήστε μια κράτηση, αποκτήστε ρητή κατευθύνσεις αλλά προχωρούν και έχουν ένα εξαιρετικό δείπνο.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :JoaofrutuosoΛισαβόνα, Πορτογαλία
#
# Review is :Είχε πολύ καλύτερη εδώ τριγύρω. Το μέρος είναι φανταχτερό και καλά διακοσμημένα... το φαγητό δεν είναι κακή, αλλά δεν είναι τόσο μεγάλη όσο αναμενόταν... αν ψάχνετε καθώς θα βρείτε καλύτερες επιλογές
#
# Rating is :  3
#
#
#
#
# User is :George AΠεριοχή Θεσσαλονίκης, Ελλάδα
#
# Review is :Ελληνικό φαγητό είναι γνωστό για την ποικιλία γεύσεων, συνδυασμός πολλών διαφορετικών υλικών και πολλούς τρόπους για μαγείρεμα. Αυτό το εστιατόριο πραγματικά γνωρίζει πώς να συνδυάζουν την παράδοση, απλότητα και έργα τέχνης, δημιουργώντας θαυμάσια πλάκες.
# Για τους ιδιοκτήτες: Παρακαλείστε να κάνουν ό,τι πράττουμε ήδη εδώ και...πολλά χρόνια. Δεν είναι εύκολο να ισορροπία ποιότητας και οικονομικά προσιτές τιμέςΠερισσότερα
#
# Rating is :  5
#
#
#
#
# User is :vasgaitΑθήνα, Ελλάδα
#
# Review is :Θαυμάσιο resto , αριστοκρατικό πλάκες με παραδοσιακά και διεθνή πινελιά.Πολύ καλή εξυπηρέτηση, καθώς και ολόκληρο το μέρος ... πολλά πιάτα από όλη την Ελλάδα.ωραία λίστα κρασιών
#
# Rating is :  5
#
#
#
#
# User is :128rickh
#
# Review is :Δεν έχω τίποτε άλλο να πω, αλλά "ΑΠΊΣΤΕΥΤΟ"
# Πλεγμένα χωριάτικη σαλάτα
# χοιρινό οσφυϊκής χώρας με τη φέτα και orzo
# πορτοκαλί Pie
# εκτός της συνηθισμένης διαδρομής, ωραία τοποθεσία στον επάνω όροφο, το προσωπικό ήταν πολύ ωραίο και η εξυπηρέτηση ήταν τέλειο!!!
#
# Rating is :  5
#
#
#
#
# User is :KeltalenΤζάκο, Κόστα Ρίκα
#
# Review is :Αυτό το εστιατόριο είναι εύκολο να το βρείτε καθώς βρίσκεται στον πρώτο όροφο ενός κτιρίου του κοινού σε ένα σκοτεινό δρόμο. Ωστόσο, η ρύθμιση είναι ωραίο και μοντέρνο, αριθ. έξω άποψη οποιουδήποτε είδους, αλλά μια διακριτική μουσική ατμόσφαιρα... Το καλό έκπληξη έρχεται με ένα δημιουργικό...μενού που συνδυάζουν την κλασική ελληνική υλικά και πιο fusion τύπους συνταγές. Νόστιμο και προσιτά. Φιλική εξυπηρέτηση. Αξιοπρεπές κρασιά.
# Ένα πολύ ωραίο μέρος για δείπνο, κοντά στην Ακρόπολη και την περιοχή της Πλάκας.Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :FarAwayEmeraldΜάνσφιλντ, Τέξας
#
# Review is :Το δείπνο ήταν υπέροχο. Ένα από τα καλύτερα που είχαμε στην Ελλάδα. Εστιατόριο για δείπνο συμπεριλήφθηκε ως τμήμα της σε μια περιήγηση με τα πόδια το πακέτο και να μας ευχάριστη έκπληξη ήταν εκπληκτικό. Το χοιρινό και Σχ πιάτο με μέλι και κατσικίσιο τυρί ήταν...από τα αγαπημένα μου.Περισσότερα
#
# Rating is :  5
# url is
# https://www.tripadvisor.com.gr/Restaurant_Review-g189400-d695929-Reviews-or490-Mani_Mani-Athens_Attica.html#REVIEWS
# User is :Steven KΜπρονξ, Νέα Υόρκη
#
# Review is :Εξαιρετική τοποθεσία, στο δεύτερο όροφο, είδος μυστικού cafe. Ως επί το πλείστον τουρίστες έφαγα εδώ, αλλά το φαγητό ήταν εξαιρετικό. Είχε μια σαλάτα ρόκας () με ψητό κατσικίσιο τυρί που ήταν να ζουν. Το μη επιλογές κρέας ήταν κάπως λεπτή για αυτό για χορτοφάγους, αλλά...ήταν πολύ εξυπηρετικοί και μου έκανε Hippolites χωρίς κοτόπουλο, χωρίς κανένα πρόβλημα. Γλυκό service με πολλά χαμόγελα και συστάσεις. Ήταν ένα αξέχαστο γεύμα και σίγουρα θα ξαναπήγαινα. Μπορείτε να πείτε ότι νοιάζονται για το φαγητό και εξυπηρέτηση.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :PholtzmanClarence Town, Νησί Long
#
# Review is :Μόλις εισέλθουν αυτό το εστιατόριο είναι διασκεδαστική, καθώς γυρίζετε το αστέρια για να εισαγάγετε ένα φωτεινό και φιλόξενα και άνετο χώρο.
# Αλλά η πραγματική έκπληξη ήταν το φαγητό!
# Δοκιμάστε την Ελληνική σαλάτα με μια πινελιά.
# (μοιραστήκαμε μια μεγάλη σειρά)
# όμως πoλύ διαφορετικά.
# Παρήγγειλα μανιταριών orzo,...ο σύζυγός μου είχε στήθος κοτόπουλου και μελιτζάνας. Μοιραστήκαμε αυτές καθώς και. Το φαγητό ήταν νόστιμο, φθηνό και η εξυπηρέτηση ήταν τέλεια.
# Ακόμη και μας έδωσαν ένα δωρεάν ποτό κακάου φουντουκιών μετά το δείπνο!Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :dreaming57Αυστραλία
#
# Review is :Απολαύσαμε Μάνη Ξενοδοχεία Μάνη, τόσο πολύ που πήγαμε εκεί 2 φορές. Εξυπηρετούν μοντέρνο ελληνικό φαγητό, οι γεύσεις είναι φρέσκα και ορισμένοι συνδυασμοί είναι ενδιαφέροντα, αλλά είναι όλα πεντανόστιμα.
# Η λίστα κρασιών ήταν καλό και όχι ακριβό. Η εξυπηρέτηση ήταν εξυπηρετικό και χαμογελαστό.
#
# Rating is :  4
#
#
#
#
# User is :jeremoquaiΤελ Αβίβ, Ισραήλ
#
# Review is :Φιλικό προσωπικό,
# μπορείτε να έρθετε με τα παιδιά σας (ακόμη και αν πρέπει να ανεβείτε τις σκάλες)
# εξαιρετικό κρασί
# πολύ καλό πιάτα (φακές, tarama, ψάρια, ριζότο...)
# ωραίο μέρος
# και σωστή τιμές
# τι μπορείτε να ζητήσετε περισσότερα;
#
# Rating is :  5
#
#
#
#
# User is :pepisima
#
# Review is :Έχουμε πάει να φάτε , όλα ήταν πολύ καλό, αλλά κυρίως ζυμαρικά house και το χοιρινό belle , νόστιμο επιδόρπιο .
# Το τοπικό πολύ ωραία.
# Η εξυπηρέτηση τέλεια, επαγγελματικό και εξυπηρετικό.
# Η σχέση ποιότητας-τιμής φανταστική.
# Είναι πάρα πολύ αξιοσύστατο
#
# Rating is :  4
#
#
#
#
# User is :3intentΛισαβόνα, Πορτογαλία
#
# Review is :Ήρθε αντιμέτωπος με αυτό το εστιατόριο επί 36 ώρες/NY Times. Σίγουρα αξίζει μια επίσκεψη, καθώς το φαγητό είναι πολύ καλό, όπως είναι η υπηρεσία. Είχαμε φάει σε πολλές ταβέρνες και ψάχναμε για κάτι λίγο πιο πολυτελές και διαφορετικά. Θα ήθελα να συστήσω την Ελληνική πιάτα...ζυμαρικών, καθώς και την κάψα meatball. Φυτικά πιάτα επίσης πολύ καλό και πολύ καλά προετοιμασμένη.Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :mobywizzaΧιούστον, Τέξας
#
# Review is :Καταλήξαμε να έρχονται εδώ μετά από ανάγνωση σπουδαίες κριτικές. η συνολική εμπειρία ήταν άνω του μέσου όρου, και το προσωπικό ήταν ωραίο επίσης. Το φαγητό ήταν καλό - πήραμε το χοιρινό κοιλιά και παραδοσιακά σπιτικά ζυμαρικά. το νομοσχέδιο ωστόσο ήταν λάθος, το οποίο διορθώθηκε και...μας έδωσαν ένα δωρεάν επιδόρπιο αργότερα.Περισσότερα
#
# Rating is :  4
#
#
#
#
# User is :760edwardk
#
# Review is :Φτάσαμε σε αυτό το εστιατόριο γύρω στις 3μμ για ένα γεύμα αργά χωρίς κράτηση. Υπήρχαν μερικά κενά τραπέζια και έτσι πήραμε κάθεται γρήγορα, ωστόσο, λιγότερο από 20 λεπτά αργότερα το εστιατόριο ήταν γεμάτο. Συνιστώ ζητώντας εν όψει της κράτησης.
# Το φαγητό ήταν μαγειρεμένο στην τελειότητα....Μπορείτε να πείτε ότι χρησιμοποιούν φρέσκα τοπικά προϊόντα. Η παρουσίαση των πιάτα είναι εξαιρετικές. Απολαύσαμε πραγματικά και απολαύσαμε κάθε μπουκιά.
# Το προσωπικό ήταν πολύ φιλικό και εξυπηρετικό. Αν θέλετε μια αυθεντική γεύση της Ελληνικής τροφίμων έκαναν θεαματική ανάπτυξη καλά, θα πρέπει να δοκιμάσετε αυτό το μέρος. Κλήση της κράτησης και να απολαύσουν το φαγητό, ζεστή ατμόσφαιρα και εξαιρετική εξυπηρέτηση.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :RichL06St. Augustine, Φλόριντα
#
# Review is :Εκπληκτικό μικρό δεύτερο όροφο το εστιατόριο στην καρδιά της Αθήνας. Καλό δημιουργικό μενού, το οποίο είναι απλή, με καλή ποικιλία από δημιουργικά επιλογές της πρώτης, δεύτερης και entrées. Θα συνιστούσα να ακούτε τις καθημερινές προσφορές συχνά βασίζεται σε διαθεσιμότητα στην αγορά. Υπέροχο καλά τιμολογημένο λίστα...κρασιών. Το προσωπικό είναι πολύ ευχάριστο και εξυπηρετικό χωρίς να είναι εξωφρενικό. Απλή διακόσμηση, τα οποία είναι άνετα, με καλά κατανεμημένες στους πίνακες που σας κάνει να νιώθετε σαν να είναι ιδιωτική τραπεζαρία. Ένα από τα μέρη που πρέπει να επισκεφθείτε στην Αθήνα.Περισσότερα
#
# Rating is :  5
#
#
#
#
# User is :Val KHonolulu, HI
#
# Review is :Είχαμε ένα υπέροχο δείπνο νωρίς το απόγευμα. Χωρίς κρατήσεις και σε μικρή απόσταση με τα πόδια από το Acropoli στάση. Παραβλέψτε την τουριστική εστιατόρια της πλάκας και ελάτε εδώ. Το φαγητό ήταν σύγχρονα, αναζωογονητική και νόστιμα! Οι τιμές ήταν πολύ λογικές. Το λάτρεψα!
#
# Rating is :  5

# %%
df_mani_mani = pd.DataFrame(data, columns=['User', 'Review','Rating'])

# %%
df_mani_mani.shape
# Out:
# (500, 3)

# %%
df_mani_mani.head()
# Out:
#               User                                             Review  Rating
# 0  _amaliakorakakh  Ένα εξαιρετικό μαγαζί με πλούσιες γευσεις βασι...       5
# 1   yiannissar2017  Λεπτες γευσεις με εκλεκτα υλικά Ελληνικής παρα...       5
# 2        Στράτος Μ  Ήταν μια γευστική εμπειρία !! Πολύ ωραίες γεύσ...       5
# 3              V M  Όμορφος χώρος σε ένα ψηλοτάβανο παλιό σπίτι, ε...       3
# 4         xripanag  Δοκιμάσαμε πιάτα από όλα τις κατηγορίες του με...       5

# %%
filepath = Path('mani_mani.csv') 
df_mani_mani.to_csv(filepath, index=False)
