# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import re
import time
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
from pathlib import Path
# Out:
# C:\Users\chris\anaconda4\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\chris\anaconda4\lib\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
# C:\Users\chris\anaconda4\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
data = []

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
url = "https://www.tripadvisor.com/Hotel_Review-g189400-d554815-Reviews-Central_Hotel-Athens_Attica.html#REVIEWS"
print("url is \n" + url)
driver.get(url)
time.sleep(10)
soup = BeautifulSoup(driver.page_source, 'html.parser')
driver.quit()
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_14008\1097654502.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# url is
# https://www.tripadvisor.com/Hotel_Review-g189400-d554815-Reviews-Central_Hotel-Athens_Attica.html#REVIEWS

# %%
containers = soup.find_all("div", {"class": "YibKl MC R2 Gi z Z BB pBbQr"})

# %%
len(containers)
# Out:
# 10

# %%
rating = containers[0].find("div", {"class": "Hlmiy F1"})

# %%
rating
# Out:
# <div class="Hlmiy F1" data-test-target="review-rating"><span class="ui_bubble_rating bubble_40"></span></div>

# %%
rating.next
# Out:
# <span class="ui_bubble_rating bubble_40"></span>

# %%
user = containers[0].find_all("a", {"class": "ui_header_link uyyBf"})

# %%
user
# Out:
# [<a class="ui_header_link uyyBf" href="/Profile/lolaf448">lola f</a>]

# %%
review = containers[0].find("q", {"class": "QewHA H4 _a"})

# %%
review
# Out:
# <q class="QewHA H4 _a"><span> Clean and comfortable hotel with an excellent location and delicious breakfasts! the room was small, but we had a balcony which overlooked the street and was a real treat. You can walk to all the attractions, plenty of great restaurant choices. We found the front desk welcoming and friendly. A good choice for our first visit to Athens.  </span></q>

# %%
containers2 = soup.find_all("div", {"class": "WAllg _T"})

# %%
for index, container in enumerate(containers):
    
    user = container.find("a", {"class": "ui_header_link uyyBf"})
    review = container.find("q", {"class": "QewHA H4 _a"})
    rating = container.find("div", {"class": "Hlmiy F1"})
    
    rating_value = 0;
    if (str(rating.next) == "<span class=\"ui_bubble_rating bubble_0\"></span>"):
        rating_value = 0
    elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_10\"></span>"):
        rating_value = 1
    elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_20\"></span>"):
        rating_value = 2
    elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_30\"></span>"):
        rating_value = 3
    elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_40\"></span>"):
        rating_value = 4
    else :
        rating_value = 5
    
    if(review):
        print("User is :" + user.text.strip() + "\n")
        print("Review is :" + review.text.strip() + "\n")
        print("Rating is : ",rating_value)
        data_point = [user.text.strip(),review.text.strip(), rating_value]
        data.append(data_point)
        print("\n")
        print("\n")
        
    if(index == 9):
        break #since there are 10 contaners with reviews per page
# Out:
# User is :lola f
#
# Review is :Clean and comfortable hotel with an excellent location and delicious breakfasts! the room was small, but we had a balcony which overlooked the street and was a real treat. You can walk to all the attractions, plenty of great restaurant choices. We found the front desk welcoming and friendly. A good choice for our first visit to Athens.
#
# Rating is :  4
#
#
#
#
# User is :TroyAsia
#
# Review is :Booked a deluxe and was given a 6th floor room with a view of the Acropolis if you turned your head.  Small size room but more than adequate. They even provided complimentary Greek snack & Greek liquor in the room which I thought was a nice touch.  Breakfast was standard but the rooftop bar restaurant was over the top.  Nice place to unwind after walking up to the Acropolis/Museum which is only about a 10mn walk and the bar closes late.  Great location with the Plaka District just down the block.  There is a school next door, so at times the school bell rings but I kinda did not mind it.
#
# Rating is :  4
#
#
#
#
# User is :Clara C
#
# Review is :There was a problem with the reservation,the hotel didn't get the payment the travel agency did that morning,and Manolis,the recepcionist treated us like we've never been treated in any hotel in the world. He was really rude,selfish,like he was the owner of the hotel,and didn't want to call to reservations,saying he has more clients...and when we got there there was no one. If i was the manager of the hotel,i'd fire him if he treats people like that. And by the way no a 4 stars hotel for us....dirty chairs un the room,very dirty windows, umconfortable bathroom,because it's so tiny....choose another hotel if you go to athens
#
# Rating is :  1
#
#
#
#
# User is :Christopher P
#
# Review is :stayed 1 night . Small but well equipped room. Bathroom also small but excellent shower . Bed  reasonably comfortable .Room was at back overlooking a small courtyard and was very quiet. Breakfast adequate .
#
# Rating is :  4
#
#
#
#
# User is :heelergrl
#
# Review is :We stayed at Central twice, at the beginning and end of our recent trip to Greece. The hotel is clean, comfortable and well-staffed, and the Acropolis views from the rooftop bar/restaurant are stunning. Breakfast is more than adequate, with a varied selection, Our first room had a tiny bathroom and no real balcony, but a fabulous view! Our second room was a bit larger and easier to maneuver in, with a small balcony and no view (we didn't care). The hotel is just a couple of blocks from Syntagma Square, and the staff were all helpful and pleasant. We would stay there again.
#
# Rating is :  5
#
#
#
#
# User is :Nichola W
#
# Review is :Chose this hotel due to it’s proximity to Syntagma Square and the X95 bus stop (we arrived in Athens at 1am from the airport). A very warm welcome despite the time, efficient check in and straight to our room. Hadn’t expected an Acropolis view but got one which was a nice touch for my partner as it was his first trip to Greece.  Nice clean room and decent bathroom (something which can be challenging in Athens). We only booked for that one night, but check out was efficient and polite and they stored our bags for us so we had time to look around before moving on to our final destination.
#
# Rating is :  5
#
#
#
#
# User is :latife2021
#
# Review is :I booked a standard room and kept trying to find out if it had a balcony and a view of the acropolis. I even called the hotel but they didn’t have my booking because it was done through a third-party. I booked it through a third-party because there were no rooms available through the hotel. When I eventually arrived at the hotel for five nights that I had already paid for,  I was sent to my standard room which was an interior room which I did not know and it looked onto an ugly wall 2 feet away from the window. It was so small and so depressing. Zero art on the wall, no tissues, no hairdryer and a tiny box that you couldn’t even open a suitcase in. I stayed one night out of the five nights but had to pay for all five nights. I couldn’t wait to get out of there and of course no refund was given. I did ask to change rooms but they were full and told me I had to wait two days until reservations was opened again to see if there was any possibility of changing rooms. Needless to say there were no pictures on their website of what my standard room looked like or  what the outlook looked like. Absolutely horrible. I have provided a picture of the room.,…
#
# Rating is :  1
#
#
#
#
# User is :fionammakou
#
# Review is :We went with friends for drinks and it was lovely. You get an amazing view of the acropolis at the roof top -it’s nice and peaceful not too busy like other central bars etc. You can also book for food. You don’t have to be staying at the hotel to be a customer. Definitely recommend !!!
#
# Rating is :  4
#
#
#
#
# User is :Peter G
#
# Review is :Good location. It’s sort of close to everything between the tourist and shopping sectors and not too far to walk from the x95 bus to the airport.  Afternoon checkin staff are lovely. The morning team are more functional.  Breakfast is a good selection.  The room was a good size but the bathroom a little compact.  Bedding comfortable and air con worked well.  Our acropolis view room did provide a view but you have to open the window and lean out to see it.  Wifi signal was weak and dropped out several times.  We were on level 6 which is immediately below the rooftop restaurant. You can hear sliding of tables and chairs through dinner service until the small hours then about dawn I presume the cleaning crew take over to do their jobs.  I suspect I’d be much happier on any floor apart from level 6.…
#
# Rating is :  4
#
#
#
#
# User is :Spang20
#
# Review is :We had the Family room option, which is very neat. You have your own hallway with 2 separate rooms. Everything was very clean, good location, nice people. The restaurant on the roof has a great view, food was good.
#
# Rating is :  4

# %%
for i in range(10,2000,10):

    driver = webdriver.Chrome(ChromeDriverManager().install())
    url = "https://www.tripadvisor.com/Hotel_Review-g189400-d554815-Reviews-or" + str(i) + "-Central_Hotel-Athens_Attica.html#REVIEWS"
    print("url is \n" + url) 
    driver.get(url)
    time.sleep(10)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    driver.quit()

    
    containers = soup.find_all("div", {"class": "YibKl MC R2 Gi z Z BB pBbQr"})

    
    for index, container in enumerate(containers):
    
        user = container.find("a", {"class": "ui_header_link uyyBf"})
        review = container.find("q", {"class": "QewHA H4 _a"})
        rating = container.find("div", {"class": "Hlmiy F1"})

        rating_value = 0;
        if (str(rating.next) == "<span class=\"ui_bubble_rating bubble_0\"></span>"):
            rating_value = 0
        elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_10\"></span>"):
            rating_value = 1
        elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_20\"></span>"):
            rating_value = 2
        elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_30\"></span>"):
            rating_value = 3
        elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_40\"></span>"):
            rating_value = 4
        else :
            rating_value = 5

        if(review):
            print("User is :" + user.text.strip() + "\n")
            print("Review is :" + review.text.strip() + "\n")
            print("Rating is : ",rating_value)
            data_point = [user.text.strip(),review.text.strip(), rating_value]
            data.append(data_point)
            print("\n")
            print("\n")

        if(index == 9):
            break #since there are 10 contaners with reviews per page
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_14008\1158134796.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# url is
# https://www.tripadvisor.com/Hotel_Review-g189400-d554815-Reviews-or10-Central_Hotel-Athens_Attica.html#REVIEWS
# User is :kambanis1988
#
# Review is :Pros:  The location is great - near the acropolis, Plaka, etc Staff is friendly and helpful  Cons: rooms are super tiny with visible dirt. It’s hard to open the balcony without drawing the curtains fully to the side and even with this it was hard to open to the balcony and it was dirty out there. Also, when they went to clean all these did was make the bed. No refills on soap we went through, etc  We stayed only a day in Athens so it was ok but after a long flight it would have been nice to have a comfy, roomier place to relax.
#
# Rating is :  3
#
#
#
#
# User is :Yiannis K
#
# Review is :The service was exceptional. The quality was way above average. The location is easily accessible from all transportation means. Don’t have any doubt to visit it and trust them for any business or family visit. Congratulations guys. Keep doing the good job.
#
# Rating is :  5
#
#
#
#
# User is :Sandy V
#
# Review is :After a week in Kos, we stayed at the Central  Hotel for 3 nights to explore Athens before heading back to the States. I was pleasantly surprised! Close to everything. Room was super clean, bed was comfy, and room was quiet! Good water pressure too! Thea’s, the rooftop bar, has a view of the Acropolis that would rival any in the city. Drinks were good and my chicken/pasta dish was excellent! Did I mention the view? The breakfasts had several options-fill up here and head out into the city for the day! ALL staff were friendly and helpful without making it seem like an inconvenience - which is rare these days. Cab to the airport is about 40 euros/45 minutes and the concierge organized it for us. Will definitely stay again if I ever get back to Athens!
#
# Rating is :  5
#
#
#
#
# User is :Sara F
#
# Review is :Lovely hotel in a central location. We stayed for 4 days in March and loved the veiws on the roof top bar.  Breakfast was lovely offered a really good selection of both hot and cold food.  Room was spacious and well maintained. Staff were very friendly.   Cons  balcony view was not as prominant from the room had to lean out on very small juliette balcony.
#
# Rating is :  4
#
#
#
#
# User is :The_Glovers_UK
#
# Review is :Stayed at the central hotel during our recent stay in Athens. Staff were friendly and helpful, everywhere was clean, the room was big enough but huge (not the smallest we have ever had either), the breakfast was really good and it lived up to its name in terms of location. Every major attraction was within easy walking distance (accepting that we quite like a walk!).
#
# Rating is :  5
#
#
#
#
# User is :hawaiipid
#
# Review is :Excellent location and price. And that roof top bar called Thea's is OMG!  We really enjoyed the front staff and the room was great. Very good prices and includes a huge full breakfast! Don't pay extra for the Parthenon view from your window. You will see all you need to if you book supper or drinks at sunset (8pm June). (book a month before at least). Easy walk to the Hop on Hop off bus stop #1.
#
# Rating is :  5
#
#
#
#
Central_Hotel-Athens_Attica.html#REVIEWS
# User is :Kay K
#
# Review is :We had a pleasant stay in this hotel. Rooms are modern with a nice bathroom. Staff was friendly and very helpful.  Breakfast was a bit basic, but sufficient. Due to covid breakfast was served at your table by one of the waiters.  What made this hotel very nice, is the rooftop bar with a beautiful view on the Acropolis. Definitely worth it to have a drink there at night!  Besides the rooftop bar, also the location is great. It’s surrounded with good restaurants (Noodlebar and Sushimou I can recommend) and all the famous historical sites can be reached by foot within 15 minutes of the hotel. Moreover, it’s only 2 minutes from the big shopping street.  Would surely come back to this hotel!
#
# Rating is :  4
#
#
#
#
# User is :Mak_T
#
# Review is :Lovely place, very clean. In my opinion the roofgarden is one of the best in the city, with amazing view of Acropolis. Nice people. I recoment it for short stay in the city center, everything around in walking distance, no need to use your car.
#
# Rating is :  5
#
#
#
#
# User is :Lee R
#
# Review is :I travel for work and on this occasion travelled with colleagues. We are booked for 3 nights, out early morning and back late evening. On the 2nd morning I woke up with bed bugs. When I went to reception to change rooms, I was refused a room by lady at the front desk. She didn’t ask me the reason was such a request, so I had lift my sleeves to show here where I have been bitten by bedbugs. After 5mins on the phone, she managed to swap the room. I returned later in the evening and as promised I was given a different room.  However, after a cursory apology from the the front desk in the morning, I hadn’t have any contact from management. It is as if they don’t care. I was not offered to have my laundry and dry cleaning done (to be certain I do not spread the damn bugs), asked if I…
#
# Rating is :  1
#
#
#
#
# User is :Taleah T
#
# Review is :My partner and I, along with his family stayed at the Central Athens Hotel as three couples. The hotel is very clean and updated. We had three rooms on the same floor, each room was a good size and had all the basics. The only thing that had the potential to be an issue were the see through doors to the bathrooms. My partner and I had a room where the bathroom could be seen from the bed area. My partner and I didn’t mind, however this could be an issue for non-couples.  The roof top bar and restaurant is amazing! The food is good and at a reasonable price. The service is great. We loved having drinks on the roof top bar both inside and out.   The reception staff are helpful. We only had one issue were we were told that we couldn’t book a airport transfer until the day before and…
#
# Rating is :  4
#
#
#
#
# User is :Monitours
#
# Review is :Optimal geographical location, walking distance to all major sights of Athens. Roof top terrace/restaurant with excellent Acropolis view and equally excellent food. Very kind, attentive service (restaurant, reception, breakfast).
#
# Rating is :  5
#
#
#
#
# User is :Eric L
#
# Review is :This is a very nice and convenient hotel to stay at in Athens.  Located in the Plaka neighborhood it is a great location to everything you want to do in Athens.  It is easy to get to from either the Syntagma Square or Monastraki metro stops.  It is an easy walk to all the main sights and has a rooftop bar with incredible views of the Acropolis.  The rooms are comfortable and clean and decent sized.  The hotel is modern with all the amenities you'd expect and the staff is very friendly and helpful.  Would recommend for a stay in Athens.
#
# Rating is :  4
#
#
#
#
# User is :ELENA PETROU ELL.
#
# Review is :We stayed 4 nights at  the hotel, in a room two adults with a kid, for b and b. Hotel was small but clean tidy and cozy.  Our room was on first floor, but was small for three people as there was no space for our luggage. Breakfast was nice (served in Menzanie floor) and all employees had a genuine smile on their faces.  Tea and coffee in room were a pleasant surprise. Realy helpful staff and when a small incident happened they were kind enough to help out.  Hotel situated close to all important landmarks of Athens, and walking dinstance to Parthenon and museums shops etc.  Still is in a very quiet area so no noise during night. Will defenately return. Highly recommended.
#
# Rating is :  5
#
#
#
#
# User is :Phil W
#
# Review is :Great location. Loved where it is for historic sites and shopping.  Space in athens is limited so rooms are tiny.  Bed is big. The rooms are clean and included breakfast is pretty good for a free meal. Recommended!
#
# Rating is :  4
#
#
#
#
# User is :Kkkatiegood
#
# Review is :Have just returned from a 4 night stay here, and have thoroughly enjoyed it. Located in the heart of the Plaka, and just a short walk from Syntagma and Monastiraki, it has all the amenities you could ask for - beautiful rooftop bar and restaurant with a lovely view of the Acropolis, wonderful buffet breakfast, modern, decent-sized, clean rooms with tv, tea/coffee facilities, nice hot shower, and hairdryer. Above all, the staff were great...very friendly and helpful.
#
# Rating is :  5
#
#
#
#
# User is :lkdou
#
# Review is :Location was excellent, hotel room was on the smaller side but was clean with good amenities (kettle, hair dryer, TV etc) and a nice balcony, breakfast was lovely and hotel roofbar had stunning views! Would recommend!
#
# Rating is :  5
# url is
# https://www.tripadvisor.com/Hotel_Review-g189400-d554815-Reviews-or60-Central_Hotel-Athens_Attica.html#REVIEWS
# User is :Jill L
#
# Review is :Stayed for 3 nights end Oct/early Nov. Location is good and view from restaurant good, not much else. Hotel room is cramped and dated, no mini bar. The room was dirty too, old curtains and linen. Bed mattress is hard, unable to get a good nights sleep. Hotel service is poor, they do the bare minimum but not much more to assist.The staff seem dis-interested. Breakfast is poor quality buffet, food all seems cheap and processed.  Would definately not stay again, tried to leave after 1 night but as we had pre-paid they refused to refund other nights accomodation.
#
# Rating is :  1
#
#
#
#
# User is :HulaHoop Will Travel
#
# Review is :Thanks for an amazing 2nd visit to Central.  The staff were professional, friendly, and super helpful; the room was lovely; the rooftop restaurant with Acropolis view was spectacular; and the breakfast buffet was the absolute best.  We look forward to our next visit!
#
# Rating is :  5
#
#
#
#
# User is :Diane D
#
# Review is :We recently stayed in the Central and had a lovely time. All the staff were helpful and efficient and the terrace restaurant was excellent.   If there was one thing that didn’t quite excel it was our shower room which was very small. Otherwise, we would thoroughly recommend a visit here.   The location of the hotel in the Plaka district was first class. Everything of interest to us was conveniently near
#
# Rating is :  4
#
#
#
#
# User is :Lizrdking
#
# Review is :The Central was clean and modern inside and a easy walks from Syntagma Square, The Acropolis and Monistraki, in fact we walked everywhere! The view from the restaurant upstairs of the Acropolis is stunning. But you'll pay high for a drink there. The buffet breakfast was fair but ask for your eggs and bacon to be microwaved! The coffee machine was really nice !
#
# Rating is :  4
#
#
#
#
# User is :Paul
#
# Review is :Although the property is listed as a 3 star, the accomodations were excellent and the staff were outstanding!  I picked the hotel for it's great location for walking access to most of the places I wanted to see while in Athens and it was a good decision.  The immediate surrounding businesses are a mix, and not high gloss, there are wonderful shops and restaurants very close by.  And, the bar/restaurant at the hotel have a nice menu and a KILLER view of the Acropolis.  I would highly recommend this hotel.
#
# Rating is :  5
#
#
#
#
# User is :Rick Linda G
#
# Review is :The beautiful rooftop bar and restaurant at the Central Athens Hotel made up for the sparse room and rude front desk staff.  There are many hotels in Athens.  Next time we'll stay in another and just go to the bar!
#
# Rating is :  3
#
#
#
#
# User is :Rohit RC
#
# Review is :The hotel staff was kind enough to guide us with the places to visit using a local map. The places are almost in a circular route - all around this hotel. Starting with the acropolis to the museum, stadium, parliament etc.  The local market area, flea market is also quite close - 5 min walk. It’s close to the Monastiraki metro station.  The hotel itself is very neat and professionally managed. The staff are courteous. The rooms are spacious, well designed and clean. The one we were in had a small balcony good enough to get a sunset view and a view of the acropolis top.  The roof top bar and restaurant is a great place to spend the evening during sunset. Get some good food, drinks and sunset photographs.  The wifi is excellent.
#
# Rating is :  5
#
#
#
#
# User is :JONYEM
#
# Review is :Beautiful Hotel in a great location.  The hotel is very modern and all of the staff is so nice,  courteous, friendly and professional .   It is a European city style  hotel,  so the rooms are small as we expected, but they were very clean with modern updates  and with a big comfortable king size bed .   They have a roof top restaurant that has a great view of the Acropolis. The menu was a little bit limited but the food was very good.  The location cannot be beat . You are in walking distance to Monastiraki Square , Plaka and the Acropolis.  Oh and a very nice buffet breakfast is included. 4 stars because of room size otherwise 5 stars for everything else
#
# Rating is :  4
#
#
#
#
# User is :Helen
#
# Review is :We liked this hotel and the location is great. The best thing about it is the rooftop bar and the view of the Acropolis. The room is small and clean, but nothing spectacular. The bathroom is also very small and not large enough for 2 people to get ready. The price point is very good though.
#
# Rating is :  4
#
#
#
#
# User is :Warren P
#
# Review is :Neat and tidy venue and location to Plaka shopping very good. 10-15 minutes walk to the Acropolis. Staff cold and unwelcoming and wifi in level 3 room terrible. Nice waiting zone behind reception with better wifi. Breakfast good value
#
# Rating is :  3
#
#
#
#
# url is
# https://www.tripadvisor.com/Hotel_Review-g189400-d554815-Reviews-or70-Central_Hotel-Athens_Attica.html#REVIEWS
# User is :Diana H
#
# Review is :The hotel is a small boutique one.  Rooms are very small for 2 persons but beds and amenities were comfortable. It is situated in the old city of Athens and the roads being very narrow, you may have to be dropped off by coach and walk for about 500m to the hotel.   It was close to restaurants and the hop on and off bus.   Staff are helpful and the breakfast delicious and a good selection to choice.
#
# Rating is :  4
#
#
#
#
# User is :BeniciaChris
#
# Review is :Small room. Noisy.  Glass in bathroom wall so when hubby got up to go to bathroom the room lit up. Even with an eye mask. Opened window to see acropolis & ac shut off.  I had to call desk to hav3 them turn on
#
# Rating is :  1
#
#
#
#
# User is :Volodymyr K
#
# Review is :I enjoyed staying in the hotel. Clean room, helpful staff, perfect location at walking distance to reach all major attractions at Athens. Although room is not so large, large balcony makes difference. I enjoyed this feature, especially taking into account the fact that I am a smoker.
#
# Rating is :  5
#
#
#
#
# User is :BevCQ
#
# Review is :Wonderful Hotel!! We were so pleased with everything the rooms were small but all we needed!! Close to everything! Highly recommend!  There daily breakfast is beyond words! Just excellent I would come back just for the breakfast!  Beautiful view of Acropolis!! Great location! Wonderful Staff! Again Highly Recommend! 5 stars!
#
# Rating is :  5
#
#
#
#
# User is :grey_hare63
#
# Review is :The hotel is well located within a few minutes walk to major sights in Athens. We had a view of the Acropolis from our room and the veiws from the rooftop terrace are stunning.  The room was clean and comfortable and the staff are pleasant.  Breakfast was good. The only shortcomings were the lack of complimentary bottled water, room slippers and a box of tissues in the room which we felt should be standard.   Tip: It's a few minutes walk to Syntagma Square where you can grab the Airport Bus X96 to and from the airport if you don't have a lot of luggage.
#
# Rating is :  4
#
#
#
#
# User is :Ed G
#
# Review is :The room and service was excellent. You must have drinks on the rooftop and enjoy view of the Parthenon and city at night. Drinks were very creative. Breakfast was good, traditional Greek fare. Very quiet for the location.
#
# Rating is :  5
#
#
#
#
# User is :Virginia
#
# Review is :Great location. Beautiful view of Acrópole. Staff was very friendly and the restaurant on rooftop is as good as they say. It’s only about 20 minutes from port and around 12/15 euros by taxi. Great restaurants around since hotel is a 3 min walk from Plaka
#
# Rating is :  4
#
#
#
#
# User is :318ise
#
# Review is :Pros: excellent position for visiting all the historical sights and museums. Good location for restaurants and transport links. Great view of the Acropolis from the rooftop restaurant. Good price. Helpful friendly staff. We would definitely stay there again.  Cons: small room in need of updating.
#
# Rating is :  4
#
#
#
#
# User is :Samir Conrado Jorge
#
# Review is :In great location just a short walk from Plaka this hotel delivers everything you could wish for such a fair price. Our room was comfortable with a nice bed and shower. The Acropolis View we had from our room was inspiring and the view you get to it from the restaurant on the rooftop is even more incredible. The staff is really helpful with a special remind of Nikos who knowing that we'd leave the hotel before the breakfast time prepared a special treat, a bag with apples, yogurt, orange juice and a a couple of sandwiches. Very thoughtful. I highly recommend the place if you're looking for a good hotel at a fair price.
#
# Rating is :  4
#
#
#
#
# User is :surya77
#
# Review is :While we were staying at the Hydroussa Hotel in Hydra, the receptionist mentioned to me that the owner also had a hotel in Athens; a hotel with a roof top terrace that has an AMAZING view of the Acropolis, so beautiful that many people come for dinner and drinks just to enjoy that. As we were in need of a room in Athens for 1 night, we followed her recommendation and booked a room. The roof terrace and the view is undoubtedly stunning. The location is great; just a minutes walk from Plaka. Not so good for parking, though. We could not even find space to unload our luggage. Had to just stop the traffic. We left our car at a paying parking on the side street. The hotel itself is modern and clean. We were upgraded to a room on the 6th floor and I strongly recommend that you choose…
#
# Rating is :  4
# url is
# https://www.tripadvisor.com/Hotel_Review-g189400-d554815-Reviews-or80-Central_Hotel-Athens_Attica.html#REVIEWS
# User is :jhony
#
# Review is :good and simple hotel ,clean,nice staff, perfect location 10 min walking distence from   any intrest place best Breakfast , the elevator is small and slow but no problem with it. i think i will visit here again
#
# Rating is :  4
#
#
#
#
# User is :NikeshGala
#
# Review is :we stayed here for 2 nights on the 5th floor & other 2 on the 4th floor, Thea the roof top cafe is on the 7th floor, so the higher u stay, the better u get the view of Acropolis & try staying on the rooms ending with 05, 06, 07 numbers, they would have a better view. the staff is friendly, they can book transfers & day trips for you too..
#
# Rating is :  5
#
#
#
#
# User is :nicola m
#
# Review is :I’d seen lots of photos of the acropolis from the terrace but I still stopped Jaw dropped it’s so much closer than it looks on the photos, you could never get tired of that view, only surprise was the jacuzzi was gone 😢 bikinis back in the suitcase then would really set the hotel off if the side terrace was open with a plunge pool and sun loungers. Standard room is cosy but do-able not enough drawers for clothes and paper cups for coffee? Really ? The hotel is modern and cool in the intense heat, breakfast room is stunning and all food lovely roof top breathtaking. Just needs a pool of some sort as so far away from the coast.
#
# Rating is :  5
#
#
#
#
# User is :Karl K
#
# Review is :A lovely hotel tucked away in the centre of Athens. Great customer service, Great breakfast and literally 2 minute walk to the main thoroughfares of central Athens. Easy to access from the airport bus stop in the square. Fantastic restaurants within 5 minutes of the hotel. Highly recommended.
#
# Rating is :  4
#
#
#
#
# User is :Kelly H
#
# Review is :The hotel staff are super nice and helpful and the room is adquate. We had a private deck which was perfect to have a cup of coffee on and soak in the sights. The roof top though, it is absolutly breathtaking. Day or night the view is worth everything!
#
# Rating is :  5
#
#
#
#
# User is :Globetrotter101
#
#
# Rating is :  5
#
#
#
#
# User is :LOM-NYC
#
# Review is :Note that I have not yet stayed in this hotel, but I have reservations for late August.       The reason for my review is because the communication with the hotel is extremely bad.  Before booking I contacted the hotel via e-mail and they answered immediately. But after booking I have been trying to contact them again for some matters regarding my reservation (at least 6 times), via e-mail and through their web page and I have not gotten a reply yet.        So, if you want a hotel which will be easy to communicate with, this is not for you, but if you don't mind having to call direclty and spend A LOT of money on phone calls, then go ahead.
#
# Rating is :  2
#
#
#
#
# User is :rustyg99
#
# Review is :We stayed at the Central Athens Hotel in June 0f 2006.  We found the room to be dirty.  The carpet was rough siisel type material.  Therre was a very large black stain around the refrigerrator and the carpet itself was not clean.  The room was for three people, the third bed was very uncomfortable and consisted of a fold out cot type bed with very flimsy slats that did not support the body of a 15 year old boy who is average weight and height. The people running the hotel were friendly and helpful and the breakfast buffet was good. Perhaps we just had a bad room.  I booked this hotel on recommendation of a travel agency in Athens and checked reviews before I finalized the hotel stayd.  Almost all the reviews were very good.  So perrhaps I just had a bad room.  At 165 euros per…
#
# Rating is :  2
#
#
#
#
# User is :ajmita
#
# Review is :My family and I really liked the Central Hotel in Athens.  It's a very short walk from Syntagma Square where the Metro stop is.  It's well situated in the Plaka near several nice eateries and also very close to the main shopping street.  My husband and I were travelling with our kids, ages 5 and 10.  We stayed in a "family suite" that had two seperate bedrooms with attached baths with a connecting passage.  It was great to have two bathrooms as well as privacy and a little extra space.  It was good value for money too.    I do agree with a previous reviewer that the bathroom with the frosted glass window would probably not be comfortable for people who were travelling together but did not know each other very well.  But for family/spouses/near and dear friends it's fine.  I…
#
# Rating is :  5
#
#
#
#
# User is :chicca62
#
# Review is :We are just back from Athens. Central hotel is  nice, clean and centrally located. You can reach the Cathedral in 1 minute and the Ancient Agora in less than 5. Rooms are small, but clean and the view from the roof garden is gorgeous. Staff at the reception desk is kind and helpful, as well as the staff at the buffet breakfast. We were allowed to keep one room until 2 pm and were also helped in finding a pharmacy on Saturday (almost all pharmacies are closed on Saturdays and the ones which should be open, are closed as well...). In order to find good prices, I would recommend contacting the hotel directly by e-mail. Have a nice stay in Athens!
#
# Rating is :  5
#
#
#
#
# User is :MartineB
#
# Review is :We stayed at the Central Hotel in 1988 when it was called the Aphrodite, and liked it then for its great location, view of the Acropolis from some rooms, the great roof-top terrace, friendly and helpful staff, and air conditioning which worked well in the summer, all at a reasonable price.  As the Central, it still has all of these things.  It was re-done a few years ago, with a great decor.  However, we found one major problem, which was that the high-concept decor, which looks great, has the bathroom wall in etched glass, with some clear areas, making the bathroom not all that private.  In addition, the glass door to the bathroom does not reach the top or bottom of the door frame, so there is little privacy from that standpoint, either. If this kind of thing would not bother…
#
# Rating is :  4
#
#
#
#
# User is :genevakiwi
#
# Review is :This hotel is located in a small side street in the Plaka area.  The street doesn't have much on it, and is a small dark street, but don't let this put you off. The location is excellent, within easy distance of the main shopping areas and many of the major attractions. Plenty of restaurants nearby. The rooms were clean, even if the carpet was a bit stained and worn, and the size adequate. Many rooms have a private balcony. Breakfast was nothing special but good enough. The best part of the hotel was the roof terrace with a fantastic view of the Acropolis. Although there was a bar up there it was never staffed. You can order drinks from room service, or purchase wine and food from local stores and bring your own. The rooftop jacuzzi was disturbingly dirty the night we arrived…
#
# Rating is :  4
#
#
#
#
# User is :NYCshopper
#
# Review is :We were recommended this hotel by our ground operator.  The rooms were small, clean and did look at the Acropolis from the back.  They were quiet and the AC worked great.  Breakfast was very good and the staff were very friendly.  The location of this hotel was EXCELLENT and right in the Plaka where you could walk anywhere and have a great meal and shop without having to take taxi's.  One of the nicest features of this hotel is a GEORGEOUS roof deck with Jacuzzi's and a bar where you overlook the acropolis at night and can have sunset drinks or evening drinks with a spectacular view.   Enjoy!
#
# Rating is :  5
# url is
# https://www.tripadvisor.com/Hotel_Review-g189400-d554815-Reviews-or1480-Central_Hotel-Athens_Attica.html#REVIEWS
# url is
# https://www.tripadvisor.com/Hotel_Review-g189400-d554815-Reviews-or1490-Central_Hotel-Athens_Attica.html#REVIEWS
# url is
# https://www.tripadvisor.com/Hotel_Review-g189400-d554815-Reviews-or1500-Central_Hotel-Athens_Attica.html#REVIEWS
# url is
# https://www.tripadvisor.com/Hotel_Review-g189400-d554815-Reviews-or1510-Central_Hotel-Athens_Attica.html#REVIEWS
# url is
# https://www.tripadvisor.com/Hotel_Review-g189400-d554815-Reviews-or1520-Central_Hotel-Athens_Attica.html#REVIEWS
# url is
# https://www.tripadvisor.com/Hotel_Review-g189400-d554815-Reviews-or1530-Central_Hotel-Athens_Attica.html#REVIEWS
# url is
# https://www.tripadvisor.com/Hotel_Review-g189400-d554815-Reviews-or1540-Central_Hotel-Athens_Attica.html#REVIEWS
# url is
# https://www.tripadvisor.com/Hotel_Review-g189400-d554815-Reviews-or1550-Central_Hotel-Athens_Attica.html#REVIEWS
# url is
# https://www.tripadvisor.com/Hotel_Review-g189400-d554815-Reviews-or1560-Central_Hotel-Athens_Attica.html#REVIEWS
# url is
# https://www.tripadvisor.com/Hotel_Review-g189400-d554815-Reviews-or1570-Central_Hotel-Athens_Attica.html#REVIEWS
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
#       4 url = "https://www.tripadvisor.com/Hotel_Review-g189400-d554815-Reviews-or" + str(i) + "-Central_Hotel-Athens_Attica.html#REVIEWS"
#       5 print("url is \n" + url)
# ----> 6 driver.get(url)
#       7 time.sleep(10)
#       8 soup = BeautifulSoup(driver.page_source, 'html.parser')
#
# File ~\anaconda4\lib\site-packages\selenium\webdriver\remote\webdriver.py:441, in WebDriver.get(self, url)
#     437 def get(self, url: str) -> None:
#     438     """
#     439     Loads a web page in the current browser session.
#     440     """
# --> 441     self.execute(Command.GET, {'url': url})
#
# File ~\anaconda4\lib\site-packages\selenium\webdriver\remote\webdriver.py:427, in WebDriver.execute(self, driver_command, params)
#     424         params['sessionId'] = self.session_id
#     426 params = self._wrap_value(params)
# --> 427 response = self.command_executor.execute(driver_command, params)
#     428 if response:
#     429     self.error_handler.check_response(response)
#
# File ~\anaconda4\lib\site-packages\selenium\webdriver\remote\remote_connection.py:344, in RemoteConnection.execute(self, command, params)
#     342 data = utils.dump_json(params)
#     343 url = f"{self._url}{path}"
# --> 344 return self._request(command_info[0], url, body=data)
#
# File ~\anaconda4\lib\site-packages\selenium\webdriver\remote\remote_connection.py:366, in RemoteConnection._request(self, method, url, body)
#     363     body = None
#     365 if self.keep_alive:
# --> 366     response = self._conn.request(method, url, body=body, headers=headers)
#     367     statuscode = response.status
#     368 else:
#
# File ~\anaconda4\lib\site-packages\urllib3\request.py:78, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
# ---> 78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File ~\anaconda4\lib\site-packages\urllib3\request.py:170, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     167 extra_kw["headers"].update(headers)
#     168 extra_kw.update(urlopen_kw)
# --> 170 return self.urlopen(method, url, **extra_kw)
#
# File ~\anaconda4\lib\site-packages\urllib3\poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File ~\anaconda4\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~\anaconda4\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda4\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~\anaconda4\lib\http\client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File ~\anaconda4\lib\http\client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File ~\anaconda4\lib\http\client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File ~\anaconda4\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
df = pd.DataFrame(data, columns=['User', 'Review','Rating'])

# %%
df.shape
# Out:
# (1478, 3)

# %%
df.tail()
# Out:
#             User                                             Review  Rating
# 1473      ajmita  My family and I really liked the Central Hotel...       5
# 1474    chicca62  We are just back from Athens. Central hotel is...       5
# 1475    MartineB  We stayed at the Central Hotel in 1988 when it...       4
# 1476  genevakiwi  This hotel is located in a small side street i...       4
# 1477  NYCshopper  We were recommended this hotel by our ground o...       5

# %%
filepath = Path('central.csv') 
df.to_csv(filepath, index=False)
