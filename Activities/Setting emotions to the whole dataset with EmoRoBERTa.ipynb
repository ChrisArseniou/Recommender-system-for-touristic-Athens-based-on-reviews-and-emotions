# %%
import pandas as pd
import numpy as np
import scipy
import math

# %%
from  google.colab  import  drive 
drive.mount ( '/content/drive' )
# Out:
# Mounted at /content/drive

# %%
! pip install transformers -q
# Out:
#      |████████████████████████████████| 5.5 MB 36.3 MB/s
#      |████████████████████████████████| 163 kB 76.4 MB/s
#      |████████████████████████████████| 7.6 MB 76.4 MB/s

# %%
from transformers import pipeline

# %%
emotion = pipeline('sentiment-analysis', model='arpanghoshal/EmoRoBERTa')
# Out:
# Downloading:   0%|          | 0.00/1.72k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/501M [00:00<?, ?B/s]
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# All the layers of TFRobertaForSequenceClassification were initialized from the model checkpoint at arpanghoshal/EmoRoBERTa.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForSequenceClassification for predictions without further training.
# Downloading:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]

# %%
def get_emotion_label(text):
  #text = str(text) # απαραίτητο όταν εξάγουμε το συναίσθημα από τον τίτλο
  text = text[:250] # απαραίτητο όταν εξάγουμε το συναίσθημα από τον κείμενο
  print((text))
  print('\n')
  return(emotion(text)[0]['label'])

# %%
#hotels = pd.read_csv('/content/drive/MyDrive/ΕΙΔΙΚΟ ΘΕΜΑ/To Do Reviews/activities.csv')
#ratings = pd.read_csv('/content/drive/MyDrive/ΕΙΔΙΚΟ ΘΕΜΑ/To Do Reviews/ratings.csv')
#df = hotels.merge(ratings, how="left", on="ActivityId")
df = pd.read_csv('/content/drive/MyDrive/ΕΙΔΙΚΟ ΘΕΜΑ/To Do Reviews/reviews_with_emotions_from_title.csv')
df.head()
# Out:
#    Unnamed: 0  ActivityId       Name  UserId  \
# 0           0           1  acropolis       1
# 1           1           1  acropolis       2
# 2           2           1  acropolis       3
# 3           3           1  acropolis       4
# 4           4           1  acropolis       5
#
#                                          ReviewTitle  \
# 0                           Acropolis - Breathtaking
# 1                               Crowded but fabulous
# 2  You can't go to Athens and fail to visit the A...
# 3                                         A must see
# 4                                     Awesome place.
#
#                                               Review EmotionFromTitle
# 0  What an experience. I highly recommend doing t...       admiration
# 1  Been there back in 1989 when you could walk an...       admiration
# 2  The Acropolis is actually the name of the hill...          neutral
# 3  You can’t visit Athens without visiting the Ac...          neutral
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0  ActivityId   Name  UserId                 ReviewTitle  \
# 11991       11991          11  plaka    1446     Best Place for Shopping
# 11992       11992          11  plaka    1447           A weekend of rest
# 11993       11993          11  plaka    1448  Shopping and more shopping
# 11994       11994          11  plaka    1449                Interesteing
# 11995       11995          11  plaka    1450                Walking Tour
#
#                                                   Review EmotionFromTitle
# 11991  This is by far my favourite part of Athens. Th...       admiration
# 11992  If you are visiting Athens it would be a crime...           relief
# 11993  I went here for a day of shopping and it was f...          neutral
# 11994  Very interesting area with lovely choices of m...       excitement
# 11995  Excellent area for walking, shopping, eating a...          neutral

# %%
df.shape
# Out:
# (11996, 7)

# %%
df['EmotionFromText'] = df['Review'].apply(get_emotion_label)
# Out:
# Η έξοδος ροής περικόπηκε στις τελευταίες 5000 γραμμές.
#
#
# Seeing one of the Worlds best known structures up close is quite breathtaking.  It would be nice if one could go into it but sadly it is under refurbishment. As others have said go early in the morning or late at night as it is extremely hot on the A
#
#
# You should go and see this place beautiful lots of cultural. No problem walking but if you have bad knees take bus or taxi.
#
#
# Wonderful structures that could withstands people abuse, wars, and natural disasters for thousands of years.
#
#
# The most beautiful archaeological ruin in the world. It’s hot so go first thing in the morning. Buy a ticket before you get to the gate. The museum is also first class. You must go.
#
#
# a must see but go early or late to avoid the crowds and heat.  one should also include the museum to get a full appreciation
#
#
# ...

# %%
df
# Out:
#        Unnamed: 0  ActivityId       Name  UserId  \
# 0               0           1  acropolis       1
# 1               1           1  acropolis       2
# 2               2           1  acropolis       3
# 3               3           1  acropolis       4
# 4               4           1  acropolis       5
# ...           ...         ...        ...     ...
# 11991       11991          11      plaka    1446
# 11992       11992          11      plaka    1447
# 11993       11993          11      plaka    1448
# 11994       11994          11      plaka    1449
# 11995       11995          11      plaka    1450
#
#                                              ReviewTitle  \
# 0                               Acropolis - Breathtaking
# 1                                   Crowded but fabulous
# 2      You can't go to Athens and fail to visit the A...
# 3                                             A must see
# 4                                         Awesome place.
# ...

# %%
df.shape
# Out:
# (11996, 8)

# %%
filepath = '/content/drive/MyDrive/ΕΙΔΙΚΟ ΘΕΜΑ/To Do Reviews/reviews_with_emotions_full.csv'
df.to_csv(filepath, index=False)
