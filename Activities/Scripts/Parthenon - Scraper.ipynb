# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import re
import time
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
from pathlib import Path

# %%
data = []

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
url = "https://www.tripadvisor.com/Attraction_Review-g189400-d198711-Reviews-Parthenon-Athens_Attica.html#REVIEWS"
print("url is \n" + url)
driver.get(url)
time.sleep(10)
soup = BeautifulSoup(driver.page_source, 'html.parser')
driver.quit()
# Out:
# <ipython-input-3-8d741c594283>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d198711-Reviews-Parthenon-Athens_Attica.html#REVIEWS

# %%
containers = soup.find_all("div", {"class": "_c"})

# %%
len(containers)
# Out:
# 11

# %%
user = containers[4].find_all("a", {"class": "BMQDV _F G- wSSLS SwZTJ FGwzt ukgoS"})

# %%
user[0].text.strip()
# Out:
# 'Darlene M'

# %%
review_header  = containers[4].find("span", {"class": "yCeTE"})
review_text = containers[4].find("div", {"class": "biGQs _P pZUbB KxBGd"})

# %%
review_header.text.strip()
# Out:
# 'Must See'

# %%
review_text.text.strip()
# Out:
# 'If you go to Athens all the touristy sites are a must see! Lots of line ups but worth seeing and the views are amazing!'

# %%
for index, container in enumerate(containers):
    
    user = container.find_all("a", {"class": "BMQDV _F G- wSSLS SwZTJ FGwzt ukgoS"})
    review_header  = container.find("span", {"class": "yCeTE"})
    review_text = container.find("div", {"class": "biGQs _P pZUbB KxBGd"})
    
    if(review_header):
        print("User is :" + user[0].text.strip() + "\n")
        print("Review header is :" + review_header.text.strip() + "\n")
        print("Review text is :" + review_text.text.strip() + "\n")
        data_point = [user[0].text.strip(),review_header.text.strip(), review_text.text.strip()]
        data.append(data_point)
        print("\n")
        print("\n")
        
    if(index == 10):
        break #since there are 10 contaners with reviews per page but the first one is empty
# Out:
# User is :Amy
#
# Review header is :So Impressive
#
# Review text is :Unfortunately covered with a great deal of scaffolding, but can’t complain if the restoration means it will be here for others to enjoy for centuries to come! Visiting in November, we didn’t need to queue for entry & it wasn’t too crowded at all. The temperature was also more comfortable for the climb up! Seeing the Parthenon close up really makes you appreciate the history & impressive architecture of the Ancient Greeks.
#
#
#
#
#
# User is :Cynthia N
#
# Review header is :Stunning Achievement of Greek's Classical Age
#
# Review text is :Coming up to the Parthenon is truly breaktaking! This building has had such an impact on the world, it is a "must-see"!
#
#
#
#
#
# User is :David N
#
# Review header is :Must See if you Visit Athens
#
# Review text is :This is well worth the walk to the top.  The views are fantastic and the feeling of history you get from the structure is amazing.
#
#
#
#
#
# User is :Darlene M
#
# Review header is :Must See
#
# Review text is :If you go to Athens all the touristy sites are a must see! Lots of line ups but worth seeing and the views are amazing!
#
#
#
#
#
# User is :Carlozik
#
# Review header is :Must-see historical monument
#
# Review text is :Someone below commented "Just entering the Akropolis - I truly had to take a deep breath. One becomes very aware of the weight of the history." - I don't mean to steal another person's comment, but this summarizes it quite perfectly! I was speechless when seeing the Parthenon, I wanted to do this for such a long time! Great experience for sure. I'm fascinated by the history but I can imagine it can be appealing also for the people not interested in it that much. Hopefully it will stand for another thousands of years!
#
#
#
#
#
# User is :Jazen
#
# Review header is :Short but nice!
#
# Review text is :Went w/ a colleague from cruise line. Took a taxi from outside the cruise terminal, 25€ each round trip.  Was pick season.
#
#
#
#
#
# User is :Questovia
#
# Review header is :The Crown of Athens
#
# Review text is :What a treat to finally see this symbol of Greek mythology. Granted it's still under restoration, but that doesn't take away from the awe of the structure at all.
#
#
#
#
#
# User is :Warren N
#
# Review header is :Went with our tour guide, Joanna, from Siva Travel services.  Extremely knowledgeable of the history and the ruins.
#
# Review text is :Excellent tour of the Acropolis and the Acropolis Museum.  Our guide was extremely knowledgeable of the history and the artifacts.  Then when you go to the Acropolis museum, it really ties everything together in your mind.
#
#
#
#
#
# User is :Ian P
#
# Review header is :Being treated as a Disney attraction
#
# Review text is :Please not that I am not ignorant of the importance of the site to the cultural history of the world, but I was somewhat disappointed in the way the Athenians have chosen to present it. I agree with many others - the crowds do tend to ruin it, as they seem to only wish to take selfies, but one cannot really blame the site for that! What is irksome is that the ongoing debate between maintaining an ancient site and reconstructing it could well be focused on this very building. It sits, at present, on a very obvious modern concrete plinth, and is a building works. Quite clearly a lot of the features are being replaced in what is believed to be their original place with the aid of steel and concrete. It greatly improves its silhouette against the sky beloved of a million tourist photos, but it's not original. Similarly, the ancillary buildings on the site have the look of 'let's see if this stone will fit here'. It's an ongoing debate, and I agree others prefer a reconstruction to a heap of stones, but - personally- I think it's being taken too far.
#
#
#
#
#
# User is :M W
#
# Review header is :Breathtaking
#
# Review text is :I went really early in the morning - was 2nd in line at 8AM. Great time as it was pretty cold and the sun was not too hot. Just entering the Akropolis - I truly had to take a deep breath. One becomes very aware of the weight of the history. Buy the 30 Euro multi site ticket for 5 days. Totally worth it.

# %%
for i in range(10,1400,10):

    driver = webdriver.Chrome(ChromeDriverManager().install())
    url = "https://www.tripadvisor.com/Attraction_Review-g189400-d198711-Reviews-or" + str(i) + "-Parthenon-Athens_Attica.html"
    print("url is \n" + url) 
    driver.get(url)
    time.sleep(10)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    driver.quit()

    
    containers = soup.find_all("div", {"class": "_c"})

    
    for index, container in enumerate(containers):
    
        user = container.find_all("a", {"class": "BMQDV _F G- wSSLS SwZTJ FGwzt ukgoS"})
        review_header  = container.find("span", {"class": "yCeTE"})
        review_text = container.find("div", {"class": "biGQs _P pZUbB KxBGd"})

        if(review_header):
            print("User is :" + user[0].text.strip() + "\n")
            print("Review header is :" + review_header.text.strip() + "\n")
            print("Review text is :" + review_text.text.strip() + "\n")
            data_point = [user[0].text.strip(),review_header.text.strip(), review_text.text.strip()]
            data.append(data_point)
            print("\n")
            print("\n")

        if(index == 10):
            break #since there are 10 contaners with reviews per page
# Out:
# <ipython-input-12-98029f1522b4>:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d198711-Reviews-or10-Parthenon-Athens_Attica.html
# User is :R Potton
#
# Review header is :Must see but crowded
#
# Review text is :Of course it is the must visit place in Athens but it looks less impressive close up than from a roof top bar. It is a hike to get there made worse by the crowds and narrow entrance. Glad i did it but like many world monuments it can be an anti climax
#
#
#
#
#
# User is :Bejul Shah
#
# Review header is :A wonderful site to visit.
#
# Review text is :A wonderful site to visit and walk round to see the ruins. You could easily spend a couple of hours walking up to and around the Parthenon.Get there early to avoid the heat but to also avoid the crowd.Buy a ticket in advance to bypass the ticket queue but do remember that you still need to queue for entry.
#
#
#
#
#
# User is :paul and monica h
#
# Review header is :Amazing views
#
# Review text is :Worth the visit and time to get there. Views over the whole of Athens and its truly a magnificent site when you see it.
#
#
#
#
#
# User is :DougD72
#
# Review header is :Worth the hike!
#
# Review text is :Its a bit of a hike to get to the top but it is worth it to stand at the opening of one of the most famous buildings in history.
#
#
#
#
#
# User is :JamesM-n-KC
#
# Review header is :Worth The Trip
#
# Review text is :Nothing one can add that isn't already well known - a once in a lifetime experience well worth the time and expense if possible.
#
#
#
#
#
# User is :nancy h
#
# Review header is :Amazing!!!
#
# Review text is :I knew that we would enjoy this but wow! It was more impressive than I expected. We purchased tickets online and were there when the gates opened at 8:00 and we had it to ourselves.
#
#
#
#
#
# User is :Cameron C
#
# Review header is :My Inner Child Was Thrilled
#
# Review text is :All I can say is that the 10-year old history and Greek Gods nerd that still is inside of me was elated beyond his imagination!The size of the Parthenon itself is amazing.  The height of the columns combined with the length and the width is something that you really aren't prepared for. It is a beautiful site to behold as you are walking up the path that brings you along the Temple of Nike and the original Temple of Athena before cresting the hill and reaching the top.  Once at the top and out of the line you can mingle around and see other lesser known temples and ruins.  A bonus to waiting in line and getting to the top is the view of Athens and the surrounding areas.  You can see all of the way to the foothills of the mountains, as well as the Mediterranean.100% worth any wait in line to get there, and the view at night when it is lit up is unreal.
#
#
#
#
#
# User is :Jimvin
#
# Review header is :One of THE sites of the world, it does get busy so time it right.
#
# Review text is :I would recommend to do the museum first before you head up top, as you will get some good background to the site.  It is incredible but it can be very busy, go early or go late on my opinion. Be aware it is constantly being restored so you are unlikely to get that perfect shot.
#
#
#
#
#
# User is :Senioronabudget
#
# Review header is :Amazing architecture
#
# Review text is :It is amazing that even after all the termoil it is still standing.  Just looking at it and wondering how the ancients carved the stones, leveled the ground and built it.
#
#
#
#
#
# User is :G Egg
#
# Review header is :Great views, huge crowds
#
# Review text is :Experience was basically fine, but the ticket takers were rude and unhelpful.  Also, avoid going on European Heritage Day or any other holiday since you'll feel like cattle when climbing up the acropolis.
#
#
#
#
#
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d198711-Reviews-or20-Parthenon-Athens_Attica.html
# User is :Heidi B
#
# Review header is :Be prepared to wait in line
#
# Review text is :An absolute must see. There is so much to take in. Just stunning how Athens has built this huge stunning city around such an incredible landmark.The process to get in, however, is lacking. Be prepared to stand in line…a long time. It was approximately a half hour line to get tickets. All of the selves serve options were out of service. We were easily another 45 minutes to an hour after purchasing tickets to get in as the QR code reader doesn’t easily read the tickets.   They could absolutely streamline this process and make it much faster.
#
#
#
#
#
# User is :gd275
#
# Review header is :A must see
#
# Review text is :Excellent, make sure you take the pathway around the entire site.  A long but unforgettable experience.  Take plenty of water to drink along the way.  The site has been really well looked after and really clean and interesting.
#
#
#
#
#
# User is :andygee2015
#
# Review header is :The Eighth Wonder Of the World
#
# Review text is :This should be the eighth wonder of the world... no words can describe the feeling of emotion and euphoria when visiting the Parthenon, thousands of years of history... truly a great moment
#
#
#
#
#
# User is :jayfish420
#
# Review header is :Amazing. Everything you expected and more. Feel the depth of history.
#
# Review text is :I mean, what can you say about the most incredible Classical site of Western Civilization? Just amazing.
#
#
#
#
#
# User is :Gints K
#
# Review header is :Not worth time
#
# Review text is :Best from distance, ruins of stone. In best days the place was amazing, but now it is overrated attraction.
#
#
#
#
#
# User is :Prophet9fla
#
# Review header is :Classic must see
#
# Review text is :Historical venue, in good weather the walk is not too difficult.   Construction/remodeling is ongoing and for people with mobility issues it would be good to take it slowly and carefully.
#
#
#
#
#
# User is :Golligosh123
#
# Review header is :Not to be missed
#
# Review text is :We didn't have a guide and maybe next time I would or get an audio service.  It really is amazing, we went mid afternoon and there was hardly any queing.   I would highly recommend and it is not to be missed.  Such an incredible place and the views when it is lit up at night are mesmerising.
#
#
#
#
#
# User is :Jan R
#
# Review header is :Get there early!
#
# Review text is :It is incredible! But get there when the gates open at 8 AM before the buses come. When the buses unload it is very hard to move around and take pictures.
#
#
#
#
#
# User is :Barry F
#
# Review header is :Amazing History
#
# Review text is :No way to describe the history. A guide is a must, and we took a private tour from Antelope Travel, feeling we'd get the best education that way
#
#
#
#
#
# User is :Chris on tour
#
# Review header is :Busy busy
#
# Review text is :The whole area is heaving with people. That said you can still get to see the main sites. An impressive place and youcan always nip to London to see the rest of it.
#
#
#
#
#
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d198711-Reviews-or30-Parthenon-Athens_Attica.html
# User is :Jim F
#
# Review header is :Must See
#
# Review text is :Buy a ticket on-line with an audio tour if you are going, Not a lot of info up on the Acropolis. Go early in the day or after 4:00 pm to avoid the crowds.
#
#
#
#
#
# User is :geologymom
#
# Review header is :Very Impressive!
#
# Review text is :This wonderful building holds a special place in my family, as my dad treasures a photo he took here at the end of the war when he was in the Navy.  There are so many details to observe that it is important to research it before you get here as it might not be obvious  I was on a private tour, so I might not have looked carefully, but if you rely on the signs, I think you will be missing things, especially if you are going at a busy time.
#
#
#
#
#
# User is :Leslie R
#
# Review header is :A Hike Through History!
#
# Review text is :Well worth the hike up to the ancient structure. A legendary monument to Greek civilization and culture!
#
#
#
#
#
# User is :clarksl1207
#
# Review header is :Must do
#
# Review text is :This is the Athens must do. We were fortunate to be staying close enough that we just walked up on our first day in town. This was certainly a highlight of the trip.
#
#
#
#
#
# User is :Tim Weymouth
#
# Review header is :Great valve for money at £18 for over 25's and breath taking
#
# Review text is :If there is only one thing you do in Athens, make sure this is it. Go early as it get packed, long queues although they move pretty fast ,  and if you don't like crowds then avoid as there will be thousands of people. Pictures can't equal the sheer size of the structure and views are simply amazing.
#
#
#
#
#
# User is :Tori M
#
# Review header is :Vacation
#
# Review text is :Amazing. Must have stamina   All uphill with steps. Worth the walk. Enjoyed this with my family. Went here with a tour guide.
#
#
#
#
#
# User is :Lesley C
#
# Review header is :Spectacular but busy
#
# Review text is :Go early to beat the crowds that clog the steps to the Parthenon.  Lots to see and it’s hard walking too
#
#
#
#
#
# User is :Sharon O
#
# Review header is :First time in Athens
#
# Review text is :Our tour guide was excellent - he went above and beyond our expectations.  We had a wonderful experience.
#
#
#
#
#
# User is :zmonaj
#
# Review header is :A different world
#
# Review text is :When you enter this place it is as if you enter the mountain where gods live! Very unique feeling and a beautiful view of the city
#
#
#
#
#
# User is :Judith G
#
# Review header is :Pick pockets abound!
#
# Review text is :Two members of our group had their wallets stolen and their trip was ruined.  Exoticca Travel was contacted and they just said sorry, we can't help.
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d198711-Reviews-or40-Parthenon-Athens_Attica.html
# User is :BRDman7
#
# Review header is :Walking Alongside History
#
# Review text is :A great place to see with your own eyes while visiting the area. the commanding hilltop location offers amazing views out over Athens.
#
#
#
#
#
# User is :Kerry S
#
# Review header is :Must see experience in Athens
#
# Review text is :Magical experience, especially with a professional guide.recommend going when they open to avoid the crowds though.
#
#
#
#
#
# User is :Antionio10
#
# Review header is :A Must See
#
# Review text is :The primary reason to visit Athens. It is not to be missed.  Do get a guide book or have a guide for the visit.  It is helpful.
#
#
#
#
#
# User is :Ladydi543
#
# Review header is :Awesome
#
# Review text is :A Beautiful walk to the top of the acropolis to the Parthenon. Im 70 years old and found it to be a long walk but if you walk slowly and take frequent breaks it’s well worth the trip to the top.
#
#
#
#
#
# User is :Brian B
#
# Review header is :Parthenon tour with Artemis!
#
# Review text is :Visiting the Parthenon is a must when in Athens.  The history is incredible.  The magnitude.  The sheer beauty.  Amazing. The work that went into the building of the Parthenon on the Acropolis is mind blowing!   The precision of the work - the math, the engineering, the stone work… everything!  Wow!Our tour guide was Artemis from Athenswalks.  She was fantastic!  Fun, very knowledgeable and thorough!  A goddess, or so she told us.  She provided us enough details to understand the history, but not too much to bog us down. And also enough to want to learn more!  A guided tour is a recommend; a tour with Artemis is highly recommended!Take the tour in the morning.  Fewer people.  Better opportunity to get that perfect selfie!
#
#
#
#
#
# User is :Nixil
#
# Review header is :Breathtaking
#
# Review text is :An amazing experience, not one to miss, and well worth the climb!Views from the top are beautiful - looking forward to seeing when the restoration is complete
#
#
#
#
#
# User is :J S
#
# Review header is :A true can't miss
#
# Review text is :It goes without saying that this is a true wonder. The temple itself is reached via a slightly taxing walk up the Acropolis. To avoid the queues, buy a combination ticket at one of the other sites (e.g., Aristotle’s Lyceum, where there is never a queue) and then enter via the south entrance (also known as the skip the queue entrance, or entrance for small groups). Also go first thing in the morning (we entered at 8:20, by 9:30 it was absolutely heaving and there was a real loss of mystique) or perhaps late in the day. There’s not a lot of shade and no refreshments on sale on the site, nor any cover if it rains. The information boards are ok – better to read up before you go, to understand the intricacies of how the temple was made and the architectural techniques used to create the optical illusions. Obviously, there are frequent mentions of the Elgin marbles in the British Museum, and these are not complimentary.
#
#
#
#
#
# User is :Angie J
#
# Review header is :Not to be missed
#
# Review text is :Probably the biggest attraction in Athens, this is not to be missed.  I went late afternoon and walked right in, no line.
#
#
#
#
#
# User is :Manusha2012
#
# Review header is :Astounding and fantastic
#
# Review text is :Absolutely a must go and superbly preserved . The entire walk  up the hill is full of old ruins very well narrated at all prominent locations . But that is true for all of Greece . Do go up the hill from the Acropolis museum side and use the sun set as the timing for super views from the top . Suggestion  do buy the 30 euro Multi site ticket and will be cheaper than paying 12 euros at each place . History buffs would love the place . Budget an hour and a half for the entire trip entry to exit at leisure and slow pace . Highlight was the live orchestra that was performing at the Theatre of the Dinosys . Don’t miss the after dark lighting as you walk around the Acropolis.
#
#
#
#
#
# User is :GLBTRTR
#
# Review header is :Ancient World Wonder atop the Acropolis.
#
# Review text is :This is a must see/do when visiting Athens. So many benefits of visiting:- Line to get in moved quickly- Many people but traffic throughout flowed well- Being PRESENT in a living portion of the PAST is an investment in your FUTURE!!!- Pro Tips: Use the restroom first. Take a bottle of water with you.- The tours are self-guided.- There are docents available for a fee that will provide MORE info in multiple languages.
#
#
#
#
#
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d198711-Reviews-or50-Parthenon-Athens_Attica.html
# User is :Daniel B
#
# Review header is :Bucket List Destination
#
# Review text is :Disappointed by the crowds.  It is a great sight and a dramatic location.  Very crowded and that took away from the experience that I was expecting from a location that has been on my Bucket List my entire life.  I would recommend going as early in the day as possible.
#
#
#
#
#
# User is :chrisfulcer
#
# Review header is :Amazing!
#
# Review text is :Actually saw some archeologists working on restoration.  Every time we go here, I’m amazed at the work that’s been done and the beauty of the Parthenon.  Thank you.
#
#
#
#
#
# User is :Peterjohnny
#
# Review header is :Absolutely amazing
#
# Review text is :Seeing how this monument was constructed so many years ago was nothing short of amazing. Despite the wear and tear of the years it was still worth the price of admission.
#
#
#
#
#
# User is :Donald Scott
#
# Review header is :Amazing
#
# Review text is :Visiting the most beautiful hotel, meet with a lot of new people friends hope to visit some day soon
#
#
#
#
#
# User is :Lou S
#
# Review header is :Parthenon Musem and strustures
#
# Review text is :Awesome a must see if you are in the city. The musem and tour with a tour tour guide is a must. If you enjoy history and artifacts it's worth it.
#
#
#
#
#
# User is :Dennis S
#
# Review header is :Truly Unique
#
# Review text is :We've all seen the pictures of it.  But being there was very special.  We did our own tour and that was fine.
#
#
#
#
#
# User is :Paul O
#
# Review header is :Amazing
#
# Review text is :I visited here the end of August 2022 and  used the entrance beside the museum. I did not have a ticket pre booked but the queue was not too long at 9.30am. I bought the €30 combination ticket that includes the Acropolis and a number of other ancient sites including the likes of the Agora and Roman forums. The ticket is good for 5 days and you can visit each site once.Although early it was already very hot so I went round at a slow pace taking any opportunity for shade and to refill my water bottle that I could get. Going up the south slope the highlight was the Theatre of Dionysus. However the true highlights were yet to come. As I went toward the summit you got to view down toward the Herodes Atticus Theatre which is extensively restored and a very impressive sight.Next came the Acropolis summit itself. I had high expectations for here but they were surpassed and more. Walking up through the Propylaia (entrance way) and viewing the Parthenon, Erechtheion and the overall area was amazing. My favourite area was at the back of the Parthenon ( it’s east side I think), simply standing there trying to take it all it. Yes it was was very hot and a bit crowded but at this stage none of that mattered. I won’t bother with any more superlatives but just say it’s a morning I will long remember.
#
#
#
#
#
# User is :KHW94587
#
# Review header is :A must see, of course!
#
# Review text is :It is worth the walk uphill. Simply amazing. It was also interesting to see the work that continually goes on. While many people had a guide, we did not. You may want to visit the Acropolis Museum first to get more knowledgeable about all the structures here.
#
#
#
#
#
# User is :avertie
#
# Review header is :Worth it!
#
# Review text is :Only go when it first opens!  We went when it first opened and the crowd wasn't bad.  Stayed for about an hour.  By the time we left, the crowds were intense.  Only got worse as the day went on.
#
#
#
#
#
# User is :wkassotis
#
# Review header is :Just breath taking
#
# Review text is :On our trip to Athens we walked up to the Parthenon. What a wonderful experience and breath taking experience. The site is clean and well cared for. Architecture is gorgeous and the work to help preserve it is exemplary. After seeing this in photos and pictures my whole life seeing it in person was so wonderful and beautiful. This is truly amazing. A must visit if in Athens
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d198711-Reviews-or60-Parthenon-Athens_Attica.html
# User is :AK_CY1
#
# Review header is :My favourite place in the world
#
# Review text is :My favourite place in the world. Every time I visit Athena I try to find some time and visit it. I find it very calming and can spend hours there doing nothing at all. Just looking around with admiration about its architectural secrets and techniques, as well as all the history it has witnessed throughout its existence and you can sort of sense it in the air around it.
#
#
#
#
#
# User is :Miky1704
#
# Review header is :Nothing changed in 60 years
#
# Review text is :I've visited this place for almost 60 years, and still the Parthenon is in restoration! I hope that I'll survive the day to see it without all the cranes etc.
#
#
#
#
#
# User is :Harvey H
#
# Review header is :The Parthenon of Athens
#
# Review text is :We recently did a cruise on the Nile and very much enjoyed the history of Egypt. Seeing the Acropolis and the Parthenon is another chapter of ancient history that has to be seen in person to really appreciate the vast challenges of what was accomplished in ancient times. It’s is a marvel to see this type of construction, so precise and large completed in places that would be difficult today, and yet these were built centuries ago.
#
#
#
#
#
# User is :Aida G
#
# Review header is :Part of the Acropolis
#
# Review text is :A part of the Acropolis. We arrived around 11 a.m., and the line for Acropolis tickets was only about 10 minutes long. Furthermore, admission is free if you are 25 or younger and an EU citizen (however, you must wait in the queue regardless). Bring plenty of water because the Parthenon is reached via a series of steps. Fantastic views from up there. The Parthenon was a little crowded, but it was possible to see all of its splendour.
#
#
#
#
#
# User is :BaydeNoc
#
# Review header is :Great slice of history
#
# Review text is :If you don't mind visiting a hugely significant historical site with 20,000 of your best friends (estimated headcount the day we visited) this is the place.  Structures are impressive to see and learn about. We had downloaded Rick Steve's free 1 hour audio tour and it was very good. We arrived about 9:00 am and the crowds were building.  Long and slow lines walking up and, but it moved okay.  Worth a visit. Suggest buying tickets online.
#
#
#
#
#
# User is :Matthew P
#
# Review header is :Living history
#
# Review text is :Living history that is worth the time to get there. Lots of work going on, trying to keep time and nature at bay. The view across Athens is magnificent from up here.
#
#
#
#
#
# User is :lotsagoldens
#
# Review header is :Classic architecture
#
# Review text is :It's very hot and crowded up there. But worth it. Bring water, wear a hat, wear shoes with good grip, and go early!
#
#
#
#
#
# User is :albert wagih sadek
#
# Review header is :My Favorite Temple
#
# Review text is :Parthenon temple is my most important temples to go as a visit as am an architect with hilarious view from there , you have to visit it
#
#
#
#
#
# User is :MNRLVEU
#
# Review header is :A must see in Athens
#
# Review text is :This is a must see when in Athens. Yes you can see it from many areas in Athens but nothing like being there. It is a long hoke and can be very hot! But don’t miss it..!
#
#
#
#
#
# User is :racer14142017
#
# Review header is :Classic site
#
# Review text is :This is of course a classic structure that is easy to walk up to, and has other good sites around the main building.
#
#
#
#
#
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d198711-Reviews-or70-Parthenon-Athens_Attica.html
# User is :Traci G
#
# Review header is :Worth it.
#
# Review text is :Our host was great and made the experience more memorable. Its a can't miss spot so do it right. We visited 3 sites and got the history behind it.
#
#
#
#
#
# User is :Lolo Gray
#
# Review header is :Classic
#
# Review text is :A must go if you're spending any time in Greece. Build in the classical age of the 5th Century BC, & now actively being restored, you just have to go, no matter the temperature, time of day, or weather in general.
#
#
#
#
#
# User is :Worlds_of_Wonder
#
# Review header is :Athens iconic site and key part of Greek identity
#
# Review text is :If you haven't visited here, you haven't visited Athens.  Strongly recommend doing it with a guide and in the earlier part of the morning.
#
#
#
#
#
# User is :jhb481947
#
# Review header is :Climbed the Parthenon
#
# Review text is :Wonderful experience, amazing view, great value, great weather, not crowded, locals very helpful and accommodating.
#
#
#
#
#
# User is :nnjprman
#
# Review header is :Parthenon is spectacular
#
# Review text is :You cannot miss this historic monument while in Athens.  I suggest you arrrange a private tour which skip the very long lines to get in.
#
#
#
#
#
# User is :Hastingsdunn
#
# Review header is :Parthenon visit
#
# Review text is :This is the main draw so go at sundown, about 7.00 in August for the avoidance of tour groups, the cool breeze and the great sunsets. Magical.
#
#
#
#
#
# User is :206TravelGuy
#
# Review header is :Clearly, a must see!
#
# Review text is :This is one of the main reasons people will visit Athens - and it does not disappoint. Buy tickets online, and skip the line, as sometimes the lines can be long. Be prepared for steep trek up some steep hills (and potentially slippery if raining) and LOTS of people walking at various speeds. Once you get to the top, there is a lot to see and several ruins to walk around and talk photos. Also, the views of the city from there are simply breathtaking. Be sure to bring good walking shoes, water (!), and patience. You won't forget this!
#
#
#
#
#
# User is :Gabriela A
#
# Review header is :Wow
#
# Review text is :Wear light comfortable clothes because it gets so hot! Also, sneackers or hiking shoes are a must. Go early to avoid crowds.
#
#
#
#
#
# User is :Juliano A
#
# Review header is :Athens pantheon with a dog
#
# Review text is :We had our small dog with us in a carrier and it was not a problem, they were very sweet with her and we all ha a great time. Everything was unreal.
#
#
#
#
#
# User is :christiano_10
#
# Review header is :impressive
#
# Review text is :It had always been a dream of mine to see it.Thought it was larger. It is really impressive, though.Currently covered partly with a scaffolding.
#
#
#
#
#
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d198711-Reviews-or80-Parthenon-Athens_Attica.html
# User is :William M
#
# Review header is :Acropolis Tour
#
# Review text is :I used Giannis who worked at the Athens Tower Hotel for the tour. He was excellent guide for the 3 hour walking tour. It was August so quite hot and make sure you are capable of walking for 3 hours.
#
#
#
#
#
# User is :Natalie J
#
# Review header is :Beautiful piece of history
#
# Review text is :Well worth the trip. Make sure to book a guide - best way to learn about the history behind the Parthenon and the Acropolis :)
#
#
#
#
#
# User is :Baldofafe
#
# Review header is :Wonderful
#
# Review text is :Wonderful place, full of history. Be there before 09:00, and use the Dionysus theater entrance, close to the Akropoli metro station exit.
#
#
#
#
#
# User is :Hannah M
#
# Review header is :what is there to say
#
# Review text is :What is there to say- the fact that we are able to visit and see this in the present day is still astounding. Crazy tourists aside, very worth seeing even from an ancient civilization perspective if you get the chance
#
#
#
#
#
# User is :VTJedi
#
# Review header is :Go early!
#
# Review text is :We walked in around 8:20am, and by the time we were leaving at 10am the place was already packed! So glad we went when we did.  We listened to the free rick Steves Audio guide which was great and allowed us to move at our own pace.  Glad to not have gone during the heat of the day.  It was easy enough to navigate while up there but on the way out I think most people had photos that had many other crowds of people in them.  By going early, we got photos of the Parthenon and acropolis without many others in the photos.
#
#
#
#
#
# User is :Bernardette P
#
# Review header is :Great visit
#
# Review text is :Excellent visit, very busy.  Lots of queues at the temples, staff trying to keep people moving Make sure you take up water, very hot at the top.
#
#
#
#
#
# User is :MacGregor Jackie
#
# Review header is :Magical monument
#
# Review text is :One of the most majestic ancient ruins I have ever visited!! Amazing view, a miracle of architecture! Just a tip go there as soon as it opens so you avoid as much heat as possible
#
#
#
#
#
# User is :mdr9
#
# Review header is :Must see
#
# Review text is :This is a must if you are in Athens.  No brainer to go see the sights.   The views of Athens are great and the history is unbelievable.
#
#
#
#
#
# User is :Wojciech B
#
# Review header is :impressive but scaffolded all the time
#
# Review text is :Great ancient building, but I would prefer to be able to walk inside along it to better experience its size and greatness. Walking around when half of it is covered with scaffolding or inaccessible due to never-ending ongoing works limits the experience.
#
#
#
#
#
# User is :EANYC
#
# Review header is :Best sight in Athens
#
# Review text is :Go up the Parthenon and spend the day. This is a monument of Western Civilisation and you are well advised to spend lots of time here
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d198711-Reviews-or90-Parthenon-Athens_Attica.html
# User is :Shane H
#
# Review header is :Athens's Must-See Attraction
#
# Review text is :It's everything you expect it to be and is one of the most majestic ruins I've seen. It's a long, gradual climb to get up to it, but it's more than worth it.
#
#
#
#
#
# User is :JayGiant
#
# Review header is :Breathtaking experience, a walk back in time.
#
# Review text is :Totally enjoyed the Parthenon experience from the winding trek up the sides to the vistas from the Acropolis plateau. A true step back in time. Wear hiking shoes for it’s a very dusty trail. Stop during your walk up and take in the views from each landing area with Greek deity shrines all over the landscape. Not for the feint of heart for the climb is a bit steep in locations with lots of steps. But the trek is well worth getting to the summit. Take time exploring the Parthenon and the other temples on site. We spent almost 2 hours taking it all in.
#
#
#
#
#
# User is :James L
#
# Review header is :Second time!
#
# Review text is :I was here 16 years ago and it is even more glorious now with all the recent renovations. I am astounded at all of the work they have done since 2006.
#
#
#
#
#
# User is :hongisto
#
# Review header is :Worth the climb
#
# Review text is :The Acroposis was fantastic, even on a hot day.  I would recommend a knowledgable guide to get the most out of it. Absolutely facinating.
#
#
#
#
#
# User is :George
#
# Review header is :No wonder it’s a wonder
#
# Review text is :Visited in the peak of summer, definitely recommend to journey to the Parthenon at opening time to avoid as much heat as possible. Packed with people and very very busy, recommend buying a ticket prior to arriving or getting a ticket pass (which covers 7 historical places total) to avoid lining up in long queues . Amazing views from all sides, take a camera!
#
#
#
#
#
# User is :Greggmc1980
#
# Review header is :Definitely Cool and a Must See
#
# Review text is :We went on a hot day right about when it opened and we were able to get through the lines fairly quickly. Lines were horrible by the time we left. All the buildings were cool, but the views were the best part.A few sections were closed or blocked off for construction/renovation so be aware of that. While climbing up there were crowds you had to navigate through that was a little annoying, but what can you do? Tough to get pictures as a group because of the crowds. It was funny to see Instagrammers all dolled-up for their photo shoots despite it being a 95 degree F day.
#
#
#
#
#
# User is :lb33wonka
#
# Review header is :Just simple title “magical”
#
# Review text is :What more can be said when you visit here? Amazing history and views! Word of caution that some of the rocks are slippery so bring good shoes because you’ll do plenty of walking. They have a disabled elevator available but need proof from what I’m told. Could be crowded of course due to it being the best and most popular thing to do in Greece
#
#
#
#
#
# User is :Sallychristine
#
# Review header is :Very Busy
#
# Review text is :Very interesting  but a lot of other people up thereA little bit hard to enjoy it like that.   Better to get there really early and avoid the crowds and the heat.
#
#
#
#
#
# User is :Alexander D
#
# Review header is :Fantastic, but couple tips
#
# Review text is :If you want to see the sights, couple of things i would recommend. 1. Go as soon as it opens. (8am) you will line up for maybe 5 mins, compared to when i left (around 10) and the line up was maybe 1 hour to get in2. You can buy a 20 euro or 30 euro ticket. Get the 20, the 30 is not needed to see the main sights
#
#
#
#
#
# User is :William Randolp... W
#
# Review header is :It’s Why You Come
#
# Review text is :It is the quintessential Greek experience and not to be missed. Absolutely buy yout tickets ahead of time and arrange a small group guide. For seniors and those with disabilities the have a golf cart and elevator combination to get you to the top without the long walk. It’s free of charge
#
#
#
#
#
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d198711-Reviews-or100-Parthenon-Athens_Attica.html
# User is :Abe Lou
#
# Review header is :A lot of walk to get there. Ticket vending machine out of order..!
#
# Review text is :A long walk from any direction to get up there, but exciting (under 101 degrees F) Vending ticket machines out of order. Long and tedious line to get tickets, under 101 F degrees . A place to see!
#
#
#
#
#
# User is :Karim P
#
# Review header is :Awsome!
#
# Review text is :Pictures don't do the place justice, you need to be there and wonder how did the ancient Greeks quarry the marbles, carry the lot uphill and build something that has survived for 2500 years! However, I had picked the wrong time to visit. 30th July was so hot (around 36/7 degrees) at 4 pm! Book tickets online to avoid queing in the hot sun. Bring plenty of water or you can buy slushies sold on site for 5 euros a cup! Once at the top, you will forget about the fatigue and the heat. It's beautiful and the view of Athens below is not bad either. Avoid the taxis, use Uber instead (no shares in Uber I swear). We were staying in Glyfada (Athens Riviera, nice :) ) ;tired as I was, I couldn't be bothered with public transport (which is regular and cheap but slow) so decided to take a taxi. Walked to the taxi rank and the guy asked me for 35 euros, except that I had done the same trip coming up with Uber for 15 euros. So I told him 15 to 20 he said no. I clicked on my Uber App and one was at the back of the rank and came to the front (less than a minute). It cost me 17.50 euros. Other than that, this was a memorable experience.
#
#
#
#
#
# User is :Brianngog
#
# Review header is :The Icing on the Cake
#
# Review text is :We wandered around the Acropolis and it’s indivual areas but the crean]m of the crop, the icing on the cake was the Parthenon itself. Currently on the way to being lovingly restored the Parthenon sits proudly at the top of the Mountain overseeing Athens as some sort of Guardian Angel. An amazing construction by whet must of been many many workers back in the day. The History just oozes from the pores. To miss this one is to miss out.
#
#
#
#
#
# User is :Jacqueline M.
#
# Review header is :Amazing, did not disappoint
#
# Review text is :A truly astounding site. The walk up is not overly difficult but wear appropriate shoes. Both the hike up and the area around the sites are slippery. We went in evening, when the sun was not at its hottest. Got some amazing photos. It was busy but not a mob. Memories to last a lifetime.
#
#
#
#
#
# User is :Richard
#
# Review header is :One of the most important buildings in the world.
#
# Review text is :The Parthenon cannot be missed. It could do with a bit more shade up there. Wish they would speed up the renovations too...
#
#
#
#
#
# User is :Eugenia P
#
# Review header is :Awesome !
#
# Review text is :It has been my dream to see one of the original Wonders of the World and i did!It was hot, but  worth the climb and the long walk.Highly recommended!
#
#
#
#
#
# User is :Martin H
#
# Review header is :This is a have to see historical landmark
#
# Review text is :Just be careful walking, the steps can take you out! This is a wonderful experience you should definitely take the time to go and experience.
#
#
#
#
#
# User is :RJohri
#
# Review header is :A must see
#
# Review text is :We took a combined ticket for the Parthenon, Acropolis Hill and the Acropolis Museum with a downloadable audio guide. It helped us skip the line. All we had to do was scan our QR code and enter.If you do plan to take one of the museum guides please remember to have your own head phones. Masks are necessary indoors. The climb to the hill is not tough but hot weather can be a problem. Make sure to keep hydrated and wear a hat to save you from the blaring sun. Lots of steps so beware with buggies etc. Tickets, toilets and drink vending machines are available up the hill. The path is a bit slippery so wear comfortable shoes. Their are a few shops selling drinks etc too, but there is very little place to sit in the shade. The history of the place is absolutely amazing. To see the temple in person was breath taking. So much history to be absorbed . The view of the city is admirable. A must see!
#
#
#
#
#
# User is :Katina C
#
# Review header is :Breathtaking
#
# Review text is :Seeing the Parthenon in person is breathtaking. Definitely wear socks and sneakers and go in the morning before it gets super hot. Bring a bottle of water with you because there is no way to purchase water once you're at the top. There is just one water fountain at the back of the Parthenon and the water is warm.
#
#
#
#
#
# User is :edgarssidorovs
#
# Review header is :Need to see once in life-time
#
# Review text is :To much tourists.Went in july, tuesday at 10:00 - overcrouded.Views are very beautifull. Acropolis itself - in my opinion - nothing special. Feeling that I went there just for: "I'v been there".We paid 24,50 online to skip the lanes.
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d198711-Reviews-or110-Parthenon-Athens_Attica.html
# User is :RickimusMaximus
#
# Review header is :Standing high above Athens
#
# Review text is :I've been to Athens 5 times on mission trips and we always plan a day to go to the Acropolis (we also do a devotional reading of Acts 17 while on the Aeropagus, Mars Hill). Visiting and walking around the Parthenon is truly an amazing experience. The views of Athens are phenomenal and the information about the history is fantastic. - and pro tip, the Dia Tauta restaurant near Monostriaki Square is always my first dining stop.
#
#
#
#
#
# User is :Brad B
#
# Review header is :Amazing views, architecture and history
#
# Review text is :I recommend acquiring a guide to hear in personal detail about the history, phases, and drama that this group of buildings has been through.
#
#
#
#
#
# User is :SusanneKL
#
# Review header is :Spectacular! Did not disappoint!
#
# Review text is :Spent a week in Athens and hit most of my  "do not miss" list, and the Parthenon was at the very top. Yes it was quite busy, but I still managed to get some great pictures without busy-body tourists ruining the shots, and even though it was warm it was pleasant. We were lucky enough to visit on a sunny day, and just seing it up close against that blue background was amazing. We were also given the tip to go across to the top of the hill overlooking the Parthenon for a great sunset shot, and that was indeed spectacular. Wish I had had more time to explore - could have spent so much longer there, just meandering around. Do not miss this!
#
#
#
#
#
# User is :Colin
#
# Review header is :Must see
#
# Review text is :Go early and get a guide to get the most of your tour.  Lots to see and learn about and a guide makes all the difference.
#
#
#
#
#
# User is :al o
#
# Review header is :One of the top landmarks in the world
#
# Review text is :Parthenon and Acropolis are among the most significant landmarks in world. Needless to say more about them or their history. The access is easy and if you are disabled you can ask the staff to use the elevator.
#
#
#
#
#
# User is :keckeley
#
# Review header is :Take a Guided Tour
#
# Review text is :This DON"T MISS attraction is best viewed with a knowledgeable tour guide who can explain the history behind the entire site.  We were there on a Saturday and while it was busy, it wasn't so crowded that we couldn't enjoy it.
#
#
#
#
#
# User is :BrushM
#
# Review header is :OK but a bit of a building site
#
# Review text is :Of course this is a great site  to visit  however when we visited there was a lot of reconstruction work going on and the whole thing was a bit of a building site.
#
#
#
#
#
# User is :BoardingPass789875
#
# Review header is :History in person
#
# Review text is :The Parthenon is amazing. Try going early in the morning because it gets hot and crowded. Be prepared for a lot of walking, but it is worth it.
#
#
#
#
#
# User is :Rick T
#
# Review header is :Avoid July and August
#
# Review text is :Well, of course, you can't visit Athens without a trip to the Acropolis, but the heat and the crowds in the summer make it more of an ordeal than a pleasure.  Come in fall or spring.
#
#
#
#
#
# User is :Anna S
#
# Review header is :Outstanding!
#
# Review text is :One of the best monuments in the world .it was an unbelievable experience to visit,you should not miss it!
#
#
#
#
#
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d198711-Reviews-or120-Parthenon-Athens_Attica.html
# User is :JJOH
#
# Review header is :A true wonder of the world
#
# Review text is :Well I have known about the Parthenon from a very early age. It’s a truly iconic building and very beautiful when lit up on the Acropolis at night. You can’t really visit and not go and see it. Such a shame that over the years people have damaged it but good work ongoing to restore it as best as can be achieved
#
#
#
#
#
# User is :S Samel
#
# Review header is :Must see in Athens
#
# Review text is :No trip to Greece is complete without a hike up the Acropolis to visit the Parthenon. Start early - 8am is the best time!
#
#
#
#
#
# User is :d ra
#
# Review header is :Get a Skip the Line tour to avoid the long lines!
#
# Review text is :If cruise ships are in the harbor, plan to visit the Parthenon before 9:30 a.m. or after 2 p.m., otherwise you'll be in a long long line at the entrance.
#
#
#
#
#
# User is :Docmom
#
# Review header is :Amazing historical site
#
# Review text is :We saw this area on a walking tour and were amazed by the history and beauty. I would advise going early in the day to avoid heat and cruise ship crowds. Went to the museum first so we could appreciate the site better. Highly recommend.
#
#
#
#
#
# User is :Phil Krueger
#
# Review header is :Enjoyed the self audio tour.
#
# Review text is :Great experience with my children to run around the track and experience the walk of an olympic athlete.
#
#
#
#
#
# User is :Neil K
#
# Review header is :Historic
#
# Review text is :Dedicated to the goddess Athena this is the most famous structure in Greece ,constructed in 438 BC and is the most important surviving structure of Ancient Greece .Over the many centuries this temple has stood it's served as a treasury,a Christian church and after the conquest and occupation by the Otterman Empire served as a mosque .This is without a shadow of a doubt the most viewed structure in Athens and rightly so ,it's stunning as is the history attached to it ,as you would expect crowds to view the Parthenon are huge especially when we were here in late May ,scorching weather really brought out the crowds ,if you're planning a trip to Athens I highly recommend you check out this historic site .
#
#
#
#
#
# User is :davidadubai
#
# Review header is :Beautiful piece of history
#
# Review text is :Great site, great views but not young child friendly (a lot of steps, stroller not allowed), baby carry bag highly advised
#
#
#
#
#
# User is :Thomas V
#
# Review header is :The Largest Building
#
# Review text is :This is the largest historic building at the Acropolis, so you will not be able to miss it.  It is the feature of all the photos taken here.  Come early in the day or at the end of the day to avoid crowds.
#
#
#
#
#
# User is :stcyprien218
#
# Review header is :breathtaking visit
#
# Review text is :it was simply mind blowing ! we had a terrific private guide Katerina and she was excellent ! Because weather was already quite hot in June we decided to go to Parthenon at the end of the afternoon, like close to 6pm and I would recommend this unless you enjoy an arduous walk in blazing sun . There is an elevator available for people like us who have mobility issues and it saved the day
#
#
#
#
#
# User is :Bobbi R
#
# Review header is :A Must See
#
# Review text is :Why come to Athens & not see this?  It is a bit of a walk and the crowds can be heavy but this is HISTORY!  Take the more scenic walk through the trees and it won't feel as hot.It costs 20 euros (10 for kids under age 8), which I don't believe my husband and I were charged during our last visit here 9-years ago. But our daughter & grandson hadn't been here before &, like I say, it's a must.
#
#
#
#
#
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d198711-Reviews-or130-Parthenon-Athens_Attica.html
# User is :Fred G
#
# Review header is :The Parthenon
#
# Review text is :We were a group of travellers from Canada, and visited the Parthenon at the Acropolis on a day trip to Athens. Awesome experience, and we stayed at the nearby Acropolis, where we had a beautiful rooftop dinner, with a floodlight Parthenon as a backdrop later that evening. Beautiful by day and night!
#
#
#
#
#
# User is :hooligirl2019
#
# Review header is :Lots of climbing Hot! very busy but worth it
#
# Review text is :Very slipperyBusy! Get a ticket from kiosk firstWell worth the trekSights are breathtaking When you come out there is a beautiful little tavern with amazing home cooked food and cold water. Lovely place.
#
#
#
#
#
# User is :Pchecoandres
#
# Review header is :Just go.
#
# Review text is :You can't miss the Parthenon + Acropolis if you are in Athens, take some time, to remember and feed your cultural knowledge and visit with a guide this place.
#
#
#
#
#
# User is :John smith
#
# Review header is :Once in a lifetime experience
#
# Review text is :The best restaurant with the best service and the best food. Felt welcome as soon as I walked in. Absolutely fantastic would recommend to a friend
#
#
#
#
#
# User is :Ernesto C
#
# Review header is :truly histortic
#
# Review text is :best to go early, during the week the site is full of children visiting the site on school trips. Truly a magnificent site. The lines can be long and it can get hot during the day so take plenty of water. wear comfortable shoes.
#
#
#
#
#
# User is :Katie A
#
# Review header is :Must see
#
# Review text is :Great experience! Very crowded. Be sure to wear comfortable shoes at the ground is very uneven and slippery.
#
#
#
#
#
# User is :Bustame2752
#
# Review header is :Parthenon Live
#
# Review text is :The Parthenon in the Acropolis is a stunning Architectural structure. It was built 5 centuries ago. It is considered the most lavish and largest temple in the Greek mainland. It was used as a Treasury early on but later transformed into a church, then a mosque. Get there early to beat the crowds and start with the Parthenon, so you can get the best quality photos without the tourist in the background. Then venture of to the rest of the archeological site. Finish your trip at the museum below the Acropolis. You will not be disappointed. Enjoy all of its beauty and Grace.
#
#
#
#
#
# User is :The_Glovers_UK
#
# Review header is :Must do in Athens
#
# Review text is :An absolute must when in Athens and something we have wanted to do for a long time. The combo ticket is worth the price even if you don’t spend too long in the other places.
#
#
#
#
#
# User is :CanuckAlberta
#
# Review header is :Parthenon Amazing
#
# Review text is :You really must combine any visit to the Parthenon with a visit to the Acropolis museum in order to see the frieze display in the museum which originally ordained the Parthenon. It really is criminal how much of the original frieze was poached by the British back in the day.
#
#
#
#
#
# User is :hawaiipid
#
# Review header is :O.M.G! Wonderful. Go early in the morning.
#
# Review text is :We got there in the morning when it opened so few tourists. Lots of steps. If you have time, see the North and West slopes as well. We stopped at #1 stop on the Hop on bus giving us only a 5 min. walk to the entrance, coming out we ended up at the Agora on the opposite side of the hill. Just the right place to catch the #14 stop of the Hop on Hop off bus.
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d198711-Reviews-or140-Parthenon-Athens_Attica.html
# User is :rebeccabrabb
#
# Review header is :Look past construction
#
# Review text is :Don’t let the construction turn you away. There is plenty to see and learn about. It’s amazing how people 2500 years ago built something so massive.
#
#
#
#
#
# User is :Sachi P
#
# Review header is :Excellent
#
# Review text is :Beautiful, a must see when in Athens. Much of the front facade is under construction. Avoid mid-day hours as the sun is brutal.
#
#
#
#
#
# User is :AAHolt
#
# Review header is :Stunning
#
# Review text is :The Parthenon is a stunning building with a rich history at the Acropolis. It is slowly being restored piece by piece and the overall effect of seeing this building in person is indescribable.
#
#
#
#
#
# User is :Geld B
#
# Review header is :History just in front of you
#
# Review text is :This place is just amazing. You can feel everything you read about the Greece- democarcy, the gods, the myths and legends.  It is one of the probalby top 10 historical places on this planet that one should see
#
#
#
#
#
# User is :Arlene Johnson
#
# Review header is :Must have
#
# Review text is :I thought it'll be boring but it was one of the greatest experiences during my Greece trip. Definitely must see
#
#
#
#
#
# User is :Ken H
#
# Review header is :3,000 years old
# ...
#
#
#
#
#
# User is :tuliplvr22
#
# Review header is :Gave me chills to see in person!
#
# Review text is :I have waited my whole life to be able to see the Parthenon. So breathtaking to see in person. We arrived at the entrance at  7:45am and there was already a line. We were very happy that we went that early since it helped with the heat and crowds. By 9:30 it was getting very crowded and we got to take some nice pictures without tons of people.  Make sure you have good walking shoes since the trek up can be slippery and also once you are up there.
#
#
#
#
#
# User is :Narelle J
#
# Review header is :Worth the walk, the lines and the crowds
#
# Review text is :I visited 30 years ago and have photos taken on the steps. Athens is justifiably safeguarding its and the world’s treasure. You simply have to take the time to marvel in its majesty.
#
#
#
#
#
# User is :Luke Smart
#
# Review header is :The very image of the ancient Western world
#
# Review text is :I've always imagined myself standing in front of the Parthenon, and at long last I got to live that wish. Slight disappointment that there was a great big crane in the middle of it spoiling the view, but these are the things you have to put up with when going to see a two thousand year old temple.
#
#
#
#
#
# User is :bikerbabe22
#
# Review header is :The apex of the Acropolis
#
# Review text is :This amazing monument is extremely imposing to see in person.  Not only is it gigantic, but it is still in good shape.
#
#
#
#
#
# User is :Debbie T
#
# Review header is :Awesome!
#
# Review text is :We decided to pay a tour guide. It got us out of the line and right in for an extra 10 euros. Our guide was informative. We then had time on our own to explore. Although it was impressive it was hard to get a good photo of it as it is undergoing extensive renovations. Needless to say the bus loads of tourists also. I would suggest going first this in morning. Still worth seeing regardless.
#
#
#
#
#
# User is :Gary V
#
# Review header is :wonderful but crowded
#
# Review text is :beautiful ruins, of course mantel panels are in the British Museum and easier to view.  There were great views of the city in all directions and several other building.  There was a huge crowd so couldn't hear the tour guide.
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d198711-Reviews-or1070-Parthenon-Athens_Attica.html
# User is :CXM
#
# Review header is :Words mean nothing when it comes to universal culture
#
# Review text is :What can I write about the Parthenon??? We are talking about Ancient Greek history, architecture and religion.
#
#
#
#
#
# User is :Phil W
#
# Review header is :All that was expected.
#
# Review text is :After a steep climb from the city side of the Dionyssiou Areopagitou this world famous ancient site was worth the trek. There is little to add to other visitors reviews.
#
#
#
#
#
# User is :Netty_Goodsign
#
# Review header is :A must see
#
# Review text is :I woke up early to be there at 8am when it would be cooler and less crowded.  There was already a ticket queue.  Buy your tickets beforehand if possible stating for which day you want them.   Alternatively, go towards the end of the day when it is cooler and less crowded.
#
#
#
#
#
# User is :lucy L
#
# Review header is :A must see
#
# Review text is :If you visit Athens you must see the Parthenon but go early as it gets ridiculously busy.  Wear good shoes because the surrounding ground is extremely slippery even in the dry.  Expect to be slightly disappointed by the scaffolding and the crowds but still worth a visit.
#
#
#
#
#
# User is :kdodds54
#
# Review header is :Beautiful views
#
# Review text is :Went here with a group tour from a cruise, I would say this is not the best way to visit although our guide was excellent very knowledgeable but we were rushed, I would recommend a private guide, like most monuments of this nature there are plenty of staff on duty to protect their history so obey the rules, no tripods for photographers don’t climb on things and basically show some respect it’s not much to ask for.You need to be very careful walking as parts are treacherous under foot and of course you need to be aware of the climb but the view is worth it.Better still when we return the Elgin Marbles to them
#
#
#
#
#
# User is :Joumana
#
# Review header is :Majestic
#
# Review text is :It is really majestic and it takes you back to the old times. you have a great view over Athens  from the top.beware to wear comfy non slippy shoes. go there early morning or in the afternoon, around noon the sun hits you hard.
#
#
#
#
#
# User is :Kenpasha
#
# Review header is :Go early go often
#
# Review text is :We were here this morning around 9 am and people were still lining up, of course, but nothing like it was at 11 and two hours after that.   Also, it's cooler in the morning. So I urge you to do the "early bird" thing.   Restoration is continuing!   Enjoy your visit --
#
#
#
#
#
# User is :Rena D
#
# Review header is :HIstorical Landmark great views
#
# Review text is :Historical landmark at the top of Acropolis Hill. The archaelogical society is working to restore it to its former glory. Alternative Athens tour gave us a great introduction to the history and mythology here.
#
#
#
#
#
# User is :KarenLillywhite
#
# Review header is :Parthenon
#
# Review text is :Please see my review on Acropolis and Parthenon. Excellent day out. Worth having a tour guide. Water fountain and loos at the top near the Parthenon. Not suitable for young children in pushchairs as there are many steps. My daughter age 11 enjoyed it.
#
#
#
#
#
# User is :nick164
#
# Review header is :Another ancient wonder ticked off my list.
#
# Review text is :Sitting atop the Acropolis, the Parthenon is the most recognisable of the ancient temples and was certainly the highlight for me. Get there early (by 930am it was already getting busy). You can opt for a single entry ticket to the Acropolis, or a multi-day multi-site pass which was 30 euros. Note, due to restoration works you'll need to be selective in your photograph to omit the huts, scaffolding and crane.
#
#
#
#
#
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d198711-Reviews-or1080-Parthenon-Athens_Attica.html
# User is :Margaret S
#
# Review header is :A life-time wish now fulfilled
#
# Review text is :I have always wanted to see the Parthenon and it was a dream come true.  Visited late morning on an -all-site ticket (ask for Senior and Student discounts if applicable); it was very hot and although there were many other tourists it was not over-powering and there is a one-way system. The building is breath-taking and we got lots of wonderful photos.  Will go back one day - it is awe-inspiring.
#
#
#
#
#
# User is :Frank S
#
# Review header is :Incredible what people can do.
#
# Review text is :You will hear "go early" and you will hear "go late" we found that if you bring water bottles and patience the time of day is not important. It is just amazing what people can accomplish in the absence of modern distractions.
#
#
#
#
#
# User is :Afrodite Sphiktou
#
# Review header is :The History and the View!
#
# Review text is :From the top you can see the whole city of Athens, an amazing view!Also, Parthenon its an amazing sign of the ancient greek history!
#
#
#
#
#
# User is :JMI
#
# Review header is :A must see in Athens!
#
# Review text is :Parthenon, dedicated to the goddess Athena, the people of Athens considered to be their patron / protector goddess. Very grand even its under repair.
#
#
#
#
#
# User is :N1ck_S9
#
# Review header is :Rating for the infrastructure around the attraction only, not the structure
#
# Review text is :Getting into the Parthenon is pretty difficult. We waited around 40 minutes in the hot sun as there are only 4 turnstiles to enter. It's not well staffed either so it takes considerably longer than it should to get through. It was a dream come true to see the structure and the old Temple of Athena as well, though. Just be prepared, bring sunscreen, water and a big hat so you don't end up sunburnt like silly old me!
#
#
#
#
#
# User is :MSJet_Setter1
#
# Review header is :Cool Attraction
#
# Review text is :Very nice historical landmark. Amazing for photo opportunities. Greek architecture is fascinating, be sure to pay close attention to the ruins if this is your interest.
#
#
#
#
#
# User is :Don S
#
# Review header is :Spectacular
#
# Review text is :Do not pass this up, it does require some effort to climb stairs but its worth every minute and effort to see first hand the history and feel, it is all that and more
#
#
#
#
#
# User is :Deb L
#
# Review header is :What's not to like?
#
# Review text is :Of course you have to go.  It's amazing.  But try to go first thing in the morning or early evening when it's less hot and much less crowded.
#
#
#
#
#
# User is :Exceedingly Seedy
#
# Review header is :Very Busy
#
# Review text is :I have been to historical sites in various places and in various states of upkeep. I was disappointed with how well preserved these ruins were given the amount of EU funding which was lauded in the signs around the location.It is not clear which bits have been renovated and restored and which are standing naturally and there are many bottle necks on the walk ways due to the sheer volume of visitors.It is still very much worth a visit and offers great views of the wider Athens and particularly across to the Pnyx. It is very close to other sites such as the Temple of Hephaestus etc.Glad to have gone.
#
#
#
#
#
# User is :Elsa D
#
# Review header is :Parthenon
#
# Review text is :It is a magnificent building.  Ingenious building strategies were employed.  Please read about its history before going.  Beautiful place.
#
#
#
#
#
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d198711-Reviews-or1090-Parthenon-Athens_Attica.html
# User is :TipppsyTraveler
#
# Review header is :Bucket list checked off!
#
# Review text is :Must see if in Athens! Go early to avoid the heat and the crowds and take water!  They have a small store selling drinks but not regular water only carbonated water.
#
#
#
#
#
# User is :Vijay K
#
# Review header is :Crown Jewel of Acropolis
#
# Review text is :Greek doric order of architecture. You can easily spend over an hour marveling the columns, metopes and triglyphs. Lots of reinforcement activities and it is hard to get a picture without a crane or scaffolding. I am glad the government is taking the efforts to stabilize the structure.
#
#
#
#
#
# User is :Trembl38
#
# Review header is :Onr of the marvel of the world
#
# Review text is :Although not really in the list, it should.Standing tall on the highest point of the Açropolis it is defying the centuries showing the greatness of ancient Greeks.Worth the little effort required to get there with a few steps ahead, but at 36C is is a bit hot.
#
#
#
#
#
# User is :DRW44
#
# Review header is :NOW A BUILDING SITE
#
# Review text is :The Parthenon site has become a building site - large cranes, building works noises, railway tracks, storage areas for the marble boulders.  I think they have even removed part of one sidel as part of the massive restoration.  Be warned - the toilets are outside the main entrance, not just inside as it appears on the directions board, but there is a WC in a 'new' block-house type of building beside the SE corner of the Parthenon and a drinking water fountain just outside.  Earlier in the day, I had tried to get into the Acropolis via the Agora but there is no access to the Acropolis. I should have lost my combo ticket entry for later in the day but for the kindness of a lady in the ticket office in the afternoon.
#
#
#
#
#
# User is :chrysa t
#
# Review header is :beautiful landmark
#
# Review text is :it's amazing! one of the best tourist attractions. once you get there it feels like you traveled back in time!
#
#
#
#
#
# User is :Jun Jacinto
#
# Review header is :History..!
#
# Review text is :A beautiful sight to enhance your mind of what it  really looks like before the excavation. History really teaches us to appreciate its value.
#
#
#
#
#
# User is :Sweetpea25
#
# Review header is :Fantastic
#
# Review text is :This is an amazing place, very atmospheric and of course full of history.The ground is quite rough so ensure you’re up for the walk!
#
#
#
#
#
# User is :Jeff M
#
# Review header is :Breathtaking experience
#
# Review text is :Get there early as the queues soon build up, and it gets really crowded. Whatever the situation, you must go and see this as it has got to be amongst the most important sightseeing venues on earth. It is a bit of an uphill climb, but not too strenuous. The ruins as you walk up and at the top are incredible, as are the views over the city. Take your time to enjoy it all, then head down for refreshments at one of the many cafes and restaurants below. A great morning out. I'd then suggest the Acropolis museum after lunch to close out a great day.
#
#
#
#
#
# User is :CBR
#
# Review header is :A must-do if in Athens, but a bit underwhelming
#
# Review text is :The ticket office close to the subway station opens at 8am. It pays to get there early as by 9 there are hordes of tour groups and it is very hot. It is quite a climb up to the top, not made easier or safer by the visitor numbers. The acropolis museum has a nice cafe which you can go to without going to the museum.
#
#
#
#
#
# User is :Empty Nesters
#
# Review header is :Amazing to see in person
#
# Review text is :We've all seen pictures and videos of the Acropolis and Parthenon, but it is absolutely amazing to see it in person.  I walked completely around the outside of the complex the first night we were in town.  The view of the Parthenon lit up at night is breathtaking.  We climbed to the top the next day.  The history is amazing and that fact that it is still standing is incredible.  Thankful that we are finally trying to save these wonderful pieces of antiquity.
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d198711-Reviews-or1100-Parthenon-Athens_Attica.html
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-12-98029f1522b4> in <module>
#       6     driver.get(url)
#       7     time.sleep(10)
# ----> 8     soup = BeautifulSoup(driver.page_source, 'html.parser')
#       9     driver.quit()
#      10
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in page_source(self)
#     538                 driver.page_source
#     539         """
# --> 540         return self.execute(Command.GET_PAGE_SOURCE)['value']
#     541
#     542     def close(self) -> None:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     427         response = self.command_executor.execute(driver_command, params)
#     428         if response:
# --> 429             self.error_handler.check_response(response)
#     430             response['value'] = self._unwrap_value(
#     431                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241                 alert_text = value['alert'].get('text')
#     242             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243         raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=107.0.5304.107)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x006CACD3+2075859]
# 	Ordinal0 [0x0065EE61+1633889]
# 	Ordinal0 [0x0055B7BD+571325]
# 	Ordinal0 [0x00542E1A+470554]
# 	Ordinal0 [0x005AAA0B+895499]
# 	Ordinal0 [0x005BAC96+961686]
# 	Ordinal0 [0x005A7136+880950]
# 	Ordinal0 [0x0057FEFD+720637]
# 	Ordinal0 [0x00580F3F+724799]
# 	GetHandleVerifier [0x0097EED2+2769538]
# 	GetHandleVerifier [0x00970D95+2711877]
# 	GetHandleVerifier [0x0075A03A+521194]
# 	GetHandleVerifier [0x00758DA0+516432]
# 	Ordinal0 [0x0066682C+1665068]
# 	Ordinal0 [0x0066B128+1683752]
# 	Ordinal0 [0x0066B215+1683989]
# 	Ordinal0 [0x00676484+1729668]
# 	BaseThreadInitThunk [0x755BFEF9+25]
# 	RtlGetAppContainerNamedObjectPath [0x76FF7BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x76FF7B8E+238]

# %%
df = pd.DataFrame(data, columns=['User', 'Review Title', 'Review'])

# %%
df.shape
# Out:
# (1100, 3)

# %%
df.tail()
# Out:
#                User                                     Review Title  \
# 1095    Jun Jacinto                                       History..!
# 1096     Sweetpea25                                        Fantastic
# 1097         Jeff M                          Breathtaking experience
# 1098            CBR  A must-do if in Athens, but a bit underwhelming
# 1099  Empty Nesters                         Amazing to see in person
#
#                                                  Review
# 1095  A beautiful sight to enhance your mind of what...
# 1096  This is an amazing place, very atmospheric and...
# 1097  Get there early as the queues soon build up, a...
# 1098  The ticket office close to the subway station ...
# 1099  We've all seen pictures and videos of the Acro...

# %%
filepath = Path('parthenon.csv') 
df.to_csv(filepath, index=False)
