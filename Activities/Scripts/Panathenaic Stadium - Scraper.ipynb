# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import re
import time
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
from pathlib import Path

# %%
data = []

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
url = "https://www.tripadvisor.com/Attraction_Review-g189400-d245991-Reviews-Panathenaic_Stadium-Athens_Attica.html#REVIEWS"
print("url is \n" + url)
driver.get(url)
time.sleep(10)
soup = BeautifulSoup(driver.page_source, 'html.parser')
driver.quit()
# Out:
# <ipython-input-3-569895759eb8>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d245991-Reviews-Panathenaic_Stadium-Athens_Attica.html#REVIEWS

# %%
containers = soup.find_all("div", {"class": "_c"})

# %%
len(containers)
# Out:
# 10

# %%
user = containers[4].find_all("a", {"class": "BMQDV _F G- wSSLS SwZTJ FGwzt ukgoS"})

# %%
user[0].text.strip()
# Out:
# 'Yanay G'

# %%
review_header  = containers[4].find("span", {"class": "yCeTE"})
review_text = containers[4].find("div", {"class": "biGQs _P pZUbB KxBGd"})

# %%
review_header.text.strip()
# Out:
# 'Nah.'

# %%
review_text.text.strip()
# Out:
# "The stadium is quite impressive, but it doesn't worth much if you can't enter it. The entrance ticket is 10€ per adult, very overpriced. I would not recommend going there, but if you are in the area you might as well check it out."

# %%
for index, container in enumerate(containers):
    
    user = container.find_all("a", {"class": "BMQDV _F G- wSSLS SwZTJ FGwzt ukgoS"})
    review_header  = container.find("span", {"class": "yCeTE"})
    review_text = container.find("div", {"class": "biGQs _P pZUbB KxBGd"})
    
    if(review_header):
        print("User is :" + user[0].text.strip() + "\n")
        print("Review header is :" + review_header.text.strip() + "\n")
        print("Review text is :" + review_text.text.strip() + "\n")
        data_point = [user[0].text.strip(),review_header.text.strip(), review_text.text.strip()]
        data.append(data_point)
        print("\n")
        print("\n")
        
    if(index == 10):
        break #since there are 10 contaners with reviews per page but the first one is empty
# Out:
# User is :Amy
#
# Review header is :Seen from outside
#
# Review text is :We didn’t pay to go inside the stadium, as we were put off by the €10 entry fee. (Especially after paying just €5 for the Acropolis Museum!) You can see the stadium well enough from the street, and it is worth going to look at through the fence if you’re nearby. I think a sports/Olympics fan would get a lot out of this place, but unfortunately it just wasn’t for me.
#
#
#
#
#
# User is :Senioronabudget
#
# Review header is :More than a stadium
#
# Review text is :The free audio guide brings the stadium to life.   Without the audio guide it is just a track with a lot of marble seats.  Listening to the history brings it to life.
#
#
#
#
#
# User is :Questovia
#
# Review header is :Grand Stadium
#
# Review text is :Our tour bus briefly stopped here so we could view this home to the modern Olympic Games.  It's a massive stadium and we weren't allotted the time to explore it, but still nice to view and learn the history.
#
#
#
#
#
# User is :Martin J
#
# Review header is :Hear the cheers from ancient times
#
# Review text is :Good audio guide. 10€ entry.You can visit the stadium without buying a ticket. The ticket allows you to enter the stadium, and gives a much better experience. The audio guide is included with the ticket.
#
#
#
#
#
# User is :Yanay G
#
# Review header is :Nah.
#
# Review text is :The stadium is quite impressive, but it doesn't worth much if you can't enter it. The entrance ticket is 10€ per adult, very overpriced. I would not recommend going there, but if you are in the area you might as well check it out.
#
#
#
#
#
# User is :ElsieF499
#
# Review header is :Worth going inside if you have the time and the money
#
# Review text is :Home of he modern Olympic Games.I spent a pleasant hour here exploring the stadium and enjoying the views from the top of the stands. The entry fee of 10 euros is a bit steep, but included in that is an audio guide giving the history of the stadium and the Olympic Games, and a small museum dedicated to the olympics with posters and torches from various games. You can climb up to the top of the stands which gives you a great view over Athens. You can always walk/run on the track and have your picture taken standing on a winner’s podium. Yes, you can see the stadium from the street, but if you have the time and the money then it is worth going in
#
#
#
#
#
# User is :Ron
#
# Review header is :Not much to see
#
# Review text is :Stadiium of first moderm olympics. Interesting, but nothing to be excited about. We were walking past this place and saw it.
#
#
#
#
#
# User is :Silva
#
# Review header is :Nothing special
#
# Review text is :Historical site. I don't know what the admission fee includes, but without it you will get a good view to it also.
#
#
#
#
#
# User is :Matthew P
#
# Review header is :Olympic venue
#
# Review text is :Easy to find as most things are in Athens. Lovely ancient Olympian venue, the entrance fee of 10 euros each you get a handheld guide. You can walk all the way around, just be aware the entrance is also the exit. Near the ticket office are the washrooms you need to have 1 euro in change ready as it does not give change.
#
#
#
#
#
# User is :Paul O
#
# Review header is :Historic Stadium
#
# Review text is :The Panathenaic Stadium which hosted the first modern Olympics in 1896 is simply a special place. You can walk around the full track (it only has 6 lanes as opposed to 8) and climb the stands and sit on the marble seats. There is also a long tunnel just off the track that you can walk up and where there is a small museum to enjoy. As a big sports fan (though you don’t need to be to enjoy) it was so cool walking around the track looking up at the stands. It costs €10 to enter and is well worth it

# %%
for i in range(10,1150,10):

    driver = webdriver.Chrome(ChromeDriverManager().install())
    url = "https://www.tripadvisor.com/Attraction_Review-g189400-d245991-Reviews-or" + str(i) + "-Panathenaic_Stadium-Athens_Attica.html#REVIEWS"
    print("url is \n" + url) 
    driver.get(url)
    time.sleep(10)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    driver.quit()

    
    containers = soup.find_all("div", {"class": "_c"})

    
    for index, container in enumerate(containers):
    
        user = container.find_all("a", {"class": "BMQDV _F G- wSSLS SwZTJ FGwzt ukgoS"})
        review_header  = container.find("span", {"class": "yCeTE"})
        review_text = container.find("div", {"class": "biGQs _P pZUbB KxBGd"})

        if(review_header):
            print("User is :" + user[0].text.strip() + "\n")
            print("Review header is :" + review_header.text.strip() + "\n")
            print("Review text is :" + review_text.text.strip() + "\n")
            data_point = [user[0].text.strip(),review_header.text.strip(), review_text.text.strip()]
            data.append(data_point)
            print("\n")
            print("\n")

        if(index == 10):
            break #since there are 10 contaners with reviews per page
# Out:
# <ipython-input-12-7b8d2cb1e6ac>:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d245991-Reviews-or10-Panathenaic_Stadium-Athens_Attica.html#REVIEWS
# User is :FreakinSweet
#
# Review header is :Go early to avoid the heat of the day
#
# Review text is :The entrance cost includes a free audio guide telling you the history of the stadium, which is worth listening to. There's no shade when walking around the stadium, so take some water to drink. It's a truly impressive structure, especially from the track in the centre and well worth a visit whilst you're in Athens. You can even have a little run on the track if it's not too hot and pose for photographs on the podium.
#
#
#
#
#
# User is :Lauren
#
# Review header is :Nice to see!
#
# Review text is :Visited the stadium during our 1 night stay in Athens. We weren't able to go in, but went to view it from the outside during the evening (which you can still see the full view of inside the arena), recommend if you want to see but short of time.
#
#
#
#
#
# User is :CraigH0901
#
# Review header is :Full Experience
#
# Review text is :A short walk from Syntagma Square (closest Metro), the stadium is impressively visible from the main road. With the entrance ticket comes an audio tour that easily tracks your way through the stadium with place markers along the way.Will be the most memorable stadium that I've visited. The all-marble seating and the thrones and the coliseum-like design. Views of the acropolis from the top of the seating is a must. The steps are very steep in some parts - built well before insurance advice was common place.Must see.
#
#
#
#
#
# User is :Baldofafe
#
# Review header is :Beautiful marble stadium
#
# Review text is :Your chance to see one of the most beautiful marble stadiums in the world. Close you can catch the tram to syntagma square.
#
#
#
#
#
# User is :VTJedi
#
# Review header is :Very good
#
# Review text is :We didn't spend too much time here, but I'm glad we visited. It's nearby to some other attractions and we got to walk through the national garden afterwards to get some break from the heat!
#
#
#
#
#
# User is :Dominykas
#
# Review header is :A monument with much to offer
#
# Review text is :An awe-inspiring monument. The entrance fee is 10 Eur (5 Eur if you are a student) but you are also provided with an audio guide (available in many languages) - a mobile telephone with a headphone jack (headphones are not given but you can still listen to the recording by holding a phone to your ear) which you need to return in an hour (you can still continue on exploring the stadium after). You can take a great picture of the stadium with Lycabettus hill or the Acropolis in the background if you climb up to the top (in some places stairs are really steep). There is little place to hide from the sun except for going to the tunnel (which you should, as it was of great importance back in a day and now it leads to a exhibition with posters of previous Olympic games). You can also have a run around the stadium and ask someone to snap your picture on the Winners' Podium.
#
#
#
#
#
# User is :ClaudioSilvermore
#
# Review header is :A nice way to spend an hour.
#
# Review text is :A interesting attraction which can be reached easily on foot from the city centre.  It only takes an hour to take the tour and see everything so not too lengthy.
#
#
#
#
#
# User is :BeakerTX
#
# Review header is :Brief interesting site.
#
# Review text is :A very interesting part of Olympic and Athens history.  Worth an hour to take the audio tour and appreciate the history of the site and the modern Olympic Games.  A nice un-crowded break from the other popular sites in Athens, and a reasonable walk from the tourist areas.
#
#
#
#
#
# User is :lb33wonka
#
# Review header is :Amazing history here
#
# Review text is :A must stop if you have time. So much history took place here. Make sure you enter the tunnel and go to the Musuem! It has all the posters and torches displayed there
#
#
#
#
#
# User is :RJohri
#
# Review header is :Spectacular!
#
# Review text is :It’s the home to the first modern Olympic Games in 1896. A great place if you’re interested in the history of Olympic Games. To be in the midst of the stadium and walk the path the gladiators walked is surreal. The museum hosting all Olympic Games paraphernalia and posters is a great way to enjoy history.There is a shop and paid toilets outside the stadium. The stadium is enroute the Hop off hop on bus.
#
#
#
#
#
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d245991-Reviews-or20-Panathenaic_Stadium-Athens_Attica.html#REVIEWS
# User is :owall
#
# Review header is :Iconic stadium visit
#
# Review text is :Well worth a visit, there is an audio guide included in price of entry that is excellent.  If you want you can run around the track.
#
#
#
#
#
# User is :NickellFamilyTravel
#
# Review header is :The first Olympic Games and a stadium that will last for thousands of years
#
# Review text is :I liked it - but i also participated on the USA medical team for the 2004 Games in Athens.  Its an impressive facility and hosted the first games, so you have to just sit and imagine the people coming to the event and participating.  It can be boring to kids, or non Olympic fans.   But i loved it.
#
#
#
#
#
# User is :Rick T
#
# Review header is :A Whole Lot of Nothing
#
# Review text is :To be fair, I am not a sports fan, but I found this place very ho-hum.  If the Olympics are a big deal to you, snap a photo as you pass by, but don't waste cash on a ticket to go inside.
#
#
#
#
#
# User is :ricky v
#
# Review header is :Epic
#
# Review text is :Yes, for me it was epic sight, not for my teen daughter, which h was a bit bored.Anyway, for me that love sport, love Olympics games this was a must visit.The place is neat, please do take the audio guide, which is included in the ticket price, it will guide and give hints for your visit.If you like the Olympics, this is highly recommended!!
#
#
#
#
#
# User is :JJOH
#
# Review header is :Worth the walk to see this
#
# Review text is :Home of the first Olympic Games this is well worth a visit. You can pay to go in but to be honest it’s probably not worth it.I was left wondering why they did not use this as a setting for the 100m races at the more recent Athens Olympics as it would have been a sensational setting
#
#
#
#
#
# User is :Kevin S
#
# Review header is :Site of the rebirth of the modern Olympic Games in 1896
#
# Review text is :Seemingly ignored by many people given the few visitors when we were there. OK, it is not as old as the sites of ancient Athens that you will have come to see but it is built on the site where athletic and other competitive challenges took place 2500 years ago. Yes, Olympia in the Peloponnese was the original Olympics site, although I actually preferred the stadium in Messene, but this is the site of the rebirth of the modern Olympic Games in 1896. Still in use for some events today, not athletics as the track does not comply with modern dimensions, it is a wonderful site. Tour buses sometimes stop for a quick photo opportunity over the low fence.
#
#
#
#
#
# User is :Katie A
#
# Review header is :Must see!
#
# Review text is :Our favorite site in Athens! Such an amazing place with so much history. There is also a museum inside with lots of Olympic history. If you're in Athens, you have to visit.
#
#
#
#
#
# User is :Aisling H
#
# Review header is :Enjoyed this immensely
#
# Review text is :This was one of the hightlights of our visit to Athens.  They give you an audio to go around and hear all the information about the stadium and then you can go see the alter and information regarding the Olympics over the years. Very interesting and as I was in Sydney for the Olympics and attended it  seeing the actual torch used for the Sydney Olympics was great.
#
#
#
#
#
# User is :The_Glovers_UK
#
# Review header is :A must visit in Athens but check to make sure it is all open.
#
# Review text is :Fantastic piece of history near the centre of Athens. Docked 1 star as the centre was closed during our visit for maintenance work so we couldn’t run where Olympians had previously run nor could we have a mock medal ceremony.
#
#
#
#
#
# User is :Timbeach3
#
# Review header is :A nice view of history!
#
# Review text is :This stadium was the site of the first modern olympics in 1896.  The access to the track and the bleachers is really cool and should not be missed when visiting Athens.  Who would't want to run the 100 meters where so many olympic athletes ran?
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d245991-Reviews-or30-Panathenaic_Stadium-Athens_Attica.html#REVIEWS
# User is :Thomas V
#
# Review header is :Impressive Statium
#
# Review text is :I walked around this huge stadium, but did not go inside.  I could tell that it could house thousands and it was built for the Olympics.  Right in the center of town near the Metro.
#
#
#
#
#
# User is :AndyP1998
#
# Review header is :Disappointed
#
# Review text is :If went again we would just take a photo of the stadium from outside. This is what the majority of bystanders did. However this is an iconic historical stadium so paid our €10 each. Audio tour ok but instantly unforgettable. The track was closed so no podium photo opportunity or seeing runners breathing life into the stadium. Difficult to get to the middle level so didn't bother trying to get to the top of the stadium. Amazingly exit was closed when we got to the end of the tour. Was really wanting to enjoy this stadium but came away disappointed
#
#
#
#
#
# User is :Bertie1224
#
# Review header is :It’s a stadium
#
# Review text is :Didn’t go in. Looked in from outside. On a hot day you would roast inside. Impressive structure. Fascinating to think this is where it all started. Worth a walk by at least.
#
#
#
#
#
# User is :Peter H
#
# Review header is :Great
#
# Review text is :Another must see, when in Athens. It is part of Greek history and worth the visit. There is a audio guide in many different languages that is included in your ticket, but it must be returned after 40mins. P.s. There is a nice museum at the end, which is a cherry on the top.
#
#
#
#
#
# User is :martina w
#
# Review header is :Highlight of Athens trip
#
# Review text is :A highlight of 3 days in Athens!! Stunning, pictures do it no justice. Standing in the stadium you can almost feel the energy from ancient times. 10 euro for entrance seems expensive but it's well worth it. Make sure and  use the audio guide (included in ticket). Take your time and soak it all in
#
#
#
#
#
# User is :Relaxing
#
# Review header is :MANY PICKPOCKETERS IN OPEN AREA OUTSIDE STADIUM !!!
#
# Review text is :We were with a tour group from the cruise. Out of our group of ~20 people, 6 people were pickpocketed outside the stadium (1 got pickpocketed in agents toilet area)!!! Some wallets were removed from backpacks, some from waist pouches and some from pant pockets. The thieves look like tourists and in particular looking for American tourists. DO NOT TAKE PICTURES outside stadium, unless your travel companion can protect you. You are not safe while taking photos even if the area looks wide open. In particular guard your US passports…money can come and go, but identity is best to protect. Port Police and Tourist Police gave a run around for logging report - it’s a lost cause sadly, in Athens.
#
#
#
#
#
# User is :Jamie C
#
# Review header is :An hour of Olympic history and worth it
#
# Review text is :10 euros to walk around the stadium and a small museum is value for money. They had  the torches and posters for every year the modern Olympics in the museum. Well worth it.
#
#
#
#
#
# User is :CMC
#
# Review header is :Panathenaic Stadium Athens in April
#
# Review text is :Photos make this look like a smaller structure than it is in reality. Possible to walk all around the stadium and on to running track and medal podium. There is a small museum accessed via the stadium with posters of past games and Olympic torches.Shop was closed but there was a temporary one outside.Buy tickets at ticket office outside, no queue (afternoon in late April) Late afternoon / early evening there is some shade on one side of the stadium so might be a good time to go if very hot day.
#
#
#
#
#
# User is :Alessio0575
#
# Review header is :Visit to the Panathenaic Stadium
#
# Review text is :Another must-see stop in Athens, not only for sport addicted people. This is a true piece of history, as this is the place were the first Olympic games took place in 1896...and a true architectural masterpiece, all made in marble. The view from the top rows is impressive, worth a number of pictures. It is located in the centre of Athens, 10min walk from the Acropolis. The museum is also very interesting and worth a visit.
#
#
#
#
#
# User is :Carrie192837465
#
# Review header is :Special morning run
#
# Review text is :A very special morning run! We were thrilled when our morning run passed the ancient Olympic stadium and realised we could continue running on the track inside! Just €10 for a ticket, we joined a few other runners on the track. After our run, we were able to explore this great historical site.
#
#
#
#
#
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d245991-Reviews-or40-Panathenaic_Stadium-Athens_Attica.html#REVIEWS
# User is :Emily
#
# Review header is :Favourite site in Athens
#
# Review text is :Probably my favourite site that we visited. The included audio tour gives enough information as you go around. Going up the tunnel and into the room with all the Olympic torches was a surprising extra (we even spotted our weird GB mascots). Some of the poster art choices were interesting obviously reflecting the times. Was fun seeing other visitors racing each other on the track and we had a go ourselves.
#
#
#
#
#
# User is :JavaMama58
#
# Review header is :Inspiring
#
# Review text is :We enjoy watching the Olympics and are enthusiastic spectators. So seeing the rebuilt stadium where it all started, was a fun activity to do. It is also centrally located, so there’s no excuse to not take the time to see it.
#
#
#
#
#
# User is :Demothesis
#
# Review header is :Personal favourite
#
# Review text is :€10 for a ticket to this fantastically preserved monument to Athens, the marathon and the Olympic Games. A personal favourite in my entire Athens visit I would certainly recommend a visit and a stroll around.The ‘surprise’ in the tunnel was quite fun.
#
#
#
#
#
# User is :JC86
#
# Review header is :Beautiful Stadium
#
# Review text is :Wow, this stadium is so big. You see it on your approach, and it looks amazing. We enjoyed climbing to the top and walking all the way around. Definitely worth a visit.
#
#
#
#
#
# User is :Vikki G
#
# Review header is :Nice Walk
#
# Review text is :Really cool to walk around, however a better map would have been more helpful. The map on the back on the pamphlet does not show everything well, so I am sure we missed things. There are a lot stairs that are slippery and uneven so be careful. Otherwise this is worth the trip
#
#
#
#
#
# User is :andyh67186334
#
# Review header is :Stunning Stadium
#
# Review text is :I am not a fan of anything sports related, but architecture and history does appeal to me, hence the visit to the stadium. I went in the late afternoon and there was hardly anyone there.There is an underground tunnel that leads to a small museum, which I had to myself.The steps to the top of the stadium are very steep in places, and I would imagine being made of marble, quite slippery when it has rained.The entry fee is 10 Euros, which in my view was value for money.
#
#
#
#
#
# User is :Thomas V
#
# Review header is :Olympic Stadium
#
# Review text is :They had Olympic events here and it is a big stadium.  You can do a tour here, but I am not sure why you would want to.  It's a huge stadium in the middle of the city and is impressive in size.
#
#
#
#
#
# User is :ERFSU82
#
# Review header is :Impressive sight
#
# Review text is :We visited early in the morning and opted to simply view it from the outside, since we were pressed for time. It’s an impressive sight, and very easy to see from the front (the open end) without going inside.   If we had more time, we would have enjoyed going in or taking a tour, but we felt like we got a sufficient up-close view from the front.
#
#
#
#
#
# User is :Thomas G
#
# Review header is :Impressive stadium
#
# Review text is :The stadium is really impressive. It is fully made of marble and the oldest Olympic stadium in the world. It is way nicer than I thought and an absolutely must do, even if you are not a sports fan. The stadium is sooo huge. I recommend on doing the audiotour, which takes about 40 minutes and it will explain everything on a fun way. There is a small museum which is nice for 10 minutes and further just enjoy the mighty stadium. One of the absolute highlights of Athens for me.PS don't forget to run a round in this historical stadium and stand on the number 1 spot for the real experience.
#
#
#
#
#
# User is :Kam S
#
# Review header is :Historical landmark you need to visit
#
# Review text is :We’ll worth the visit just for the ability to have a run (or brisk walk in my case) around this historic landmark. Not a huge amount to do but is the history and immense scale of the structure is worth the admission!
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d245991-Reviews-or50-Panathenaic_Stadium-Athens_Attica.html#REVIEWS
# User is :RandyRoss
#
# Review header is :It's a Major Athenian Attraction
#
# Review text is :The Panathenaic Stadium, one of the main historic attractions of Athens, is the only stadium in the world built entirely of marble.A stadium was built on the site of a simple racecourse about 330 BC, primarily for the Panathenaic Games. It was rebuilt in marble by Herodes Atticus, an Athenian Roman senator, and by 144 AD and had a capacity of 50,000 seats. After the rise of Christianity in the 4th century it was largely abandoned. The stadium was excavated in 1869 and hosted the Zappas Olympics in 1870 and 1875. After being refurbished, it hosted the opening and closing ceremonies of the first modern Olympics in 1896 and was the venue for 4 of the 9 contested sports. It was once again used as an Olympic venue in 2004 and is the finishing point for the annual Athens Classic Marathon.One highlight of our tour was that Lynda got to pose with man dressed as a Greek soldier.  He charged 1 Euro for photos.
#
#
#
#
#
# User is :Fireflyanddragon
#
# Review header is :Excellent way to spend an hour
#
# Review text is :Visited the stadium with two children and all of us loved this part of our trip. To have the opportunity to run around the track and see this amazing place made it well worth the visit. It was a lovely walk from our hotel and it's right next to the National Gallery Gardens, which are also worth a visit.
#
#
#
#
#
# User is :Hany G
#
# Review header is :Marble stadium!
#
# Review text is :A big marble stadium that was constructed in the 19Th century. You can book a ticket and get it but we just visitedthe stadium and didn't get in. We were able to take picturesfrom outside.
#
#
#
#
#
# User is :Mary
#
# Review header is :Definitely Add to your To Visit List
#
# Review text is :A must on your list.  Definietly pay a little extra to take the self guided tour inside the stadium.  You will get a hand held device that you can replay at anytime.  Take time to run on the track and take pictures on the podiums.  They do have a small room as you make your way through the stone tunnel where the athletes enter and exit the stadium. This room have some of the Olympic torches on display.  This stadium is built entirely of marble.  The original stadium was built in 330 B.C.   During the Roman Occupation the stadium was abandoned in 6th century B.C.  It was in 1836 that the stadium was excavated and renovated.  It held its first Modern Games in 1870.Don't forget to stop by at night when the stadium is lit up.  Beautiful!!
#
#
#
#
#
# User is :Janka K
#
# Review header is :Worth of a picture, if you are into history, not sure what else to get here
#
# Review text is :I walked around, took a picture, it was enough for me. Not sure what can you get for your ticket, besides getting closer to the stadium.
#
#
#
#
#
# User is :Steve_Grant1
#
# Review header is :The ancient stadium
#
# Review text is :This is the ancient stadium. Its size is tremendous and more than a credit to its age. We visited on the way to see the "Changing of the Guard" which was a nice walk.
#
#
#
#
#
# User is :GBJ-Cookies
#
# Review header is :Worth a Visit
#
# Review text is :Located just a twenty minute walk away from The Acropolis this is the birthplace of the modern Olympics and hosted the first Olympics back in 1896.The whole stadium is made completely from marble and costs only 5€ to enter. If you arrive early in the morning the stadium is open to runners before opening to the general public, although you still have to pay the entrance fee.There was a large police presence along with a film crew setting up for the torch ceremony for the Beijing winter Olympics when we were there.There is a small but interesting museum that includes every torch from every single Olympic games.Their are toilets located just outside which cost .50€ to use, there is also a small coffee shop that sells alcoholic beverages.
#
#
#
#
#
# User is :Cait C
#
# Review header is :Early morning run
#
# Review text is :As a runner, it was such a unique experience to run on a track once run by Olympians. The stadium itself, all in marble, is gorgeous. Truly a highlight of my trip to Greece!
#
#
#
#
#
# User is :Deirdre Tampa
#
# Review header is :Loved this way more than we thought we would
#
# Review text is :The audio is a great history of the stadium and is included with the entrance fee. So fun to see the actual track and run around it and stand on the podiums. Very worth the 5 euro!!
#
#
#
#
#
# User is :Maaike
#
# Review header is :Great visit!
#
# Review text is :What an impressive building! It not only has a rich history in ancient times, but also in more recent history. I'd recommend taking the audiotour which is available at the entrance and is included in the entry ticket price (€5).
#
#
#
#
#
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d245991-Reviews-or60-Panathenaic_Stadium-Athens_Attica.html#REVIEWS
# User is :phat_dawg_21
#
# Review header is :Worth a quick stop
#
# Review text is :It was a quick stop for us. Lots of ancient and modern history. Interesting how it was built taking advantage of the existing landscape.
#
#
#
#
#
# User is :leileireid
#
# Review header is :Great cultural landmark
#
# Review text is :Wonderfully restored cultural landmark, ticket price does include a free audio guide which is worth picking up and is informative. It would have been nice if there was some staff members inside the stadium and possibly a few more information points but overall it was a great visit.
#
#
#
#
#
# User is :Harald Gracholski
#
# Review header is :Beautifully restored cultural landmark!
#
# Review text is :The Panathenaic Stadium is, for me personally, the point of reference, when I think of an ancient, greek stadium. While it has not necessarily improved since the Olympic Games in 2004 due to a lack of funds,  it is still a sight to behold as it was extensively renovated, prior to the games. I suggest the audiowalk, which was enough context for us to better understand the importance of the landmark, so not sure if a privately guided tour really is necessary. Definitely a must see when in Athens, which can also easily be combined with other central monuments, as its fairly close to the city center.
#
#
#
#
#
# User is :B1714D
#
# Review header is :The second best thing in Athens
#
# Review text is :Imo, just after the Acropolis site and museum, the Panathenaic Stadium is the second best thing to visit in Athens.It's a place with such an outstanding history dating back to 4c BC when the athletic competitions where held here, in then rectilinear shaped stadium.The Roman Emperor Hadrian is responsible for the today's spheric horseshoe look, as well for building the spectators stands. In Roman times it also served for gladiator fights, which were banned later with adopting Christianity.After the Romans the stadium experienced a decay phase, when it's terrific white marble was used for house building around.The revival phase started with Pierre de Coubertain who initiated the first modern Olympics to be held on this stadium in 1896. For this occasion the stadium was renovated with the same white marble we see today.The entry fee is only 5 Euros and is well worth it, including an audio guide.Be sure to climb the stands for great views of Athens and Acropolis.On the far left end is a tunnel leading to a small but nice museum with Olympic torches and memorabilia.
#
#
#
#
#
# User is :Thomas V
#
# Review header is :Ancient Roots to the Stadium
#
# Review text is :I stood at the end and gazed in at the empty stadium and could see that some tourists were taking a tour.  Not sure why.  It's big, it's built into the hillside and it has ancient roots.
#
#
#
#
#
# User is :Sue M
#
# Review header is :Great Oudoor Venue
#
# Review text is :I attended the Verdi Gala Greek National Opera performance at the Panathenaic Stadium on July 10th! It was absolutely stunning, and there was a huge crowd! Alghouth it was brilliantely managed, but be aware that getting to and from you seat would be challenging for anyone with a physical disability.
#
#
#
#
#
# User is :Beer Bottles C
#
# Review header is :You won't be sorry you went there
#
# Review text is :My favorite place that I visited in Athens. For a price of 5€ you get to enter the stadium that hosted the 1st modern Olympics and an audio guide that gives a lot of information. Also, one of the things that I liekd about the stadum was that it has amazing vies of teh Acropolis for the top of the stands. A bit underrated place but definitely worth the visit.
#
#
#
#
#
# User is :Béla M
#
# Review header is :Really unique
#
# Review text is :I had never been in such an old stadium before, and I really enjoyed that is had been rebuilt completely and it is not a ruin. It is a MUST to visit for everybody who likes sports.
#
#
#
#
#
# User is :Gert D
#
# Review header is :Impressive set-up
#
# Review text is :The stadium as such is impressive - there is a small "museum" offering an overview of the olympics games over time with representation of all cities etc - this is perfect to cool off in between visiting the stadium outdoors.
#
#
#
#
#
# User is :tumbleweedchris
#
# Review header is :Must Visit
#
# Review text is :The Panathenaic Stadium isn't quite as old as it looks but has been a piece of Athens history one way or another for awhile. When I visited, I got a free audio tour, which was helpful. The audio tour was informative but not too dense. Without the audio tour, it might have been a much quicker visit. The Stadium is really beautiful. As an added bonus, there is a collection of old Olympic torches. Towards the end of the tour, you will get an excellent picture of the stadium and Acropolis together in one shot from the top of the steps. Don't tell the Acropolis this, but I think I enjoyed my visit to this stadium more. Check it out.
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d245991-Reviews-or70-Panathenaic_Stadium-Athens_Attica.html#REVIEWS
# User is :Supermumof3
#
# Review header is :Absolutely incredible
#
# Review text is :Absolutely incredible place. Would highly recommend was so very interesting. We got the free audio tour guide and it was so interesting. We spent a good couple of hours here. I loved it.
#
#
#
#
#
# User is :William Peden
#
# Review header is :Steeped in History
#
# Review text is :Amazing venue, steeped in history,Go up to the top of the stadium for terrific views and pictures.Also don't miss the museum under the steps, there is a passage in the middle of the stadium.
#
#
#
#
#
# User is :Kathleen B
#
# Review header is :Fantastic place
#
# Review text is :This is one of my favorite things we did in Athens! Spent an hour or two. The stadium is amazing, so grand! The 5 euro entrance fee comes with the free audio guide. The tunnel to the Olympic room with all the posters and torches from all the Olympics was so neat! Beautiful views from the top of the stadium! Worth a visit!
#
#
#
#
#
# User is :elena
#
# Review header is :Quality time together on a cloudy day in Athens
#
# Review text is :An unique feeling running on this stadium. A minimum fee of 5 euro, kids and parents quality time together :). Do not miss the exposition with the olympic games
#
#
#
#
#
# User is :theconciergemom
#
# Review header is :Go! So interesting
#
# Review text is :I wasn’t expecting to think this was so interesting- but we ran all over the track and up the stairs- it was a great stop for 20-30 minutes. To imagine this was made all of marble is incredible.
#
#
#
#
#
# User is :ImmerWandern
#
# Review header is :Definitely worth the small entrance fee to visit the classic stadium
#
# Review text is :The Panathinaiko or Panathenaic Stadium is a must-see when visiting Athens. This was the site of the precursor of the modern Olympics, the Panathenaic Games that took place every 4 years from the 4th Century BCE to the 6th Century AD.  We had first spotted the stadium from the east end of the Acropolis, nestled in a ravine between two wooded hills, Agra and Ardettos, and it was a fairly easy stroll from our hotel.This is the world’s only stadium made entirely of marble, but the current structure does not date that far back. The narrow valley been the site of a race course since the 6th Century BCE, even prior to the Panathenaic Games, and initially spectators just watched from the hillside. 200 years later, during the 4th Century BCE, formal seating was built. In the 2nd Century AD Herodotus Atticus - the builder of the Odeon theatre at the Acropolis - constructed the precursor to this particular stadium completely out of white marble. Using the same white Pentelic marble of which the Parthenon was built the new stadium seated 50,000. Gladiator fights were apparently held here in addition to athletic competitions.  After the collapse of the Roman Empire the stadium fell into ruin, was grown over, and even became a field of wheat. Stadium marble was repurposed for local construction, similar to what happened to the marble of the Colosseum in Rome.In the late 19th Century the stadium was rebuilt for the start of modern Olympic Games, the first of which was held in 1896 here in Athens. Once again using white Pentelic marble the stadium was expanded to seat 80,000. Two special seats were created for the King George I and Queen Olga of Greece; you can find these seats at the lowest level on the right side when facing the curved end of the stadium.It is a U-shaped stadium, not a complete oval. At 200 meters in length it is not of regulation proportions for current athletic games. It was rehabbed for the 2004 Olympic Games and hosted the archery events and was the finishing line for the marathon. It continues to be the finish line for the Athens marathon.Be sure to check out the small museum displaying the posters of all the modern Olympics as well as the official torches used to carry the Olympic flame. The Olympic flame is lit at the Temple of Hera in Olympia and a relay carries it around Greece. The final stop in Greece is the Panathenaic Stadium where the flame is transferred to the runners of that year’s host city.The track features a comfortable black rubber surface. The rubber track may have been 21st Century in origin but the stadium features a drainage design from 19th Century, a critical design feature as the stadium would have to handle the drainage of rainfall pouring off the 2 hills into the valley. In addition to a drain surrounding the athletic field the drainage was facilitated by having the track raised 30 cm above the surrounding ground level.From the U-end of the stadium we had a good view of the Acropolis and the Parthenon.
#
#
#
#
#
# User is :Temer2
#
# Review header is :Feeling energetic!
#
# Review text is :Yet another gem that Athens has to offer. We only viewed from the outside, though we could have gone in, but the views from the street are great. Worth a visit on an Athens day trip.
#
#
#
#
#
# User is :permia
#
# Review header is :Fabulous
#
# Review text is :It was a perfect time to visit, as the sun began to set and in low season. With so few other visitors we were able to wander throughout and marvel at the accomplishment of its building.It was fascinating to discover that it is unique in being the only stadium in the world made entirely of marble.A cogent history abounds. It being the location of the ancient Games in honour of Athena, through its nadir while hosting Roman gladiatorial spectacles, to the marvellous rebirth for the first Modern Olympics in 1896.An atmospheric tunnel walk with beautiful stone and enhancing lighting leads to another grand area of the terrific enterprise.
#
#
#
#
#
# User is :Tom3588
#
# Review header is :Race on the track!
#
# Review text is :We did a couple of laps of the stadium, one around the top row of seats and then jogging a lap, could have done some races but didn’t fancy my chances against son.,
#
#
#
#
#
# User is :FellowTraveler2785
#
# Review header is :good deal
#
# Review text is :amazing view from the top 🔝 for just 5€...close to acropolis just 15 min ...something you should not miss
#
#
#
#
#
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d245991-Reviews-or80-Panathenaic_Stadium-Athens_Attica.html#REVIEWS
# User is :I W
#
# Review header is :Very interesting
#
# Review text is :We visited in October during covid. We visited on a Sunday morning and it wasn't crowded. We spent at least an hour looking round, with the self guided audio. If you're interested in the Olympics, this is a must.
#
#
#
#
#
# User is :T L
#
# Review header is :Beautiful sunset time
#
# Review text is :We came here 30min before it is closed.  We thought we were stupid but the lighting up surprised us!  It was beautiful!
#
#
#
#
#
# User is :Ginges_revenge
#
# Review header is :Closed and very empty. Still worth seeing.
#
# Review text is :We were in Athens in March 2020 at the start of the Covid restrictions and the city was effectively closed. When we walked into the square in front of the stadium, we were literally alone in the square with no-one else. It was again closed due to Covid restrictions but you can see a lot of the stadium so it wasn't to bad. A couple of Japanese reporters came and interviewed us as they were doing a story on the lighting of the flame for the Tokyo 2020 Olympics which was happening in 3 days. I would of loved to go in but at least you could see most of it. Well worth seeing as it is the birth place of the modern Olympics.
#
#
#
#
#
# User is :Sarah b
#
# Review header is :Very interesting visit
#
# Review text is :We enjoyed our visit here which was excellent value at €5 entrance each. We spent around 90 minutes here walking up to the top row and around. There is an audio guide but we found the leaflet very informative. The museum, though small contained posters and memorabilia from Olympics through the years which was really interesting. Also helped us make the connections between ancient and modern. Well worth a visit.
#
#
#
#
#
# User is :Sherlock arting
#
# Review header is :Panathinaic Stadium
#
# Review text is :The Panathenaic Stadium  or Kallimarmaro "beautiful marble") is a multi-purpose stadium in Athens, Greece. One of the main historic attractions of Athens, it is the only stadium in the world built entirely of marble.A stadium was built on the site of a simple racecourse by the Athenian statesman Lykourgos (Lycurgus) c. 330 BC, primarily for the Panathenaic Games. It was rebuilt in marble by Herodes Atticus, an Athenian Roman senator, by 144 AD and had a capacity of 50,000 seats. After the rise of Christianity in the 4th century it was largely abandoned. The stadium was excavated in 1869 and hosted the Zappas Olympics in 1870 and 1875. After being refurbished, it hosted the opening and closing ceremonies of the first modern Olympics in 1896 and was the venue for 4 of the 9 contested sports. It was used for various purposes in the 20th century and was once again used as an Olympic venue in 2004. It is the finishing point for the annual Athens Classic Marathon. It is also the last venue in Greece from where the Olympic flame handover ceremony to the host nation takes place.
#
#
#
#
#
# User is :Chris W
#
# Review header is :Home of the Olympics
#
# Review text is :Located on a main road near the park it is moving to see the home of the Olympics. A vast structure only for sport. The original cathedral to sport.
#
#
#
#
#
# User is :Susannah P
#
# Review header is :Impressive
#
# Review text is :Definitely worth a visit, it won't take you long.Stunning architecture, and pretty atmospheric.Beautiful marble everywhere.
#
#
#
#
#
# User is :Berit P
#
# Review header is :Amazing Place
#
# Review text is :The ticket was 5 € and an Audioguides is included. The self guided tour took me about 30 min and gave lots of interesting facts about the stadium, the architecture and the history. Climbing the steps to the highest point, walking through the arena, all very interesting. The Audioguides let the atmosphere of a packed stadium come alive. There’s a small museum but that’s partly closed due to COVID-19. I enjoyed the visit immensely.
#
#
#
#
#
# User is :Beraterin
#
# Review header is :Very impressing
#
# Review text is :You will like it! It is impressive, pure, full of history and 5 Euros is not too much. Perfect site for snapshots.
#
#
#
#
#
# User is :Steve Buckley
#
# Review header is :Well worth seeing even from the outside!
#
# Review text is :My wife and myself visited the Panathenaic Stadium (originally built In 1896 to host the  fIrst Olympic Games outside Olympus) earlier today as part of a full day’s tour of Athens.As we were a little tight on time, we decided just to view the impressive Stadium from the outside which was still well worth doing. It is probably one of Athens’ less visited attractions and I would encourage more visitors to spare 30 minutes of their time to do so as - largely because it is constructed of marble - it resisted the ravages of time better than most other similar vintage attractions!
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d245991-Reviews-or90-Panathenaic_Stadium-Athens_Attica.html#REVIEWS
# User is :Sarah Noonan
#
# Review header is :great place to visit
#
# Review text is :Covid did us a favour...no queues but be sure to check the opening and closing times - we arrived too late to walk around inside but its pretty awesome standing looking in especially with a fantastic sunset behind you. Really well kept stadium with great views.
#
#
#
#
#
# User is :ARoberts
#
# Review header is :Great!
#
# Review text is :Visited here quite early to avoid the midday heat! Only €5 each for entry which was good value for money for approx 1h of education and entertainment. They took card and cash. Was given a headset using like a mobile phone which was in a bag to be covid safe to listen about the history of the stadium and olympics. Masks only had to be worn when going instead and great to see all the flame torches. Had a fanatic little run around the track!
#
#
#
#
#
# User is :Dan L
#
# Review header is :Not just a stadium
#
# Review text is :The Panayhenaic Stadium isn’t just a stadium, but a tour through history. Be sure to climb all the way to the top, you won’t be disappointed with the views and the spectacular stadium.
#
#
#
#
#
# User is :Olivia P
#
# Review header is :My favourite site in Athens
#
# Review text is :The Panathenaic Stadium needs more recognition as one of the best and most impressive sites in Athens. Sit in the stands and just take it in. I went in October so it was very hot and sticky around the afternoon. Go earlier in the day because the track gets hot. Walk up to the top to soak up the impressive view of marble
#
#
#
#
#
# User is :penguinprint
#
# Review header is :Amazing morning experience before official opening time
#
# Review text is :Just went and it was absolutely the highlight of our Athens trip. Tips to make the most of your visit: go in the morning before the stadium opens at 9am for the tourists. They allow you to run around the track or just explore the space on your own (and yes, there are ticket staff there that early).We arrived at 8am and practically had the place to ourselves for an entire hour, running 5km around the historic track and enjoying the peace of the place. Also, contrary to the previous reviewer, the entrance fee is in fact EUR 5 and not EUR 10, so well worth the experience, especially if you're an Olympic/running/history fan. It's an amazing experience and there are loads of tiny details all around that you would never even see if you didn't go in and see the place up close (eg. the cool tunnel through which the athletes emerged, the unexpected view from the Parthenon from the rafters of the stadium, the two seats for the rulers right at the far end of the track, etc. There are too many details to list).More so than the Acropolis/Parthenon/Temple of Zeus, etc. this place in the early morning light was the favourite spot for our group of four. A must see.
#
#
#
#
#
# User is :Guy T
#
# Review header is :Great place - but wouldn't pay to go in!
#
# Review text is :The size of the stadium and the architecture are amazing, but I wouldn't pay to go in. I think it was about €10 each. You can get a feel for the size etc by standing in front of it, but the blue barriers.If it's included on one of your tickets then definitely go in. You can stand on s podium and take your picture.But you can view it from outside just as well!
#
#
#
#
#
# User is :ellieitalia
#
# Review header is :Kids love
#
# Review text is :Fantastic - feel the history. Run down the track. Sit in the stadium. Super views of city from the top seats. Stand on the podium! Inexpensive ticket. Self guided tour. Small museum could be developed but for the price and the fact the outdoor stadium  is the main attraction, it’s well worth it.
#
#
#
#
#
# User is :makalu8000
#
# Review header is :Iconic, Amazing Panathenaic Olympic Stadium!
#
# Review text is :A must do visit in Athens. The iconic Olympic stadium from 1896 built in the same marble as the Parthenon. An archeological masterpiece! Not to be missed. And before 9am you can run around the track in the stadium. Entrance-5 Euros
#
#
#
#
#
# User is :In-Yong H
#
# Review header is :Come early for a morning jog!
#
# Review text is :If you can motivate yourself, come for the 7.30-9.00 morning jog session - it's an awe-inspiring feeling to run around the tracks of this incredible historic stadium. You still need to pay the €5 entrance fee. There is an audio guide on offer, but you need to have an ID with you to give as a deposit. There is also a nice exhibit with past Olympic posters and torches, but since that is indoors, make sure you bring a mask. Take a walk up the stairs up the stands for a great view. If you go up at around tier 20, you get an incredible view of the Acropolis. Definitely a must-see sight in Athens.
#
#
#
#
#
# User is :Philip C
#
# Review header is :Great site if Olympic sport interests you
#
# Review text is :The site gives you a good impression of the first modern Olympic Games. Do not expect a lot of detail. The remarkable part is that it is so much different from current day Olympics. Keep in mind it is the place where it all started again. If that is your interest, come and see it yourself.
#
#
#
#
#
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d245991-Reviews-or100-Panathenaic_Stadium-Athens_Attica.html#REVIEWS
# User is :A_Amri
#
# Review header is :Great piece of history
#
# Review text is :This is an amazing part of history in general and the only pics in particular. Make sure you go inside their little museum with all the Olympic torches.
#
#
#
#
#
# User is :JalynCameron
#
# Review header is :Very nice view
#
# Review text is :Really nice view walking around the fully marble stadium. Entey fee is a bit pricey since you can basically see the entire stadium from the outside. But you also gain access to a mini museum of the stadium underground.  Its suuuuuper small and not worth calling a "museum".
#
#
#
#
#
# User is :Kasventures
#
# Review header is :HELLENIC OLYMPIC STADIUM
#
# Review text is :AKA the Hellenic Olympic Stadium, it was THE BEST TIME, so make sure you do this! We were most excited for the Panathenaic Stadium stop on this tour, and spent quite a bit of time here. They have headsets for you to use, for free, that come in most languages and give you the history of the stadium as you walk around at your own pace. Make sure you run a lap around the stadium, and get you a picture on the First-Second-Third place blocks afterwards.🙂 This stadium is such an iconic part of our world’s history, so be sure NOT to miss out!
#
#
#
#
#
# User is :TravelinSuz
#
# Review header is :Original marathon
#
# Review text is :The battle of marathon results were once here. The messenger died after delivering the message (summer heat plus no water enroute was not good).
#
#
#
#
#
# User is :Komal Pargi
#
# Review header is :Mesmerising stadium
#
# Review text is :keep good amount of time in hand for visiting this awesome stadium. They have an audio device guide in different languages. If you are interested in history the audio guide gives a detailed description and details.
#
#
#
#
#
# User is :gbsbiol
#
# Review header is :If you enjoy sports, specially running, is a must!
#
# Review text is :The audio guide explains quite well everything and you have a feeling that you are there with the athletes!
#
#
#
#
#
# User is :Wood77
#
# Review header is :Panathenaic Stadium
#
# Review text is :This stadium has been rebuilt over existing stadium several times and is the only one built with marble. This was used as an Olympic venue in 2004 and also for the Olympic flame handover ceremony. Just a quick look is all you need here, not much more.
#
#
#
#
#
# User is :StevenPJ
#
# Review header is :If you have time
#
# Review text is :If you have extra time the stadium is worth the visit but I would not go out of my way to see it. The audio guide is worth listening to as you walk the path around the site. Climb to the top for some of the best views of the Acropolis.
#
#
#
#
#
# User is :Ewa K
#
# Review header is :Great
#
# Review text is :no need to buy a ticket. I was disappointed that they will charge for entrance we saw outside and it took 3-4min to read about it.
#
#
#
#
#
# User is :Mas L
#
# Review header is :Spectacular
#
# Review text is :The photos don't do it justice - make sure you visit in person. It's spectacular and walking up to the top gives you a real sense of perspective on the size of the place. Definitely worth the cheap entry fee to actually go in and walk round.
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d245991-Reviews-or110-Panathenaic_Stadium-Athens_Attica.html#REVIEWS
# User is :abhinav goel
#
# Review header is :Birth place of olympic
#
# Review text is :This is mecca for any sports lover. This stadium is the birth place of modern olympic. Till today its in use, not for sports but for some open air musical events.
#
#
#
#
#
# User is :Emmanouil R
#
# Review header is :Master Craftmanship
#
# Review text is :One can only marvel at this stadium made entirely out of marble..the symmetry and size are impressive..a must see while in Athens!
#
#
#
#
#
# User is :chatdad
#
# Review header is :More than just a track
#
# Review text is :Sure you can snap pictures from beyond the fence but pay the small entrance fee to walk or run around, sit on the marble seats and go through the tunnel to see some of the past Olympic memorabilia
#
#
#
#
#
# User is :Jennifer S
#
# Review header is :Not to be missed when in Athens
#
# Review text is :I was pleasantly surprised by the stadium, you have an audio guide to guide you around the stadium which is beautiful.  Make sure to sit in the VIP seats! You can walk up the tunnel where athletes walked to start there race,  stand on the podium and pretend you've won a race.  The views from the cheap seats over to the acropolis are fantastic.  For 5 euros it's a great place to spend a few hours.
#
#
#
#
#
# User is :SherryDlk
#
# Review header is :Well worth a visit to the home of the modern day Olympics
#
# ...
#
#
#
#
#
# User is :Nicolas V
#
# Review header is :wonderful stadium
#
# Review text is :Impressive to see such a big stadium all in marble, in the middle of Athens. Also a nice little museum about the Olympic Games can be visited.
#
#
#
#
#
# User is :MILOUW
#
# Review header is :Huge
#
# Review text is :This is a modern replica of an Antique Stadium.It is beautiful and enormous, it is ready to be used and sometimes is.Worth taking a quick look
#
#
#
#
#
# User is :puckstopper31
#
# Review header is :Amazing outdoor venue
#
# Review text is :Set in the ground and set back in time. Various renewals but to think this is where it all began is stunning.
#
#
#
#
#
# User is :Cristian T
#
# Review header is :Amazing experience
#
# Review text is :This is one of the best experiences we've had in Athens. The stadium itself is really impressive and it looks new (rennovated at the beginning of the '00's); due to the fact that the ticket includes an audioguide, we got to learn about the history of this amazing stadium and, moreover, the history of the Olympic Games.The stadium's museum includes all the Olympic Torches in the modern era of Games (1896 to the present day).Of course, from the top rows of the Stadium, you can see the Acropolis (which are visible from most Athenian objectives).When in Athens, this is a place you shouldn't miss, in my opinion. It will be worth all your time.
#
#
#
#
#
# User is :Terry M
#
# Review header is :It’s an impressive structure, no doubt.
#
# Review text is :Gives one a feel of what all the other main, unrestored sites, would have looked like (bright, fresh cut, beautiful stone).  It’s a quick stop, check it out if you have lots of time.
#
#
#
#
#
# User is :Carl H
#
# Review header is :Lot of history but they don’t let you near the gates!!
#
# Review text is :You can see the stadium from outside the gates but they won’t let you inside. We did a tour and this was a stop and amazing the history and design of this stadium. Never ceases to amaze the craftsmanship and designs of these ancient structures in Greece. We were very bummed that we couldn’t access the stadium only 50 yards off the gate and couldn’t see much. It was roped off even. Very odd. Again, it was part of the tour and worth seeing but very underwhelming compared to other attractions in Athens. We spent maybe 5 minutes tops and then went back to the bus.
#
#
#
#
#
# User is :AnastasiaGhighis
#
# Review header is :The Kallimarmaro - stadium of Athens
#
# Review text is :A few days ago the Stadium hosted the Olympic flame events ,which i attended because a friend of mine was participating in the group of the girls that lit the flame in Olympia and welcome the flame in Athens. Stadium is glorious .Its name describes its elegance ,-KALLIMARMARO - which means in Greek language something that is made by selected good quality marble .It does not show how big it is as by tradition the ancient architects cared that the building becomes part of the inviroment in harmony and does not dominate the area. It does have its long History and still helds its space in the nowtimes events like the Marathons( all Marathins the originals or the mini Marathons end up in the Stadium of Athens ,The Olympic flame ceremony ,as well as classic sport events occasionallyetc  Kids would love it and will have the chance to run and enjoy the atmospheare of the Stadium  .
#
#
#
#
#
# User is :KlausPeterUnlustig
#
# Review header is :Nice to look at - but save the entrance fee
#
# Review text is :We went there on the last day of our stay since we needed an acitivity that doesn`t take too long before the flight. The dimension of this stadium are overwhelming when you are on the ground. But save the entrance fee of 5 Euros. When you are in front of the stadium turn left and go up the stairs and around the stadium. On the backside you can enter the stadium and walk around the top. You will not be able to go down but you have a fantastic view.
#
#
#
#
#
# User is :Kaitsu K
#
# Review header is :Olympics history
#
# Review text is :If you go to the Athens, this is the place where you have to visit. Ancient sport history. Visit the museum also. There you can see the olympics poster and olympics torcs
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d245991-Reviews-or1120-Panathenaic_Stadium-Athens_Attica.html#REVIEWS
# User is :Shelby S
#
# Review header is :Amazing to be in venue
#
# Review text is :I love the Olympics. Many times over the years I’ve gone out of my way to see the Olympic venues. This was must stop! Incredible! It was €5 to climb, run, sit, scream in the coliseum. Beautifully well done. Not only did they use it in 1896, but also in 2004. Just breath taking to be in there. Also had a museum that was included in your ticket.  Only thing not included, toilets, €0.50 fee, and they require exact change. So worth stopping to see this!
#
#
#
#
#
# User is :ijw36
#
# Review header is :Amazing insight into the past
#
# Review text is :Not sure what to write. I really enjoyed my visit. A word of warning is that everyone may be surprised by the height of the steps into the seating area. It is also one of the most intact ancient sites with only limited damage. I think it has been restored but well worth the €5 entry fee
#
#
#
#
#
# User is :Ben T
#
# Review header is :Worth a visit
#
# Review text is :Roughly a 10 Min walk from the nearest metro station. Do remember to take an audio guide and be blown away by the facts relating to the stadium!
#
#
#
#
#
# User is :tor2424
#
# Review header is :Good value
#
# Review text is :This is a must when visiting Athens. Costs only 5€  each which includes a free audio guide. Fascinating facts and a vast stadium. Great to sit in King and Queen thrones. Small museum through gladiator gate. Excellent photo opportunities throughout the visit too.
#
#
#
#
#
# User is :Paul O
#
# Review header is :Preserved history still in use today
#
# Review text is :The Panathenaic Stadium is a great example of an ancient stadium updated for use in the 1896 Olympics and still in used today. In fact, the Olympic flame was being officially handed over to Korean officials for the 2018 Winter Olympics the day we visited. It is covered in marble and seats 60,000. Imagine sporting events taking place the 2000 years ago.
#
#
#
#
#
# User is :csandman
#
# Review header is :Must see place while in Athens!
#
# Review text is :It is worth it to buy a ticket and go in. You get an audio guide with the ticket that provides a lot of interesting information and historical context.
#
#
#
#
#
# User is :kairlotta
#
# Review header is :Very cool!
#
# Review text is :This is the only all stadium in the world built entirely of marble!  Definitely worth the €5 to enter the stadium, even though we didn't stay long.  We walked the track, sat in the marble seats reserved for royalty (one of the coolest photos we took of the trip), and walked up the tunnel to the Olympic museum.
#
#
#
#
#
# User is :n0tis
#
# Review header is :The must of Athens visit
#
# Review text is :The OLYMPIC games are very well known all over the world . Once you are in Athens you must see the place where the first OLYMPIC games took place . No ticket is needed.
#
#
#
#
#
# User is :Shiv M
#
# Review header is :nice
#
# Review text is :yes, nice, thats it.actually its not quite as impressive as you may be led to believe.it is of course replete with history - the first olympics, the startin point of the olympic flame, .....and, as they repeatedly tell you, fully marbled seats
#
#
#
#
#
# User is :Emmanuel D
#
# Review header is :Well Worth it
#
# Review text is :Initially I sent my husband in and I waited outside. I wasn’t too interested and thought saving €5 was much wider. But once my husband went inside he insisted I wouldn’t regret coming in. When I got my ticket and went inside I agreed. It was so cool to be inside a stadium, sit where the royalty would have sat... race around the black track, stand on the winning steps and imagine what winning that medal would have felt like. We didn’t stay any longer than 30 mins but it was most definitely worth the €5. One thing I think could be better is you should be able to visit multiple times on the same day, this way you could take day shots and also come back in the evening. But unfortunately once you leave the stadium you cannot re-enter. Worth the visit though.
#
#
#
#
#
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d245991-Reviews-or1130-Panathenaic_Stadium-Athens_Attica.html#REVIEWS
# User is :MikeFo
#
# Review header is :Fascinating venue, shows clearly how stadia have changed
#
# Review text is :The first modern Olympics held here, must have been amazing, the track is much more longated than a current one, which have have had a profound impact on the racing. Must alo have been quite an atmosphere too given the proximity of the crowd to the athletes.
#
#
#
#
#
# User is :Angela Holanda
#
# Review header is :Cradle the Marathon
#
# Review text is :I confess that I didn't know that it was the place where was born the Marathon with 42.195 kilometres as we know nowadays. It is a magical place. They have a interesting museum, showing its history and the Olympics Game history till now. If you like history and sports, it is a perfect place to spend some minutes.
#
#
#
#
#
# User is :Smitmag
#
# Review header is :Don't under-estimate this site it's well worth the trip.
#
# Review text is :To be honest, I didn't think it would be worthwhile visiting here, but was pleasantly surprised. You could get the token selfie from the road but pay the 5 euro admission and take the audio guide it's much more interesting than I expected. It was nice to sit in the marble seating and listen to the history of the Olympic games and the original stadium in particular. Better still when you make your way through the entry/exit tunnel and see the inner rooms that show the posters and original torches back to 1936. It's quite exposed to the sun on a very hot day but we were there in October so it was just about right.
#
#
#
#
#
# User is :Lindsay D
#
# Review header is :Worth going 'in' (just make sure you have cash!)
#
# Review text is :I'm an avid runner, so I enjoyed this place by default. Only 5 Euro to enter. We walked over after seeing the Acropolis in the morning. Ticket booth is cash (euros) only and wouldn't accept the larger bills from the ATM. Had to purchase a snack from the nearby snack tent/shop in order to break the bill down. Once we got through that headache, we found the audio tour to be 'ok' (a little repetitive / lengthy). Definitely a cool place to see and be sure to take your lap around the track. There is obviously no shade so dress / plan accordingly. They have some cool replica Olympic posters available in the gift shop.
#
#
#
#
#
# User is :anushina
#
# Review header is :Very cool place!
#
# Review text is :It’s a very impressive place and has a lot of history. It’s obviously looking very different from what it was thousands of years ago but they used some original elements to restore it. Entry fee is 5 euros and it’s usually not very crowded, especially in the morning on a weekday. Go up on top, make a loop to admire the view, sit in the special seats where kings used to sit and watch performances, pics come out very cool there especially during sunset.
#
#
#
#
#
# User is :DSWWinchester
#
# Review header is :Well worth a visit
#
# Review text is :This was far more interesting than we had expected. It seems that many coach tours stop here for a brief photo-stop but it definately deserves more time than this; we spent nearly 2 hours there! Very good audio guide (12 or so stops around the stadium). An historic site but would also make a great venue for sporting events or concerts today, Would benefit from an on-site cafe.
#
#
#
#
#
# User is :KeithLacey
#
# Review header is :A must see!
#
# Review text is :Loved going here being an athlete myself. One important note it’s cash only except the museum shop that takes visa. I had to walk 1km to atm and back again. Free audio guide included with plenty to listen too. Bring earphones for audio but there is a speaker in case you don’t anyway. Go here it’s a must!
#
#
#
#
#
# User is :marsad31
#
# Review header is :Fans
#
# Review text is :Spent a couple of hours around the stadium and took advantage of opportunity to pose in winner’s position. Not a sport fan at all but overwhelmed by magnificence of stadium.
#
#
#
#
#
# User is :Lisa J
#
# Review header is :Tour
#
# Review text is :Great place to see and experience.  Lots of history.  Kept very clean and tidy.  Would definately go again
#
#
#
#
#
# User is :Dave1018
#
# Review header is :a true work of art
#
# Review text is :I was not aware of this place built in late 1800's for the modern Olympics it holds 70K, it is in magnificent condition and could pass for  modern building.You cannot get onto the track or stands they are blocked off, their are toilets there and a small souvenir shop but the prices are really over inflated.
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d245991-Reviews-or1140-Panathenaic_Stadium-Athens_Attica.html#REVIEWS
# User is :Emanuele G
#
# Review header is :A dream come true!
#
# Review text is :I have always dreamed of being there. With a low ticket (5 euro) you can walk in the most iconic Olympic stadium ever built.
#
#
#
#
#
# User is :DipuKV
#
# Review header is :Nice!
#
# Review text is :The stadium is worth two peeks - one by day and the other by night! The former gives you a measure of the place and the latter tells you how beautifully it can be done up!!
#
#
#
#
#
# User is :Rod H
#
# Review header is :Olympic stadium
#
# Review text is :This is a not to be missed attraction in Athens. The small entry fee includes audio guide. Everyone is focused on the ancient sites so this is something different.
#
#
#
#
#
# User is :Joe F
#
# Review header is :Awesome and a must visit!
#
# Review text is :I had been looking forward to coming to the Panathenaic Stadium since a friend showed me pictures of their trip and boy it did not let me down! It's so beautiful!I liked the fact they gave audio tours for free. I loved that you could climb and sit in the stadium at your own leisure and imagine the stadium in its hay day full of cheering people. For those that have fitness and a competitive streak you can even run the track and stand on the podium. Very enjoyable!!
#
#
#
#
#
# User is :Giannis G
#
# Review header is :First Olympic Games!!!!
#
# Review text is :Do not miss it.One of the most historical place of the world.First Olympic Games was here.The energy of the place is amazing.In the center of the Athens.For everyone-anytime.
#
#
#
#
#
# User is :Ivana K
#
# Review header is :Touristic atraction
#
# Review text is :Beautiful olimpic stadium. Student discount includeed and also a guide.  Don't miss underground museum of olimpic games at a stadium which is amazing.
#
#
#
#
#
# User is :bigjoelittlejoe
#
# Review header is :Olympic Games
#
# Review text is :While in Athens you have to visit this place, a wonderful arena on a grand scale, this is where it all stated and finished, the Marathon for instance.There a small museum, selling the usual stuff.There’s a lovely park across the road, in which to cool from the heat of the day.There also the lawn tennis club nearby.
#
#
#
#
#
# User is :millie516
#
# Review header is :Worth the fee
#
# Review text is :Ok basic info..5€ entrance fee. Free audio tour, bathrooms were .50€ Easy to get to, totally worth doing. You can run a lap and feel like an Olympic champion...lol
#
#
#
#
#
# User is :SeaininBrennan
#
# Review header is :Awesome!
#
# Review text is :My husband and I loved this place. Audio guides are provided. A must see and offers great photo opportunities.
#
#
#
#
#
# User is :CardiffMaddie
#
# Review header is :Great to see
#
# Review text is :We visited here as part of our free walking tour. You pay €4 entry but we just passed through. A great spectacle. Our guide said there was a 500m running track along the top, accessed via a path to the left. This is open 24 hours and is free and offers great views. Recommended.

# %%
df = pd.DataFrame(data, columns=['User', 'Review Title', 'Review'])

# %%
df.shape
# Out:
# (1150, 3)

# %%
df.tail()
# Out:
#                  User         Review Title  \
# 1145          Ivana K  Touristic atraction
# 1146  bigjoelittlejoe        Olympic Games
# 1147        millie516        Worth the fee
# 1148   SeaininBrennan             Awesome!
# 1149    CardiffMaddie         Great to see
#
#                                                  Review
# 1145  Beautiful olimpic stadium. Student discount in...
# 1146  While in Athens you have to visit this place, ...
# 1147  Ok basic info..5€ entrance fee. Free audio tou...
# 1148  My husband and I loved this place. Audio guide...
# 1149  We visited here as part of our free walking to...

# %%
filepath = Path('panathenaic_stadium.csv') 
df.to_csv(filepath, index=False)
