# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import re
import time
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
from pathlib import Path

# %%
data = []

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
url = "https://www.tripadvisor.com/Attraction_Review-g189400-d245989-Reviews-Mount_Lycabettus-Athens_Attica.html#REVIEWS"
print("url is \n" + url)
driver.get(url)
time.sleep(10)
soup = BeautifulSoup(driver.page_source, 'html.parser')
driver.quit()
# Out:
# <ipython-input-3-8f7de40498b2>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d245989-Reviews-Mount_Lycabettus-Athens_Attica.html#REVIEWS

# %%
containers = soup.find_all("div", {"class": "_c"})

# %%
len(containers)
# Out:
# 11

# %%
user = containers[4].find_all("a", {"class": "BMQDV _F G- wSSLS SwZTJ FGwzt ukgoS"})

# %%
user[0].text.strip()
# Out:
# 'Debbie S'

# %%
review_header  = containers[4].find("span", {"class": "yCeTE"})
review_text = containers[4].find("div", {"class": "biGQs _P pZUbB KxBGd"})

# %%
review_header.text.strip()
# Out:
# 'Best Views of Athens'

# %%
review_text.text.strip()
# Out:
# 'Took the funicular one way costing €7. The views are breathtaking! Almost a 360 degree view of the city, with mountains and Piraeus in the distance. A nice downhill return walk finished off a lovely few hours.'

# %%
for index, container in enumerate(containers):
    
    user = container.find_all("a", {"class": "BMQDV _F G- wSSLS SwZTJ FGwzt ukgoS"})
    review_header  = container.find("span", {"class": "yCeTE"})
    review_text = container.find("div", {"class": "biGQs _P pZUbB KxBGd"})
    
    if(review_header):
        print("User is :" + user[0].text.strip() + "\n")
        print("Review header is :" + review_header.text.strip() + "\n")
        print("Review text is :" + review_text.text.strip() + "\n")
        data_point = [user[0].text.strip(),review_header.text.strip(), review_text.text.strip()]
        data.append(data_point)
        print("\n")
        print("\n")
        
    if(index == 10):
        break #since there are 10 contaners with reviews per page but the first one is empty
# Out:
# User is :MSV
#
# Review header is :Beautiful sunset views over Athens
#
# Review text is :A great view over all of Athens - we went around sunset which was beautiful. At €10 for a return trip , this is a great activity for if you have a free evening , don’t forget to visit the small church at the top as well !
#
#
#
#
#
# User is :PA T
#
# Review header is :splendid views
#
# Review text is :One of the most beautiful views we have seen at night in Athens- so romantic! Would do it regularly whenever back in Athens. The way up the top can be a bit difficult if out of shape but defo worth it!
#
#
#
#
#
# User is :Ori L
#
# Review header is :Great view and area
#
# Review text is :Great place with the highest point of view at Athens , it was great to climb there thru the forest , just look at my photos to see the views from there.
#
#
#
#
#
# User is :Debbie S
#
# Review header is :Best Views of Athens
#
# Review text is :Took the funicular one way costing €7. The views are breathtaking! Almost a 360 degree view of the city, with mountains and Piraeus in the distance. A nice downhill return walk finished off a lovely few hours.
#
#
#
#
#
# User is :Jack L
#
# Review header is :Great Views of Athens
#
# Review text is :Lycabettus is a great spot to enjoy the expanse of Athens—particularly at night. The illuminations of the Acropolis alone make it worthwhile. The K.Grill is a reasonable place for a drink or meal. If you need a taxi from the funicular, beware of the fares at the station after 2100. The drivers often double the rate. Might be a good idea to book a taxi in advance.
#
#
#
#
#
# User is :Gints K
#
# Review header is :Best place to see Athens
#
# Review text is :Amazing place to see all Athens.Climb was easy and took around 10 minutes max. I recommend to go before sunset - see Athens in daylight and in dark. And it was so relaxing there- no noice. This must be TOP1 attraction in Athens.
#
#
#
#
#
# User is :Jan R
#
# Review header is :Ascend by funicular, descend on foot
#
# Review text is :We took the funicular to the top and enjoyed a windy but gorgeous view of Athens. Then, on the advice of a friend we walked down, stopping at the cafe for an Aperol Spritz and a snack. A most enjoyable outing!
#
#
#
#
#
# User is :Shirley L
#
# Review header is :Great city views
#
# Review text is :The funicular is an easy way to reach the top, however it travels through a tunnel and is thus not a place for views. The area on the top is spectacular and busy near sunset. I suggest the bar or cafe for eats and drinks. I ate at the restaurant, Orizontes Lykavittou. While the sunset view is spectacular the service and food were not.
#
#
#
#
#
# User is :Ron
#
# Review header is :Gorgeous views from the top
#
# Review text is :Views of Athens from the top were spectacular. We took a cable car to the top and walked down afterwards. It’s a shame a little church at the top was closed.
#
#
#
#
#
# User is :CuriousTravelerRadio
#
# Review header is :Fresh Air Summit
#
# Review text is :We love walking up Lycabettos every time we are in town. You can take the steep steps all the way to the Greek flag and St George's. You can also take other steps or a short taxi ride to St Isadore and see an incredible church built into the rock. This allows you to then walk 1 minute to a great cafe - Prasini Tenta, for great views of the city. A breath of fresh air either way!

# %%
for i in range(10,1250,10):

    driver = webdriver.Chrome(ChromeDriverManager().install())
    url = "https://www.tripadvisor.com/Attraction_Review-g189400-d245989-Reviews-or" + str(i) + "-Mount_Lycabettus-Athens_Attica.html#REVIEWS"
    print("url is \n" + url) 
    driver.get(url)
    time.sleep(10)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    driver.quit()

    
    containers = soup.find_all("div", {"class": "_c"})

    
    for index, container in enumerate(containers):
    
        user = container.find_all("a", {"class": "BMQDV _F G- wSSLS SwZTJ FGwzt ukgoS"})
        review_header  = container.find("span", {"class": "yCeTE"})
        review_text = container.find("div", {"class": "biGQs _P pZUbB KxBGd"})

        if(review_header):
            print("User is :" + user[0].text.strip() + "\n")
            print("Review header is :" + review_header.text.strip() + "\n")
            print("Review text is :" + review_text.text.strip() + "\n")
            data_point = [user[0].text.strip(),review_header.text.strip(), review_text.text.strip()]
            data.append(data_point)
            print("\n")
            print("\n")

        if(index == 10):
            break #since there are 10 contaners with reviews per page
# Out:
# <ipython-input-12-c30411ac8813>:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d245989-Reviews-or10-Mount_Lycabettus-Athens_Attica.html#REVIEWS
# User is :MNRLVEU
#
# Review header is :Great 360 view
#
# Review text is :Beautiful view of all of Athens. You are able to see what a huge city this is. The restaurants serve food and drinks at fair prices. Worth the effort to get there just to take in what a metropolis this is.
#
#
#
#
#
# User is :CraigH0901
#
# Review header is :Sunset Experience
#
# Review text is :Like just about everyone, we went there for the sunset over Athens. We took the metro to Evangalismos and then walked up to the funicular from there. Uphill with lots and lots of steps. Not for the faint hearted or poor fitness (get a taxi). At the top, there will be a line for a ticket and a line to get on. Only EUR10 each person and beats walking up there! Having said that, the walk would be spectacular and plenty of photo opportunities.When you get to the top at sunset, be prepared for a throng of people and fighting for the best vantage points. One of the best spots would be along the path going up to the top. Not as many people and the same views.You can see everything from here - sea, Acropolis, all of Athens. Great views, great pictures. There is also an expensive restaurant at the top but you have to book ahead.
#
#
#
#
#
# User is :Jon
#
# Review header is :Great views but a disappointing lack of information
#
# Review text is :I took the Funicular railway to the top and walked down. It was 30C+ during my daytime visit in September. Pros:-Helpful and pleasant staff. -Restaurant and cocktail bar at top. -Male and female toilets. -Great elevated views across Athens city, Greater Athens and islands beyond. -Church. Cons:-No information boards at top. -No signage boards with arrows highlighting the main sites at top.-Some views blocked due to restaurant and cocktail bar premises. -Footpath down from summit needs urgent attention as it is falling apart.
#
#
#
#
#
# User is :banmagoxon
#
# Review header is :Excellent Excellent Excellent
#
# Review text is :Allowed me to experience the most amazing panoramic views of Athens. My only quibble was with the WC facilities up there but the inadequacies of these in no way detracted from the views or from the effort that must have gone into building such a railway.
#
#
#
#
#
# User is :BeakerTX
#
# Review header is :Amazing view!
#
# Review text is :Best view in Athens!  You can walk up for free, or pay a small fee to take the Funicular.  The funicular offers no views, just convenience.  Once at the top, there is a restaurant, small chapel, and plenty of spots to take in the 360 degree view of Athens.  We walked back down and found some better unobstructed and less crowded views down the switchbacks.  A great way to appreciate Athens and maybe take in a sunset.
#
#
#
#
#
# User is :blurredadventures
#
# Review header is :A must do on your first day in Athens!
#
# Review text is :Amazing views, awesome options of food and bars up the top and along the way, there are many meandering paths up the hill from the city. The view along the way, and at the top is fabulous. The church at the top is nice to visit too. Make sure to take water with you, it can be hot walking up! A perfect thing to do when you first arrive to get a good overview of the city.
#
#
#
#
#
# User is :keckeley
#
# Review header is :Fun Experience on the Funicular
#
# Review text is :After exiting the Hop-On Hop-Off bus, we walked (climbed!) to the start of the funicular to ride to the top.  The views are outstanding and we even opted to put a euro in the binoculars to see even better.  You get a much better perspective of just how big Athens really is since more tourists only see a small part of the city.
#
#
#
#
#
# User is :Neil K
#
# Review header is :Great photo opportunities
#
# Review text is :The view over to Mount Lycabettus are really cool ,you take in the mountain and the vista of the city of Athens ,we were trekking up towards the Acropolis and stopped periodically to enjoy the great views of the mountain and city ,some great photographic opportunities ,if you're planning a trip to Athens it's most definitely well worth checking out.
#
#
#
#
#
# User is :The_Glovers_UK
#
# Review header is :Best views in Athens
#
# Review text is :We went up most of the hills in and around Athens including the odd roof top bar and the views from Mount Lycabettus are easily the best as it is higher than The Acropolis. We took the cable car which was around €6 each which seems a little steep (pun intended) but it saved us the climb.
#
#
#
#
#
# User is :Timbeach3
#
# Review header is :Skip it if you have already done the Acropolis.
#
# Review text is :This mount was touted as the highest point in Athens.  OK, but what are you seeing from that height?  The answer is not much.  The trek up the hill is not shaded, and it takes you to a place that is tiny, unshaded and the view is not spectacular.  It's just a layout of the city.  The Acropolis is a much better view!The funicular to get tot he top is cramped dark and hot.  If you are prone to claustrophobia, forget it.It is not worth the time, effort or expense to go to the top of this "mount."
#
#
#
#
#
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d245989-Reviews-or20-Mount_Lycabettus-Athens_Attica.html#REVIEWS
# User is :Thomas V
#
# Review header is :Behind Our Neiborhood
#
# Review text is :Our neighborhood was on one of the slopes.  A couple of times I climbed fairly high up still in the city, but never took the ride up to the top.  This mountain stands out in the landscape.
#
#
#
#
#
# User is :Mccloud24
#
# Review header is :Nice overview of Athens
#
# Review text is :Beautiful view that hill. Church is nice but needs to be restaurated. i imaged it would be bigger. The restaurants are nice.
#
#
#
#
#
# User is :Diana
#
# Review header is :Wonderful View
#
# Review text is :The experience once we were up the mountain was great. We stumbled upon the sunset by accident and it was lovely to see it from Mount Lycabettus. If you haven't climbed another hill that day (like we did Acropolis), go there by foot from the Evagelismos metro station. It's a steep hill and in the end there are a LOT LOT LOT of stairs. It may show like 500 meters or so on maps, and trust me, all of that is HILL. We should've taken a bus that day because by the time we got to the cable car, we already felt like we climbed the mountain. paying 10€ for the round trip of up and down seemed unnecessary. 7.5€ for one way which is a ridiculous price difference. I don't mind the unspectacular ride up. The cable car was in an okay condition.
#
#
#
#
#
# User is :Vacation699854
#
# Review header is :Fantastic Views
#
# Review text is :This was such a pleasure, the most fantastic views of the city.Pretty little church at the top with beautiful art work. Several different places to sit and enjoy a drink or food. Well worth the effort .
#
#
#
#
#
# User is :Gina F
#
# Review header is :Great views
#
# Review text is :It is a worthwhile excursion and the views are wonderful. It was a bit misty when we went. We visited near dusk and so it was not too crowded. If you are walking to the entrance, it is quite difficult to find. I'd recommend taking the funicular up, especially if you are tired from the walk just to get there, and if you have the energy (we did not) you can walk down. It's just one euro more for roundtrip so you might as well buy a roundtrip ticket and decide later how to get down.
#
#
#
#
#
# User is :pfefmeister
#
# Review header is :The Top of Athens
#
# Review text is :Certainly not as awe inspiring as the Acropolis view point, but a fun excursion nonetheless. Take the funicular up and walk back down on the easy sloped trail. Great 180 degree views from the top with a small church to poke your head in. Despite all the communication towers, my cell service was non existent. Nice restaurant for a coffee before heading back down - about 90 minutes total. One way is 7 Euro.
#
#
#
#
#
# User is :CMC
#
# Review header is :Mount Lycabettus Athens in April
#
# Review text is :Go early as possible. It’s quite a small area at the top so gets crowded with the perimeter full of people sitting and facing inwards making it awkward to take in the views from the edge without invading someone’s space.Got a bit put off by all the people sitting around with their backs facing the view and not moving out the way for other people. Acropolis just as good view so if going there don’t bother with this.However if a hike up and then a meal or ice cream at one of the cafes at the top appeals to you then probably worth it. There were plenty of free tables despite the summit being crowded.
#
#
#
#
#
# User is :DesignsOnTravel
#
# Review header is :The OTHER Unique Mountain in Greece
#
# Review text is :(I'm writing this not just for the experience but because Tripadvisor should be ashamed to have a random almost-10-yo negative experience with rather selfish advice as the first review for others to read.) Just got back from a family visit to Athens, rode the teleferik up Mt. Lycabettus which we had never heard of..and it was awesome! No, they don't make it abundantly clear that you DO NOT require a return trolly ride back down (you can buy a one way up as it's a nice long walk back down the mountain) but that's a very welcome option for mama or pop-pop or anyone who simply can't be on their feet for too long (you're going to walk alot visiting the abundance of Greece's ancient sites.) It's ridiculous to complain about there being nothing to see while the teleferik car ascends the interior of a mountain...IT'S THE INTERIOR OF A MOUNTAIN and therefore no windows, no sightseeing or entertainment. Which would be a waste if not an ingeneering imposibility; the view once at the top is the best in all of Athens. You are at a significantly higher elevation than the Acropolis and if you go later in the day as we did, you get incredibly beautiful views of a lit-up Parthenon and what seems like the entirety of Athens herself. In April 2022 the ride is 7 Euros, so about $7.50..SO worth it. There's a restaurant with equally great views of Athens also near the top, and at the very top is the small church of St. George which you can pick out against the Greek sky from virtually any other site you visit. We crammed ALOT of visits into our 7 days - if you only had one day in Athens, Mt. Lycabettus should figure somewhere near the "top" of your list (see what I did there?)
#
#
#
#
#
# User is :EmmaP
#
# Review header is :Stunning views
#
# Review text is :A beautiful place for stunning city views. The lady at the shop for the cable car was helpful and friendly. A nice cafe at the top for a cool drink before a pretty walk back down
#
#
#
#
#
# User is :Doby47
#
# Review header is :A must in Athens!
#
# Review text is :Best part of our recent trip to Athens. We walked through the upscale neighborhood of Kolonaki, stopped for coffee on a pedestrian cafe street and then walked uphill to the vase of the hill. From there we took the funicular, but it looked ok to walk. (We we’re tired from the earlier walk). Funicular runs every 20 min. 3 min ride straight up. Then you’re among gorgeous views. Simply stunning. A bunch of cute cafes and restaurants and a quaint old church. More views all around. We decided to have lunch at Skylab because it was so beautiful. Walked downhill through the wooded path.
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d245989-Reviews-or30-Mount_Lycabettus-Athens_Attica.html#REVIEWS
# User is :Harrison F. Carter
#
# Review header is :Beautiful
#
# Review text is :Wonderful views in all directions, and very beautiful and busy at sunset... with people lining the pathways to watch the sun go down. An easy ascent too, very gentle and gradual. Loved it.
#
#
#
#
#
# User is :Lottie
#
# Review header is :Fantastic views
#
# Review text is :Absolutely incredible views of all aspects of the city! We took the funicular up and down which was efficient and a bit different as we normally walk everywhere. Definitely recommend.
#
#
#
#
#
# User is :ERFSU82
#
# Review header is :Breathtaking views.
#
# Review text is :Our adventure to the top started with a leisurely, yet uphill, walk through the charming neighborhood on the south side of the mountain. We made our way to the funicular, opting to take that to the top rather than hiking up. The ride was short, and we emerged at the top to breathtaking 360 degree views. There is a restaurant at the top, with beautiful views from every table. The picturesque Chapel of St. George looks out over Athens and makes a nice backdrop for photos. The funicular runs every 30 minutes and takes less than 5 minutes each way, making it an easy way to get up and back.
#
#
#
#
#
# User is :Thomas V
#
# Review header is :The Mountain behind Our Neighborhood
#
# Review text is :I tried to walk up this mountain/hill, but did not get as far as I wanted.  I did get to the edge of the developed city.  You can go way up top to get the best views, but there is a lot of life on the sides.
#
#
#
#
#
# User is :Thomas G
#
# Review header is :Fireworks!
#
# Review text is :We were on top of the hill with all the fireworks on New Years Eve and it was spectacular. We could only come here to go to the restaurant up there so unfortunately we could not walk it, but the view was spectacular! You can see the whole city from up here. I would definitely recommend on going up this hill!
#
#
#
#
#
# User is :MargotPrist
#
# Review header is :Best view on the city of Athens
#
# Review text is :The view from this place is incredible! It's a lot of walking uphill so be prepared! But the view is totally worth it! There a two cafés/restaurants close or at the top where you can have a drink or diner with the best view on Athens.
#
#
#
#
#
# User is :RandyRoss
#
# Review header is :Great Views.
#
# Review text is :Take the funicular up (or walk) and enjoy the views and have a drink.  This is an especially to see the acropolis.   At 277 meters (908 feet) above sea level, this Cretaceous limestone hill in Athens is the highest point in Central Athens and pine trees cover its base.
#
#
#
#
#
# User is :Hany G
#
# Review header is :Top of athens!
#
# Review text is :We took the cable cart round trip so we skipped the hiking part, you can just get a taxi to the cable cart station.we went by the sunset. It was already packed but the view was spectacular.
#
#
#
#
#
# User is :ludor
#
# Review header is :Nice walk, spectacular views
#
# Review text is :It's a nice walk towards the Lycabettus top, not extremely difficult and quite rewarding in terms of views over Athens. Once arrived to the top, the views over the city and over the Acropolis are amazing. There is also a funicular that may be handy.
#
#
#
#
#
# User is :Yulia F
#
# Review header is :Athens' treasure
#
# Review text is :People in Athens are lucky to have this treasure in the city! I would love to visit the hill dozens of times in any weather. However, we were lucky to admire great views and not get blown away by the wind. I can't say that the paths are accessible to everybody, however if you are able to walk, then it's the best option, in my opinion. We loved exploring small paths around the main one and everything felt calm and safe for a casual exploration.
#
#
#
#
#
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d245989-Reviews-or40-Mount_Lycabettus-Athens_Attica.html#REVIEWS
# User is :belgianguy1
#
# Review header is :What a view!
#
# Review text is :Easy enough hike up on a well made concrete path, and amazing views from the top... there's a cute little church there too, check out the interior
#
#
#
#
#
# User is :Luke-n-LauraB
#
# Review header is :Views
#
# Review text is :Visited as a family, taking the reasonably priced funicular up with minimal wait. Gorgeous views at the top, plenty busy as you'd expect for such a great viewpoint. Would definitely have it on your hit list when visiting athens!
#
#
#
#
#
# User is :Adam I
#
# Review header is :Great place to visit at night
#
# Review text is :We came here at night, having hiked up there through the trails, It was enjoyable ad a great view receives you upon arrival, Definitely worth it
#
#
#
#
#
# User is :Peter B
#
# Review header is :Not essential on a first trip to Athens
#
# Review text is :The views are great, and I recommend getting a taxi to at least take you to the funicular station, or all the way to the top. Its quite an uphill walk from the metro to the station. I seemed like I walked halfway up the mount.Unless you plan to eat at the small restaurant, 15 minutes is adequate to take in the views and see the little church.
#
#
#
#
#
# User is :Carole W
#
# Review header is :Excellent
#
# Review text is :Be prepared to do some gradient walking,   worth the adventurous walk. Cable cart in use €7.50 return. Stunning views overlooking the entire city. Places to eat and enjoy the ambience 😘
#
#
#
#
#
# User is :phat_dawg_21
#
# Review header is :Great views of the city
#
# Review text is :We went up with our driver for the great views of the city. It was taking a chance because the road is not always open, but we got lucky that day.
#
#
#
#
#
# User is :B1714D
#
# Review header is :Athens best views
#
# Review text is :Lycabettus is the highest hill in the Greek capital with spectacular views of entire city, the Acropolis hill and all the way over the sea and the Egina island.There're 3 ways to reach the top:1. hiking on foot, which is pretty challenging as the hill is very steep, and I wouldn't do it, but it's free - no entrance fee2. by car almost to the top where's a parking lot, and then little bit of walking. This one is often closed, so it's a gamble, but it's also free,3. paying a funicular - you can opt for a return ticket or for one way and then descend down on foot.Once up, views are amazing and there's also a small picturesque Church at the top, along with a restaurant (with high prices as you guess).Best time to come is late afternoon before sunset.
#
#
#
#
#
# User is :Thomas V
#
# Review header is :We Lived on the Slope
#
# Review text is :We stayed on the slope of this Mount and I walked way up to see the upper suburbs and enjoy the views.  There is a teleferic to the top, looks like fun.  Prominent site in town.
#
#
#
#
#
# User is :Zoltán P
#
# Review header is :Spectacular view of Athens and the Acropolis hill!!!
#
# Review text is :We hiked the hill by foot! It is about 30 minutes walk with shorter breaks. The stairs and the path can be easily reachable from Syntagma subway station. The view from the top is absolutely magnificent to the city of Athens and the Acropolis hill... we spent only 20-30 minutes on the top.... there is a small monastery to visit and the observation terrace. Take a big bottle of water with you if you take the trip by foot!
#
#
#
#
#
# User is :Béla M
#
# Review header is :Magnificent view in the light breeze
#
# Review text is :We climbed the hill in the evening, and watched the sunset. Apart from the crowd on the top, it was very beautiful. Due to the light breeze it was not scorching, either. The scenery is unique.
#
#
#
#
#
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d245989-Reviews-or50-Mount_Lycabettus-Athens_Attica.html#REVIEWS
# User is :Catalina N
#
# Review header is :Beautiful View
#
# Review text is :It wasn't in our plan to go there. We went and is beautiful.  We loved the view,fresh air and you can sit and have some drinks.  From Plaka we took taxi 10 minutes and we come back by walk. We used the cable car to go on top.  I saw some people walking as well but us we were already tired from Acropolis.
#
#
#
#
#
# User is :Jerry Mattern
#
# Review header is :Challenging hike. Stunning views.
#
# Review text is :For some reason I didn’t have this on my to do list while in Athens I did it spur the moment on the last day. I’m glad I did; the 900 foot climb was difficult especially in the 90° plus heat. Totally worth it. The views from the top are absolutely stunning.There’s also a restaurant and a bar at the top that you can relax at before retreating back downhill. I didn’t have any to eat but I did enjoy a Super Mojito
#
#
#
#
#
# User is :Rafał PL
#
# Review header is :Go for it
#
# Review text is :It's a challenging hike, but in exchange we get stunning view, cable car is a good option if you do not want to end up all wet! Went on a cloudy day, but sunsets seem to be amazing from there.
#
#
#
#
#
# User is :Barry C
#
# Review header is :top view from this place
#
# Review text is :We were there as a group, a few times. Mega view from the top, it is for free. But you can also take cable car - not free.
#
#
#
#
#
# User is :TheKidsMum2014
#
# Review header is :Great views of the city
#
# Review text is :It is a great walk to the base of the funicular - not so great if you have a stroller as there are lots of steps. Once at the base you can choose a one-way ticket or a return. There is nothing to see on the way up. Once you get to the top the views are fantastic. There is a cafe if you need refreshments, and a small church. There are no signs to show you where to start your walking descent (take the path to the right of the church as you face it!) It is a lovely walk down and fine with a stroller. You get to see lots of plants, butterflies etc. There is a cafe/bar half-way down if you need it. At the bottom you can walk down the narrow alleyways down steps to town. It's a great walk.
#
#
#
#
#
# User is :Mike X
#
# Review header is :Take any path
#
# Review text is :Good workout for sure. Bring some water with you. Doesn't matter which path you take, as long as it's going upward you'll end up at the top.
#
#
#
#
#
# User is :Emma
#
# Review header is :SO beautiful and peaceful!
#
# Review text is :Wow what an amazing place! Take an Uber up and walk the rest up to the church. It has an amazing panorama view over Athen and a cute church. I really recommend it!
#
#
#
#
#
# User is :permia
#
# Review header is :Singular attraction
#
# Review text is :On a gorgeous sunny blue sky Sunday afternoon we took a grand stroll to the pinnacle. While the scenes on the way were good, those to be enjoyed from the summit were incomparable. Walking around, fabulous vistas of the white city below, stretching to mountains are to be marvelled at. A lovely Chapel, that of St. George, is worth dropping into. A grand frescoed dome, impressive iconostasis and images of St. George are some of the tranquil highlights.We stopped off for refreshments at the lovely placed café which was busy with weekend visitors.Another treat was taking the funicular down. While a short descent it was lovely seeing the city fast approaching.
#
#
#
#
#
# User is :Art1985
#
# Review header is :Our favourite spot in Athens
#
# Review text is :We managed to come here before sunset and saw the views from the day/sunset/dark and it was fantastic. Having been to the other sites we just fell in love with the views you get here and would say its a must do when you come to Athens. The funicular goes every hour and was €7 per person as a return i think. Definitely worth it.
#
#
#
#
#
# User is :speak0fthejamie
#
# Review header is :The climb is worth it
#
# Review text is :Climbing up to the top of Mount Lycabettus is definitely worth the views from the top.. 360° of the whole city, the only thing is the climb can be pretty tough but even stopping half way up to take in some extra views is well worth it.
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d245989-Reviews-or60-Mount_Lycabettus-Athens_Attica.html#REVIEWS
# User is :Ginges_revenge
#
# Review header is :The hill of Wolves was closed.
#
# Review text is :Again, closed. Due to Covid restrictions closing a lot of the city attractions, we couldn't gain entrance to one of the places I really wanted to see. Its either the Hill of Wolves after the Lykan myth or a large rock that the Goddess Athena dropped, I prefer the wolf story. I love going on a funicular in whatever city I am in and I missed this one. It had some good walks which I wanted to do when going down. I would of loved to see the view from up there as it would have been glorious.I'll just have to go back when travel restrictions have been lifted to see it.
#
#
#
#
#
# User is :hiritos
#
# Review header is :Great view
#
# Review text is :This place have a great view of Athens.it is really high but worth visiting. We took teleferik to go up and down by foot.
#
#
#
#
#
# User is :Dale-icious
#
# Review header is :The most spectacular sunset spot in Athens 🇬🇷.
#
# Review text is :The most spectacular sunset spot in Athens 🇬🇷.Lycabettus is Athens' highest and most central point, and once at the top offers unbeaten 360° views of the city; a cafe (where we shared a delightful chocolate cake and sipped sparkling wine); a seafood restaurant; and a tiny 19th century Chapel.There are several different routes to it's summit - The easiest way via cable car (The Teleferik), costing €7 for a round trip or €5 one way. Although, I highly recommend the 30 to 90 minute walk to the top/bottom for the ultimate experience - you may even cross the path of one of the native Greek tortoises that live on the hill.
#
#
#
#
#
# User is :37SueFo
#
# Review header is :What a view
#
# Review text is :Get a taxi to the funicular railway, and when you get out at the top, a couple of flights of steps will bring you out to the church and terrace, with 360° views of the city, looking down on the Olympic stadium and the Acropolis and across to Piraeus. There are a couple of bar/restaurants so you can have a drink and take in the views
#
#
#
#
#
# User is :ARoberts
#
# Review header is :Great View!
#
# Review text is :We opted for the funicular rather than walking up as thought it would be quicker to see the sunset as it was due within 30 minutes of arrival. Paid €15 euros for 2 return tickets. The ride goes a few times an hour and has seats, only takes 1-2 minutes to get to the top. It was quite busy at the top as everyone was waiting for sunset, recommend to get there early if want the best view. Lovely sunset, then got cocktails in the bar whilst awaiting for photos in the dark. The bar had cocktail offers, responsibly price with good quick service!
#
#
#
#
#
# User is :Doxakis
#
# Review header is :Amazing sunset
#
# Review text is :Amazing sunset with view to the Parthenon and the whole Athenean basin. Use the teleferik (a bit expensive bad worths) to go up to the hill and prefer the time close to sunset.
#
#
#
#
#
# User is :ausseertraveller
#
# Review header is :Not worth it
#
# Review text is :We hiked up the stairs at dusk. It‘s not worth it. A lot of people are going up there to watch the sunset, but actually you are getting better views from the Acropolis. Maybe it‘s different at dawn. We were really disappointed and started our descend straight away.
#
#
#
#
#
# User is :Lyka
#
# Review header is :Fascinating 🤩
#
# Review text is :Take a taxi  from the city  center Going to mo ung lycabettus. ITS too  long to walk. Taxi  cost 4-6euro.  Download the app "beat" so you Know  how much you need to play, and Will not be Surprise. You  need to walk 5mins more to reach the top. There is no  elevator  or  lift, so if your parents/ family  has problem with  it, reconsider coming. We had  our  dinner  with  us, so we ate  our dinner  there  while  enjoying  the view.  ITS a must  see in Athens and see the sunset. 🥰
#
#
#
#
#
# User is :Susan R
#
# Review header is :A great walk and fantastic view
#
# Review text is :The walk up to Lycabettus Hill took us approx 40 mins. We walked in the morning as it was cooler and was quite strenuous at times. Absolutely worth the climb as the view across Athens and especially the Acropolis was amazing. Would definitely recommend.
#
#
#
#
#
# User is :janetdbarker
#
# Review header is :Call am Uber when you want to get back to Central Athens, DO NOT USE TAXIS WAITING OUTSIDE
#
# Review text is :Lovely visit to Mount Lycabbetus today but was spoilt with taxi driver conning me and claiming I'd underpaid him (he was waiting outside the funicular) - he swopped my 20 euro for a 5 and I fell for it.Call an Uber which is a fraction of the cost.Athens taxi drivers are a disgrace!!!
#
#
#
#
#
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d245989-Reviews-or70-Mount_Lycabettus-Athens_Attica.html#REVIEWS
# User is :Lavinia P
#
# Review header is :Nice
#
# Review text is :I climbed Lycabettus Hill on a Sunday morning, by funicular. The view is amazing, you can see the sea, the city, which seems overwhelming ... There is a small church, St. George, where I witnessed the baptism of a little girl, there are restaurants where you can have a coffee looking around.
#
#
#
#
#
# User is :Guy T
#
# Review header is :The best view of athens
#
# Review text is :Literally the best view of athens. Photos do not do it justice. The railway up to the top go every half an hour (although we are told in peak season this is more often). It is 4euros one way or 7.5euros return. It was empty when we went at 1100. Beautiful church at the top that you can see from the whole of athens although this was shut when we went. & then a resturant/bar that we had a drink in before  coming back down. The walk back into town from the railway is only 20 minutes & we would claim this really is a must do in athens.
#
#
#
#
#
# User is :Ruth H
#
# Review header is :Sunrise visit
#
# Review text is :We visited Mount Lycabettus at 6am to catch the sunset. We found the route up to be initally poorly signposted but once you get on the track it is very easy to follow. Not too difficult up there (we are very fit and took maybe 15 mins steady walk). Views are good. Spoilt slightly by restaurants at the top and lots of rubbish flowing over the bins (unsure if this is currently due to covid situation but still worth to mention). Overall worth a visit to view the city - I imagine it is pretty for sunset but we didn't see. Nothing extra spectacular but certainley better than the views at the acropolis.
#
#
#
#
#
# User is :tripman
#
# Review header is :Beautifull view
#
# Review text is :2 words Beautifull view but a little bit hard to find and there is a Nice restaurant up there becuse i have to have 100 letters
#
#
#
#
#
# User is :In-Yong H
#
# Review header is :Incredible views of Athens
#
# Review text is :This is probably where you can get the best view of the Acropolis, as well as other major sights of Athens, such as the Panathenaic Stadium and the Olympaieon. You can even see all the way to the sea! I imagine the best time to visit would be for the sunset but unfortunately I couldn't stick around! You can either walk up or get the funicular. It's €5 for a one way ticket so you can get the train up and then walk down (like I did!)
#
#
#
#
#
# User is :Paul R
#
# Review header is :Stunning
#
# Review text is :We caught the metro to Evangelismos then walked the several hundred metres to the funicular railway. The walk is a hard walk ... up a steep incline with numerous sets of steps. So if you have any mobility issues or its extremely hot, then a taxi to the funicular railway is certainly the better choice. There is a small café near the station entrance to recharge your batteries or wait for the train (it is possible to walk to the top... but it was far too hot). The train ran every half hour with a return ticket costing € 7.50. The views from the top are stunning. The small church is certainly worth a visit and the restaurant provided a nice reasonably priced meal and drink before catching the train back down. I would certainly go back up Mount Lycabettus... and if your time in Athens is short, it needs to be near the top of your list.
#
#
#
#
#
# User is :aleksandra s
#
# Review header is :Astonishing Athens panorama
#
# Review text is :Hard to explain how stunning Athens panorama is. Look my photos amd you will understand. The best place to see everything like on the palm of your hand is here. There is a "easy" way to use funicular which cost 7,5 eur both directions ( goes on each round  hour on 30min), one direction is 5eur. Alternative is to walk up and down, ruther steep path ( hight 300m). Location, well you need to walk up the hils toward Lycabettus hill ( exact location- in the middle section of Aristippou street, well marked). Well worth the time, money, energy.
#
#
#
#
#
# User is :Linda B
#
# Review header is :Do it!
#
# Review text is :The hike is quite difficult, that of course mostly depend on your condition, but the views on top are amazing and if you’re in Athens you should do it! Doesn’t take much time, it’s free and it has amazing reviews from up top!
#
#
#
#
#
# User is :AB_US
#
# Review header is :Great Views of Athens
#
# Review text is :A great place for a 360 view of Athens. You can hike the mountain or you can hike the street, sidewalks, and stairs and use the Funicular for the last part of the climb. The climb is steep but the views are awesome, so, it is worth it!
#
#
#
#
#
# User is :exploringwithjune
#
# Review header is :Best hike in Athens
#
# Review text is :Obviously, most tourists tend to climb the acropolis first. What some might not know tough, is that if you climb the lycabettos mountain, you'll have some great views over the acropolis, the city and its ancient ruins and even up to the see. The climb seems rough, and the mountain seems far a way from the city centre, but I'd say it is very doable. I think it is only a 15 minute walk from the city centre to the foot of the mountain. You'll come across some great neighbourhoods, with hips cafes and fancy stores, along the way. The climb to the top of the hill is doable but it is quite steep. No need to bring walking shoes or anything, but keep that in mind. Before reaching the top after about a 30/30 minute climb, you'll find several little seating areas along the way. At the top there is a lovely little church and two cafes. It is nice to walk up one way, and take another route down. Would highly recommend taking this hike. It us becoming more well known to tourists, but still it might be a nice break from the overcrowded main city sights.
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d245989-Reviews-or80-Mount_Lycabettus-Athens_Attica.html#REVIEWS
# User is :Diane2703
#
# Review header is :Lovely Views Of Athens!!
#
# Review text is :We got a taxi to take us up Lycabettus, they dropped us at the car park.  There was a bit of steep walking up to the top.  As the Covid19 lockdown had started, the restaurant was closed off.  The bar had the seating area closed, but was open to get a drink and I think food.  We bought a drink and just sat on the wall to drink it.The views at the top are spectacular.  You really appreciate the size of Athens.  It is fun to try and spot the historical monuments from up there.It would be lovely to have a meal in the restaurant or chill in the bar with a drink.Perhaps on our next visit !!
#
#
#
#
#
# User is :Grace Pachuau
#
# Review header is :Good view
#
# Review text is :Offers a good view of the city. Quite a long walk to the top. We took an Uber from the main city square which drove us near the top with a few steps of walking requires. There are restaurants with amazing views. Gets crowded during sunset.
#
#
#
#
#
# User is :plumcox
#
# Review header is :Amazing Views!
#
# Review text is :You really get a sense of how large Athens is, how it relates to the sea and the mountains and what other strange bits of rock stick up out of the city!  What a great view from here (along with lovely cafe tables to allow you to day dream over the view for even longer).  Interesting paths down through cacti / succulent gardens.
#
#
#
#
#
# User is :Steve B
#
# Review header is :The views!
#
# Review text is :Our hotel was at the bottom of Mount Lycabettus so we decided to walk to the top one day. At the top there is a small church and a  restaurant. The views are what make it worthwhile though. You get a 360 degree view of Athens and see just how sprawling the city is. The walk isn’t too difficult, there are plenty of places to stop and rest if you feel the need. Well worth a look, and surprisingly for Athens - it’s free!
#
#
#
#
#
# User is :Mohamed Shouman
#
# Review header is :When you see Athens from the highest mountain
#
# Review text is :Lycabettus in the top of a great garden, where you can use for sports, couple meetings and etc.At the top, you will find a small good looking church and you can watch Athens and Acropolis. Also, an amazing place to watch the sunset.I visited Greece in June 2018 and I enjoyed it a lot.
#
#
#
#
#
# User is :JES522
#
# Review header is :One of our favorite experiences!
#
# Review text is :We didn’t intend on climbing the mountain, but ended up doing it and I’m so grateful! The climb, although likely challenging for some, was totally doable. The views at the top are worth every step! This was one of the highlights of our Athens trip! We sat at the restaurant on top & had an appetizer while taking in the amazing views.
#
#
#
#
#
# User is :Wareaglemac
#
# Review header is :Mount Lycabettus Hike
#
# Review text is :My wife, daughter and I hiked to the top of Mount Lycabettus from the Zafolia Hotel.  It took less than 45 minutes from the hotel to get to the top.  We walked the road that takes you about two thirds of the way to the top.  It is a gradual climb and I worked up a pretty good sweat but I never felt like it was extremely difficult.  There are several benches and overlooks to stop and take a break.  There are numerous trails throughout the area and we sometimes took shortcuts on a trail and hooked back up with the road a little farther up the hill.  About two thirds of the way up, you take a paved trail with a lot of stairs to the top.  Many cars were dropping people off at this spot.  At the top there is a small viewing area, a bar, restaurant, and the Chapel of St. George.  The views are spectacular and well worth the hike.  I got some great pictures of the Acropolis and Parthenon from the viewing area.  When you look at the mountain from below, you would think it would be a difficult climb, but don’t let that scare you from making the climb.  If you really don’t feel you can make the entire climb from the bottom, get a taxi to take you up to the drop off point, or alternatively take the funicular.  Even if you didn’t make it all the way to the top, there are a number of places to stop that also have wonderful views of Athens.
#
#
#
#
#
# User is :January
#
# Review header is :Great trek to the top!
#
# Review text is :From the base of the hill, it took us about 20 mins to walk to the top.  It wasn't a steep incline but more gradual.  I didn't find it strenuous, but I definitely broke a sweat.  I wasn't taking a stroll; I was walking to get to the stop.  I would NOT recommend bringing little kids on the walk/hike.  There are ZERO safety precautions from the edge.  Even if a tree or bush broke one's fall, it will hurt very very much and will more than likely cause permanent injury.  The views on the walk up were pretty spectacular!  It was a clear and sunny day and one could see all the way to the Acropolis and beyond.  In general, the hill provides a 360 degree view of Athens.  A LOT of people watch the sunset from Lycabettus Hill but I didn't think it was that great.  I was expecting a show stopper and for some reason the sun's colors were hidden by clouds.  Not sure how that works since visibility was all the way to the sea.Re: dress...I had on sneakers, loose pants, and a tank top and I was sweating as I trekked up the winding hill.  Once we sat at the cafe at the top, it got really windy.  Thank goodness I had my scarf to wrap around my upper body!  Otherwise, I would have been miserable.  The wind at the top is very unforgiving.
#
#
#
#
#
# User is :Oeliram
#
# Review header is :Great view
#
# Review text is :Worth it for the trek and great views. Steep climb but if you are in good shape it's not very hard to go up by foot - it took us about 20-25 min from the base of the hill (stairs going through the neighborhood) all the way up to the top. We actually looked for the funicular but couldn't find it and just ended up walking on our own. Area at the top is quite small but wasn't very crowded when we were there.
#
#
#
#
#
# User is :DejZu
#
# Review header is :Actually Hill
#
# Review text is :Very attractive place in Athens to visit. Walking to the top or only to the funicular is pleasant. There are no a lot to see there but you can see far around, almost all Athens, even Piraeus and the See. If you do not have enough time or want to save your legs for further walking, take the funicular to the top, although it is only passing through the long dark tunnel.
#
#
#
#
#
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d245989-Reviews-or90-Mount_Lycabettus-Athens_Attica.html#REVIEWS
# User is :BlrTravR
#
# Review header is :Nice views
#
# Review text is :If you are looking for a trek and views a bit off the tourist trail, this is the place with great views of the city.
#
#
#
#
#
# User is :multitaskingmum214
#
# Review header is :Great views
#
# Review text is :Well worth it for great views. The actual space at the top is pretty small but wasn't too crowded in Feb half term. The cafe is nice if as pricey as you'd expect in such a spot (9euros for fruit salad with yoghurt). The funicular up is functional, through a tunnel, so don't worry about a window seat!
#
#
#
#
#
# User is :Krishhere
#
# Review header is :Beautiful night view of Athens
#
# Review text is :Went there around 9 pm. Got a nice view of the city by night including landmarks like the Parthenon and the Parliament building. There is a chapel at the top of the mount, which was closed at this time. The restaurant was open. There were groups of revellers and couples around with the police keeping a watchful eye.
#
#
#
#
#
# User is :Ion Frantzeskakis
#
# Review header is :A rocky hill overlooking Athens
#
# Review text is :Mount Lycabettus, or rather the Hill of Lycabettus, is a rocky hill of limestone at 300 meters above sea level, overlooking Athens. Pine trees cover the foothills, and the 19th c. Chapel of St. George, is built atop. An open-air theatre hosts mostly music events, and a restaurant, offers stupendous night views of the city. A funicular railway can take you to the top of the hill, unless you are fit enough to use the steps...
#
#
#
#
#
# User is :Sensible Wanderer
#
# Review header is :Best view of Athens, Mount Lycabettus
#
# Review text is :Despite having made peace with missing Mount Lycabettus this trip, we found ourselves walking around it’s base on the way back from lunch in Exarcheia and thought, why not?! We took the funicular slowly up through a dark tunnel and stepped out essentially into a cafe. Spectacular 360 view, good cafe options both food and drink, and even a feisty cat. Easy trip, needs no more than 90 minutes, but definitely stay longer to take in the view from the cafe. Glad not to have missed it!
#
#
#
#
#
# User is :Irina B
#
# Review header is :The highest viewpoint in Athens
#
# Review text is :It can be climbed on foot or you can take a cable car, round trip ticket was 7.5 euro. I would recommended take a cable car to get on top and then descend on foot.On the mountain top there are several cafes to have a drink or a snack and enjoy the skyline view :)
#
#
#
#
#
# User is :MrsWBN
#
# Review header is :Cable car up - walk down!
#
# Review text is :We bought the return cable car ticket to save a few €, but ended up walking down and it was super lovely trails through lush, green areas and great views, and easily done. Unless you really have trouble walking for any reason, just do the cable car up the hill.Only went up to enjoy the views but there is a café and a restaurant which we didn't try. Great little excursion to get a overview of the city, and we enjoyed the area at the foot of the hill too.
#
#
#
#
#
# User is :Shush
#
# Review header is :Plenty of steps
#
# Review text is :We walked from our hotel and climbed the flights of steps to the funicular. There we were approached by taxi drivers who said that they would take us to top fo 8 euros as the funicular would have been double that we took advantage. The drive took us around the other side of the hill and we were dropped at some steps which was quite a climb. On deciding to walk down we discovered we had hardly saved any walking distance by taking taxi so if you are relatively active it is quite easy to do complete climb - we are pensioners. Well worth the effort as the 360 degree panoramic view it incredible. Well designed cafe set into the top along with a small Orthodox Church. Of course we did it in February, the hot sun of summer may make it a difficult journey as there is no shade
#
#
#
#
#
# User is :drue
#
# Review header is :Amazing view
#
# Review text is :Great spot, walk up hill was energising and view was amazing, restaurant has everything you need from a coffee or beer to a full dining experience!!
#
#
#
#
#
# User is :74krisztiank
#
# Review header is :Great round-panorama to Athen
#
# Review text is :This hill is not very high but provides a great panoramic view to the whole area of Athen. The Acropolis e.g. becomes a small piece of the extra-large complex of the buildings from the mountains to the sea. If you manage to climb about 200 stairs from the Metro station Evangelismos (M3) you will find a funiculaire going every 30 minutes up and down (7 EUR together). On the top there is no too much place just feel yourself good and look around or have something in the restaurant.
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d245989-Reviews-or100-Mount_Lycabettus-Athens_Attica.html#REVIEWS
# User is :CuriousTraveller
#
# Review header is :what a joy to enjoy the view in night
#
# Review text is :We were staying close by during our trip to Athens but undecided whether to go on top or not as it did not look impressive during day time from outside but eventually we went and couldn't believe that we would have missed the wonderful view of city and Acropolis. There are a couple of very good restaurants at the top for evening meal preferably you should book in advance otherwise long wait. We used lift going up and walked down as lift were busy and again it was good choice. Certainly recommended for feeling young couple  !
#
#
#
#
#
# User is :David K
#
# Review header is :Mt Lycabettus in Athens.
#
# Review text is :Nice path through a park to the top.  360 degree view of Athens.   Small Orthodox chapel at the top and a cafe.
#
#
#
#
#
# User is :frugalarnie
#
# Review header is :Hilltop overlooking the historic city
#
# Review text is :Mount Lycabettus is a majestic place.  A park. A church.  A special place to see the city all the way to the port. A long hike up. Need to get in shape.
#
#
#
#
#
# User is :Traveler256905
#
# Review header is :What a view
#
# Review text is :Lycabettus hill is 377 meter high.Climb by the funicular and enjoy fantastic view, 360 degree wide.See the Acropolis, you climed before and it seems so high, lower than you, like a lego building  in children's game.After the hundreds of pictures you'll take,  eat something in one of the restaurants or the bar,  wait in the line for the cable car to get down (every half an hour) and here you have experienced a very special site.
#
#
#
#
#
# User is :Iulian S
#
# Review header is :amazing view
#
# Review text is :amazing 360 degrees view of Athens. You can see all the important points of Athens from the highest point of the city.
#
#
#
#
#
# User is :Dominik
#
# Review header is :Amazing view
#
# Review text is :Must see in Athens. ONLY there you can realize how big the city is. Nice path up to hill with numerous fantastic views. At the top basically 360 view. Great around a sunset and worth to wait for city night lights!
#
#
#
#
#
# User is :ESK71
#
# Review header is :My favourite view in Athens
#
# Review text is :Lycabettus was the first place I went to in Athens. I was taken there in the middle of the night by the close friend who used to live in Athens years ago. I was mesmerized by the view and by the silence of the city. Never skip it!
#
#
#
#
#
# User is :Daniela A
#
# Review header is :Mount Lykabettus
#
# Review text is :Half a day worth spending to see an incredible panorama of  beautiful Athens. A  rather difficult way till the funicular,  but pleasant  nevertheless,  then a short  trip by the  funicular and here you are o  top let,s say of Athens. Beautiful images,  a real pleasure to watch.  Going down rather tirering to walk, but worth in terms of landscape. Allow at least 4 hours for the whole trip
#
#
#
#
#
# User is :victoria2307
#
# Review header is :Great views
#
# ...
#
#
#
#
#
# User is :wennitiong
#
# Review header is :View point of Athens
#
# Review text is :As the title saying, it is the best spot to see the city of Athens. At several angle, you could see the Acropolis, port of Athens and the metropolitan of the Athens. The view is stunning!
#
#
#
#
#
# User is :Gregg C
#
# Review header is :Stunning views
#
# Review text is :What an amazing view.  We took the funicular to the top 7.50 euros each on a Sunday and enjoyed the stunning views.There was a church service on that added to the ambience!Would definitely visit again!
#
#
#
#
#
# User is :Burger77Norway
#
# Review header is :Fantastic view point
#
# Review text is :Great place to view the city. Not a long walk up. Nice monastery at the top and also good service at the restaurant. This is a must do if you like to get a overview on your journeys.
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d245989-Reviews-or1220-Mount_Lycabettus-Athens_Attica.html#REVIEWS
# User is :Totaa
#
# Review header is :it was a nice view
#
# Review text is :The view was so nice that you can see all Athens, I was there in summer it was very very hot but  they are many restaurants there to stay and enjoy the view  i used the tram rather than walking in hot weather, the ticket didn't cost me much for the tram (teleferik)
#
#
#
#
#
# User is :Hay B
#
# Review header is :high exeptations
#
# Review text is :but in real the place is dirty and ugly grafities on the walls. the teleferik is very expencive. the view is grate, but no shade. very hot.
#
#
#
#
#
# User is :Robert T
#
# Review header is :Sunset <3
#
# Review text is :Make the 15 minute trek uphill to the top of he mountain to watch the sunset. It's absolute gorgeous! Tip: Skip the over priced restaurant - grab some supplies from a local deli and have a beautiful picnic as the sun goes down. Get there at least a half hour before sunset to get yourself a good spot!
#
#
#
#
#
# User is :janao
#
# Review header is :The views!
#
# Review text is :Mount Lycabettus has some nice views over the entire Athens. Is is a easy walk from the city centre. Skip the funicular and walk up. Enjoy the views especially at sunset.
#
#
#
#
#
# User is :Becky B
#
# Review header is :Hot but worth it
#
# Review text is :Climbing mount lycabettus through the woods was quite the experience! The sights were well worth it, once we made it to the top. I would recommend taking on the challenge of hiking up it if you are looking for a moderately long walk with a steep incline. Otherwise I would suggest taking a taxi to the top. The view was breath taking.
#
#
#
#
#
# User is :Dimitris L
#
# Review header is :Stunning Views
#
# Review text is :Lycabettus is one of two hills in the centre of Athens, and it is absolutely beautiful with some of the most stunning views of the city. The other hill is, of course, the Acropolis. You can walk up the Hill, which is what we did. There are steps from various places. The steps can be a little demanding, depending on your fitness level, but you can stop now and then, so you will not be exhausted by the time you reach the top. There are several hundred steps, I think, but they are worth it. There is only a very small chapel at  the top of the hill and an entrepreneurial drinks sales man! That's all! And of course a few dozen visitors enjoying the wonderful views of the city and beyond. It is like a dream. You have to be there to really appreciate the beauty o9f the place. There are different stories about the naming of the hill, and one is that it derives from the name for 'wolf', which in Greek is "lykos", or "lycos". So the place was meant to be 'the place where wolves went, or took refuge", hence "Lycabettus". Interesting!
#
#
#
#
#
# User is :Tara C
#
# Review header is :Great views
#
# Review text is :After the acropolis this was my favorite thing In athens.It took maybe 20 minutes up hill but was worth it.The walk up had some lovely views of the city and the views from the top were breathtaking. We went for sunset it was a little crowded but like all good spots .I'd highly recommend it .the walk up isn't that bad
#
#
#
#
#
# User is :Diane P
#
# Review header is :Beautiful view-long climb
#
# Review text is :Saw Mt. Lycabettus in our view from our hotel St. George Lycabettus. Has a chapel on top of the mountain and wanted to see it.  The day we went the funicular was not working and my husband and I decided use the stairs to the top. It is a steep climb but rest areas on the way--you will need them. Visited the small chapel at the top and sad to say, saw graffiti sprayed on the wall of the chapel. There is a restaurant next to the chapel which we visited for lunch. The food was prepared well, and reasonable in price as well. Very good photo opportunity as well!
#
#
#
#
#
# User is :Traci T
#
# Review header is :Lycabettus and Hotel
#
# Review text is :We stayed half way up Lycabettus Mountain at a boutique Hotel. It was a beautiful view seeing across the city to the Acropolis and Parthenon.
#
#
#
#
#
# User is :Mary Z
#
# Review header is :Very nice views
#
# Review text is :We went up for sunset and it didn't disappoint. We took an uber most of the way since it was getting late and our feet were tired. There's a nice looking restaurant up there. We didn't stop at it but good for a beer. It's worth your time. Was quite crowded.
#
#
#
#
#
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d245989-Reviews-or1230-Mount_Lycabettus-Athens_Attica.html#REVIEWS
# User is :MiamiGreekGirl
#
# Review header is :Awesome views!
#
# Review text is :I went here when I was a kid and it was awesome to take my kids there now.  The view from the top does not get old.  There is a beautiful little church up there where you can go in and light a candle. We didn't take the funicular train up - we had a taxi take us halfway up and wait for our return - all the taxi drivers know where to go - and we walked the rest of the way which took about 5 minutes. We went at night to see the city and the Acropolis lit up.  It was breathtaking!  This is the highest point in Athens - almost 1,000 feet above the city.  Anytime you go is a great time to go.  Most people love going at sunset - too crowded for me.  I prefer to see the city at night all lit up with less people around me.  It's a personal preference.  There is also an amazing restaurant up there.  You can make a night of it.  When in Athens - there are 3 places, in my opinion, which can't be missed...Acropolis, Sounion and Mt. Lycabettus.  You won't regret going - and it really doesn't take too much time at all.
#
#
#
#
#
# User is :Lydz1970
#
# Review header is :Great views
#
# Review text is :We caught a taxi from Syntagma Square and asked the driver to take us to the cable car which takes you to the top of Mount Lycabettus. The driver insisted that he could take us further up the mountain and that it would be a very short walk to the top. Unfortunately, it was a very steep climb, which was not short at all, and considering I had my 75 year old mother in law with me, I would've thought the driver would have been more considerate. So we eventually made it to the top after many rest breaks and sat down at the restaurant to order lunch- which was pleasant. The view is amazing from the restaurant and from the top of the hill. We travelled back down using the cable car- no problems. We grabbed a taxi at the bottom and asked our driver to take us back to Monastiraki where we were staying. He was very pleasant and we enjoyed his conversation. But- he decided he wouldn't take us directly to our apartment and dropped us off at a point of his choosing. He told us it was a short, easy walk back- but it wasn't! Very frustrated with our taxi drivers today!
#
#
#
#
#
# User is :grahamfield
#
# Review header is :Great views of Athens, no access for wheel chair users
#
# Review text is :Stunning views over Athens, we took the funicular, wheel chair access was limited and we carried the wheel chair up, using crutches to get up the stairs. There is a nice restaurant at the top.
#
#
#
#
#
# User is :pedage10
#
# Review header is :Beautiful view - don't go on Saturday morning!
#
# Review text is :We went to this gorgeous site on Saturday morning. The hilltop and view of the city was excellent, but on Saturday mornings the church is often used for baptisms so we didn't get to go up to it. We're planning another trio while in Athens however, as it's simply stunning from the outside.
#
#
#
#
#
# User is :SuzeStar
#
# Review header is :Nice views. That's about it.
#
# Review text is :A very steep climb, or can catch the short rail. Views at the top are fabulous, with a small church on the top and a few restaurants (which looked unappealing). 20 minutes at the top was enough. Wouldn't bother again but if you like views and an overall viewpoint of Athens then this is for you.
#
#
#
#
#
# User is :Doris R
#
# Review header is :Spectacular
#
# Review text is :Climbed on a night time for about 20 minutes up. Amazing view. You can see the entire Athens well lit at night. The breeze is just so amazing.
#
#
#
#
#
# User is :sharonearly
#
# Review header is :worth the visit!
#
# Review text is :It was a rainy day but we decided to visit Mount Lycabettus.   We took the tram to the Syntagma station and walked the remainder of the way using our Around Me app.   We stumbled upon the Hi-Fai Grill House (highly recommend) where we had a snack before our long walk up the hill.    We rambled through winding streets and were helped along by some passersby who could tell we were looking for Mount Lycabettus.   We took the funicular to the top and paid for the ride back down as well.   But I wanted to walk down.   So I took a path down and then my husband decided to walk down after I had left the top of the hill.   Luckily we could text message to locate each other as we took paths down on opposite sides of the hill.   (there are many walking paths so I recommend you stay with your group if walking).    We met back at the St. George Hotel as that was the only close landmark that we both knew.  The views from the Lycabettus are amazing and it's worth the trip.
#
#
#
#
#
# User is :Ryan M
#
# Review header is :Cool Experience off the beaten Path
#
# Review text is :Taking the cable car to the top of Mount Lycabettus is a bit out of the way but worth it. We took the big bus to Banski Museum top and walked about 15 minutes to get to the cable car which leaves every 30 mins on the hour and half hour. It takes all of 3 mins to get to the top and offers great views of Athens. It departs the top every 30 mins as well. It costs 7 euro and also has a restaurant at the top we did not eat at.
#
#
#
#
#
# User is :Jorge U
#
# Review header is :Have a cab number ready
#
# Review text is :Views are potentially great. 360 almost awesome. BUT the view of the Acropolis is obstructed by antennas. The rest of the view are houses and the Athenian landscape. Easily accessible. Another BUT- the way down is a gamble. Have a cab number just in case there aren't any cabs.
#
#
#
#
#
# User is :spirospap
#
# Review header is :The start of your visit in Athens
#
# Review text is :This is the place from where you should start your trip to Athens. Have a great view of the city, explore the relationship between the city, the sea and the mountains and get a whole view of Athens. You can either walk from Kolonaki, through the lovely although a little bit neglected trails for pedestrians (this is what i suggest) or enjoy a more spectacular way, to get the funicular to the top. And of course by "mount Lycabettus" we mean that you should get to the top, to the small church of Saint George. Try early in the evening for a more magnificent view of the city and stay till the sun starts to set.
# url is
# https://www.tripadvisor.com/Attraction_Review-g189400-d245989-Reviews-or1240-Mount_Lycabettus-Athens_Attica.html#REVIEWS
# User is :Grpaok1
#
# Review header is :The best view of Athems
#
# Review text is :This is the highest point with a great 360 degree view of Athens. Nice climb or ride up to the top. Food and drink available as well.
#
#
#
#
#
# User is :Robin S
#
# Review header is :Cool View
#
# Review text is :Wonderful view of the Acropolis from here, as well as the entire city of Athens.  The view was amazing!
#
#
#
#
#
# User is :bednarczyk
#
# Review header is :Magnificent  view over Athens
#
# Review text is :Go there for a breathtaking view over Anthens.Best way to get there is by tube, then approx 10 min to the cable car station which will take you up on a hill.
#
#
#
#
#
# User is :Jim R
#
# Review header is :Great Hike Stunning Views
#
# Review text is :You can ride a cable car up or take a taxi if your lazy or have had a long day but I love the walk up and back down.  There are paths and a road to follow if you decide to hike.  The whole little mountain is covered with trees and lookouts with fantastic 360 views of the whole city, port and ocean.  There's a restaurant on the top as well as vendors with water and other drinks.  It's not a difficult hike but don't even try in warm weather if you're overweight or out of shape.  Take a taxi or the cable car for about 3-4 Euros for either.  The view is worth it regardless of how you get there.
#
#
#
#
#
# User is :aubriemallen
#
# Review header is :Beautiful Sunset View
#
# Review text is :We rushed up to see the sunset, it was beautiful! Some of us used the lift car and some walked.. If you aren't in a hurry they said the walk up isn't too bad.. The lift is hard to find and a good bit of a walk up lots of stairs, unless you take a taxi, so not so sure if it's worth it.. Overall, really great because of the view!
#
#
#
#
#
# User is :Ilenuca Mare
#
# Review header is :Great view of the city
#
# Review text is :there is a funicular but you can also walk up the hill, as it does not take too long. the view from the top is beautiful, but as with any tourist attraction, it is fairly crowded and people are taking pictures all around - photobombing is unavoidable.
#
#
#
#
#
# User is :NattyDragonfly
#
# Review header is :Fantastic views
#
# Review text is :Love this place. Worth going as the sun is setting up here. Beautiful as the sun is going down. Lovely little church right at the top. 360 degree views of Athens. Worth a visit. Quite a steep up hill and up steps walk before you get to the Funicular. For those who are older and maybe little less able to walk worth getting a taxi from the metro station up to the Funicular. The Funicular takes you up to the top and returns you back down for 7.50 euro. Can walk up and down - or either. No views from the Funicular as it goes up - goes up inside a tunnel inside the mountain. But to be honest the views from the top make up for the lack of any view inside the Funicular lift.
#
#
#
#
#
# User is :JessDichow
#
# Review header is :Hot walk in the afternoon!
#
# Review text is :We had an afternoon in Athens before going to Piraeus for the ferry. We decided to walk up Mount Lycabettus for its amazing views. It was about 3pm, hot, and we had our travel backpacks on. Haha talk about a hot and difficult way to do it, but it wasn't really too bad. Took us about 20 min from the neighborhood below to get to the top. Bring water and enjoy the panaoramic views from the top. Great way to take in the beauty of the Acropolis and Athens.
#
#
#
#
#
# User is :yiabi
#
# Review header is :Amazing panoramic view of Athens!
#
# Review text is :As a born and raised Athenian (i.e. I am biased) I definitely recommend visiting Lycabettus. The view of Athens is indeed breathtaking from that spot!you can take the cable car (which I think costs 7 euros) or you can walk up the hill. There is also a cafe but I think it's very expensive! If you can, plan your visit to be around the sunset because it's then when you'll enjoy the view most! Try not to visit Lycabettus between 12-3, it's unbearably hot!
#
#
#
#
#
# User is :Andreea Oana
#
# Review header is :Honeymoon
#
# Review text is :If you want to see Athens every morning down of your feet, u found the best place in world. Good place the sit after sunset

# %%
df = pd.DataFrame(data, columns=['User', 'Review Title', 'Review'])

# %%
df.shape
# Out:
# (1250, 3)

# %%
df.tail()
# Out:
#                 User                       Review Title  \
# 1245    Ilenuca Mare             Great view of the city
# 1246  NattyDragonfly                    Fantastic views
# 1247      JessDichow         Hot walk in the afternoon!
# 1248           yiabi  Amazing panoramic view of Athens!
# 1249    Andreea Oana                          Honeymoon
#
#                                                  Review
# 1245  there is a funicular but you can also walk up ...
# 1246  Love this place. Worth going as the sun is set...
# 1247  We had an afternoon in Athens before going to ...
# 1248  As a born and raised Athenian (i.e. I am biase...
# 1249  If you want to see Athens every morning down o...

# %%
filepath = Path('mount_lycabettus.csv') 
df.to_csv(filepath, index=False)
