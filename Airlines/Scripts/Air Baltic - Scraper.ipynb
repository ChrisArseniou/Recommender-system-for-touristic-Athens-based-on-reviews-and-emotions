# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import re
import time
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
from pathlib import Path

# %%
data = []

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
url = "https://www.tripadvisor.com/Airline_Review-d8728996-Reviews-Air-Baltic#REVIEWS"
print("url is \n" + url)
driver.get(url)
time.sleep(10)
soup = BeautifulSoup(driver.page_source, 'html.parser')
driver.quit()
# Out:
# <ipython-input-3-1dcc0ee10c0b>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# url is
# https://www.tripadvisor.com/Airline_Review-d8728996-Reviews-Air-Baltic#REVIEWS

# %%
containers = soup.find_all("div", {"class": "lgfjP Gi z pBVnE MD bZHZM"})

# %%
len(containers)
# Out:
# 15

# %%
user = containers[0].find_all("a", {"class": "ui_header_link uyyBf"})

# %%
user
# Out:
# [<a class="ui_header_link uyyBf" href="/Profile/airplanes2022">Airplane S</a>]

# %%
review = containers[0].find("a", {"class": "Qwuub"})

# %%
review
# Out:
# <a class="Qwuub" href="/ShowUserReviews-g1-d8728996-r867904671-Air_Baltic-World.html"><span><span>33 min flight</span></span></a>

# %%
rating = containers[0].find("div", {"class": "Hlmiy F1"})

# %%
rating.next
# Out:
# <span class="ui_bubble_rating bubble_50"></span>

# %%
for index, container in enumerate(containers):

    user = container.find("a", {"class": "ui_header_link uyyBf"})
    review = container.find("a", {"class": "Qwuub"})
    rating = container.find("div", {"class": "Hlmiy F1"})
    
    rating_value = 0;
    if (str(rating.next) == "<span class=\"ui_bubble_rating bubble_0\"></span>"):
        rating_value = 0
    elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_10\"></span>"):
        rating_value = 1
    elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_20\"></span>"):
        rating_value = 2
    elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_30\"></span>"):
        rating_value = 3
    elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_40\"></span>"):
        rating_value = 4
    else :
        rating_value = 5
    
    if(review):
        print("User is :" + user.text.strip() + "\n")
        print("Review is :" + review.text.strip() + "\n")
        print("Rating is : ",rating_value)
        data_point = [user.text.strip(),review.text.strip(), rating_value]
        data.append(data_point)
        print("\n")
        print("\n")
        
    if(index == 4):
        break #since there are 5 contaners with reviews per page
# Out:
# User is :Airplane S
#
# Review is :33 min flight
#
# Rating is :  5
#
#
#
#
# User is :Brigita P
#
# Review is :Delayed flights company
#
# Rating is :  1
#
#
#
#
# User is :F. E.
#
# Review is :„Air Baltic“ - Never again
#
# Rating is :  1
#
#
#
#
# User is :Mint T
#
# Review is :Terrible airlines
#
# Rating is :  1
#
#
#
#
# User is :Иван И
#
# Review is :They steal your money!
#
# Rating is :  1

# %%
for i in range(5,1050,5):

    driver = webdriver.Chrome(ChromeDriverManager().install())
    url = "https://www.tripadvisor.com/Airline_Review-d8728996-Reviews-or" + str(i) + "-Air-Baltic.html#REVIEWS"
    print("url is \n" + url) 
    driver.get(url)
    time.sleep(10)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    driver.quit()

    
    containers = soup.find_all("div", {"class": "lgfjP Gi z pBVnE MD bZHZM"})

    
    for index, container in enumerate(containers):
    
        user = container.find("a", {"class": "ui_header_link uyyBf"})
        review = container.find("a", {"class": "Qwuub"})
        rating = container.find("div", {"class": "Hlmiy F1"})

        rating_value = 0;
        if (str(rating.next) == "<span class=\"ui_bubble_rating bubble_0\"></span>"):
            rating_value = 0
        elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_10\"></span>"):
            rating_value = 1
        elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_20\"></span>"):
            rating_value = 2
        elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_30\"></span>"):
            rating_value = 3
        elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_40\"></span>"):
            rating_value = 4
        else :
            rating_value = 5

        if(review):
            print("User is :" + user.text.strip() + "\n")
            print("Review is :" + review.text.strip() + "\n")
            print("Rating is : ",rating_value)
            data_point = [user.text.strip(),review.text.strip(), rating_value]
            data.append(data_point)
            print("\n")
            print("\n")

        if(index == 4):
            break #since there are 5 contaners with reviews per page
# Out:
# <ipython-input-13-5b753f6598ee>:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# url is
# https://www.tripadvisor.com/Airline_Review-d8728996-Reviews-or5-Air-Baltic.html#REVIEWS
# User is :Rachel S
#
# Review is :Worst service
#
# Rating is :  1
#
#
#
#
# User is :JWH
#
# Review is :Extortion! Liars! AVOID at ALL COSTS!
#
# Rating is :  1
#
#
#
#
# User is :averyglenthorne
#
# Review is :Not to be repeated
#
# Rating is :  2
#
#
#
#
# User is :Arletro
#
# Review is :Avoid this company
#
# Rating is :  1
#
#
#
#
# User is :David B
#
# Review is :Choose something else
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728996-Reviews-or10-Air-Baltic.html#REVIEWS
# User is :Zippa
#
# Review is :Mr
#
# Rating is :  1
#
#
#
#
# User is :Yuliya C
#
# Review is :AVOID!!! AVOID! AVOID!
#
# Rating is :  1
#
#
#
#
# User is :Andrey
#
# Review is :No more AirBaltic
#
# Rating is :  1
#
#
#
#
# User is :slgnns4
#
# Review is :Back to future
#
# Rating is :  1
#
#
#
#
# User is :Piter P
#
# Review is :Scammers
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728996-Reviews-or15-Air-Baltic.html#REVIEWS
# User is :Stanislava D
#
# Review is :Terrible behavior on board the flight attendants
#
# Rating is :  1
#
#
#
#
# User is :Alexei Melnik
#
# Review is :My trip to Paris.
#
# Rating is :  3
#
#
#
#
# User is :Adamwest1
#
# Review is :No responsibility for broken luggage
#
# Rating is :  1
#
#
#
#
# User is :Bertold
#
# Review is :Do not choose AirBaltic!
#
# Rating is :  1
#
#
#
#
# User is :viktorija729
#
# Review is :Awful airline experience and the worst customer service
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728996-Reviews-or20-Air-Baltic.html#REVIEWS
# User is :ClaytonTheCat
#
# Review is :Good deals and they fly so many places
#
# Rating is :  4
#
#
#
#
# User is :Henk N
#
# Review is :Refund if you change ticket
#
# Rating is :  1
#
#
#
#
# User is :Bjarni
#
# Review is :Terrible
#
# Rating is :  1
#
#
#
#
# User is :Julija K
#
# Review is :Delayed as always
#
# Rating is :  1
#
#
#
#
# User is :Kiureli
#
# Review is :Denied hand baggage
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728996-Reviews-or25-Air-Baltic.html#REVIEWS
# User is :BK
#
# Review is :Highly Recommended
#
# Rating is :  5
#
#
#
#
# User is :Marcus
#
# Review is :Booked Air Baltic A220-300, got Carpatair F 100.
#
# Rating is :  1
#
#
#
#
# User is :Christian M
#
# Review is :Nothing on time, not using again.
#
# Rating is :  1
#
#
#
#
# User is :Kristina M
#
# Review is :Poor airlines
#
# Rating is :  1
#
#
#
#
# User is :Milena D
#
# Review is :Replaced carrier and crew compromising the quality
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728996-Reviews-or30-Air-Baltic.html#REVIEWS
# User is :MinnieTheTraveller
#
# Review is :Air Baltic charged
#
# Rating is :  1
#
#
#
#
# User is :A H
#
# Review is :Delayed luggage
#
# Rating is :  1
#
#
#
#
# User is :Mykola H
#
# Review is :Took last money from Ukrainian war refugees who lost everything, declined boarding and refused to refund
#
# Rating is :  1
#
#
#
#
# User is :enveprofessor
#
# Review is :STAY AWAY
#
# Rating is :  1
#
#
#
#
# User is :Adriano K
#
# Review is :Absolute dog feces
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728996-Reviews-or35-Air-Baltic.html#REVIEWS
# User is :_tiinagodfrey
#
# Review is :Charging for extra few Gramms on luggage!!!
#
# Rating is :  1
#
#
#
#
# User is :Stas L
#
# Review is :THE WORST European Airline, Stay Away
#
# Rating is :  1
#
#
#
#
# User is :0504Traveller
#
# Review is :Average flight around Europe
#
# Rating is :  3
#
#
#
#
# User is :Elizabete
#
# Review is :Unreliable and horrible customer service!
#
# Rating is :  1
#
#
#
#
# User is :Grete K
#
# Review is :Extremely unrealiable!!!
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728996-Reviews-or40-Air-Baltic.html#REVIEWS
# User is :MsTzo
#
# Review is :Horrible and unreliable
#
# Rating is :  1
#
#
#
#
# User is :Stan K
#
# Review is :Most unreliable airline there is!
#
# Rating is :  1
#
#
#
#
# User is :Razmik Oganesian
#
# Review is :Horrible
#
# Rating is :  1
#
#
#
#
# User is :Laila D
#
# Review is :Total horror!!!!! And look out!
#
# Rating is :  1
#
#
#
#
# User is :Verena D
#
# Review is :Really pleasant experience for a  nervous flyer
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728996-Reviews-or45-Air-Baltic.html#REVIEWS
# User is :Romualds
#
# Review is :Like a lowcoster
#
# Rating is :  1
#
#
#
#
# User is :Olga T
#
# Review is :Huge delays
#
# Rating is :  1
#
#
#
#
# User is :Travelator_7
#
# Review is :Baltic Air - last minute change of flight - unaccepable.
#
# Rating is :  1
#
#
#
#
# User is :Lukáš S
#
# Review is :😎
#
# Rating is :  5
#
#
#
#
# User is :Lii R
#
# Review is :I can't recommend the company.
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728996-Reviews-or50-Air-Baltic.html#REVIEWS
# User is :Niklavs
#
# Review is :Money scam
#
# Rating is :  1
#
#
#
#
# User is :Imasha H
#
# Review is :Don't fly Airbaltic
#
# Rating is :  1
#
#
#
#
# User is :LinasV
#
# Review is :Too expensive for such a service
#
# Rating is :  2
#
#
#
#
# User is :Ovidijus B
#
# Review is :Ovidijus
#
# Rating is :  1
#
#
#
#
# User is :Andy G
#
# Review is :Good Airline
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728996-Reviews-or55-Air-Baltic.html#REVIEWS
# User is :Ans
#
# Review is :Thank you Guys!
#
# Rating is :  5
#
#
#
#
# User is :Living L
#
# Review is :Customer Service Scam
#
# Rating is :  1
#
#
#
#
# User is :Lina K
#
# Review is :Great flight but the baggage pick up was a disaster.
#
# Rating is :  4
#
#
#
#
# User is :Sergiu L
#
# Review is :Hard-time Experience
#
# Rating is :  1
#
#
#
#
# User is :ABVGD
#
# Review is :Awful experience
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728996-Reviews-or60-Air-Baltic.html#REVIEWS
# User is :Maxim
#
# Review is :Terrible airline for flying with children
#
# Rating is :  1
#
#
#
#
# User is :Andra T
#
# Review is :One of the worst and unfriendly airlines in Europe!
#
# Rating is :  1
#
#
#
#
# User is :CharlotteR
#
# Review is :False advertising
#
# Rating is :  1
#
#
#
#
# User is :JaneMay
#
# Review is :Average Flight
#
# Rating is :  3
#
#
#
#
# User is :Karolina K
#
# Review is :Awful just AWFUL
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728996-Reviews-or65-Air-Baltic.html#REVIEWS
# User is :Aidan Boland
#
# Review is :Wonderful flight
#
# Rating is :  5
#
#
#
#
# User is :REDMAN
#
# Review is :Very good
#
# Rating is :  5
#
#
#
#
# User is :Evija J
#
# Review is :Excellent service
#
# Rating is :  5
#
#
#
#
# User is :Jarmo M
#
# Review is :Covid-19 dangerous company
#
# Rating is :  1
#
#
#
#
# User is :Eug
#
# Review is :BAD DISGUSTING CUSTOMER SERVICE !!!!
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728996-Reviews-or70-Air-Baltic.html#REVIEWS
# User is :Andrius J
#
# Review is :Bottom line
#
# Rating is :  1
#
#
#
#
# User is :Jojo W
#
# Review is :No humanity here
#
# Rating is :  1
#
#
#
#
# User is :Romain C
#
# Review is :their modificable option has a heavy price
#
# Rating is :  1
#
#
#
#
# User is :Jelena L
#
# Review is :Never agree to any Airbaltic offer
#
# Rating is :  1
#
#
#
#
# User is :Diga H
#
# Review is :Di
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728996-Reviews-or75-Air-Baltic.html#REVIEWS
# User is :Evelina J
#
# Review is :Poor customer service
#
# Rating is :  2
#
#
#
#
# User is :slonichek
#
# Review is :No ticket voucher.
#
# Rating is :  1
#
#
#
#
# User is :Alisa V
#
# Review is :Horrible experience, would never recommend
#
# Rating is :  1
#
#
#
#
# User is :Robert K
#
# Review is :Airplane was nice, but poor customer service
#
# Rating is :  2
#
#
#
#
# User is :Lynell D
#
# Review is :The worst!
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728996-Reviews-or80-Air-Baltic.html#REVIEWS
# User is :Anna K
#
# Review is :Украли ценные вещи из багажа! My expensive items were stolen from my luggage!
#
# Rating is :  1
#
#
#
#
# User is :Giorgio F
#
# Review is :Kiev service good
#
# Rating is :  5
#
#
#
#
# User is :Sandra
#
# Review is :Your health is not their priority as they claim
#
# Rating is :  2
#
#
#
#
# User is :Mike Y
#
# Review is :Terrible company, discriminates agaisnt disabled
#
# Rating is :  1
#
#
#
#
# User is :Thomas wegener F
#
# Review is :Watch out for hidden extra costs
#
# Rating is :  2
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728996-Reviews-or85-Air-Baltic.html#REVIEWS
# User is :MilenaV89
#
# Review is :Expensive and unprofessional!
#
# Rating is :  1
#
#
#
#
# User is :Karl Martin S
#
# Review is :The most climate friendly way to fly! And also good service.
#
# Rating is :  5
#
#
#
#
# User is :Oiskert
#
# Review is :Test?
#
# Rating is :  1
#
#
#
#
# User is :ddailey2017
#
# Review is :Clean, roomy, on-time
#
# Rating is :  5
#
#
#
#
# User is :Leif B
#
# Review is :From Riga to Helsinki with Air Baltic
#
# Rating is :  4
# url is
# https://www.tripadvisor.com/Airline_Review-d8728996-Reviews-or90-Air-Baltic.html#REVIEWS
# User is :Leif B
#
# Review is :With Air Baltic from Copenhagen to Riga
#
# Rating is :  4
#
#
#
#
# User is :Oksana
#
# Review is :Outrageous rude behaviour of  flight attendants
#
# Rating is :  1
#
#
#
#
# User is :Olga S
#
# Review is :NO refund for cancelled flight
#
# Rating is :  1
#
#
#
#
# User is :Helen Casou
#
# Review is :Not even water...
#
# Rating is :  2
#
#
#
#
# User is :Nils
#
# Review is :Scammed
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728996-Reviews-or95-Air-Baltic.html#REVIEWS
# User is :Toni
#
# Review is :Best customer service I've ever received!
#
# Rating is :  5
#
#
#
#
# User is :Turo50
#
# Review is :Lost my money
#
# Rating is :  1
#
#
#
#
# User is :Aleksei Sirotkin
#
# Review is :Poor service
#
# Rating is :  1
#
#
#
#
# User is :Irina D
#
# Review is :Absolutely awful airline. They have cancelled the flight 10 minutes before the check in. No refund was issued.
#
# Rating is :  1
#
#
#
#
# User is :Ernest M
#
# Review is :Worst Airline in the World
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728996-Reviews-or100-Air-Baltic.html#REVIEWS
# User is :Pavel H
#
# Review is :Horrible experience with Airbaltic across 5 booking in a row
#
# Rating is :  1
#
#
#
#
# User is :Fady Tarek
#
# Review is :Can I give zero stars?
#
# Rating is :  1
#
#
#
#
# User is :ramas
#
# Review is :No money back
#
# Rating is :  1
#
#
#
#
# User is :GeEnO74
#
# Review is :Worst airline I ever used
#
# Rating is :  1
#
#
#
#
# User is :Kristina I
#
# Review is :Go for Ryanair or any other airline especially during the covid-19
#
# Rating is :  3
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728996-Reviews-or105-Air-Baltic.html#REVIEWS
# User is :Karina J
#
# Review is :Miss
#
# Rating is :  1
#
#
#
#
# User is :Cahoma
#
# Review is :On time and without any issues
#
# Rating is :  5
#
#
#
#
# User is :Svetoslav M
#
# Review is :WORST Airline Ever
#
# Rating is :  1
#
#
#
#
# User is :Dreamer36900955148
#
# Review is :No reply, no refund for 6 months
#
# Rating is :  1
#
#
#
#
# User is :Anya K
#
# Review is :My favorite airline
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728996-Reviews-or110-Air-Baltic.html#REVIEWS
# User is :lill K
#
# Review is :Won't keep up promised refund
#
# Rating is :  1
#
#
#
#
# User is :Nauris B
#
# Review is :Pleasant flight - Air Baltic - Airbus A220-371
#
# Rating is :  5
#
#
#
#
# User is :Leah
#
# Review is :HORRIBLE and abusive
#
# Rating is :  1
#
#
#
#
# User is :Mikael F
#
# Review is :Pleasant VNO -> RIX -> HEL
#
# Rating is :  5
#
#
#
#
# User is :Mikael F
#
# Review is :Pleasant HEL -> RIX -> VNO
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728996-Reviews-or115-Air-Baltic.html#REVIEWS
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-5b753f6598ee> in <module>
#      20
#      21         rating_value = 0;
# ---> 22         if (str(rating.next) == "<span class=\"ui_bubble_rating bubble_0\"></span>"):
#      23             rating_value = 0
#      24         elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_10\"></span>"):
#
# AttributeError: 'NoneType' object has no attribute 'next'

# %%
df = pd.DataFrame(data, columns=['User', 'Review','Rating'])

# %%
df.shape
# Out:
# (115, 3)

# %%
df.tail()
# Out:
#          User                                          Review  Rating
# 110    lill K                   Won't keep up promised refund       1
# 111  Nauris B  Pleasant flight - Air Baltic - Airbus A220-371       5
# 112      Leah                            HORRIBLE and abusive       1
# 113  Mikael F                      Pleasant VNO -> RIX -> HEL       5
# 114  Mikael F                      Pleasant HEL -> RIX -> VNO       5

# %%
filepath = Path('air_baltic.csv') 
df.to_csv(filepath, index=False)
