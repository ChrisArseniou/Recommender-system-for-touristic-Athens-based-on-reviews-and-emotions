# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import re
import time
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
from pathlib import Path

# %%
data = []

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
url = "https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-Aer-Lingus#REVIEWS"
print("url is \n" + url)
driver.get(url)
time.sleep(10)
soup = BeautifulSoup(driver.page_source, 'html.parser')
driver.quit()
# Out:
# <ipython-input-3-84dca84b85c7>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-Aer-Lingus#REVIEWS

# %%
containers = soup.find_all("div", {"class": "lgfjP Gi z pBVnE MD bZHZM"})

# %%
len(containers)
# Out:
# 15

# %%
user = containers[0].find_all("a", {"class": "ui_header_link uyyBf"})

# %%
user
# Out:
# [<a class="ui_header_link uyyBf" href="/Profile/jamesaH3988JW">James A</a>]

# %%
review = containers[0].find("a", {"class": "Qwuub"})

# %%
review
# Out:
# <a class="Qwuub" href="/ShowUserReviews-g1-d8728986-r867862052-Aer_Lingus-World.html"><span><span>AVOID THIS AIRLINE AT ALL COSTS</span></span></a>

# %%
rating = containers[0].find("div", {"class": "Hlmiy F1"})

# %%
rating.next
# Out:
# <span class="ui_bubble_rating bubble_10"></span>

# %%
for index, container in enumerate(containers):

    user = container.find("a", {"class": "ui_header_link uyyBf"})
    review = container.find("a", {"class": "Qwuub"})
    rating = container.find("div", {"class": "Hlmiy F1"})
    
    rating_value = 0;
    if (str(rating.next) == "<span class=\"ui_bubble_rating bubble_0\"></span>"):
        rating_value = 0
    elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_10\"></span>"):
        rating_value = 1
    elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_20\"></span>"):
        rating_value = 2
    elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_30\"></span>"):
        rating_value = 3
    elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_40\"></span>"):
        rating_value = 4
    else :
        rating_value = 5
    
    if(review):
        print("User is :" + user.text.strip() + "\n")
        print("Review is :" + review.text.strip() + "\n")
        print("Rating is : ",rating_value)
        data_point = [user.text.strip(),review.text.strip(), rating_value]
        data.append(data_point)
        print("\n")
        print("\n")
        
    if(index == 4):
        break #since there are 5 contaners with reviews per page
# Out:
# User is :James A
#
# Review is :AVOID THIS AIRLINE AT ALL COSTS
#
# Rating is :  1
#
#
#
#
# User is :Guestsoftheworld
#
# Review is :NEVER AGAIN
#
# Rating is :  1
#
#
#
#
# User is :Erika
#
# Review is :Fly another airline if you can
#
# Rating is :  1
#
#
#
#
# User is :aeroone52
#
# Review is :Leg room
#
# Rating is :  1
#
#
#
#
# User is :Odugg
#
# Review is :Cancelled booking without any communication
#
# Rating is :  1

# %%
for i in range(5,900,5):

    driver = webdriver.Chrome(ChromeDriverManager().install())
    url = "https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or" + str(i) + "-Aer-Lingus.html#REVIEWS"
    print("url is \n" + url) 
    driver.get(url)
    time.sleep(10)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    driver.quit()

    
    containers = soup.find_all("div", {"class": "lgfjP Gi z pBVnE MD bZHZM"})

    
    for index, container in enumerate(containers):
    
        user = container.find("a", {"class": "ui_header_link uyyBf"})
        review = container.find("a", {"class": "Qwuub"})
        rating = container.find("div", {"class": "Hlmiy F1"})

        rating_value = 0;
        if (str(rating.next) == "<span class=\"ui_bubble_rating bubble_0\"></span>"):
            rating_value = 0
        elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_10\"></span>"):
            rating_value = 1
        elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_20\"></span>"):
            rating_value = 2
        elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_30\"></span>"):
            rating_value = 3
        elif (str(rating.next) == "<span class=\"ui_bubble_rating bubble_40\"></span>"):
            rating_value = 4
        else :
            rating_value = 5

        if(review):
            print("User is :" + user.text.strip() + "\n")
            print("Review is :" + review.text.strip() + "\n")
            print("Rating is : ",rating_value)
            data_point = [user.text.strip(),review.text.strip(), rating_value]
            data.append(data_point)
            print("\n")
            print("\n")

        if(index == 4):
            break #since there are 5 contaners with reviews per page
# Out:
# <ipython-input-13-e9f9c431cffc>:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or5-Aer-Lingus.html#REVIEWS
# User is :rfc
#
# Review is :Rudest Air Stewardess
#
# Rating is :  2
#
#
#
#
# User is :Disgusted
#
# Review is :Disgraceful customer service
#
# Rating is :  1
#
#
#
#
# User is :Mr67
#
# Review is :I upgraded my seat, but it was the same size as the other and had a box blocking half the foot room.
#
# Rating is :  2
#
#
#
#
# User is :Imogen Hart
#
# Review is :Aer fungus
#
# Rating is :  1
#
#
#
#
# User is :Jillian F
#
# Review is :Worst airline experience ever
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or10-Aer-Lingus.html#REVIEWS
# User is :tracey c
#
# Review is :changed flight time
#
# Rating is :  1
#
#
#
#
# User is :Shaun McGinn
#
# Review is :Constructive criticism?
#
# Rating is :  1
#
#
#
#
# User is :Francesco L
#
# Review is :WORST CLIENT SERVICE EVER
#
# Rating is :  1
#
#
#
#
# User is :Jacob L
#
# Review is :How does an airline lose dozens of bags on one flight???
#
# Rating is :  1
#
#
#
#
# User is :Neena K
#
# Review is :Poor customer service in Dublin airport
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or15-Aer-Lingus.html#REVIEWS
# User is :dos200
#
# Review is :Exceeded Expectations
#
# Rating is :  5
#
#
#
#
# User is :Lorilynn B
#
# Review is :Lost Luggage, NOBODY Helping
#
# Rating is :  1
#
#
#
#
# User is :Denise
#
# Review is :Legal actions needed due to lost luggage
#
# Rating is :  1
#
#
#
#
# User is :Mary C
#
# Review is :Terrible Experience with Aer Lingus
#
# Rating is :  1
#
#
#
#
# User is :Pedro Melo
#
# Review is :Made the passengers wait 1 and a half hour inside the plane.
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or20-Aer-Lingus.html#REVIEWS
# User is :ViPhanFr
#
# Review is :too bad I can't make a minus note ...
#
# Rating is :  1
#
#
#
#
# User is :Gupta
#
# Review is :All of the online services for this airline are the worst I've ever used
#
# Rating is :  1
#
#
#
#
# User is :Bubbles
#
# Review is :Overpriced Misleading National Airline
#
# Rating is :  1
#
#
#
#
# User is :Matty D
#
# Review is :Delayed bag - 5 days
#
# Rating is :  1
#
#
#
#
# User is :Dee W
#
# Review is :I want to give it a ZERO
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or25-Aer-Lingus.html#REVIEWS
# User is :Barbara shepherd
#
# Review is :Rescheduling my flights
#
# Rating is :  5
#
#
#
#
# User is :barry m
#
# Review is :Superb
#
# Rating is :  5
#
#
#
#
# User is :Tony M
#
# Review is :One to avoid - Very poor service!
#
# Rating is :  1
#
#
#
#
# User is :Mark L
#
# Review is :Awful aircraft configuration with all toilets located at the very rear a321lr
#
# Rating is :  1
#
#
#
#
# User is :In Again
#
# Review is :How do you spell extrtion? A-E-R  L-I-N-G-U-S
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or30-Aer-Lingus.html#REVIEWS
# User is :Pamela C
#
# Review is :Update on September 28, 2022 review
#
# Rating is :  2
#
#
#
#
# User is :Christopher M
#
# Review is :Duplicitous business practices, buyer beware!
#
# Rating is :  1
#
#
#
#
# User is :Nutty R
#
# Review is :If you can’t avoid using this airline LOWER your expectations
#
# Rating is :  1
#
#
#
#
# User is :LOuiseB28_12
#
# Review is :Will never fly Aer Lingus again!
#
# Rating is :  2
#
#
#
#
# User is :Foch F
#
# Review is :Don’t
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or35-Aer-Lingus.html#REVIEWS
# User is :dave m
#
# Review is :Terrible,never again.
#
# Rating is :  1
#
#
#
#
# User is :Floyd R
#
# Review is :Most dissapointing expeience
#
# Rating is :  1
#
#
#
#
# User is :Alyssa S
#
# Review is :Book with ANY OTHER AIRLINE
#
# Rating is :  1
#
#
#
#
# User is :yogesh T
#
# Review is :Useless to say the best.
#
# Rating is :  1
#
#
#
#
# User is :ACM42
#
# Review is :Their business class seat ripped my trousers - and still no response.
#
# Rating is :  2
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or40-Aer-Lingus.html#REVIEWS
# User is :BAMBIE30
#
# Review is :Left an awful lot to be desired
#
# Rating is :  2
#
#
#
#
# User is :Adam T
#
# Review is :Pathetic customer service
#
# Rating is :  1
#
#
#
#
# User is :Mi0211
#
# Review is :Aerclub is now a scam
#
# Rating is :  1
#
#
#
#
# User is :Chris D
#
# Review is :Yikes! What a disaster
#
# Rating is :  1
#
#
#
#
# User is :Patricia S
#
# Review is :Don’t fly Aer Lingus if you are disabled.
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or45-Aer-Lingus.html#REVIEWS
# User is :Kanchan V
#
# Review is :Baggage delay
#
# Rating is :  1
#
#
#
#
# User is :Daryl M
#
# Review is :JFK-Dublin poor service
#
# Rating is :  1
#
#
#
#
# User is :Brian H
#
# Review is :Aer Lingus
#
# Rating is :  1
#
#
#
#
# User is :DaleManchester
#
# Review is :Still no sign of our Honeymoon Baggage.
#
# Rating is :  1
#
#
#
#
# User is :Julia H
#
# Review is :Flight Delayed 7 Hours - Still No Compensation
#
# Rating is :  2
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or50-Aer-Lingus.html#REVIEWS
# User is :Ramit D
#
# Review is :Very rude behaviour
#
# Rating is :  1
#
#
#
#
# User is :Kathy S
#
# Review is :We had an awesome flight! Great airline and staff!
#
# Rating is :  5
#
#
#
#
# User is :Neo2609
#
# Review is :Supposed to be a leisure trip….
#
# Rating is :  1
#
#
#
#
# User is :worcesterwoman22
#
# Review is :Some good, some bad
#
# Rating is :  3
#
#
#
#
# User is :Jimmie K
#
# Review is :Worst
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or55-Aer-Lingus.html#REVIEWS
# User is :Dave H
#
# Review is :Avoid this airline at all costs
#
# Rating is :  1
#
#
#
#
# User is :Coolchick555
#
# Review is :Very average
#
# Rating is :  3
#
#
#
#
# User is :Mss
#
# Review is :Customer care non existence
#
# Rating is :  1
#
#
#
#
# User is :lstazko
#
# Review is :rude flight attendants
#
# Rating is :  2
#
#
#
#
# User is :donald p
#
# Review is :Not that Irish !
#
# Rating is :  3
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or60-Aer-Lingus.html#REVIEWS
# User is :Rosemary P
#
# Review is :No tea or coffee on transatlantic flight
#
# Rating is :  3
#
#
#
#
# User is :Sally S
#
# Review is :The worst customer service
#
# Rating is :  1
#
#
#
#
# User is :Debbie G
#
# Review is :Flights delayed with no communication
#
# Rating is :  3
#
#
#
#
# User is :Liisa D
#
# Review is :Never fly this airline without AirTags!
#
# Rating is :  3
#
#
#
#
# User is :Rich F
#
# Review is :Aer Lingus is Irish for "Always Late"
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or65-Aer-Lingus.html#REVIEWS
# User is :Grahamshire
#
# Review is :Lee G
#
# Rating is :  2
#
#
#
#
# User is :Ber19701929
#
# Review is :Aer Lingus Upgrade Scam
#
# Rating is :  1
#
#
#
#
# User is :Carol D
#
# Review is :Another lost baggage
#
# Rating is :  2
#
#
#
#
# User is :Jim O
#
# Review is :addendum to previous Aer Lingus, baggage missing
#
# Rating is :  1
#
#
#
#
# User is :Pamela C
#
# Review is :Flight attendant abruptly removes my meal.
#
# Rating is :  2
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or70-Aer-Lingus.html#REVIEWS
# User is :rickturnbull
#
# Review is :Avoid this airline
#
# Rating is :  1
#
#
#
#
# User is :mags e
#
# Review is :Return flight
#
# Rating is :  3
#
#
#
#
# User is :rniamtu
#
# Review is :Delayed baggage- TERRIBLE Customer service. I feel completely invisible
#
# Rating is :  2
#
#
#
#
# User is :John Sterling
#
# Review is :Worst Airline Ever
#
# Rating is :  1
#
#
#
#
# User is :Miriam A
#
# Review is :NEVER FLY THIS AIRLINE
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or75-Aer-Lingus.html#REVIEWS
# User is :egwanderlust
#
# Review is :Trust Me On This One
#
# Rating is :  4
#
#
#
#
# User is :RPence
#
# Review is :Customer Service
#
# Rating is :  1
#
#
#
#
# User is :Fabio N
#
# Review is :They have to fail!!
#
# Rating is :  1
#
#
#
#
# User is :WorcesterMoray
#
# Review is :Got us here
#
# Rating is :  3
#
#
#
#
# User is :ladybelle A
#
# Review is :An experience I would love to erase  from my memory
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or80-Aer-Lingus.html#REVIEWS
# User is :Mss
#
# Review is :Disaster Experience
#
# Rating is :  1
#
#
#
#
# User is :X5882HNpatriciam
#
# Review is :P. Mallen
#
# Rating is :  1
#
#
#
#
# User is :BRK
#
# Review is :Aer Lingus has ZERO systems to track luggage...DO NOT FLY THEM unless you have none.
#
# Rating is :  1
#
#
#
#
# User is :gratitude13
#
# Review is :NEVER FLY THIS AIRLINE!
#
# Rating is :  1
#
#
#
#
# User is :Nicolas G
#
# Review is :Worst Customer support ever
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or85-Aer-Lingus.html#REVIEWS
# User is :GlasgowRobbo
#
# Review is :Dreadful flight.
#
# Rating is :  1
#
#
#
#
# User is :Michael C
#
# Review is :I'd give it a 0 star if I could - cancelled my flight then refused a refund
#
# Rating is :  1
#
#
#
#
# User is :HMF
#
# Review is :Average flight, rude staff, good entertainment
#
# Rating is :  3
#
#
#
#
# User is :Elijah B
#
# Review is :Horrible experience
#
# Rating is :  1
#
#
#
#
# User is :Elijah B
#
# Review is :Horrible flight service
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or90-Aer-Lingus.html#REVIEWS
# User is :herondoodle16
#
# Review is :Both flights delayed and no luggage.
#
# Rating is :  1
#
#
#
#
# User is :dorlucie
#
# Review is :No communication
#
# Rating is :  1
#
#
#
#
# User is :Amaya L
#
# Review is :Awful
#
# Rating is :  1
#
#
#
#
# User is :Aidan H
#
# Review is :Staff
#
# Rating is :  5
#
#
#
#
# User is :Iwanttotravelnow_11
#
# Review is :Don’t check your baggage
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or95-Aer-Lingus.html#REVIEWS
# User is :Bernie O
#
# Review is :Late but...
#
# Rating is :  3
#
#
#
#
# User is :Jet782507
#
# Review is :Awful customer service-non existent and uncontactable
#
# Rating is :  1
#
#
#
#
# User is :Ginny S
#
# Review is :Lost bags -- horrible sham of pretending to help!
#
# Rating is :  1
#
#
#
#
# User is :Pam K
#
# Review is :Worst customer service ever
#
# Rating is :  1
#
#
#
#
# User is :Harry H
#
# Review is :Hold luggage cost pure theft
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or100-Aer-Lingus.html#REVIEWS
# User is :Tobey P
#
# Review is :Never Again!
#
# Rating is :  1
#
#
#
#
# User is :Kat F
#
# Review is :Worst customer service and aftercare ever
#
# Rating is :  1
#
#
#
#
# User is :Michelle C
#
# Review is :A shambles of an airline
#
# Rating is :  1
#
#
#
#
# User is :Andrew W
#
# Review is :What a mess!
#
# Rating is :  1
#
#
#
#
# User is :Lance K
#
# Review is :Irish Airlines are consistent.....rubbish
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or105-Aer-Lingus.html#REVIEWS
# User is :gary s
#
# Review is :Respect
#
# Rating is :  1
#
#
#
#
# User is :Brittany P
#
# Review is :Most poorly managed airline
#
# Rating is :  1
#
#
#
#
# User is :Cathy H
#
# Review is :This airline has really gone downhill
#
# Rating is :  2
#
#
#
#
# User is :Earl L
#
# Review is :Worst airline in my 50 years of travel!
#
# Rating is :  1
#
#
#
#
# User is :Anthony N
#
# Review is :Worst customer service ever!
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or110-Aer-Lingus.html#REVIEWS
# User is :Bare77
#
# Review is :Just bad
#
# Rating is :  1
#
#
#
#
# User is :LaLunaStella
#
# Review is :Unfriendly, chaotic
#
# Rating is :  1
#
#
#
#
# User is :Marco A
#
# Review is :Garbage
#
# Rating is :  1
#
#
#
#
# User is :Patrick C
#
# Review is :Warning: Pile of pop just caught fire
#
# Rating is :  1
#
#
#
#
# User is :ukdave65
#
# Review is :Worst run airline in Europe, possibly the world
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or115-Aer-Lingus.html#REVIEWS
# User is :Kevin B
#
# Review is :Most incompetent airline ever
#
# Rating is :  1
#
#
#
#
# User is :Kyra
#
# Review is :So bad Im getting sick
#
# Rating is :  1
#
#
#
#
# User is :rusty s
#
# Review is :Late on departure every time
#
# Rating is :  1
#
#
#
#
# User is :Gladiatore
#
# Review is :Aer Lingus Excellent Terminal 5 JFK a disaster
#
# Rating is :  5
#
#
#
#
# User is :Lauren B
#
# Review is :AWFUL AIRLINE- not worth saving on tickets
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or120-Aer-Lingus.html#REVIEWS
# User is :Maggie
#
# Review is :Flight Cancelled, after months of getting no response, they're offering 0 compensation
#
# Rating is :  1
#
#
#
#
# User is :Pete Murphy
#
# Review is :Very poor service
#
# Rating is :  3
#
#
#
#
# User is :A Very Relaxed & Happy Guest
#
# Review is :Not Perfect But Great Value
#
# Rating is :  4
#
#
#
#
# User is :Adventurers_64_80
#
# Review is :The WORST experience we have ever had.
#
# Rating is :  1
#
#
#
#
# User is :Mr B
#
# Review is :DO NOT USE THIS COMPANY
#
# Rating is :  2
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or125-Aer-Lingus.html#REVIEWS
# User is :Nainsi C
#
# Review is :Clicked wheelchair assistance when booking  my flight and again on check in - it did not arrive
#
# Rating is :  2
#
#
#
#
# User is :Liz C
#
# Review is :Where's my bag?
#
# Rating is :  1
#
#
#
#
# User is :Maddie P
#
# Review is :Don't fly if you value your luggage
#
# Rating is :  1
#
#
#
#
# User is :Sarah V
#
# Review is :Terrible customer service-delayed 25 hours with no response/no compensation
#
# Rating is :  1
#
#
#
#
# User is :Matthew O
#
# Review is :Worst airline ever
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or130-Aer-Lingus.html#REVIEWS
# User is :Claire Z
#
# Review is :Crew members are horribly bad ever
#
# Rating is :  1
#
#
#
#
# User is :CjM M
#
# Review is :Customer service is a joke!
#
# Rating is :  1
#
#
#
#
# User is :George G
#
# Review is :Coach conecting to airport
#
# Rating is :  4
#
#
#
#
# User is :Amy R
#
# Review is :Fly with anyone else
#
# Rating is :  1
#
#
#
#
# User is :Kierenwilletts0224
#
# Review is :Possibly the worst airline we have ever travelled on.
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or135-Aer-Lingus.html#REVIEWS
# User is :Sarah
#
# Review is :Unprofessional service, lost bags
#
# Rating is :  1
#
#
#
#
# User is :danant000
#
# Review is :Poor all round.
#
# Rating is :  1
#
#
#
#
# User is :Liam msyt
#
# Review is :Sure look it gets ya from a to b
#
# Rating is :  4
#
#
#
#
# User is :LadyIvy Opoku Adusei
#
# Review is :Amino and Sima at the Manchester Airport are Awesome.The flight was just incredible.Its roomier inside,the seats,food...
#
# Rating is :  5
#
#
#
#
# User is :Paul O
#
# Review is :Doing their job for them…
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or140-Aer-Lingus.html#REVIEWS
# User is :michaelbrio
#
# Review is :My first and last time flying this Airline
#
# Rating is :  1
#
#
#
#
# User is :Mark L
#
# Review is :Small aircraft(a321LR)all toilets at the back. Poor crew stuck in the kitche’ couldnt even come out with the service
#
# Rating is :  1
#
#
#
#
# User is :Mauricio Freitas
#
# Review is :If you think Ryanair and  EasyJet are crap?
# Try Aer Lingus! 🤦‍♂️
#
# Rating is :  1
#
#
#
#
# User is :rith_s
#
# Review is :Rudest & backwards airline.
#
# Rating is :  1
#
#
#
#
# User is :Carol G
#
# Review is :Horrible Experience
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or145-Aer-Lingus.html#REVIEWS
# User is :I am B
#
# Review is :Air Lingus: incompetent or actively discriminating ?
#
# Rating is :  1
#
#
#
#
# User is :zen3344
#
# Review is :Outstanding service and comfort
#
# Rating is :  5
#
#
#
#
# User is :chrisg2876
#
# Review is :Aer fungus
#
# Rating is :  1
#
#
#
#
# User is :Nick
#
# Review is :Worst customer service
#
# Rating is :  1
#
#
#
#
# User is :NvK
#
# Review is :Terrible customer service
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or150-Aer-Lingus.html#REVIEWS
# User is :Fynn
#
# Review is :America to Germany
#
# Rating is :  1
#
#
#
#
# User is :Michael B
#
# Review is :They will not keep confirmed seats.  Lotsa luck, Expect Delays
#
# Rating is :  2
#
#
#
#
# User is :D F
#
# Review is :Adequate experience  with 1 horrid baggage check employee
#
# Rating is :  3
#
#
#
#
# User is :Weezer22
#
# Review is :Unless you are an experienced traveller I would not recommend using Aer Lingus
#
# Rating is :  1
#
#
#
#
# User is :Geri T
#
# Review is :Disappointed
#
# Rating is :  2
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or155-Aer-Lingus.html#REVIEWS
# User is :Yosen91
#
# Review is :No Masks or Pre-Departure Testing
#
# Rating is :  1
#
#
#
#
# User is :JOHN S
#
# Review is :TERRIBLE N AWFUL N DO NOT USE THEM
#
# Rating is :  1
#
#
#
#
# User is :Eva C
#
# Review is :AGP-DUB
#
# Rating is :  5
#
#
#
#
# User is :PeterM
#
# Review is :Murphy’s Law Airline.
#
# Rating is :  1
#
#
#
#
# User is :Road92320
#
# Review is :Aer Lingus cancelled my flight
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or160-Aer-Lingus.html#REVIEWS
# User is :Mus
#
# Review is :Awful airline, worst humans I’ve met
#
# Rating is :  1
#
#
#
#
# User is :Cam M
#
# Review is :Appalling
#
# Rating is :  1
#
#
#
#
# User is :Alan J
#
# Review is :Shocking!
#
# Rating is :  1
#
#
#
#
# User is :Coast2CoastTravelBug
#
# Review is :Horrible Customer Service
#
# Rating is :  1
#
#
#
#
# User is :Matthew C
#
# Review is :Feels like a company on the cusp of bankruptcy
#
# Rating is :  1
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or165-Aer-Lingus.html#REVIEWS
# User is :Maureen Burns
#
# Review is :Avoid Avoid Avoid
#
# Rating is :  1
#
#
#
#
# User is :whatatripwehad
#
# Review is :avoid if at all possible
#
# Rating is :  1
#
#
#
#
# User is :Ash De
#
# Review is :Racist airline and CEO
#
# Rating is :  1
#
#
#
#
# User is :Izabelle C
#
# Review is :Horrific customer service
#
# Rating is :  1
#
#
#
#
# User is :Amy Steinfeld
#
# Review is :Avoid this airline at all costs!!!
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or170-Aer-Lingus.html#REVIEWS
# User is :Heather Freitag
#
# Review is :Decent enough especially after a recent flight
#
# Rating is :  4
#
#
#
#
# User is :Brigsy72
#
# Review is :Received confirmation for flight with partner airline that did not exist!!!
#
# Rating is :  1
#
#
#
#
# User is :jeff k
#
# Review is :Client Service
#
# Rating is :  5
#
#
#
#
# User is :ned1Ireland
#
# Review is :Most awful travel experience and follow up customer service
#
# Rating is :  1
#
#
#
#
# User is :Alexis3245
#
# Review is :Incompetent in Every Operation
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or175-Aer-Lingus.html#REVIEWS
# User is :Mojdeh B
#
# Review is :Aer Lingus is cheating.
#
# Rating is :  1
#
#
#
#
# User is :cecile757grace
#
# Review is :Fantastic service
#
# Rating is :  5
#
#
#
#
# User is :Klaus S
#
# Review is :Worst experience ever
#
# Rating is :  1
#
#
#
#
# User is :rossj818
#
# Review is :Incredible service
#
# Rating is :  5
#
#
#
#
# User is :ashleydavies2019
#
# Review is :Business Class Flight
#
# Rating is :  4
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or180-Aer-Lingus.html#REVIEWS
# User is :Jenny F
#
# Review is :Rude and unhelpful ground staff
#
# Rating is :  1
#
#
#
#
# User is :John K
#
# Review is :Kicked off flight but no refund !! Terrible customer service
#
# Rating is :  1
#
#
#
#
# User is :Barbara G.
#
# Review is :It started out great, but...
#
# Rating is :  3
#
#
#
#
# User is :lovechampagnebubbles
#
# Review is :just ok!!
#
# Rating is :  3
#
#
#
#
# User is :Marlene
#
# Review is :Left stranded without my luggage
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or185-Aer-Lingus.html#REVIEWS
# User is :syed farrukh h
#
# Review is :If you can’t manage don’t have too many flights
#
# Rating is :  2
#
#
#
#
# User is :Gus P
#
# Review is :If flying from Paris, use air france
#
# Rating is :  2
#
#
#
#
# User is :Wahaay🇬🇧
#
# Review is :Poor service without a smile
#
# Rating is :  3
#
#
#
#
# User is :Daniel W
#
# Review is :Awful flight
#
# Rating is :  1
#
#
#
#
# User is :World Traveler
#
# Review is :Senora
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or190-Aer-Lingus.html#REVIEWS
# User is :Patrick C
#
# Review is :Everyone was told to leave the Business Class Lounge, it was 4pm and apparently that's when they close at Dublin!
#
# Rating is :  3
#
#
#
#
# User is :Alanmurray.nov@gmail.com
#
# Review is :Aer lingus
#
# Rating is :  1
#
#
#
#
# User is :Laoisesta
#
# Review is :Cancel flights. Don't tell customers
#
# Rating is :  1
#
#
#
#
# User is :Jake C
#
# Review is :NEVER FLY ON THIS AIRLINE.
#
# Rating is :  1
#
#
#
#
# User is :LauraA
#
# Review is :Aer Lingus - Baggage Handling - Lost Baggage - No Response
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or195-Aer-Lingus.html#REVIEWS
# User is :Martin B
#
# Review is :If they lose your bag good luck contacting them!!
#
# Rating is :  1
#
#
#
#
# User is :tctcccf6c6
#
# Review is :Lost baggage
#
# Rating is :  2
#
#
#
#
# User is :Karin B
#
# Review is :Baggage still lost
#
# Rating is :  1
#
#
#
#
# User is :Andy C
#
# Review is :Flight experience was good - however customer service terrible
#
# Rating is :  2
#
#
#
#
# User is :William H
#
# Review is :Worst flight of my life
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or200-Aer-Lingus.html#REVIEWS
# User is :tribune1
#
# Review is :Medical emergency!
#
# Rating is :  1
#
#
#
#
# User is :Daire
#
# Review is :Every step was a problem, avoid
#
# Rating is :  1
#
#
#
#
# User is :Daniel K
#
# Review is :DO NOT FLY WITH THEM!!!!
#
# Rating is :  1
#
#
#
#
# User is :Rich C
#
# Review is :Terrible Customer Service
#
# Rating is :  1
#
#
#
#
# User is :Rich S
#
# Review is :DO NOT USE THIS AIRLINE!
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or205-Aer-Lingus.html#REVIEWS
# User is :Mike
#
# Review is :Should've Gone by Sea
#
# Rating is :  1
#
#
#
#
# User is :Fidel M
#
# Review is :Worst Airline in the world
#
# Rating is :  1
#
#
#
#
# User is :Austin B
#
# Review is :Changed flight time
#
# Rating is :  1
#
#
#
#
# User is :Charles M
#
# Review is :Terrible Airline compny
#
# Rating is :  1
#
#
#
#
# User is :Geoff cross
#
# Review is :Delayed again
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or210-Aer-Lingus.html#REVIEWS
# User is :brad p1gle
#
# Review is :Used to be good before covid.
#
# Rating is :  3
#
#
#
#
# User is :Sarah B
#
# Review is :Never use this company
#
# Rating is :  1
#
#
#
#
# User is :Deirdre
#
# Review is :Missing luggage 40 days and counting, worst customer experience to date
#
# Rating is :  1
#
#
#
#
# User is :Ally S
#
# Review is :WORST AIRLINE
#
# Rating is :  1
#
#
#
#
# User is :David E
#
# Review is :Avoid - Disgusting Experience
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or215-Aer-Lingus.html#REVIEWS
# User is :Daniel B
#
# Review is :Never will I fly this airline again if I can possibly avoid it
#
# Rating is :  2
#
#
#
#
# User is :Janer P
#
# Review is :Might as well have booked Ryanair
#
# Rating is :  1
#
#
#
#
# User is :Dougal70
#
# Review is :Total Lack of Customer Service Presence in London Airports
#
# Rating is :  1
#
#
#
#
# User is :littlelululamb
#
# Review is :Long delay, sat on tarmac, waited for luggage
#
# Rating is :  1
#
#
#
#
# User is :Declanloy
#
# Review is :What can i say - Aer Lingus diaster airline
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or220-Aer-Lingus.html#REVIEWS
# User is :Lewis Wildridge
#
# Review is :Absolute Shambles
#
# Rating is :  1
#
#
#
#
# User is :George P
#
# Review is :Amazing crew
#
# Rating is :  5
#
#
#
#
# User is :Jordi A
#
# Review is :Flight cancelled and no refund
#
# Rating is :  1
#
#
#
#
# User is :LAH
#
# Review is :Waste of time and inefficiency in boarding
#
# Rating is :  2
#
#
#
#
# User is :Njoilyfe
#
# Review is :Lost baggage....still waiting
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or225-Aer-Lingus.html#REVIEWS
# User is :Fire T
#
# Review is :Do not expect your checked in bags they ruined our holiday due to stress and anxiety it caused
#
# Rating is :  1
#
#
#
#
# User is :Jacob C
#
# Review is :Pure evil airline
#
# Rating is :  1
#
#
#
#
# User is :Mrs. Thompson
#
# Review is :Mrs. Thompson
#
# Rating is :  1
#
#
#
#
# User is :Kevin F
#
# Review is :Delay baggage
#
# Rating is :  1
#
#
#
#
# User is :Geoff cross
#
# Review is :Worst airline ever
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or230-Aer-Lingus.html#REVIEWS
# User is :Geoff cross
#
# Review is :I fly home every weekend to Dublin and don’t normally mind paying extra rather than flying Ryan air but no more
#
# Rating is :  1
#
#
#
#
# User is :geezwillthiswork1
#
# Review is :PILOTS ARE UNLOADING AND LOADING LUGGAGE
#
# Rating is :  2
#
#
#
#
# User is :Aaron M
#
# Review is :Don’t Expect to Get Your Bags
#
# Rating is :  1
#
#
#
#
# User is :Ryan m
#
# Review is :Badly trained staff, dirty plane and always late!
#
# Rating is :  2
#
#
#
#
# User is :Jason H
#
# Review is :Worst service when something goes wrong
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or235-Aer-Lingus.html#REVIEWS
# User is :Shauna C
#
# Review is :Absolute worst!
#
# Rating is :  1
#
#
#
#
# User is :Danush M
#
# Review is :HORRIBLE AIRLINE NEVER FLY WITH THEM
#
# Rating is :  1
#
#
#
#
# User is :Derek O
#
# Review is :Excellent trip
#
# Rating is :  5
#
#
#
#
# User is :Pam J
#
# Review is :Horrible!!!
#
# Rating is :  1
#
#
#
#
# User is :Adrian L
#
# Review is :Worst airline ever
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or240-Aer-Lingus.html#REVIEWS
# User is :Genetix71
#
# Review is :return flight was less impressive
#
# Rating is :  2
#
#
#
#
# User is :Genetix71
#
# Review is :I believe economy flights are what they are
#
# Rating is :  3
#
#
#
#
# User is :Mike W
#
# Review is :Very negative experience coming back to the US from Ireland
#
# Rating is :  1
#
#
#
#
# User is :Greg S
#
# Review is :Aer Lingus is a substandard air carrier
#
# Rating is :  1
#
#
#
#
# User is :chrisU23OOWS
#
# Review is :Mobile App not fit for purpose
#
# Rating is :  2
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or245-Aer-Lingus.html#REVIEWS
# User is :Courtney S
#
# Review is :Baggage Handling, Mobile App, Website and Telephone Support are very bad - Geneva to Seattle
#
# Rating is :  2
#
#
#
#
# User is :tania g
#
# Review is :Great staff
#
# Rating is :  5
#
#
#
#
# User is :Pallavi M
#
# Review is :Most pathetic airlines
#
# Rating is :  1
#
#
#
#
# User is :Gregory B
#
# Review is :Average Airline with zero ground support
#
# Rating is :  2
#
#
#
#
# User is :ann w
#
# Review is :Great staff, old out of date entertainment
#
# Rating is :  4
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or250-Aer-Lingus.html#REVIEWS
# User is :Billy B
#
# Review is :Fun Flight Attendants and mostly on time!
#
# Rating is :  5
#
#
#
#
# User is :bigflirty
#
# Review is :HORRIBLE SERVICE
#
# Rating is :  1
#
#
#
#
# User is :Laura F
#
# Review is :Lost Stroller
#
# Rating is :  1
#
#
#
#
# User is :Libuse K
#
# Review is :Such amazing flight crew!
#
# Rating is :  5
#
#
#
#
# User is :LAH
#
# Review is :Good service, disrespectful conduct towards waiting passengers and
#
# Rating is :  3
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or255-Aer-Lingus.html#REVIEWS
# User is :John P
#
# Review is :Racist and incompetent
#
# Rating is :  1
#
#
#
#
# User is :Tony M
#
# Review is :Loss of baggege and uncontactble
#
# Rating is :  1
#
#
#
#
# User is :wanttoretireinPA
#
# Review is :Lost Luggage
#
# Rating is :  1
#
#
#
#
# User is :ray646
#
# Review is :flight cancellation
#
# Rating is :  1
#
#
#
#
# User is :Lion W
#
# Review is :DO NOT FLY WITH THIS AIRLINE
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or260-Aer-Lingus.html#REVIEWS
# User is :Maryann L
#
# Review is :Flight good don’t expect your baggage or get anyone to speak with about ever locating it. 54 hours after landing nothing
#
# Rating is :  2
#
#
#
#
# User is :Michael T
#
# Review is :I hate that I must write a negative review because there are many things I liked about the flight. However, they flew ou
#
# Rating is :  1
#
#
#
#
# User is :Steve Chick
#
# Review is :Rearranged Flight
#
# Rating is :  1
#
#
#
#
# User is :Antonia Fore
#
# Review is :Do not check in luggage! Chances are high you will never see it again!
#
# Rating is :  1
#
#
#
#
# User is :Christina T
#
# Review is :Worst transplanting trip ever!!
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or265-Aer-Lingus.html#REVIEWS
# User is :Rachael L
#
# Review is :Would not let my parents and grandma on their flight
#
# Rating is :  1
#
#
#
#
# User is :SSS444
#
# Review is :Wonderful Trip So Far
#
# Rating is :  4
#
#
#
#
# User is :Linda A
#
# Review is :We Had a Good Experience
#
# Rating is :  4
#
#
#
#
# User is :Janice H
#
# Review is :Missing bag , no customer service (shocker)
#
# Rating is :  2
#
#
#
#
# User is :Ben D
#
# Review is :Do not fly this airline until they can hire more staff
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or270-Aer-Lingus.html#REVIEWS
# User is :DJL
#
# Review is :Lost Baggage
#
# Rating is :  1
#
#
#
#
# User is :jennypenny28
#
# Review is :Terrible customer service and check-in process
#
# Rating is :  1
#
#
#
#
# User is :Culturebee
#
# Review is :missing bags after 10 days
#
# Rating is :  3
#
#
#
#
# User is :Matthew N
#
# Review is :Zero customer service and worst business experience ever!
#
# Rating is :  1
#
#
#
#
# User is :Dee G
#
# Review is :First time on AerLingus
#
# Rating is :  4
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or275-Aer-Lingus.html#REVIEWS
# User is :arcticnorth
#
# Review is :High Quality
#
# Rating is :  5
#
#
#
#
# User is :Linda G
#
# Review is :Most uncomfortable flight ever!
#
# Rating is :  1
#
#
#
#
# User is :Coastal821247
#
# Review is :I really hate this airline and their staff and customer service.
#
# Rating is :  1
#
#
#
#
# User is :Mike R
#
# Review is :Atrocious customer service, ignorant cabin crew, poor communication
#
# Rating is :  1
#
#
#
#
# User is :keno33
#
# Review is :Trying to book seats
#
# Rating is :  2
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or280-Aer-Lingus.html#REVIEWS
# User is :David H
#
# Review is :No luggage
#
# Rating is :  1
#
#
#
#
# User is :Lisa
#
# Review is :Avoid Aer Lingus If You Can!
#
# Rating is :  1
#
#
#
#
# User is :Steve drone
#
# Review is :The worst airline company in the world! The customer service was atrocious and they don’t even deserve a 1 rating!
#
# Rating is :  1
#
#
#
#
# User is :rollotomasi
#
# Review is :What's with the smaller plane on a 7 hour transatlantic flight???
#
# Rating is :  2
#
#
#
#
# User is :endikaexle
#
# Review is :Worst company EVER
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or285-Aer-Lingus.html#REVIEWS
# User is :Lyndsey K
#
# Review is :More comfort in budget airlines
#
# Rating is :  2
#
#
#
#
# User is :G. C. C
#
# Review is :Upgrade if you are tall!
#
# Rating is :  3
#
#
#
#
# User is :SRL
#
# Review is :Operational Disaster in LHR Ruins Golf Trip
#
# Rating is :  1
#
#
#
#
# User is :Paul R
#
# Review is :No upgrades offered on booking flight. Business class was almost empty on boarding.
#
# Rating is :  2
#
#
#
#
# User is :Rich510
#
# Review is :THE WORST customer service
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or290-Aer-Lingus.html#REVIEWS
# User is :D B
#
# Review is :DO NOT FLY THIS AIRLINE
#
# Rating is :  1
#
#
#
#
# User is :Bonnie D
#
# Review is :Flight canceled no options offered
#
# Rating is :  1
#
#
#
#
# User is :heysash
#
# Review is :Don’t Even Know Where To Begin
#
# Rating is :  1
#
#
#
#
# User is :Kevin S
#
# Review is :As if run buy a kid in his basement
#
# Rating is :  1
#
#
#
#
# User is :Steve J
#
# Review is :Waiting so far 1 hour and 18 mins to add a piece of luggage
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or295-Aer-Lingus.html#REVIEWS
# User is :Ansteytraveller1
#
# Review is :Third Flight with Emerald - Third 1hr plus delay
#
# Rating is :  1
#
#
#
#
# User is :rambler07
#
# Review is :Don’t fly Aer Lingus
#
# Rating is :  1
#
#
#
#
# User is :Dan Kidd
#
# Review is :A total shambles of an airline.
#
# Rating is :  1
#
#
#
#
# User is :Andrew J
#
# Review is :Customer Service Black Hole
#
# Rating is :  1
#
#
#
#
# User is :Christopher k
#
# Review is :Terrible customer service and very misleading information
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or300-Aer-Lingus.html#REVIEWS
# User is :bobo
#
# Review is :never will i ever use this airline
#
# Rating is :  2
#
#
#
#
# User is :Tasha Marie
#
# Review is :Okay
#
# Rating is :  4
#
#
#
#
# User is :Jhovany L
#
# Review is :Delay Nightmare
#
# Rating is :  1
#
#
#
#
# User is :Sara L
#
# Review is :Dublin airport staff
#
# Rating is :  1
#
#
#
#
# User is :John N
#
# Review is :DON'T EVER FLY WITH AER LINGUS
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or305-Aer-Lingus.html#REVIEWS
# User is :Romeny A
#
# Review is :Never ever ever FLY with Aer Lingus!!
#
# Rating is :  1
#
#
#
#
# User is :Harry M
#
# Review is :Horrendous customer service - AVOID
#
# Rating is :  1
#
#
#
#
# User is :Greg
#
# Review is :Terrible Service and Poor Planning
#
# Rating is :  1
#
#
#
#
# User is :Scenic320209
#
# Review is :Lost luggage
#
# Rating is :  1
#
#
#
#
# User is :pauline c
#
# Review is :Vacation home
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or310-Aer-Lingus.html#REVIEWS
# User is :Ezra L
#
# Review is :Flight Cancelled and no word refund for expenses
#
# Rating is :  1
#
#
#
#
# User is :s s
#
# Review is :Lost my luggage
#
# Rating is :  1
#
#
#
#
# User is :Michael F
#
# Review is :Very poor , choose elsewhere
#
# Rating is :  2
#
#
#
#
# User is :StephenCross
#
# Review is :Overall reasonably good
#
# Rating is :  4
#
#
#
#
# User is :Mandies41
#
# Review is :Does this airline ever leave on time
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or315-Aer-Lingus.html#REVIEWS
# User is :srtraveler41
#
# Review is :User unfriendly
#
# Rating is :  1
#
#
#
#
# User is :Deacon m
#
# Review is :Service
#
# Rating is :  2
#
#
#
#
# User is :Martin D
#
# Review is :Awful All Round
#
# Rating is :  1
#
#
#
#
# User is :galanewcastle
#
# Review is :AERLINGUS none compliant with sca approved by visa
#
# Rating is :  1
#
#
#
#
# User is :Anjy
#
# Review is :No bags and no communication. Worst Flight ever.
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or320-Aer-Lingus.html#REVIEWS
# User is :Tony M
#
# Review is :Never ever fly Aer Lingus
#
# Rating is :  1
#
#
#
#
# User is :Michael C
#
# Review is :Horrid Customer Service .. Lost Bags and Wedding to Go to!
#
# Rating is :  1
#
#
#
#
# User is :labliz
#
# Review is :First and Last time with Aer Lingus
#
# Rating is :  1
#
#
#
#
# User is :MLG
#
# Review is :none
#
# Rating is :  1
#
#
#
#
# User is :Chloe M
#
# Review is :Don’t fly with them!
#
# Rating is :  1
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or325-Aer-Lingus.html#REVIEWS
# User is :GXC
#
# Review is :Aer Lingus Refused Refund
#
# Rating is :  1
#
#
#
#
# User is :Melanie
#
# Review is :Money non refunded
#
# Rating is :  1
#
#
#
#
# User is :William L
#
# Review is :Woeful checkin procedure for premium clients
#
# Rating is :  2
#
#
#
#
# User is :Kimberly
#
# Review is :Awful airline lost luggage
#
# Rating is :  1
#
#
#
#
# User is :Kathleen
#
# Review is :Absolutely terrible.
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or330-Aer-Lingus.html#REVIEWS
# User is :Mathias F
#
# Review is :Absolute disaster
#
# Rating is :  1
#
#
#
#
# User is :DusanRosner
#
# Review is :flight PRG-JFK-VIE
#
# Rating is :  4
#
#
#
#
# User is :Stuart T
#
# Review is :Very poor service
#
# Rating is :  1
#
#
#
#
# User is :Hein D
#
# Review is :Bad service
#
# Rating is :  1
#
#
#
#
# User is :sf w
#
# Review is :Not Great
#
# Rating is :  2
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or335-Aer-Lingus.html#REVIEWS
# User is :Nug97
#
# Review is :Average experience, was much better back in 2013
#
# Rating is :  3
#
#
#
#
# User is :Scenic320209
#
# Review is :Lost luggage
#
# Rating is :  1
#
#
#
#
# User is :susanem2013
#
# Review is :Useless airline
#
# Rating is :  1
#
#
#
#
# User is :Wendy F
#
# Review is :Delayed Baggage
#
# Rating is :  1
#
#
#
#
# User is :Carol R
#
# Review is :Misplaced baggage
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or340-Aer-Lingus.html#REVIEWS
# User is :Bri F
#
# Review is :Terrible Treatment of Mother and Baby
#
# Rating is :  1
#
#
#
#
# User is :Cynthia i
#
# Review is :Helpless gate agent leaves delayed passengers in dark
#
# Rating is :  1
#
#
#
#
# User is :Miranda S
#
# Review is :Don’t book if you value your time
#
# Rating is :  2
#
#
#
#
# User is :Connor C
#
# Review is :Shockingly bad service
#
# Rating is :  1
#
#
#
#
# User is :Sadie L
#
# Review is :Don’t use this company!
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or345-Aer-Lingus.html#REVIEWS
# User is :conor o
#
# Review is :Terrible
#
# Rating is :  1
#
#
#
#
# User is :KurtHoward
#
# Review is :This Airline is a Dumpster Fire
#
# Rating is :  1
#
#
#
#
# User is :george h
#
# Review is :Late Late cancellation and NO communication
#
# Rating is :  1
#
#
#
#
# User is :Joe M
#
# Review is :In a rush, Aer Lingus left my bag in Malaga and also managed to lose the tag.
#
# Rating is :  1
#
#
#
#
# User is :CJ401
#
# Review is :no refund, after three months, despite being within guaranteed cancel time
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or350-Aer-Lingus.html#REVIEWS
# User is :VittelWater
#
# Review is :Miss
#
# Rating is :  1
#
#
#
#
# User is :GoPlaces755797
#
# Review is :Lost my luggage and wont reply
#
# Rating is :  1
#
#
#
#
# User is :Paul2101
#
# Review is :Incompetent Staff on so called Help
#
# Rating is :  1
#
#
#
#
# User is :Emily Jane
#
# Review is :We’ll done to Aer lingus and Shannon Airport in general on a job very well done.
#
# Rating is :  5
#
#
#
#
# User is :Debanne163
#
# Review is :Total lack of communication
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or355-Aer-Lingus.html#REVIEWS
# User is :Helen W
#
# Review is :Mrs Helen wharton
#
# Rating is :  5
#
#
#
#
# User is :Scenic320209
#
# Review is :Lost luggage
#
# Rating is :  1
#
#
#
#
# User is :#2 Man
#
# Review is :Worst Airline
#
# Rating is :  1
#
#
#
#
# User is :Extraordinary301440
#
# Review is :Basic service ok but don’t try to contact or make any change.
#
# Rating is :  2
#
#
#
#
# User is :Tawanda C
#
# Review is :Worst airline ever!!!!! Stay away from this!!!
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or360-Aer-Lingus.html#REVIEWS
# User is :johnmM754OI
#
# Review is :Flights were fine; airport experience marginal
#
# Rating is :  4
#
#
#
#
# User is :MItch M
#
# Review is :small seats, bad terminal in Dublin
#
# Rating is :  2
#
#
#
#
# User is :S T
#
# Review is :Lost Items from my Luggage
#
# Rating is :  1
#
#
#
#
# User is :Scenic320209
#
# Review is :Lost luggage
#
# Rating is :  1
#
#
#
#
# User is :Veronica g
#
# Review is :Not impressed
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or365-Aer-Lingus.html#REVIEWS
# User is :Saeed F
#
# Review is :Saeed
#
# Rating is :  1
#
#
#
#
# User is :Caitlin R
#
# Review is :Customer Service
#
# Rating is :  1
#
#
#
#
# User is :rufuscrewe
#
# Review is :Great experience
#
# Rating is :  5
#
#
#
#
# User is :Aniruddha C
#
# Review is :If you have a connecting flight quite immediately (say within a couple of hrs or 3 hrs) after your 1st plane, beware!
#
# Rating is :  1
#
#
#
#
# User is :Janine
#
# Review is :Worst Airline Experience
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or370-Aer-Lingus.html#REVIEWS
# User is :simon4059
#
# Review is :Fantastic Airline.  Was very impressed so I booked again
#
# Rating is :  5
#
#
#
#
# User is :Spenhull
#
# Review is :Poor is an understatement
#
# Rating is :  1
#
#
#
#
# User is :courtney d
#
# Review is :Mrs
#
# Rating is :  1
#
#
#
#
# User is :J L K
#
# Review is :Baggage - No Customer service
#
# Rating is :  1
#
#
#
#
# User is :Julia C
#
# Review is :Expect Delays
#
# Rating is :  2
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or375-Aer-Lingus.html#REVIEWS
# User is :Fionnuala K
#
# Review is :Flight cancelled with only a couple of hours notice
#
# Rating is :  1
#
#
#
#
# User is :Mario K
#
# Review is :Worst Customer Service
#
# Rating is :  1
#
#
#
#
# User is :Docwake
#
# Review is :Customer service - what customer service
#
# Rating is :  1
#
#
#
#
# User is :Kevin Hewitt
#
# Review is :Pretend this airline doesn't exist
#
# Rating is :  1
#
#
#
#
# User is :Traveler
#
# Review is :Save yourself the headache
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or380-Aer-Lingus.html#REVIEWS
# User is :Kenneth K
#
# Review is :Lost bag and no one is  willing to help
#
# Rating is :  1
#
#
#
#
# User is :Radek D
#
# Review is :Never more
#
# Rating is :  2
#
#
#
#
# User is :seamus f
#
# Review is :#aerlingus
#
# Rating is :  5
#
#
#
#
# User is :PIT
#
# Review is :Call Wait Times Outrageously Unacceptable
#
# Rating is :  1
#
#
#
#
# User is :PIT
#
# Review is :Call Wait Time Unacceptable
#
# Rating is :  2
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or385-Aer-Lingus.html#REVIEWS
# User is :Andrew W
#
# Review is :Are Lingus is ridiculous!
#
# Rating is :  1
#
#
#
#
# User is :Tony J
#
# Review is :Cancelled Flight
#
# Rating is :  1
#
#
#
#
# User is :Conrad Berriff
#
# Review is :LOST LUGGAGE & TERRIBLE CUSTOMER SERVICE
#
# Rating is :  1
#
#
#
#
# User is :Taraj45
#
# Review is :Lost luggage & rude staff
#
# Rating is :  1
#
#
#
#
# User is :Pete Murphy
#
# Review is :Lost luggage and poor customer service
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or390-Aer-Lingus.html#REVIEWS
# User is :Guy P
#
# Review is :Mr
#
# Rating is :  2
#
#
#
#
# User is :Lukasz
#
# Review is :I do not recommend
#
# Rating is :  1
#
#
#
#
# User is :Katranyc217
#
# Review is :Very disappointed ...paid a lot of money for nothing (poor service/food and communication)
#
# Rating is :  3
#
#
#
#
# User is :Mir S
#
# Review is :Customer friendly Airline
#
# Rating is :  5
#
#
#
#
# User is :Shiva A
#
# Review is :Horrible Airline with terrible customer service
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or395-Aer-Lingus.html#REVIEWS
# User is :Pete Murphy
#
# Review is :Lost luggage and poor customer service
#
# Rating is :  2
#
#
#
#
# User is :Paul F
#
# Review is :Incompetent travel company
#
# Rating is :  1
#
#
#
#
# User is :Mark W
#
# Review is :Terrible experience
#
# Rating is :  1
#
#
#
#
# User is :Rachpk
#
# Review is :Face masks were mandatory...
#
# Rating is :  2
#
#
#
#
# User is :peridotite
#
# Review is :Be careful if your booking includes multiple airlines…online check in is not an option
#
# Rating is :  3
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or400-Aer-Lingus.html#REVIEWS
# User is :Grace
#
# Review is :Avoid Aer Lingus even if it’s significantly cheaper!!!!!
#
# Rating is :  1
#
#
#
#
# User is :jade_dubai100
#
# Review is :No hand luggage allowance
#
# Rating is :  1
#
#
#
#
# User is :Theo P
#
# Review is :Terrible rip off airline
#
# Rating is :  1
#
#
#
#
# User is :thequinns2017
#
# Review is :Customer Service Agents who do NOT speak or communicate in English
#
# Rating is :  1
#
#
#
#
# User is :Josip S
#
# Review is :Worst customer service and company policy
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or405-Aer-Lingus.html#REVIEWS
# User is :Ciro Vivacqua
#
# Review is :Run away from it if you have pets
#
# Rating is :  1
#
#
#
#
# User is :MKEAmyS
#
# Review is :Nothing good about Aer Lingus
#
# Rating is :  1
#
#
#
#
# User is :Jalayne M
#
# Review is :Don't book if you will need any customer service help
#
# Rating is :  1
#
#
#
#
# User is :Molly B
#
# Review is :The most terrible customer service EVER
#
# Rating is :  1
#
#
#
#
# User is :Companion775447
#
# Review is :Lied about cancellation policy
# Please read
# Worst customer 🐕‍🦺
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or410-Aer-Lingus.html#REVIEWS
# User is :james b
#
# Review is :Staff don't care
#
# Rating is :  1
#
#
#
#
# User is :Gemma J
#
# Review is :DO NOT USE THIS AIRLINE
#
# Rating is :  1
#
#
#
#
# User is :Kathleen W
#
# Review is :Never again
#
# Rating is :  1
#
#
#
#
# User is :james b
#
# Review is :Terrible customer service, staff sleeps on the flight, oversell upgrade seats and keep the money, they now sell sodas
#
# Rating is :  1
#
#
#
#
# User is :Traveller346
#
# Review is :Worst customer service
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or415-Aer-Lingus.html#REVIEWS
# User is :Netty
#
# Review is :Staff questionable
#
# Rating is :  3
#
#
#
#
# User is :Gillianb2004
#
# Review is :Hmmm ok
#
# Rating is :  3
#
#
#
#
# User is :Patrick M
#
# Review is :Just lovely
#
# Rating is :  5
#
#
#
#
# User is :Rob F
#
# Review is :AVOID AT ALL COSTS!  Took flight from Chicago to Dublin to Naples and back on same path.  Lost luggage both times!
#
# Rating is :  1
#
#
#
#
# User is :gary P
#
# Review is :Will never use fly Aer Lingus business class lounge!
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or420-Aer-Lingus.html#REVIEWS
# User is :Barry M
#
# Review is :Birthday treat!
#
# Rating is :  5
#
#
#
#
# User is :bunkaluka
#
# Review is :Criminal customer service.
#
# Rating is :  1
#
#
#
#
# User is :Lisa
#
# Review is :Avoid at all costs. Discriminatory against disabled
#
# Rating is :  1
#
#
#
#
# User is :Fair and square
#
# Review is :Pretty awful both ways. Poor business model.
#
# Rating is :  2
#
#
#
#
# User is :Andy B
#
# Review is :Business Class Excellent Flight and Service
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or425-Aer-Lingus.html#REVIEWS
# User is :Andy P
#
# Review is :Sub standard transatlantic flight
#
# Rating is :  1
#
#
#
#
# User is :Fonda S
#
# Review is :Confusing, misleading, avoid at all costs
#
# Rating is :  1
#
#
#
#
# User is :Amy W
#
# Review is :Don’t help with food allergies
#
# Rating is :  2
#
#
#
#
# User is :David B
#
# Review is :Scam Alert
#
# Rating is :  1
#
#
#
#
# User is :David B
#
# Review is :No service in First Class
#
# Rating is :  2
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or430-Aer-Lingus.html#REVIEWS
# User is :MikeGPortland
#
# Review is :Absolutely unreachable in any way - how is this possible?
#
# Rating is :  1
#
#
#
#
# User is :declan maloney
#
# Review is :Kinds and supportive
#
# Rating is :  5
#
#
#
#
# User is :Jeremy H
#
# Review is :Update on baggage
#
# Rating is :  2
#
#
#
#
# User is :Ethan M
#
# Review is :Outrageous customer service
#
# Rating is :  1
#
#
#
#
# User is :RM356
#
# Review is :Standards have fallen
#
# Rating is :  3
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or435-Aer-Lingus.html#REVIEWS
# User is :Climber656674
#
# Review is :Don’t waste your money !
#
# Rating is :  1
#
#
#
#
# User is :Climber656674
#
# Review is :Appalling
#
# Rating is :  1
#
#
#
#
# User is :Tyler R
#
# Review is :Very disappointed
#
# Rating is :  1
#
#
#
#
# User is :61Cater
#
# Review is :Time Travel Required
#
# Rating is :  1
#
#
#
#
# User is :Martine M
#
# Review is :Telling a wee lady And Colin a gent.
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or440-Aer-Lingus.html#REVIEWS
# User is :Jeremy H
#
# Review is :Missing baggage
#
# Rating is :  1
#
#
#
#
# User is :Joe B
#
# Review is :Terrible service
#
# Rating is :  1
#
#
#
#
# User is :Luis H
#
# Review is :WORST AIRLINE EVER!
#
# Rating is :  1
#
#
#
#
# User is :John m
#
# Review is :Customer services contact
#
# Rating is :  1
#
#
#
#
# User is :Tia G
#
# Review is :Non existent customer service!!!!
#
# Rating is :  2
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or445-Aer-Lingus.html#REVIEWS
# User is :moravidiar@web.de
#
# Review is :A terrible experience that should be avoided at any costs
#
# Rating is :  1
#
#
#
#
# User is :Michael S
#
# Review is :Aer Lingus - one of the worst airlines
#
# Rating is :  1
#
#
#
#
# User is :Graham T
#
# Review is :Appalling Customer Service
#
# Rating is :  1
#
#
#
#
# User is :Craig
#
# Review is :Worst airline I have ever used
#
# Rating is :  1
#
#
#
#
# User is :Anja123
#
# Review is :STILL NO REFUND
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or450-Aer-Lingus.html#REVIEWS
# User is :Kimberly W
#
# Review is :RACIST, RUDE, UNPROFESSIONAL and DISMISSIVE especially at the Dublin, Ireland airport check-in desks.
#
# Rating is :  1
#
#
#
#
# User is :Shane R
#
# Review is :Worst airline of all time
#
# Rating is :  1
#
#
#
#
# User is :Evaristo_Lobato
#
# Review is :Thank you, Aer Lingus
#
# Rating is :  5
#
#
#
#
# User is :Andrew C
#
# Review is :Jokers!
#
# Rating is :  1
#
#
#
#
# User is :Linda M
#
# Review is :Good flight!
#
# Rating is :  4
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or455-Aer-Lingus.html#REVIEWS
# User is :Anonymous
#
# Review is :Aer Lingus Customer Service or lack of
#
# Rating is :  1
#
#
#
#
# User is :Jim P
#
# Review is :I'm a fan
#
# Rating is :  5
#
#
#
#
# User is :Edward D
#
# Review is :Ripped me off $900.00
#
# Rating is :  1
#
#
#
#
# User is :Scott E
#
# Review is :Insane hold times.
#
# Rating is :  1
#
#
#
#
# User is :Sandra M
#
# Review is :Aer Lingus 100% best airline
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or460-Aer-Lingus.html#REVIEWS
# User is :Hayden A
#
# Review is :Refund Voucher scam
#
# Rating is :  1
#
#
#
#
# User is :KingOfHypocrites
#
# Review is :Broken website and it takes literally hours to get someone on the phone
#
# Rating is :  1
#
#
#
#
# User is :Dee55
#
# Review is :Rude, incompetent check-in staff at Zurich airport
#
# Rating is :  1
#
#
#
#
# User is :AndyOwl1867
#
# Review is :Avoid at all costs for long haul
#
# Rating is :  1
#
#
#
#
# User is :Angie N
#
# Review is :Airline needs to smooth over several areas of service.
#
# Rating is :  2
#
#
#
#
# url is
# ...
#
# Rating is :  1
#
#
#
#
# User is :kfarrell425
#
# Review is :Avoid if at all possible
#
# Rating is :  1
#
#
#
#
# User is :Tracy M
#
# Review is :Coronavirus Cancellation
#
# Rating is :  1
#
#
#
#
# User is :StephenDublin
#
# Review is :Good commuter routes from Dublin
#
# Rating is :  4
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or745-Aer-Lingus.html#REVIEWS
# User is :Moonpickle
#
# Review is :St. Patty's Christmas gift
#
# Rating is :  1
#
#
#
#
# User is :Judy B
#
# Review is :NOT EVEN A ONE STAR DON'T BOOK!!!
#
# Rating is :  1
#
#
#
#
# User is :Orin Onion
#
# Review is :Careful Now! Enough of Aer Lingus Already!
#
# Rating is :  1
#
#
#
#
# User is :441glenng
#
# Review is :Customer service keeps hanging up.
#
# Rating is :  1
#
#
#
#
# User is :935liut
#
# Review is :Aer Lingus - Worst Airline Ever
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or750-Aer-Lingus.html#REVIEWS
# User is :RpuzUK
#
# Review is :Worst ever airline- Don’t fly with them
#
# Rating is :  1
#
#
#
#
# User is :Pathfinder588635
#
# Review is :Do not fly this airline.
#
# Rating is :  1
#
#
#
#
# User is :Scott Johnson
#
# Review is :BA and Air Lingus
#
# Rating is :  1
#
#
#
#
# User is :Kyle C
#
# Review is :Simply the worst
#
# Rating is :  1
#
#
#
#
# User is :Linda M
#
# Review is :Cash Refunds from cancelled flights
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or755-Aer-Lingus.html#REVIEWS
# User is :StephenCross
#
# Review is :Good service as usual
#
# Rating is :  5
#
#
#
#
# User is :Passport558900
#
# Review is :Refund for flight from EWR to Dublin
#
# Rating is :  5
#
#
#
#
# User is :T A
#
# Review is :Worst Airline
#
# Rating is :  1
#
#
#
#
# User is :Elma1
#
# Review is :Shame on you, should be zero star more than terrible
#
# Rating is :  1
#
#
#
#
# User is :Mustafa O
#
# Review is :They Cancelled my flight, forced me to take voucher instead refund
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or760-Aer-Lingus.html#REVIEWS
# User is :bubble2000uk
#
# Review is :Thieves of the highest order
#
# Rating is :  1
#
#
#
#
# User is :giacomo
#
# Review is :They literally stole our money in March 2020
#
# Rating is :  1
#
#
#
#
# User is :podmomma
#
# Review is :Aer Lingus is cheating passengers during this stressful time
#
# Rating is :  1
#
#
#
#
# User is :Bamitbach
#
# Review is :Airline
#
# Rating is :  1
#
#
#
#
# User is :Shannon A
#
# Review is :Aer Lingus customer service sucks!
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or765-Aer-Lingus.html#REVIEWS
# User is :Katlynn S
#
# Review is :Never use Aer Lingus
#
# Rating is :  1
#
#
#
#
# User is :Eric
#
# Review is :Won't fly with Aer Lingus again
#
# Rating is :  1
#
#
#
#
# User is :Parsons
#
# Review is :Witholding refund.
#
# Rating is :  1
#
#
#
#
# User is :Ally9898
#
# Review is :TERRIBLE Customer Service
#
# Rating is :  1
#
#
#
#
# User is :Clairabellaboom
#
# Review is :Cancelled flight refund without issue.
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or770-Aer-Lingus.html#REVIEWS
# User is :Ruth W
#
# Review is :totally and utterly disgusting who care nothing about no one but themselves
#
# Rating is :  1
#
#
#
#
# User is :goodeats00
#
# Review is :The worst airline
#
# Rating is :  1
#
#
#
#
# User is :Gooner10-8
#
# Review is :Poor Ground Staff let Us + the Airline down - Badly!
#
# Rating is :  2
#
#
#
#
# User is :agnieszka g
#
# Review is :They have no respect for their clients at all! Shame on Aer Lingus.
#
# Rating is :  1
#
#
#
#
# User is :Natalie P
#
# Review is :Irresponsible airline
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or775-Aer-Lingus.html#REVIEWS
# User is :Pau B
#
# Review is :want full refund
#
# Rating is :  1
#
#
#
#
# User is :Gooner10-8
#
# Review is :The Challenge of Delivering Consistent Customer Care....
#
# Rating is :  4
#
#
#
#
# User is :HughMc
#
# Review is :Did what it said on the tin, easy boarding, comfortable seats good care from the stewards. Flew just before the closedow
#
# Rating is :  4
#
#
#
#
# User is :Jin Tae Lee
#
# Review is :refund
#
# Rating is :  1
#
#
#
#
# User is :SRJG
#
# Review is :Aer Lingus flight fantastic, Aer Lingus customer service pathetic
#
# Rating is :  2
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or780-Aer-Lingus.html#REVIEWS
# User is :Ryan B
#
# Review is :Brilliant Trip
#
# Rating is :  5
#
#
#
#
# User is :NYsquirrel
#
# Review is :Nice overall experience!
#
# Rating is :  4
#
#
#
#
# User is :Jin Tae Lee
#
# Review is :refund
#
# Rating is :  1
#
#
#
#
# User is :nuala r
#
# Review is :Terrible service
#
# Rating is :  1
#
#
#
#
# User is :Piermarie
#
# Review is :Appalling Customer Service
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or785-Aer-Lingus.html#REVIEWS
# User is :Paradise62979
#
# Review is :Worst experience of a flight to San Francisco
#
# Rating is :  1
#
#
#
#
# User is :qian
#
# Review is :Somewhere between standard bearers and low cost.
#
# Rating is :  4
#
#
#
#
# User is :Katie M
#
# Review is :Flight chaos during Pandemic
#
# Rating is :  5
#
#
#
#
# User is :jwcdublin
#
# Review is :Will Always chose Aer Lingus
#
# Rating is :  5
#
#
#
#
# User is :Brendan K
#
# Review is :A Wonderful Flight & Crew
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or790-Aer-Lingus.html#REVIEWS
# User is :Marcia2424
#
# Review is :Outstanding Service During Coronavirus Pandemic
#
# Rating is :  5
#
#
#
#
# User is :Erik88884U
#
# Review is :Aer Lingus reliable and fine airline
#
# Rating is :  5
#
#
#
#
# User is :Shely M
#
# Review is :Awful, Heartless
#
# Rating is :  1
#
#
#
#
# User is :Linda M
#
# Review is :Disgraceful Coronavirus policy!
#
# Rating is :  1
#
#
#
#
# User is :Teresa S
#
# Review is :Customer Service Agent hung up in me.
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or795-Aer-Lingus.html#REVIEWS
# User is :Explorer454990
#
# Review is :Don't bother paying for extrra leg room
#
# Rating is :  4
#
#
#
#
# User is :James
#
# Review is :The best
#
# Rating is :  5
#
#
#
#
# User is :Donna N
#
# Review is :Disney trip
#
# Rating is :  5
#
#
#
#
# User is :Janelle D
#
# Review is :Don't care about the customer.  Deserve a 0
#
# Rating is :  1
#
#
#
#
# User is :Oscar M
#
# Review is :Problems rescheduling flights
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or800-Aer-Lingus.html#REVIEWS
# User is :Tara K
#
# Review is :Delays outside their control
#
# Rating is :  5
#
#
#
#
# User is :Gearoid G
#
# Review is :Class
#
# Rating is :  5
#
#
#
#
# User is :Amanda D
#
# Review is :Worst airline ever!!!!
#
# Rating is :  1
#
#
#
#
# User is :Justin W
#
# Review is :Wonderful staff and flight crew
#
# Rating is :  4
#
#
#
#
# User is :Heather M
#
# Review is :Customer service during the current crisis
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or805-Aer-Lingus.html#REVIEWS
# User is :Pat Enright
#
# Review is :The Best Airline Ever
#
# Rating is :  5
#
#
#
#
# User is :123midnight
#
# Review is :Why are Aer Lingus Still Taking bookings
#
# Rating is :  5
#
#
#
#
# User is :MEGA_10
#
# Review is :Don’t use aer lingus
#
# Rating is :  1
#
#
#
#
# User is :Ann Mc Auley
#
# Review is :Pleasent
#
# Rating is :  4
#
#
#
#
# User is :WMui
#
# Review is :Lack of customer service and empathy
#
# Rating is :  1
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or810-Aer-Lingus.html#REVIEWS
# User is :ViajeSinFin
#
# Review is :What kind of people are behind this company???
#
# Rating is :  1
#
#
#
#
# User is :Julie F
#
# Review is :I just want to thank Aer Lingus for getting us home last night.  They handled the chaos created by U.S. governmental r
#
# Rating is :  5
#
#
#
#
# User is :Kristine B
#
# Review is :Gluten Free Meal no longer good
#
# Rating is :  3
#
#
#
#
# User is :LoveTheSun
#
# Review is :Great airline, unless there are any issues
#
# Rating is :  1
#
#
#
#
# User is :Kay
#
# Review is :The worst ever...ever..ever
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or815-Aer-Lingus.html#REVIEWS
# User is :Alan D
#
# Review is :Customer Services ....not
#
# Rating is :  1
#
#
#
#
# User is :Peterbl131
#
# Review is :Good flight in a troubled time.
#
# Rating is :  4
#
#
#
#
# User is :Nirmal P
#
# Review is :Heartless airline
#
# Rating is :  1
#
#
#
#
# User is :dannyf32
#
# Review is :New York Kathy & Brad visit
#
# Rating is :  5
#
#
#
#
# User is :Samantha G.
#
# Review is :Worst airline ever!
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or820-Aer-Lingus.html#REVIEWS
# User is :Brad M
#
# Review is :Abysmal Customer Service Around Covid-19
#
# Rating is :  1
#
#
#
#
# User is :kartmanka
#
# Review is :Another delay
#
# Rating is :  3
#
#
#
#
# User is :Eniale
#
# Review is :Uncaring, rude customer service from an airline that has lost its way
#
# Rating is :  1
#
#
#
#
# User is :Suzanne R
#
# Review is :POOR CUSTOMER SERVICE AND CUSTOMER APPRECIATION
#
# Rating is :  1
#
#
#
#
# User is :Tiffany C
#
# Review is :Great price, but very cramped
#
# Rating is :  4
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or825-Aer-Lingus.html#REVIEWS
# User is :Scott Vodrey
#
# Review is :A disgusting, greedy and morally reprehensible company
#
# Rating is :  1
#
#
#
#
# User is :A P F
#
# Review is :Bad Customer Service
#
# Rating is :  1
#
#
#
#
# User is :Meghan P
#
# Review is :The. Absolute. Worst.
#
# Rating is :  1
#
#
#
#
# User is :motorcar1
#
# Review is :Trip to London
#
# Rating is :  4
#
#
#
#
# User is :James
#
# Review is :Scam company, refusing to cooperate with current state of affairs
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or830-Aer-Lingus.html#REVIEWS
# User is :James H
#
# Review is :Worst company I've ever had to deal with, period.
#
# Rating is :  1
#
#
#
#
# User is :Lucia
#
# Review is :We were pleasantly surprised with Aer Lingus
#
# Rating is :  4
#
#
#
#
# User is :Karyn Y
#
# Review is :Aer Lingus Customer Service - Awful
#
# Rating is :  1
#
#
#
#
# User is :fatfreelife1
#
# Review is :Aer Lingus Bargin Airline
#
# Rating is :  3
#
#
#
#
# User is :celcor_IRL
#
# Review is :Definitely the best from Ireland to Europe
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or835-Aer-Lingus.html#REVIEWS
# User is :Lauren C
#
# Review is :NEVER AGAIN!!
#
# Rating is :  1
#
#
#
#
# User is :deuce_sean
#
# Review is :Excellent Customer Service
#
# Rating is :  5
#
#
#
#
# User is :Katie G
#
# Review is :Absolutely horrific customer service
#
# Rating is :  1
#
#
#
#
# User is :roisin k
#
# Review is :Aer lingus flight
#
# Rating is :  5
#
#
#
#
# User is :Samster888
#
# Review is :Horrible customer service and expensive change fees even with coranavirus crisis
#
# Rating is :  1
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or840-Aer-Lingus.html#REVIEWS
# User is :Sammy119
#
# Review is :Good Flight
#
# Rating is :  4
#
#
#
#
# User is :Naomi
#
# Review is :Worst flight
#
# Rating is :  1
#
#
#
#
# User is :FromNJ
#
# Review is :Find another airline!
#
# Rating is :  1
#
#
#
#
# User is :Gary W
#
# Review is :Not bad flight
#
# Rating is :  4
#
#
#
#
# User is :Jjcvab
#
# Review is :Champion stakes
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or845-Aer-Lingus.html#REVIEWS
# User is :Jennifer D
#
# Review is :DO NOT BOOK. HORRIFIC EXPERIENCE.
#
# Rating is :  1
#
#
#
#
# User is :Nicole
#
# Review is :Horrific customer service during the COVID-19 outbreak
#
# Rating is :  1
#
#
#
#
# User is :Olivia C
#
# Review is :Somewhat disappointing
#
# Rating is :  3
#
#
#
#
# User is :J0Pet
#
# Review is :Great flights inbound and outbound
#
# Rating is :  5
#
#
#
#
# User is :Janette R
#
# Review is :Friendly comfortable and reliable service to Dublin from Birmingham
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or850-Aer-Lingus.html#REVIEWS
# User is :TouristBoy
#
# Review is :Mundane journey made pleasant
#
# Rating is :  5
#
#
#
#
# User is :Tom
#
# Review is :Easy way to get to Europe
#
# Rating is :  5
#
#
#
#
# User is :Shezsharks
#
# Review is :On time, not freezing, great landing all fab
#
# Rating is :  5
#
#
#
#
# User is :annatravel737
#
# Review is :Good service
#
# Rating is :  4
#
#
#
#
# User is :Ed O’Donnell
#
# Review is :THE BEST WAY TO GET TO IRELAND
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or855-Aer-Lingus.html#REVIEWS
# User is :lilly_white_tourist
#
# Review is :Comfortable, reasonably priced and awesome food
#
# Rating is :  5
#
#
#
#
# User is :martin h
#
# Review is :Diverted Flight
#
# Rating is :  5
#
#
#
#
# User is :philomenal841
#
# Review is :Mother and daughter
#
# Rating is :  5
#
#
#
#
# User is :Gulliver63
#
# Review is :Consistently friendly, pleasant, common sense approach. The best way to fly between Dublin & London
#
# Rating is :  5
#
#
#
#
# User is :L0ve2travle
#
# Review is :Business Class and  Delays
#
# Rating is :  3
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or860-Aer-Lingus.html#REVIEWS
# User is :Duncan Macarthur
#
# Review is :Very seamless ,travelled to Seattle, great attention at US immigration and customs
#
# Rating is :  4
#
#
#
#
# User is :robert m
#
# Review is :Geat Service!
#
# Rating is :  5
#
#
#
#
# User is :Nicky
#
# Review is :Cheap great flight
#
# Rating is :  5
#
#
#
#
# User is :Miriam B
#
# Review is :Only watY to fly
#
# Rating is :  4
#
#
#
#
# User is :s c
#
# Review is :Usual service
#
# Rating is :  4
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or865-Aer-Lingus.html#REVIEWS
# User is :Nick G
#
# Review is :Dublin trip
#
# Rating is :  4
#
#
#
#
# User is :Barry2137
#
# Review is :Long Haul to U S A
#
# Rating is :  4
#
#
#
#
# User is :Robert S
#
# Review is :Amazing
#
# Rating is :  5
#
#
#
#
# User is :FRANK O
#
# Review is :Wembley Bound.
#
# Rating is :  5
#
#
#
#
# User is :danieldC1452OK
#
# Review is :Perfect choice
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or870-Aer-Lingus.html#REVIEWS
# User is :luchtsiuil
#
# Review is :Crew very efficient
#
# Rating is :  5
#
#
#
#
# User is :Globetrotter
#
# Review is :Great flight experience
#
# Rating is :  4
#
#
#
#
# User is :pinkthis
#
# Review is :Sardine airship
#
# Rating is :  3
#
#
#
#
# User is :_judysnaith
#
# Review is :Good service
#
# Rating is :  5
#
#
#
#
# User is :WarwickshireMonty
#
# Review is :Excellent all-round
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or875-Aer-Lingus.html#REVIEWS
# User is :jedbo2017
#
# Review is :Disappointing experience from a national carrier
#
# Rating is :  1
#
#
#
#
# User is :Amy G
#
# Review is :Good value
#
# Rating is :  3
#
#
#
#
# User is :Bob W
#
# Review is :Wedding Weekend
#
# Rating is :  5
#
#
#
#
# User is :Ali90
#
# Review is :Quick flight
#
# Rating is :  5
#
#
#
#
# User is :Janette K
#
# Review is :Mrs. Janette Nosella
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or880-Aer-Lingus.html#REVIEWS
# User is :logginsirl
#
# Review is :Direct to Orlando
#
# Rating is :  4
#
#
#
#
# User is :duganjo
#
# Review is :Vacation in Ireland 2020
#
# Rating is :  5
#
#
#
#
# User is :caroline y
#
# Review is :Travel
#
# Rating is :  5
#
#
#
#
# User is :drewcraigie
#
# Review is :Took off, landed,  perfect flight.
#
# Rating is :  4
#
#
#
#
# User is :Carrib
#
# Review is :Worst flights I've ever been on
#
# Rating is :  2
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or885-Aer-Lingus.html#REVIEWS
# User is :Hamish T
#
# Review is :Just ok In Flight, Disastrous Pre Boarding
#
# Rating is :  2
#
#
#
#
# User is :John H
#
# Review is :Pure Class Service - Genuine & Pure Irish at its Best
#
# Rating is :  5
#
#
#
#
# User is :Inese
#
# Review is :Winter trip
#
# Rating is :  5
#
#
#
#
# User is :tedthed0g
#
# Review is :Friendly and comfortable
#
# Rating is :  4
#
#
#
#
# User is :Nik C
#
# Review is :Dublin to Paris
#
# Rating is :  5
#
#
#
#
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or890-Aer-Lingus.html#REVIEWS
# User is :Bert O
#
# Review is :Very nice flight
#
# Rating is :  5
#
#
#
#
# User is :Nancy M
#
# Review is :The only way to return from Europe
#
# Rating is :  5
#
#
#
#
# User is :Alan O
#
# Review is :Hassle free flight
#
# Rating is :  5
#
#
#
#
# User is :jamcol
#
# Review is :Pre Clearance United States
#
# Rating is :  4
#
#
#
#
# User is :josie137
#
# Review is :Awful
#
# Rating is :  1
# url is
# https://www.tripadvisor.com/Airline_Review-d8728986-Reviews-or895-Aer-Lingus.html#REVIEWS
# User is :Inspire590241
#
# Review is :Re ent Aer Lingus glight
#
# Rating is :  5
#
#
#
#
# User is :LizH99
#
# Review is :Great experience
#
# Rating is :  5
#
#
#
#
# User is :Jjcvab
#
# Review is :Erin go braugh
#
# Rating is :  5
#
#
#
#
# User is :sescommunications
#
# Review is :Direct Flight to Orlando
#
# Rating is :  3
#
#
#
#
# User is :Helen S
#
# Review is :Disappointment on arrival in Spain
#
# Rating is :  3

# %%
df = pd.DataFrame(data, columns=['User', 'Review','Rating'])

# %%
df.shape
# Out:
# (900, 3)

# %%
df.tail()
# Out:
#                   User                              Review  Rating
# 895      Inspire590241            Re ent Aer Lingus glight       5
# 896             LizH99                    Great experience       5
# 897             Jjcvab                      Erin go braugh       5
# 898  sescommunications            Direct Flight to Orlando       3
# 899            Helen S  Disappointment on arrival in Spain       3

# %%
filepath = Path('aer_lingus.csv') 
df.to_csv(filepath, index=False)
