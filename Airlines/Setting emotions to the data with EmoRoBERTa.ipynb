# %%
import pandas as pd
import numpy as np
import scipy
import math

# %%
from  google.colab  import  drive 
drive.mount ( '/content/drive' )
# Out:
# Mounted at /content/drive

# %%
! pip install transformers -q
# Out:
#      |████████████████████████████████| 5.5 MB 5.3 MB/s
#      |████████████████████████████████| 163 kB 53.5 MB/s
#      |████████████████████████████████| 7.6 MB 57.8 MB/s

# %%
from transformers import pipeline

# %%
emotion = pipeline('sentiment-analysis', model='arpanghoshal/EmoRoBERTa')
# Out:
# Downloading:   0%|          | 0.00/1.72k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/501M [00:00<?, ?B/s]
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# All the layers of TFRobertaForSequenceClassification were initialized from the model checkpoint at arpanghoshal/EmoRoBERTa.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForSequenceClassification for predictions without further training.
# Downloading:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]

# %%
def get_emotion_label(text):
  text = str(text)
  #text = text[:250]
  print((text))
  print('\n')
  return(emotion(text)[0]['label'])

# %%
hotels = pd.read_csv('/content/drive/MyDrive/ΕΙΔΙΚΟ ΘΕΜΑ/Airlines Reviews/airlines.csv')
ratings = pd.read_csv('/content/drive/MyDrive/ΕΙΔΙΚΟ ΘΕΜΑ/Airlines Reviews/ratings.csv')
df = hotels.merge(ratings, how="left", on="AirlineId")
df.head()
# Out:
#    AirlineId    Name  UserId                                Review  Rating
# 0          1  aegean       1                     Forgot my baggage       1
# 1          1  aegean       2                     Late or cancelled       1
# 2          1  aegean       3  Worst experience ever! AVOID AEGEAN!       1
# 3          1  aegean       4                       A great airline       4
# 4          1  aegean       5         Accommodating, Lovely Airline       5

# %%
df.tail()
# Out:
#        AirlineId    Name  UserId  \
# 11406         12  nippon    1296
# 11407         12  nippon    1297
# 11408         12  nippon    1298
# 11409         12  nippon    1299
# 11410         12  nippon    1300
#
#                                                   Review  Rating
# 11406  an airline that cares about your comfort, not ...       5
# 11407                                        Pure Luxury       5
# 11408  Comfy Economy Seats, But Lack of Air Conditioning       3
# 11409                                         Good Value       5
# 11410                                  True Friendly Sky       5

# %%
df.shape
# Out:
# (11411, 5)

# %%
df['Emotion'] = df['Review'].apply(get_emotion_label)
# Out:
# Η έξοδος ροής περικόπηκε στις τελευταίες 5000 γραμμές.
#
# Need new management
#
#
# Worst flying experience I have EVER had
#
#
# Never again!!!
#
#
# HAZZARD TO PERSONS FLYING
#
#
# Astounding incompetence
#
#
# Awful and irresponsible
#
#
# Customer Service Phone Line
#
#
# Got the run around
#
#
# THIS AIRLINE IS UNRELIABLE IN REGARDS TO ARRIVALS AND DEPARTURES.
#
#
# Stuck on Runway
#
#
# AMERICAN AIRLINES HAS THE WORST CUSTOMER SERVICE!!!
#
#
# Disgraceful
#
#
# American Airlines has pathetic non-existent customer service. NEVER AGAIN!!!
#
#
# Terrible customer service
#
#
# Poor customer service
#
#
# American Airlines canceling flight and rebooking on earlier flight
#
#
# Worst and most Incompetent Customer Service
#
#
# American Airlines negligent service
#
#
# Don't fly American
#
#
# Don't waste money on 1st class
#
#
# Overall good.
#
#
# Wheelchair use
#
#
# No Refund Despite Travel Warning from Government
#
#
# New Orleans
#
#
# Horrible Experience
#
#
# ...

# %%
df
# Out:
#        AirlineId    Name  UserId  \
# 0              1  aegean       1
# 1              1  aegean       2
# 2              1  aegean       3
# 3              1  aegean       4
# 4              1  aegean       5
# ...          ...     ...     ...
# 11406         12  nippon    1296
# 11407         12  nippon    1297
# 11408         12  nippon    1298
# 11409         12  nippon    1299
# 11410         12  nippon    1300
#
#                                                   Review  Rating     Emotion
# 0                                      Forgot my baggage       1     neutral
# 1                                      Late or cancelled       1   confusion
# 2                   Worst experience ever! AVOID AEGEAN!       1        fear
# 3                                        A great airline       4  admiration
# 4                          Accommodating, Lovely Airline       5  admiration
# ...                                                  ...     ...         ...
# ...

# %%
df.shape
# Out:
# (11411, 6)

# %%
filepath = '/content/drive/MyDrive/ΕΙΔΙΚΟ ΘΕΜΑ/Airlines Reviews/reviews_with_emotions_full.csv'
df.to_csv(filepath)
